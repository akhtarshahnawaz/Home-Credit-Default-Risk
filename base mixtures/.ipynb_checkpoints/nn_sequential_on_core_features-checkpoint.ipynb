# %%
model_name = "nn_sequential_on_core_features_1"

# %%
import numpy as np
import pandas as pd
import gc
from time import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
timesheet = [time()]
def timer(statement):
    global timesheet
    timesheet.append(time())
    print statement+" :", (timesheet[-1]-timesheet[-2]),"seconds"

def one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

def postprocess(df):
    cols = [c for c in df.columns if c not in ["SK_ID_CURR","SK_ID_PREV","TARGET"]]
    df = df.replace([np.inf, -np.inf], np.nan)
    df.loc[:, cols] = MinMaxScaler().fit_transform(df.loc[:, cols].fillna(df.loc[:, cols].mean()).clip(-1e11,1e11))
    return df

# %% [markdown]
# ## Get Application Train/Test Data

# %%
def application_train_test(num_rows = None, nan_as_category = False):
    # Read data and merge
    df = pd.read_csv('../data/application_train.csv', nrows= num_rows)
    test_df = pd.read_csv('../data/application_test.csv', nrows= num_rows)

    print("Train samples: {}, test samples: {}".format(len(df), len(test_df)))
    df = df.append(test_df).reset_index()
    # Optional: Remove 4 applications with XNA CODE_GENDER (train set)
    df = df[df['CODE_GENDER'] != 'XNA']

    docs = [_f for _f in df.columns if 'FLAG_DOC' in _f]
    live = [_f for _f in df.columns if ('FLAG_' in _f) & ('FLAG_DOC' not in _f) & ('_FLAG_' not in _f)]

    # NaN values for DAYS_EMPLOYED: 365.243 -> nan
    df['DAYS_EMPLOYED'].replace(365243, np.nan, inplace= True)

    inc_by_org = df[['AMT_INCOME_TOTAL', 'ORGANIZATION_TYPE']].groupby('ORGANIZATION_TYPE').median()['AMT_INCOME_TOTAL']

    df['NEW_CREDIT_TO_ANNUITY_RATIO'] = df['AMT_CREDIT'] / df['AMT_ANNUITY'].astype("float32")
    df['NEW_CREDIT_TO_GOODS_RATIO'] = df['AMT_CREDIT'] / df['AMT_GOODS_PRICE'].astype("float32")
    df['NEW_DOC_IND_KURT'] = df[docs].kurtosis(axis=1)
    df['NEW_LIVE_IND_SUM'] = df[live].sum(axis=1)
    df['NEW_INC_PER_CHLD'] = df['AMT_INCOME_TOTAL'] / (1 + df['CNT_CHILDREN']).astype("float32")
    df['NEW_INC_BY_ORG'] = df['ORGANIZATION_TYPE'].map(inc_by_org)
    df['NEW_EMPLOY_TO_BIRTH_RATIO'] = df['DAYS_EMPLOYED'] / df['DAYS_BIRTH'].astype("float32")
    df['NEW_ANNUITY_TO_INCOME_RATIO'] = df['AMT_ANNUITY'] / (1 + df['AMT_INCOME_TOTAL']).astype("float32")
    df['NEW_SOURCES_PROD'] = df['EXT_SOURCE_1'] * df['EXT_SOURCE_2'] * df['EXT_SOURCE_3']
    df['NEW_EXT_SOURCES_MEAN'] = df[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
    df['NEW_SCORES_STD'] = df[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].std(axis=1)
    df['NEW_SCORES_STD'] = df['NEW_SCORES_STD'].fillna(df['NEW_SCORES_STD'].mean())
    df['NEW_CAR_TO_BIRTH_RATIO'] = df['OWN_CAR_AGE'] / df['DAYS_BIRTH'].astype("float32")
    df['NEW_CAR_TO_EMPLOY_RATIO'] = df['OWN_CAR_AGE'] / df['DAYS_EMPLOYED'].astype("float32")
    df['NEW_PHONE_TO_BIRTH_RATIO'] = df['DAYS_LAST_PHONE_CHANGE'] / df['DAYS_BIRTH'].astype("float32")
    df['NEW_PHONE_TO_BIRTH_RATIO_EMPLOYER'] = df['DAYS_LAST_PHONE_CHANGE'] / df['DAYS_EMPLOYED'].astype("float32")
    df['NEW_CREDIT_TO_INCOME_RATIO'] = df['AMT_CREDIT'] / df['AMT_INCOME_TOTAL'].astype("float32")

    # Categorical features with Binary encode (0 or 1; two categories)
    for bin_feature in ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY']:
        df[bin_feature], uniques = pd.factorize(df[bin_feature])
    # Categorical features with One-Hot encode
    df, cat_cols = one_hot_encoder(df, nan_as_category)
    dropcolum=['FLAG_DOCUMENT_2','FLAG_DOCUMENT_4',
    'FLAG_DOCUMENT_5','FLAG_DOCUMENT_6','FLAG_DOCUMENT_7',
    'FLAG_DOCUMENT_8','FLAG_DOCUMENT_9','FLAG_DOCUMENT_10', 
    'FLAG_DOCUMENT_11','FLAG_DOCUMENT_12','FLAG_DOCUMENT_13',
    'FLAG_DOCUMENT_14','FLAG_DOCUMENT_15','FLAG_DOCUMENT_16',
    'FLAG_DOCUMENT_17','FLAG_DOCUMENT_18','FLAG_DOCUMENT_19',
    'FLAG_DOCUMENT_20','FLAG_DOCUMENT_21']
    df= df.drop(dropcolum,axis=1)
    del test_df
    gc.collect()
    return df

# %% [markdown]
# ## Get Bureau & Bureau Balance Data

# %%
def bureau_and_balance(num_rows = None, nan_as_category = True):
    bureau = pd.read_csv('../data/bureau.csv', nrows = num_rows)
    bb = pd.read_csv('../data/bureau_balance.csv', nrows = num_rows)
    bb, bb_cat = one_hot_encoder(bb, nan_as_category)
    bureau, bureau_cat = one_hot_encoder(bureau, nan_as_category)

    # Bureau balance: Perform aggregations and merge with bureau.csv
    bb_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size']}
    for col in bb_cat:
        bb_aggregations[col] = ['mean']
    bb_agg = bb.groupby('SK_ID_BUREAU').agg(bb_aggregations)
    bb_agg.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bb_agg.columns.tolist()])
    bureau = bureau.join(bb_agg, how='left', on='SK_ID_BUREAU')
    bureau.drop(['SK_ID_BUREAU'], axis=1, inplace= True)
    del bb, bb_agg
    gc.collect()

    # Bureau and bureau_balance numeric features
    num_aggregations = {
        'DAYS_CREDIT': [ 'mean', 'var'],
        'DAYS_CREDIT_ENDDATE': [ 'mean'],
        'DAYS_CREDIT_UPDATE': ['mean'],
        'CREDIT_DAY_OVERDUE': ['mean'],
        'AMT_CREDIT_MAX_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM': [ 'mean', 'sum'],
        'AMT_CREDIT_SUM_DEBT': [ 'mean', 'sum'],
        'AMT_CREDIT_SUM_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM_LIMIT': ['mean', 'sum'],
        'AMT_ANNUITY': ['max', 'mean'],
        'CNT_CREDIT_PROLONG': ['sum'],
        'MONTHS_BALANCE_MIN': ['min'],
        'MONTHS_BALANCE_MAX': ['max'],
        'MONTHS_BALANCE_SIZE': ['mean', 'sum']
    }
    # Bureau and bureau_balance categorical features
    cat_aggregations = {}
    for cat in bureau_cat: cat_aggregations[cat] = ['mean']
    for cat in bb_cat: cat_aggregations[cat + "_MEAN"] = ['mean']

    num_cat = num_aggregations.copy()
    num_cat.update(cat_aggregations)

    bureau_agg = bureau.groupby('SK_ID_CURR').agg(num_cat)
    bureau_agg.columns = pd.Index(['BURO_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
    bureau_agg = bureau_agg.reset_index()
    # Bureau: Active credits - using only numerical aggregations
    active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
    active_agg = active.groupby('SK_ID_CURR').agg(num_aggregations)
    active_agg.columns = pd.Index(['ACTIVE_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
    active_agg = active_agg.reset_index()
    bureau_agg = bureau_agg.merge(active_agg, how='left', on='SK_ID_CURR')
    del active, active_agg
    gc.collect()
    # Bureau: Closed credits - using only numerical aggregations
    closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
    closed_agg = closed.groupby('SK_ID_CURR').agg(num_aggregations)
    closed_agg.columns = pd.Index(['CLOSED_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')
    del closed, closed_agg, bureau
    gc.collect()
    return bureau_agg

# %% [markdown]
# ## Get Previous Applications Data

# %%
def previous_applications(num_rows = None, nan_as_category = True):
    prev = pd.read_csv('../data/previous_application.csv', nrows = num_rows)
    prev, cat_cols = one_hot_encoder(prev, nan_as_category= True)
    # Days 365.243 values -> nan
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    # Add feature: value ask / value received percentage
    prev['APP_CREDIT_PERC'] = prev['AMT_APPLICATION'] / prev['AMT_CREDIT']
    # Previous applications numeric features
    num_aggregations = {
        'AMT_ANNUITY': [ 'max', 'mean'],
        'AMT_APPLICATION': [ 'max','mean'],
        'AMT_CREDIT': [ 'max', 'mean'],
        'APP_CREDIT_PERC': [ 'max', 'mean'],
        'AMT_DOWN_PAYMENT': [ 'max', 'mean'],
        'AMT_GOODS_PRICE': [ 'max', 'mean'],
        'HOUR_APPR_PROCESS_START': [ 'max', 'mean'],
        'RATE_DOWN_PAYMENT': [ 'max', 'mean'],
        'DAYS_DECISION': [ 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
    }
    # Previous applications categorical features
    cat_aggregations = {}
    for cat in cat_cols:
        cat_aggregations[cat] = ['mean']

    num_cat = num_aggregations.copy()
    num_cat.update(cat_aggregations)

    prev_agg = prev.groupby('SK_ID_CURR').agg(num_cat)
    prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])
    prev_agg = prev_agg.reset_index()
    # Previous Applications: Approved Applications - only numerical features
    approved = prev[prev['NAME_CONTRACT_STATUS_Approved'] == 1]
    approved_agg = approved.groupby('SK_ID_CURR').agg(num_aggregations)
    approved_agg.columns = pd.Index(['APPROVED_' + e[0] + "_" + e[1].upper() for e in approved_agg.columns.tolist()])
    approved_agg = approved_agg.reset_index()
    prev_agg = prev_agg.merge(approved_agg, how='left', on='SK_ID_CURR')
    # Previous Applications: Refused Applications - only numerical features
    refused = prev[prev['NAME_CONTRACT_STATUS_Refused'] == 1]
    refused_agg = refused.groupby('SK_ID_CURR').agg(num_aggregations)
    refused_agg.columns = pd.Index(['REFUSED_' + e[0] + "_" + e[1].upper() for e in refused_agg.columns.tolist()])
    prev_agg = prev_agg.join(refused_agg, how='left', on='SK_ID_CURR')
    del refused, refused_agg, approved, approved_agg, prev
    gc.collect()
    return prev_agg

# %% [markdown]
# ## Get POS Cash Data

# %%
def pos_cash(num_rows = None, nan_as_category = True):
    pos = pd.read_csv('../data/POS_CASH_balance.csv', nrows = num_rows)
    pos, cat_cols = one_hot_encoder(pos, nan_as_category= True)
    # Features
    aggregations = {
        'MONTHS_BALANCE': ['max', 'mean', 'size'],
        'SK_DPD': ['max', 'mean'],
        'SK_DPD_DEF': ['max', 'mean']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']

    pos_agg = pos.groupby('SK_ID_CURR').agg(aggregations)
    pos_agg.columns = pd.Index(['POS_' + e[0] + "_" + e[1].upper() for e in pos_agg.columns.tolist()])
    # Count pos cash accounts
    pos_agg['POS_COUNT'] = pos.groupby('SK_ID_CURR').size()
    del pos
    gc.collect()
    return pos_agg

# %% [markdown]
# ## Get Installments Payments Data

# %%
def installments_payments(num_rows = None, nan_as_category = True):
    ins = pd.read_csv('../data/installments_payments.csv', nrows = num_rows)
    ins, cat_cols = one_hot_encoder(ins, nan_as_category= True)
    # Percentage and difference paid in each installment (amount paid and installment value)
    ins['PAYMENT_PERC'] = ins['AMT_PAYMENT'] / ins['AMT_INSTALMENT']
    ins['PAYMENT_DIFF'] = ins['AMT_INSTALMENT'] - ins['AMT_PAYMENT']
    # Days past due and days before due (no negative values)
    ins['DPD'] = ins['DAYS_ENTRY_PAYMENT'] - ins['DAYS_INSTALMENT']
    ins['DBD'] = ins['DAYS_INSTALMENT'] - ins['DAYS_ENTRY_PAYMENT']
    ins['DPD'] = ins['DPD'].apply(lambda x: x if x > 0 else 0)
    ins['DBD'] = ins['DBD'].apply(lambda x: x if x > 0 else 0)
    # Features: Perform aggregations
    aggregations = {
        'NUM_INSTALMENT_VERSION': ['nunique'],
        'DPD': ['max', 'mean', 'sum','min','std' ],
        'DBD': ['max', 'mean', 'sum','min','std'],
        'PAYMENT_PERC': [ 'max','mean',  'var','min','std'],
        'PAYMENT_DIFF': [ 'max','mean', 'var','min','std'],
        'AMT_INSTALMENT': ['max', 'mean', 'sum','min','std'],
        'AMT_PAYMENT': ['min', 'max', 'mean', 'sum','std'],
        'DAYS_ENTRY_PAYMENT': ['max', 'mean', 'sum','std']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    ins_agg = ins.groupby('SK_ID_CURR').agg(aggregations)
    ins_agg.columns = pd.Index(['INSTAL_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
    # Count installments accounts
    ins_agg['INSTAL_COUNT'] = ins.groupby('SK_ID_CURR').size()
    del ins
    gc.collect()
    return ins_agg

# %% [markdown]
# ## Get Credit Card Balance Data

# %%
def credit_card_balance(num_rows = None, nan_as_category = True):
    cc = pd.read_csv('../data/credit_card_balance.csv', nrows = num_rows)
    cc, cat_cols = one_hot_encoder(cc, nan_as_category= True)
    # General aggregations
    cc.drop(['SK_ID_PREV'], axis= 1, inplace = True)
    cc_agg = cc.groupby('SK_ID_CURR').agg([ 'max', 'mean', 'sum', 'var'])
    cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
    # Count credit card lines
    cc_agg['CC_COUNT'] = cc.groupby('SK_ID_CURR').size()
    del cc
    gc.collect()
    return cc_agg

# %% [markdown]
# # Generate Data For Training

# %%
num_rows = None
timer("Init.. ")

data = application_train_test(num_rows)
timer("Done with Application Train and Test")

data = data.merge(bureau_and_balance(num_rows),  how='left', on='SK_ID_CURR')
timer("Done with Bureau and Bureau Balance")

data = data.merge(previous_applications(num_rows),  how='left', on='SK_ID_CURR')
timer("Done with Previous Applications")

data = data.join(pos_cash(num_rows),  how='left', on='SK_ID_CURR')
timer("Done with POS Cash")

data = data.join(installments_payments(num_rows),  how='left', on='SK_ID_CURR')
timer("Done with Installment Payments")

data = data.join(credit_card_balance(num_rows),  how='left', on='SK_ID_CURR')
timer("Done with Credit Card balance")

data = postprocess(data)
timer("Done with Postprocessing")

train = data[data['TARGET'].notnull()]
test = data[data['TARGET'].isnull()]

target = train.TARGET
train_id = train[["SK_ID_CURR"]]
test_id = test[["SK_ID_CURR"]]

train = train.drop(['TARGET','SK_ID_CURR','index'], axis=1)
test = test.drop(['TARGET','SK_ID_CURR','index'], axis=1)
# Out:
# Init..  : 0.313107013702 seconds
# Train samples: 307511, test samples: 48744
# Done with Application Train and Test : 16.5842328072 seconds
# Done with Bureau and Bureau Balance : 40.845375061 seconds
# Done with Previous Applications : 33.8466601372 seconds
# Done with POS Cash : 22.1108598709 seconds
# Done with Installment Payments : 63.8235521317 seconds
# Done with Credit Card balance : 26.1148939133 seconds
# Done with Postprocessing : 124.733544111 seconds

# %% [markdown]
# # Defining Model

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Activation,InputLayer, Dropout, PReLU, BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from keras.layers.advanced_activations import PReLU
from keras.optimizers import Adam
from keras import metrics
from keras import optimizers
from keras import backend as K

K.tf.set_random_seed(0)
cfg = K.tf.ConfigProto()
cfg.gpu_options.allow_growth = True 
K.set_session(K.tf.Session(config=cfg))
np.random.seed(0)

def model_nn(x_train, x_test, y_train, y_test, test, meta_train, meta_test,train_index, test_index,fold_id):
    model = Sequential()
    model.add(Dense(units = 400 , kernel_initializer = 'normal', input_dim = 718))
    model.add(PReLU())
    model.add(Dropout(.4))
    model.add(Dense(units = 160 , kernel_initializer = 'normal'))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(.4))
    model.add(Dense(units = 64 , kernel_initializer = 'normal'))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(.4))
    model.add(Dense(units = 26, kernel_initializer = 'normal'))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(.4))
    model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
    model.compile(loss="binary_crossentropy", optimizer="adam")
    
    checkpoint = ModelCheckpoint("weights/{}.hdf5".format(model_name), monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    early_stop = EarlyStopping(monitor='val_loss', patience=5, mode='auto') 

    model.fit(x_train, y_train, epochs=100, batch_size=30000, validation_data =(x_test, y_test), callbacks=[checkpoint, early_stop], class_weight={1:np.mean(y_train), 0: 1-np.mean(y_train)})

    model.load_weights("weights/{}.hdf5".format(model_name))
    meta_train[test_index] = model.predict(x_test).flatten().clip(0,1)
    meta_test.append(model.predict(test).flatten().clip(0,1))
    print "ROC_AUC_SCORE: {}".format(roc_auc_score(y_test, meta_train[test_index]))

    del model
    gc.collect()
    K.clear_session()
    K.tf.set_random_seed(0)
# Out:
# /home/sakhtar0092/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Training Classifier

# %%
meta_train = np.zeros(train.shape[0])
meta_test = []

kf = StratifiedKFold(n_splits= 10, shuffle=True, random_state=47)
for fold_id, (train_index, test_index) in enumerate(kf.split(train, target)):
    x_train, x_test = train.iloc[train_index], train.iloc[test_index]
    y_train, y_test = target[train_index], target[test_index]

    model_nn(x_train, x_test, y_train, y_test, test, meta_train, meta_test,train_index, test_index,fold_id)

test_id["TARGET"] = np.array(meta_test).T.mean(axis=1)
train_id["TARGET"] = meta_train
# Out:
# Train on 276755 samples, validate on 30752 samples
# Epoch 1/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5933
# Epoch 00001: val_loss improved from inf to 0.67206, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 9s 33us/step - loss: 0.5932 - val_loss: 0.6721
# Epoch 2/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5835
# Epoch 00002: val_loss improved from 0.67206 to 0.66778, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 26us/step - loss: 0.5834 - val_loss: 0.6678
# Epoch 3/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5755
# Epoch 00003: val_loss improved from 0.66778 to 0.65955, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 26us/step - loss: 0.5755 - val_loss: 0.6595
# Epoch 4/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5664
# Epoch 00004: val_loss improved from 0.65955 to 0.65150, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 26us/step - loss: 0.5663 - val_loss: 0.6515
# Epoch 5/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5554
# Epoch 00005: val_loss improved from 0.65150 to 0.63496, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.5551 - val_loss: 0.6350
# Epoch 6/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5408
# Epoch 00006: val_loss improved from 0.63496 to 0.62454, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.5406 - val_loss: 0.6245
# Epoch 7/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5231
# Epoch 00007: val_loss improved from 0.62454 to 0.60947, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 26us/step - loss: 0.5229 - val_loss: 0.6095
# Epoch 8/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5009
# Epoch 00008: val_loss improved from 0.60947 to 0.56581, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 27us/step - loss: 0.5007 - val_loss: 0.5658
# Epoch 9/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.4768
# Epoch 00009: val_loss improved from 0.56581 to 0.55307, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.4765 - val_loss: 0.5531
# Epoch 10/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.4485
# Epoch 00010: val_loss improved from 0.55307 to 0.48661, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 6s 23us/step - loss: 0.4481 - val_loss: 0.4866
# Epoch 11/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.4178
# Epoch 00011: val_loss improved from 0.48661 to 0.45886, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.4174 - val_loss: 0.4589
# Epoch 12/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.3859
# Epoch 00012: val_loss improved from 0.45886 to 0.41991, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 26us/step - loss: 0.3856 - val_loss: 0.4199
# Epoch 13/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.3506
# Epoch 00013: val_loss improved from 0.41991 to 0.37456, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.3501 - val_loss: 0.3746
# Epoch 14/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.3132
# Epoch 00014: val_loss improved from 0.37456 to 0.34578, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.3127 - val_loss: 0.3458
# Epoch 15/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.2775
# Epoch 00015: val_loss improved from 0.34578 to 0.32791, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.2771 - val_loss: 0.3279
# Epoch 16/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.2434
# Epoch 00016: val_loss improved from 0.32791 to 0.31927, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 26us/step - loss: 0.2431 - val_loss: 0.3193
# Epoch 17/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.2145
# Epoch 00017: val_loss improved from 0.31927 to 0.31766, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.2142 - val_loss: 0.3177
# Epoch 18/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1898
# Epoch 00018: val_loss improved from 0.31766 to 0.30655, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 27us/step - loss: 0.1895 - val_loss: 0.3065
# Epoch 19/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1680
# Epoch 00019: val_loss improved from 0.30655 to 0.29320, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.1678 - val_loss: 0.2932
# Epoch 20/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1499
# Epoch 00020: val_loss improved from 0.29320 to 0.28464, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 27us/step - loss: 0.1496 - val_loss: 0.2846
# Epoch 21/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1332
# Epoch 00021: val_loss improved from 0.28464 to 0.27822, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 26us/step - loss: 0.1331 - val_loss: 0.2782
# Epoch 22/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1230
# Epoch 00022: val_loss improved from 0.27822 to 0.27545, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.1228 - val_loss: 0.2754
# Epoch 23/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1112
# Epoch 00023: val_loss improved from 0.27545 to 0.27471, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 26us/step - loss: 0.1110 - val_loss: 0.2747
# Epoch 24/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1011
# Epoch 00024: val_loss did not improve
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.1009 - val_loss: 0.2780
# Epoch 25/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.0923
# Epoch 00025: val_loss did not improve
# 276755/276755 [==============================] - 7s 26us/step - loss: 0.0922 - val_loss: 0.2783
# Epoch 26/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.0856
# Epoch 00026: val_loss did not improve
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.0856 - val_loss: 0.2792
# Epoch 27/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.0801
# Epoch 00027: val_loss did not improve
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.0800 - val_loss: 0.2808
# Epoch 28/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.0758
# Epoch 00028: val_loss did not improve
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.0757 - val_loss: 0.2813
# ROC_AUC_SCORE: 0.725905487678
# Train on 276755 samples, validate on 30752 samples
# Epoch 1/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5934
# Epoch 00001: val_loss improved from inf to 0.70723, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 8s 30us/step - loss: 0.5932 - val_loss: 0.7072
# Epoch 2/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5834
# Epoch 00002: val_loss improved from 0.70723 to 0.65991, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.5833 - val_loss: 0.6599
# Epoch 3/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5753
# Epoch 00003: val_loss improved from 0.65991 to 0.63189, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 27us/step - loss: 0.5752 - val_loss: 0.6319
# Epoch 4/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5664
# Epoch 00004: val_loss did not improve
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.5662 - val_loss: 0.6347
# Epoch 5/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5551
# Epoch 00005: val_loss improved from 0.63189 to 0.63114, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.5550 - val_loss: 0.6311
# Epoch 6/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5410
# Epoch 00006: val_loss did not improve
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.5407 - val_loss: 0.6387
# Epoch 7/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5234
# Epoch 00007: val_loss improved from 0.63114 to 0.62363, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.5231 - val_loss: 0.6236
# Epoch 8/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.5020
# Epoch 00008: val_loss improved from 0.62363 to 0.57300, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.5016 - val_loss: 0.5730
# Epoch 9/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.4769
# Epoch 00009: val_loss improved from 0.57300 to 0.52956, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 26us/step - loss: 0.4766 - val_loss: 0.5296
# Epoch 10/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.4481
# Epoch 00010: val_loss improved from 0.52956 to 0.46768, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.4476 - val_loss: 0.4677
# Epoch 11/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.4171
# Epoch 00011: val_loss improved from 0.46768 to 0.43861, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.4169 - val_loss: 0.4386
# Epoch 12/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.3827
# Epoch 00012: val_loss improved from 0.43861 to 0.40816, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.3823 - val_loss: 0.4082
# Epoch 13/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.3468
# Epoch 00013: val_loss improved from 0.40816 to 0.39358, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.3463 - val_loss: 0.3936
# Epoch 14/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.3100
# Epoch 00014: val_loss improved from 0.39358 to 0.37201, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 27us/step - loss: 0.3095 - val_loss: 0.3720
# Epoch 15/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.2760
# Epoch 00015: val_loss improved from 0.37201 to 0.35999, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.2757 - val_loss: 0.3600
# Epoch 16/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.2460
# Epoch 00016: val_loss improved from 0.35999 to 0.33461, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.2456 - val_loss: 0.3346
# Epoch 17/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.2163
# Epoch 00017: val_loss improved from 0.33461 to 0.30881, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.2160 - val_loss: 0.3088
# Epoch 18/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1918
# Epoch 00018: val_loss improved from 0.30881 to 0.29251, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.1914 - val_loss: 0.2925
# Epoch 19/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1696
# Epoch 00019: val_loss improved from 0.29251 to 0.28298, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.1693 - val_loss: 0.2830
# Epoch 20/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1501
# Epoch 00020: val_loss improved from 0.28298 to 0.27633, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.1500 - val_loss: 0.2763
# Epoch 21/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1343
# Epoch 00021: val_loss improved from 0.27633 to 0.27556, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.1342 - val_loss: 0.2756
# Epoch 22/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1212
# Epoch 00022: val_loss improved from 0.27556 to 0.27487, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 26us/step - loss: 0.1210 - val_loss: 0.2749
# Epoch 23/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1102
# Epoch 00023: val_loss improved from 0.27487 to 0.27231, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.1101 - val_loss: 0.2723
# Epoch 24/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.1014
# Epoch 00024: val_loss did not improve
# 276755/276755 [==============================] - 6s 23us/step - loss: 0.1013 - val_loss: 0.2751
# Epoch 25/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.0934
# Epoch 00025: val_loss improved from 0.27231 to 0.27160, saving model to weights/nn_sequential_on_core_features.hdf5
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.0932 - val_loss: 0.2716
# Epoch 26/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.0859
# Epoch 00026: val_loss did not improve
# 276755/276755 [==============================] - 7s 24us/step - loss: 0.0858 - val_loss: 0.2781
# Epoch 27/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.0800
# Epoch 00027: val_loss did not improve
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.0799 - val_loss: 0.2772
# Epoch 28/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.0756
# Epoch 00028: val_loss did not improve
# 276755/276755 [==============================] - 6s 23us/step - loss: 0.0755 - val_loss: 0.2810
# Epoch 29/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.0713
# Epoch 00029: val_loss did not improve
# 276755/276755 [==============================] - 7s 25us/step - loss: 0.0712 - val_loss: 0.2822
# Epoch 30/100
# 270000/276755 [============================>.] - ETA: 0s - loss: 0.0678
# Epoch 00030: val_loss did not improve
# 276755/276755 [==============================] - 6s 22us/step - loss: 0.0678 - val_loss: 0.2838
# ROC_AUC_SCORE: 0.740134146766
# Train on 276756 samples, validate on 30751 samples
# Epoch 1/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5953
# Epoch 00001: val_loss improved from inf to 0.66297, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 9s 32us/step - loss: 0.5951 - val_loss: 0.6630
# Epoch 2/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5838
# Epoch 00002: val_loss did not improve
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5836 - val_loss: 0.6644
# Epoch 3/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5756
# Epoch 00003: val_loss improved from 0.66297 to 0.64210, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 25us/step - loss: 0.5755 - val_loss: 0.6421
# Epoch 4/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5664
# Epoch 00004: val_loss improved from 0.64210 to 0.63421, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5663 - val_loss: 0.6342
# Epoch 5/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5551
# Epoch 00005: val_loss improved from 0.63421 to 0.63095, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.5550 - val_loss: 0.6310
# Epoch 6/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5416
# Epoch 00006: val_loss improved from 0.63095 to 0.60296, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 25us/step - loss: 0.5415 - val_loss: 0.6030
# Epoch 7/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5242
# Epoch 00007: val_loss improved from 0.60296 to 0.56911, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5240 - val_loss: 0.5691
# Epoch 8/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5039
# Epoch 00008: val_loss improved from 0.56911 to 0.56517, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5035 - val_loss: 0.5652
# Epoch 9/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.4793
# Epoch 00009: val_loss improved from 0.56517 to 0.54330, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.4790 - val_loss: 0.5433
# Epoch 10/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.4526
# Epoch 00010: val_loss improved from 0.54330 to 0.51800, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.4522 - val_loss: 0.5180
# Epoch 11/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.4232
# Epoch 00011: val_loss improved from 0.51800 to 0.48456, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.4228 - val_loss: 0.4846
# Epoch 12/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.3920
# Epoch 00012: val_loss improved from 0.48456 to 0.45330, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.3917 - val_loss: 0.4533
# Epoch 13/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.3602
# Epoch 00013: val_loss improved from 0.45330 to 0.44012, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.3597 - val_loss: 0.4401
# Epoch 14/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.3268
# Epoch 00014: val_loss improved from 0.44012 to 0.38646, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.3264 - val_loss: 0.3865
# Epoch 15/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.2932
# Epoch 00015: val_loss improved from 0.38646 to 0.35491, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.2927 - val_loss: 0.3549
# Epoch 16/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.2585
# Epoch 00016: val_loss improved from 0.35491 to 0.34657, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.2581 - val_loss: 0.3466
# Epoch 17/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.2261
# Epoch 00017: val_loss improved from 0.34657 to 0.33132, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.2258 - val_loss: 0.3313
# Epoch 18/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1980
# Epoch 00018: val_loss improved from 0.33132 to 0.30781, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1977 - val_loss: 0.3078
# Epoch 19/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1748
# Epoch 00019: val_loss improved from 0.30781 to 0.29087, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1748 - val_loss: 0.2909
# Epoch 20/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1566
# Epoch 00020: val_loss improved from 0.29087 to 0.28738, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1563 - val_loss: 0.2874
# Epoch 21/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1386
# Epoch 00021: val_loss improved from 0.28738 to 0.28170, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1384 - val_loss: 0.2817
# Epoch 22/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1234
# Epoch 00022: val_loss improved from 0.28170 to 0.27893, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.1234 - val_loss: 0.2789
# Epoch 23/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1117
# Epoch 00023: val_loss improved from 0.27893 to 0.27834, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1116 - val_loss: 0.2783
# Epoch 24/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1022
# Epoch 00024: val_loss did not improve
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1021 - val_loss: 0.2790
# Epoch 25/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0933
# Epoch 00025: val_loss did not improve
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.0933 - val_loss: 0.2799
# Epoch 26/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0869
# Epoch 00026: val_loss did not improve
# 276756/276756 [==============================] - 6s 22us/step - loss: 0.0868 - val_loss: 0.2811
# Epoch 27/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0814
# Epoch 00027: val_loss did not improve
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.0813 - val_loss: 0.2810
# Epoch 28/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0768
# Epoch 00028: val_loss did not improve
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.0769 - val_loss: 0.2841
# ROC_AUC_SCORE: 0.649839846288
# Train on 276756 samples, validate on 30751 samples
# Epoch 1/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5934
# Epoch 00001: val_loss improved from inf to 0.65308, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 8s 29us/step - loss: 0.5933 - val_loss: 0.6531
# Epoch 2/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5832
# Epoch 00002: val_loss did not improve
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5830 - val_loss: 0.6610
# Epoch 3/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5751
# Epoch 00003: val_loss improved from 0.65308 to 0.64948, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 25us/step - loss: 0.5750 - val_loss: 0.6495
# Epoch 4/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5659
# Epoch 00004: val_loss improved from 0.64948 to 0.62159, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 26us/step - loss: 0.5658 - val_loss: 0.6216
# Epoch 5/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5541
# Epoch 00005: val_loss did not improve
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5540 - val_loss: 0.6232
# Epoch 6/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5403
# Epoch 00006: val_loss improved from 0.62159 to 0.59764, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5401 - val_loss: 0.5976
# Epoch 7/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5221
# Epoch 00007: val_loss improved from 0.59764 to 0.58654, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 25us/step - loss: 0.5219 - val_loss: 0.5865
# Epoch 8/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5004
# Epoch 00008: val_loss improved from 0.58654 to 0.56472, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5002 - val_loss: 0.5647
# Epoch 9/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.4759
# Epoch 00009: val_loss improved from 0.56472 to 0.51418, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.4755 - val_loss: 0.5142
# Epoch 10/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.4482
# Epoch 00010: val_loss improved from 0.51418 to 0.51035, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.4477 - val_loss: 0.5103
# Epoch 11/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.4178
# Epoch 00011: val_loss improved from 0.51035 to 0.48339, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.4175 - val_loss: 0.4834
# Epoch 12/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.3860
# Epoch 00012: val_loss improved from 0.48339 to 0.46443, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.3855 - val_loss: 0.4644
# Epoch 13/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.3524
# Epoch 00013: val_loss improved from 0.46443 to 0.41996, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.3520 - val_loss: 0.4200
# Epoch 14/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.3174
# Epoch 00014: val_loss improved from 0.41996 to 0.37101, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.3169 - val_loss: 0.3710
# Epoch 15/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.2805
# Epoch 00015: val_loss improved from 0.37101 to 0.34860, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.2802 - val_loss: 0.3486
# Epoch 16/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.2459
# Epoch 00016: val_loss improved from 0.34860 to 0.32844, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.2454 - val_loss: 0.3284
# Epoch 17/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.2151
# Epoch 00017: val_loss improved from 0.32844 to 0.31027, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.2147 - val_loss: 0.3103
# Epoch 18/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1881
# Epoch 00018: val_loss improved from 0.31027 to 0.29973, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1879 - val_loss: 0.2997
# Epoch 19/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1661
# Epoch 00019: val_loss improved from 0.29973 to 0.29008, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.1659 - val_loss: 0.2901
# Epoch 20/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1486
# Epoch 00020: val_loss improved from 0.29008 to 0.28511, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.1485 - val_loss: 0.2851
# Epoch 21/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1328
# Epoch 00021: val_loss improved from 0.28511 to 0.28021, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1326 - val_loss: 0.2802
# Epoch 22/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1201
# Epoch 00022: val_loss improved from 0.28021 to 0.28019, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1200 - val_loss: 0.2802
# Epoch 23/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1128
# Epoch 00023: val_loss improved from 0.28019 to 0.27692, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1127 - val_loss: 0.2769
# Epoch 24/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1133
# Epoch 00024: val_loss improved from 0.27692 to 0.27466, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1130 - val_loss: 0.2747
# Epoch 25/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0954
# Epoch 00025: val_loss improved from 0.27466 to 0.27459, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.0955 - val_loss: 0.2746
# Epoch 26/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0878
# Epoch 00026: val_loss improved from 0.27459 to 0.27267, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.0877 - val_loss: 0.2727
# Epoch 27/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0808
# Epoch 00027: val_loss did not improve
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.0807 - val_loss: 0.2754
# Epoch 28/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0766
# Epoch 00028: val_loss did not improve
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.0767 - val_loss: 0.2774
# Epoch 29/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0723
# Epoch 00029: val_loss did not improve
# 276756/276756 [==============================] - 6s 22us/step - loss: 0.0728 - val_loss: 0.2813
# Epoch 30/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0703
# Epoch 00030: val_loss did not improve
# 276756/276756 [==============================] - 6s 22us/step - loss: 0.0702 - val_loss: 0.2821
# Epoch 31/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0673
# Epoch 00031: val_loss did not improve
# 276756/276756 [==============================] - 6s 22us/step - loss: 0.0672 - val_loss: 0.2818
# ROC_AUC_SCORE: 0.731649940125
# Train on 276756 samples, validate on 30751 samples
# Epoch 1/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5934
# Epoch 00001: val_loss improved from inf to 0.68124, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 26us/step - loss: 0.5933 - val_loss: 0.6812
# Epoch 2/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5837
# Epoch 00002: val_loss improved from 0.68124 to 0.65777, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5836 - val_loss: 0.6578
# Epoch 3/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5754
# Epoch 00003: val_loss improved from 0.65777 to 0.65593, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5751 - val_loss: 0.6559
# Epoch 4/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5664
# Epoch 00004: val_loss improved from 0.65593 to 0.65247, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5663 - val_loss: 0.6525
# Epoch 5/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5553
# Epoch 00005: val_loss improved from 0.65247 to 0.64735, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 26us/step - loss: 0.5552 - val_loss: 0.6473
# Epoch 6/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5411
# Epoch 00006: val_loss improved from 0.64735 to 0.62131, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5408 - val_loss: 0.6213
# Epoch 7/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5232
# Epoch 00007: val_loss improved from 0.62131 to 0.58962, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.5231 - val_loss: 0.5896
# Epoch 8/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.5019
# Epoch 00008: val_loss improved from 0.58962 to 0.56396, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 26us/step - loss: 0.5016 - val_loss: 0.5640
# Epoch 9/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.4779
# Epoch 00009: val_loss improved from 0.56396 to 0.53750, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.4776 - val_loss: 0.5375
# Epoch 10/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.4494
# Epoch 00010: val_loss improved from 0.53750 to 0.48330, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.4490 - val_loss: 0.4833
# Epoch 11/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.4195
# Epoch 00011: val_loss improved from 0.48330 to 0.44178, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 25us/step - loss: 0.4191 - val_loss: 0.4418
# Epoch 12/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.3860
# Epoch 00012: val_loss improved from 0.44178 to 0.43997, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.3856 - val_loss: 0.4400
# Epoch 13/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.3495
# Epoch 00013: val_loss improved from 0.43997 to 0.40425, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.3490 - val_loss: 0.4043
# Epoch 14/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.3116
# Epoch 00014: val_loss improved from 0.40425 to 0.37404, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.3112 - val_loss: 0.3740
# Epoch 15/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.2754
# Epoch 00015: val_loss improved from 0.37404 to 0.36341, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.2750 - val_loss: 0.3634
# Epoch 16/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.2415
# Epoch 00016: val_loss improved from 0.36341 to 0.33568, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.2412 - val_loss: 0.3357
# Epoch 17/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.2122
# Epoch 00017: val_loss improved from 0.33568 to 0.31084, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.2122 - val_loss: 0.3108
# Epoch 18/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1903
# Epoch 00018: val_loss improved from 0.31084 to 0.29921, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.1903 - val_loss: 0.2992
# Epoch 19/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1680
# Epoch 00019: val_loss improved from 0.29921 to 0.29222, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1677 - val_loss: 0.2922
# Epoch 20/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1497
# Epoch 00020: val_loss improved from 0.29222 to 0.28696, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1495 - val_loss: 0.2870
# Epoch 21/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1340
# Epoch 00021: val_loss improved from 0.28696 to 0.28359, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1342 - val_loss: 0.2836
# Epoch 22/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1309
# Epoch 00022: val_loss improved from 0.28359 to 0.28084, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1311 - val_loss: 0.2808
# Epoch 23/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1127
# Epoch 00023: val_loss improved from 0.28084 to 0.28016, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.1125 - val_loss: 0.2802
# Epoch 24/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.1038
# Epoch 00024: val_loss improved from 0.28016 to 0.27744, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.1037 - val_loss: 0.2774
# Epoch 25/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0956
# Epoch 00025: val_loss improved from 0.27744 to 0.27715, saving model to weights/nn_sequential_on_core_features.hdf5
# 276756/276756 [==============================] - 7s 24us/step - loss: 0.0956 - val_loss: 0.2771
# Epoch 26/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0875
# Epoch 00026: val_loss did not improve
# 276756/276756 [==============================] - 6s 22us/step - loss: 0.0874 - val_loss: 0.2792
# Epoch 27/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0808
# Epoch 00027: val_loss did not improve
# 276756/276756 [==============================] - 6s 22us/step - loss: 0.0808 - val_loss: 0.2812
# Epoch 28/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0766
# Epoch 00028: val_loss did not improve
# 276756/276756 [==============================] - 6s 22us/step - loss: 0.0766 - val_loss: 0.2827
# Epoch 29/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0722
# Epoch 00029: val_loss did not improve
# 276756/276756 [==============================] - 6s 22us/step - loss: 0.0722 - val_loss: 0.2850
# Epoch 30/100
# 270000/276756 [============================>.] - ETA: 0s - loss: 0.0682
# Epoch 00030: val_loss did not improve
# 276756/276756 [==============================] - 6s 23us/step - loss: 0.0683 - val_loss: 0.2869
# ROC_AUC_SCORE: 0.727110397113
# Train on 276757 samples, validate on 30750 samples
# Epoch 1/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5940
# Epoch 00001: val_loss improved from inf to 0.67631, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.5939 - val_loss: 0.6763
# Epoch 2/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5840
# Epoch 00002: val_loss did not improve
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.5838 - val_loss: 0.6826
# Epoch 3/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5756
# Epoch 00003: val_loss did not improve
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.5755 - val_loss: 0.6841
# Epoch 4/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5661
# Epoch 00004: val_loss improved from 0.67631 to 0.66318, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 7s 25us/step - loss: 0.5660 - val_loss: 0.6632
# Epoch 5/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5548
# Epoch 00005: val_loss improved from 0.66318 to 0.61052, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 7s 24us/step - loss: 0.5546 - val_loss: 0.6105
# Epoch 6/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5396
# Epoch 00006: val_loss improved from 0.61052 to 0.58221, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 7s 23us/step - loss: 0.5394 - val_loss: 0.5822
# Epoch 7/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5216
# Epoch 00007: val_loss improved from 0.58221 to 0.56611, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 7s 25us/step - loss: 0.5213 - val_loss: 0.5661
# Epoch 8/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.4994
# Epoch 00008: val_loss improved from 0.56611 to 0.55213, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.4991 - val_loss: 0.5521
# Epoch 9/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.4744
# Epoch 00009: val_loss improved from 0.55213 to 0.49512, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.4740 - val_loss: 0.4951
# Epoch 10/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.4464
# Epoch 00010: val_loss improved from 0.49512 to 0.48553, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.4461 - val_loss: 0.4855
# Epoch 11/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.4158
# Epoch 00011: val_loss improved from 0.48553 to 0.46247, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.4155 - val_loss: 0.4625
# Epoch 12/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.3826
# Epoch 00012: val_loss improved from 0.46247 to 0.40510, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 7s 24us/step - loss: 0.3822 - val_loss: 0.4051
# Epoch 13/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.3472
# Epoch 00013: val_loss improved from 0.40510 to 0.39169, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 7s 25us/step - loss: 0.3469 - val_loss: 0.3917
# Epoch 14/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.3119
# Epoch 00014: val_loss improved from 0.39169 to 0.36662, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.3115 - val_loss: 0.3666
# Epoch 15/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.2769
# Epoch 00015: val_loss improved from 0.36662 to 0.34661, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.2766 - val_loss: 0.3466
# Epoch 16/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.2439
# Epoch 00016: val_loss improved from 0.34661 to 0.33555, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.2438 - val_loss: 0.3355
# Epoch 17/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.2152
# Epoch 00017: val_loss improved from 0.33555 to 0.31740, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 7s 24us/step - loss: 0.2149 - val_loss: 0.3174
# Epoch 18/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1908
# Epoch 00018: val_loss improved from 0.31740 to 0.30577, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.1905 - val_loss: 0.3058
# Epoch 19/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1697
# Epoch 00019: val_loss improved from 0.30577 to 0.29315, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.1694 - val_loss: 0.2932
# Epoch 20/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1507
# Epoch 00020: val_loss improved from 0.29315 to 0.28204, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.1505 - val_loss: 0.2820
# Epoch 21/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1353
# Epoch 00021: val_loss improved from 0.28204 to 0.27946, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.1351 - val_loss: 0.2795
# Epoch 22/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1227
# Epoch 00022: val_loss improved from 0.27946 to 0.27502, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.1224 - val_loss: 0.2750
# ...
# Train on 276757 samples, validate on 30750 samples
# Epoch 1/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5922
# Epoch 00001: val_loss improved from inf to 0.67327, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 9s 31us/step - loss: 0.5921 - val_loss: 0.6733
# Epoch 2/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5831
# Epoch 00002: val_loss did not improve
# 276757/276757 [==============================] - 7s 27us/step - loss: 0.5830 - val_loss: 0.6791
# Epoch 3/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5757
# Epoch 00003: val_loss did not improve
# 276757/276757 [==============================] - 7s 27us/step - loss: 0.5755 - val_loss: 0.6809
# Epoch 4/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5673
# Epoch 00004: val_loss improved from 0.67327 to 0.66624, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.5671 - val_loss: 0.6662
# Epoch 5/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5563
# Epoch 00005: val_loss improved from 0.66624 to 0.63342, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.5561 - val_loss: 0.6334
# Epoch 6/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5423
# Epoch 00006: val_loss improved from 0.63342 to 0.60905, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.5421 - val_loss: 0.6091
# Epoch 7/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5250
# Epoch 00007: val_loss improved from 0.60905 to 0.59656, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.5247 - val_loss: 0.5966
# Epoch 8/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5033
# Epoch 00008: val_loss improved from 0.59656 to 0.56115, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 30us/step - loss: 0.5031 - val_loss: 0.5612
# Epoch 9/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.4783
# Epoch 00009: val_loss improved from 0.56115 to 0.54566, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.4781 - val_loss: 0.5457
# Epoch 10/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.4504
# Epoch 00010: val_loss improved from 0.54566 to 0.48867, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.4502 - val_loss: 0.4887
# Epoch 11/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.4198
# Epoch 00011: val_loss improved from 0.48867 to 0.45071, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.4194 - val_loss: 0.4507
# Epoch 12/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.3877
# Epoch 00012: val_loss improved from 0.45071 to 0.41214, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 30us/step - loss: 0.3872 - val_loss: 0.4121
# Epoch 13/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.3536
# Epoch 00013: val_loss improved from 0.41214 to 0.37576, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.3532 - val_loss: 0.3758
# Epoch 14/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.3187
# Epoch 00014: val_loss improved from 0.37576 to 0.34584, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 27us/step - loss: 0.3182 - val_loss: 0.3458
# Epoch 15/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.2831
# Epoch 00015: val_loss improved from 0.34584 to 0.32216, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.2827 - val_loss: 0.3222
# Epoch 16/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.2506
# Epoch 00016: val_loss improved from 0.32216 to 0.32114, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.2502 - val_loss: 0.3211
# Epoch 17/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.2205
# Epoch 00017: val_loss improved from 0.32114 to 0.29911, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.2201 - val_loss: 0.2991
# Epoch 18/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1939
# Epoch 00018: val_loss improved from 0.29911 to 0.28442, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.1936 - val_loss: 0.2844
# Epoch 19/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1702
# Epoch 00019: val_loss improved from 0.28442 to 0.28109, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 30us/step - loss: 0.1700 - val_loss: 0.2811
# Epoch 20/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1502
# Epoch 00020: val_loss improved from 0.28109 to 0.28086, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.1500 - val_loss: 0.2809
# Epoch 21/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1344
# Epoch 00021: val_loss improved from 0.28086 to 0.27804, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.1343 - val_loss: 0.2780
# Epoch 22/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1211
# Epoch 00022: val_loss did not improve
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.1209 - val_loss: 0.2783
# Epoch 23/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1089
# Epoch 00023: val_loss improved from 0.27804 to 0.27688, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 9s 31us/step - loss: 0.1088 - val_loss: 0.2769
# Epoch 24/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1001
# Epoch 00024: val_loss improved from 0.27688 to 0.27592, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 30us/step - loss: 0.1000 - val_loss: 0.2759
# Epoch 25/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.0919
# Epoch 00025: val_loss did not improve
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.0918 - val_loss: 0.2774
# Epoch 26/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.0853
# Epoch 00026: val_loss did not improve
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.0852 - val_loss: 0.2768
# Epoch 27/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.0794
# Epoch 00027: val_loss did not improve
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.0793 - val_loss: 0.2783
# Epoch 28/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.0746
# Epoch 00028: val_loss did not improve
# 276757/276757 [==============================] - 7s 26us/step - loss: 0.0745 - val_loss: 0.2794
# Epoch 29/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.0749
# Epoch 00029: val_loss did not improve
# 276757/276757 [==============================] - 7s 25us/step - loss: 0.0757 - val_loss: 0.2843
# ROC_AUC_SCORE: 0.731184344744
# Train on 276757 samples, validate on 30750 samples
# Epoch 1/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5991
# Epoch 00001: val_loss improved from inf to 0.70135, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 9s 33us/step - loss: 0.5989 - val_loss: 0.7013
# Epoch 2/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5853
# Epoch 00002: val_loss improved from 0.70135 to 0.68715, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.5852 - val_loss: 0.6871
# Epoch 3/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5756
# Epoch 00003: val_loss improved from 0.68715 to 0.68121, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.5757 - val_loss: 0.6812
# Epoch 4/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5661
# Epoch 00004: val_loss improved from 0.68121 to 0.67470, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 27us/step - loss: 0.5659 - val_loss: 0.6747
# Epoch 5/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5552
# Epoch 00005: val_loss improved from 0.67470 to 0.64879, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.5551 - val_loss: 0.6488
# Epoch 6/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5419
# Epoch 00006: val_loss improved from 0.64879 to 0.61702, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 9s 31us/step - loss: 0.5416 - val_loss: 0.6170
# Epoch 7/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5258
# Epoch 00007: val_loss improved from 0.61702 to 0.61174, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.5255 - val_loss: 0.6117
# Epoch 8/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.5061
# Epoch 00008: val_loss improved from 0.61174 to 0.59328, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.5059 - val_loss: 0.5933
# Epoch 9/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.4837
# Epoch 00009: val_loss improved from 0.59328 to 0.52708, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.4834 - val_loss: 0.5271
# Epoch 10/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.4581
# Epoch 00010: val_loss improved from 0.52708 to 0.47420, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 31us/step - loss: 0.4578 - val_loss: 0.4742
# Epoch 11/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.4310
# Epoch 00011: val_loss did not improve
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.4306 - val_loss: 0.4885
# Epoch 12/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.4016
# Epoch 00012: val_loss improved from 0.47420 to 0.43087, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.4012 - val_loss: 0.4309
# Epoch 13/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.3708
# Epoch 00013: val_loss improved from 0.43087 to 0.39388, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 29us/step - loss: 0.3705 - val_loss: 0.3939
# Epoch 14/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.3405
# Epoch 00014: val_loss improved from 0.39388 to 0.36930, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 8s 28us/step - loss: 0.3400 - val_loss: 0.3693
# Epoch 15/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.3091
# Epoch 00015: val_loss improved from 0.36930 to 0.35529, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.3087 - val_loss: 0.3553
# Epoch 16/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.2783
# Epoch 00016: val_loss improved from 0.35529 to 0.34952, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.2780 - val_loss: 0.3495
# Epoch 17/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.2474
# Epoch 00017: val_loss improved from 0.34952 to 0.31849, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.2469 - val_loss: 0.3185
# Epoch 18/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.2174
# Epoch 00018: val_loss improved from 0.31849 to 0.30079, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.2170 - val_loss: 0.3008
# Epoch 19/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1924
# Epoch 00019: val_loss improved from 0.30079 to 0.29375, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 7s 24us/step - loss: 0.1922 - val_loss: 0.2937
# Epoch 20/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1682
# Epoch 00020: val_loss improved from 0.29375 to 0.28367, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.1680 - val_loss: 0.2837
# Epoch 21/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1492
# Epoch 00021: val_loss improved from 0.28367 to 0.27931, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 7s 24us/step - loss: 0.1491 - val_loss: 0.2793
# Epoch 22/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1331
# Epoch 00022: val_loss improved from 0.27931 to 0.27741, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 7s 24us/step - loss: 0.1330 - val_loss: 0.2774
# Epoch 23/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1201
# Epoch 00023: val_loss improved from 0.27741 to 0.27660, saving model to weights/nn_sequential_on_core_features.hdf5
# 276757/276757 [==============================] - 7s 24us/step - loss: 0.1199 - val_loss: 0.2766
# Epoch 24/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.1084
# Epoch 00024: val_loss did not improve
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.1083 - val_loss: 0.2771
# Epoch 25/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.0982
# Epoch 00025: val_loss did not improve
# 276757/276757 [==============================] - 6s 22us/step - loss: 0.0981 - val_loss: 0.2781
# Epoch 26/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.0901
# Epoch 00026: val_loss did not improve
# 276757/276757 [==============================] - 6s 22us/step - loss: 0.0901 - val_loss: 0.2785
# Epoch 27/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.0842
# Epoch 00027: val_loss did not improve
# 276757/276757 [==============================] - 6s 23us/step - loss: 0.0841 - val_loss: 0.2804
# Epoch 28/100
# 270000/276757 [============================>.] - ETA: 0s - loss: 0.0797
# Epoch 00028: val_loss did not improve
# 276757/276757 [==============================] - 7s 24us/step - loss: 0.0796 - val_loss: 0.2824
# ROC_AUC_SCORE: 0.715892860747

# %%
train_id.to_csv("csv/{}.csv".format(model_name), index=False)
test_id.to_csv("csv/{}.csv".format(model_name), index=False)
