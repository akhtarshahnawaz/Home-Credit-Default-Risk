# %%
model_name = "xgb_on_l1_and_basemixtures_neptune"

# %%
import numpy as np
import pandas as pd
import gc
from time import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
timesheet = [time()]
def timer(statement):
    global timesheet
    timesheet.append(time())
    print statement+" :", (timesheet[-1]-timesheet[-2]),"seconds"

def one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

def load_meta(directory, prefix, modeltype):
    m_tr = pd.read_csv(directory+prefix+"_train.csv")
    m_te = pd.read_csv(directory+prefix+"_test.csv")
    data = pd.concat([m_tr, m_te], axis=0).reset_index(drop=True)
    data.columns = ["{}_{}_{}".format(c, prefix, modeltype) if c!="SK_ID_CURR" else c for c in data.columns]
    return data

def join_features(data, features):
    for item in features:
        data = data.merge(item, how = "left", on = "SK_ID_CURR")
    return data

def postprocess(df):
    cols = [c for c in df.columns if c not in ["SK_ID_CURR","SK_ID_PREV","TARGET"]]
    df = df.replace([np.inf, -np.inf], np.nan)
    return df

def load_neptune(directory, modelname):
    m_tr = pd.read_csv(directory+"lightGBM_out_of_fold_train_predictions.csv", usecols = ["SK_ID_CURR","lightGBM_prediction"])
    m_te = pd.read_csv(directory+"lightGBM_out_of_fold_test_predictions.csv", usecols = ["SK_ID_CURR","lightGBM_prediction"])
    m_te = m_te.groupby("SK_ID_CURR")["lightGBM_prediction"].mean().reset_index()
    
    data = pd.concat([m_tr, m_te], axis=0).reset_index(drop=True)
    data.columns = ["SK_ID_CURR", "neptune_{}".format(modelname)]
    return data

# %% [markdown]
# # Loading Meta Files

# %%
l1_features = [
    load_meta("../l1/csv/", "l1_gnb", "l1"),
    load_meta("../l1/csv/", "l1_lr", "l1"),
    load_meta("../l1/csv/", "l1_tree_with_flags", "l1"),
    load_meta("../l1/csv/", "l1_tree_without_flags", "l1"),
    load_meta("../l1/csv/", "tree_with_flags_without_meta", "l1"),
    load_meta("../l1/csv/", "tree_without_flags_without_meta", "l1"),
    load_meta("../l1/csv/", "tree_on_core_features_with_meta", "l1"),
]

neptune_features = [
    load_neptune("../base neptune/m1/csv/", "m1"),
    load_neptune("../base neptune/m2/csv/", "m2"),
    load_neptune("../base neptune/m3/csv/", "m3"),
    load_neptune("../base neptune/m4/csv/", "m4"),
]

mixture_models = [
    load_meta("../base mixtures/csv/", "knn_on_selected_pca", "mixtures"),
    load_meta("../base mixtures/csv/", "lgbm_on_core_features", "mixtures"),
    load_meta("../base mixtures/csv/", "lgbm_on_gp_features", "mixtures"),
    load_meta("../base mixtures/csv/", "lr_on_core_features", "mixtures"),
    load_meta("../base mixtures/csv/", "nn", "mixtures"),
    load_meta("../base mixtures/csv/", "using_lags_bureau_data", "mixtures"),

]

# %% [markdown]
# ## Get Application Train/Test Data

# %%
def application_train_test(num_rows = None, nan_as_category = False):
    # Read data and merge
    df = pd.read_csv('../data/application_train.csv', nrows= num_rows)
    test_df = pd.read_csv('../data/application_test.csv', nrows= num_rows)

    print("Train samples: {}, test samples: {}".format(len(df), len(test_df)))
    df = df.append(test_df).reset_index()
    # Optional: Remove 4 applications with XNA CODE_GENDER (train set)
    df = df[df['CODE_GENDER'] != 'XNA']

    docs = [_f for _f in df.columns if 'FLAG_DOC' in _f]
    live = [_f for _f in df.columns if ('FLAG_' in _f) & ('FLAG_DOC' not in _f) & ('_FLAG_' not in _f)]

    # NaN values for DAYS_EMPLOYED: 365.243 -> nan
    df['DAYS_EMPLOYED'].replace(365243, np.nan, inplace= True)

    inc_by_org = df[['AMT_INCOME_TOTAL', 'ORGANIZATION_TYPE']].groupby('ORGANIZATION_TYPE').median()['AMT_INCOME_TOTAL']

    df['NEW_CREDIT_TO_ANNUITY_RATIO'] = df['AMT_CREDIT'] / df['AMT_ANNUITY'].astype("float32")
    df['NEW_CREDIT_TO_GOODS_RATIO'] = df['AMT_CREDIT'] / df['AMT_GOODS_PRICE'].astype("float32")
    df['NEW_DOC_IND_KURT'] = df[docs].kurtosis(axis=1)
    df['NEW_LIVE_IND_SUM'] = df[live].sum(axis=1)
    df['NEW_INC_PER_CHLD'] = df['AMT_INCOME_TOTAL'] / (1 + df['CNT_CHILDREN']).astype("float32")
    df['NEW_INC_BY_ORG'] = df['ORGANIZATION_TYPE'].map(inc_by_org)
    df['NEW_EMPLOY_TO_BIRTH_RATIO'] = df['DAYS_EMPLOYED'] / df['DAYS_BIRTH'].astype("float32")
    df['NEW_ANNUITY_TO_INCOME_RATIO'] = df['AMT_ANNUITY'] / (1 + df['AMT_INCOME_TOTAL']).astype("float32")
    df['NEW_SOURCES_PROD'] = df['EXT_SOURCE_1'] * df['EXT_SOURCE_2'] * df['EXT_SOURCE_3']
    df['NEW_EXT_SOURCES_MEAN'] = df[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
    df['NEW_SCORES_STD'] = df[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].std(axis=1)
    df['NEW_SCORES_STD'] = df['NEW_SCORES_STD'].fillna(df['NEW_SCORES_STD'].mean())
    df['NEW_CAR_TO_BIRTH_RATIO'] = df['OWN_CAR_AGE'] / df['DAYS_BIRTH'].astype("float32")
    df['NEW_CAR_TO_EMPLOY_RATIO'] = df['OWN_CAR_AGE'] / df['DAYS_EMPLOYED'].astype("float32")
    df['NEW_PHONE_TO_BIRTH_RATIO'] = df['DAYS_LAST_PHONE_CHANGE'] / df['DAYS_BIRTH'].astype("float32")
    df['NEW_PHONE_TO_BIRTH_RATIO_EMPLOYER'] = df['DAYS_LAST_PHONE_CHANGE'] / df['DAYS_EMPLOYED'].astype("float32")
    df['NEW_CREDIT_TO_INCOME_RATIO'] = df['AMT_CREDIT'] / df['AMT_INCOME_TOTAL'].astype("float32")

    # Categorical features with Binary encode (0 or 1; two categories)
    for bin_feature in ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY']:
        df[bin_feature], uniques = pd.factorize(df[bin_feature])
    # Categorical features with One-Hot encode
    df, cat_cols = one_hot_encoder(df, nan_as_category)
    dropcolum=['FLAG_DOCUMENT_2','FLAG_DOCUMENT_4',
    'FLAG_DOCUMENT_5','FLAG_DOCUMENT_6','FLAG_DOCUMENT_7',
    'FLAG_DOCUMENT_8','FLAG_DOCUMENT_9','FLAG_DOCUMENT_10', 
    'FLAG_DOCUMENT_11','FLAG_DOCUMENT_12','FLAG_DOCUMENT_13',
    'FLAG_DOCUMENT_14','FLAG_DOCUMENT_15','FLAG_DOCUMENT_16',
    'FLAG_DOCUMENT_17','FLAG_DOCUMENT_18','FLAG_DOCUMENT_19',
    'FLAG_DOCUMENT_20','FLAG_DOCUMENT_21']
    df= df.drop(dropcolum,axis=1)
    del test_df
    gc.collect()
    return df

# %% [markdown]
# ## Get Bureau & Bureau Balance Data

# %%
def bureau_and_balance(num_rows = None, nan_as_category = True):
    bureau = pd.read_csv('../data/bureau.csv', nrows = num_rows)
    bb = pd.read_csv('../data/bureau_balance.csv', nrows = num_rows)
    bb, bb_cat = one_hot_encoder(bb, nan_as_category)
    bureau, bureau_cat = one_hot_encoder(bureau, nan_as_category)

    # Bureau balance: Perform aggregations and merge with bureau.csv
    bb_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size']}
    for col in bb_cat:
        bb_aggregations[col] = ['mean']
    bb_agg = bb.groupby('SK_ID_BUREAU').agg(bb_aggregations)
    bb_agg.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bb_agg.columns.tolist()])
    bureau = bureau.join(bb_agg, how='left', on='SK_ID_BUREAU')
    bureau.drop(['SK_ID_BUREAU'], axis=1, inplace= True)
    del bb, bb_agg
    gc.collect()

    # Bureau and bureau_balance numeric features
    num_aggregations = {
        'DAYS_CREDIT': [ 'mean', 'var'],
        'DAYS_CREDIT_ENDDATE': [ 'mean'],
        'DAYS_CREDIT_UPDATE': ['mean'],
        'CREDIT_DAY_OVERDUE': ['mean'],
        'AMT_CREDIT_MAX_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM': [ 'mean', 'sum'],
        'AMT_CREDIT_SUM_DEBT': [ 'mean', 'sum'],
        'AMT_CREDIT_SUM_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM_LIMIT': ['mean', 'sum'],
        'AMT_ANNUITY': ['max', 'mean'],
        'CNT_CREDIT_PROLONG': ['sum'],
        'MONTHS_BALANCE_MIN': ['min'],
        'MONTHS_BALANCE_MAX': ['max'],
        'MONTHS_BALANCE_SIZE': ['mean', 'sum']
    }
    # Bureau and bureau_balance categorical features
    cat_aggregations = {}
    for cat in bureau_cat: cat_aggregations[cat] = ['mean']
    for cat in bb_cat: cat_aggregations[cat + "_MEAN"] = ['mean']

    num_cat = num_aggregations.copy()
    num_cat.update(cat_aggregations)

    bureau_agg = bureau.groupby('SK_ID_CURR').agg(num_cat)
    bureau_agg.columns = pd.Index(['BURO_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
    bureau_agg = bureau_agg.reset_index()
    # Bureau: Active credits - using only numerical aggregations
    active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
    active_agg = active.groupby('SK_ID_CURR').agg(num_aggregations)
    active_agg.columns = pd.Index(['ACTIVE_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
    active_agg = active_agg.reset_index()
    bureau_agg = bureau_agg.merge(active_agg, how='left', on='SK_ID_CURR')
    del active, active_agg
    gc.collect()
    # Bureau: Closed credits - using only numerical aggregations
    closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
    closed_agg = closed.groupby('SK_ID_CURR').agg(num_aggregations)
    closed_agg.columns = pd.Index(['CLOSED_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')
    del closed, closed_agg, bureau
    gc.collect()
    return bureau_agg

# %% [markdown]
# ## Get Previous Applications Data

# %%
def previous_applications(num_rows = None, nan_as_category = True):
    prev = pd.read_csv('../data/previous_application.csv', nrows = num_rows)
    prev, cat_cols = one_hot_encoder(prev, nan_as_category= True)
    # Days 365.243 values -> nan
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    # Add feature: value ask / value received percentage
    prev['APP_CREDIT_PERC'] = prev['AMT_APPLICATION'] / prev['AMT_CREDIT']
    # Previous applications numeric features
    num_aggregations = {
        'AMT_ANNUITY': [ 'max', 'mean'],
        'AMT_APPLICATION': [ 'max','mean'],
        'AMT_CREDIT': [ 'max', 'mean'],
        'APP_CREDIT_PERC': [ 'max', 'mean'],
        'AMT_DOWN_PAYMENT': [ 'max', 'mean'],
        'AMT_GOODS_PRICE': [ 'max', 'mean'],
        'HOUR_APPR_PROCESS_START': [ 'max', 'mean'],
        'RATE_DOWN_PAYMENT': [ 'max', 'mean'],
        'DAYS_DECISION': [ 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
    }
    # Previous applications categorical features
    cat_aggregations = {}
    for cat in cat_cols:
        cat_aggregations[cat] = ['mean']

    num_cat = num_aggregations.copy()
    num_cat.update(cat_aggregations)

    prev_agg = prev.groupby('SK_ID_CURR').agg(num_cat)
    prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])
    prev_agg = prev_agg.reset_index()
    # Previous Applications: Approved Applications - only numerical features
    approved = prev[prev['NAME_CONTRACT_STATUS_Approved'] == 1]
    approved_agg = approved.groupby('SK_ID_CURR').agg(num_aggregations)
    approved_agg.columns = pd.Index(['APPROVED_' + e[0] + "_" + e[1].upper() for e in approved_agg.columns.tolist()])
    approved_agg = approved_agg.reset_index()
    prev_agg = prev_agg.merge(approved_agg, how='left', on='SK_ID_CURR')
    # Previous Applications: Refused Applications - only numerical features
    refused = prev[prev['NAME_CONTRACT_STATUS_Refused'] == 1]
    refused_agg = refused.groupby('SK_ID_CURR').agg(num_aggregations)
    refused_agg.columns = pd.Index(['REFUSED_' + e[0] + "_" + e[1].upper() for e in refused_agg.columns.tolist()])
    prev_agg = prev_agg.join(refused_agg, how='left', on='SK_ID_CURR')
    del refused, refused_agg, approved, approved_agg, prev
    gc.collect()
    return prev_agg

# %% [markdown]
# ## Get POS Cash Data

# %%
def pos_cash(num_rows = None, nan_as_category = True):
    pos = pd.read_csv('../data/POS_CASH_balance.csv', nrows = num_rows)
    pos, cat_cols = one_hot_encoder(pos, nan_as_category= True)
    # Features
    aggregations = {
        'MONTHS_BALANCE': ['max', 'mean', 'size'],
        'SK_DPD': ['max', 'mean'],
        'SK_DPD_DEF': ['max', 'mean']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']

    pos_agg = pos.groupby('SK_ID_CURR').agg(aggregations)
    pos_agg.columns = pd.Index(['POS_' + e[0] + "_" + e[1].upper() for e in pos_agg.columns.tolist()])
    # Count pos cash accounts
    pos_agg['POS_COUNT'] = pos.groupby('SK_ID_CURR').size()
    del pos
    gc.collect()
    return pos_agg

# %% [markdown]
# ## Get Installments Payments Data

# %%
def installments_payments(num_rows = None, nan_as_category = True):
    ins = pd.read_csv('../data/installments_payments.csv', nrows = num_rows)
    ins, cat_cols = one_hot_encoder(ins, nan_as_category= True)
    # Percentage and difference paid in each installment (amount paid and installment value)
    ins['PAYMENT_PERC'] = ins['AMT_PAYMENT'] / ins['AMT_INSTALMENT']
    ins['PAYMENT_DIFF'] = ins['AMT_INSTALMENT'] - ins['AMT_PAYMENT']
    # Days past due and days before due (no negative values)
    ins['DPD'] = ins['DAYS_ENTRY_PAYMENT'] - ins['DAYS_INSTALMENT']
    ins['DBD'] = ins['DAYS_INSTALMENT'] - ins['DAYS_ENTRY_PAYMENT']
    ins['DPD'] = ins['DPD'].apply(lambda x: x if x > 0 else 0)
    ins['DBD'] = ins['DBD'].apply(lambda x: x if x > 0 else 0)
    # Features: Perform aggregations
    aggregations = {
        'NUM_INSTALMENT_VERSION': ['nunique'],
        'DPD': ['max', 'mean', 'sum','min','std' ],
        'DBD': ['max', 'mean', 'sum','min','std'],
        'PAYMENT_PERC': [ 'max','mean',  'var','min','std'],
        'PAYMENT_DIFF': [ 'max','mean', 'var','min','std'],
        'AMT_INSTALMENT': ['max', 'mean', 'sum','min','std'],
        'AMT_PAYMENT': ['min', 'max', 'mean', 'sum','std'],
        'DAYS_ENTRY_PAYMENT': ['max', 'mean', 'sum','std']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    ins_agg = ins.groupby('SK_ID_CURR').agg(aggregations)
    ins_agg.columns = pd.Index(['INSTAL_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
    # Count installments accounts
    ins_agg['INSTAL_COUNT'] = ins.groupby('SK_ID_CURR').size()
    del ins
    gc.collect()
    return ins_agg

# %% [markdown]
# ## Get Credit Card Balance Data

# %%
def credit_card_balance(num_rows = None, nan_as_category = True):
    cc = pd.read_csv('../data/credit_card_balance.csv', nrows = num_rows)
    cc, cat_cols = one_hot_encoder(cc, nan_as_category= True)
    # General aggregations
    cc.drop(['SK_ID_PREV'], axis= 1, inplace = True)
    cc_agg = cc.groupby('SK_ID_CURR').agg([ 'max', 'mean', 'sum', 'var'])
    cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
    # Count credit card lines
    cc_agg['CC_COUNT'] = cc.groupby('SK_ID_CURR').size()
    del cc
    gc.collect()
    return cc_agg

# %% [markdown]
# # Generate Data For Training

# %%
num_rows = None
timer("Init.. ")

data = application_train_test(num_rows)
timer("Done with Application Train and Test")

data = data.merge(bureau_and_balance(num_rows),  how='left', on='SK_ID_CURR')
timer("Done with Bureau and Bureau Balance")

data = data.merge(previous_applications(num_rows),  how='left', on='SK_ID_CURR')
timer("Done with Previous Applications")

data = data.join(pos_cash(num_rows),  how='left', on='SK_ID_CURR')
timer("Done with POS Cash")

data = data.join(installments_payments(num_rows),  how='left', on='SK_ID_CURR')
timer("Done with Installment Payments")

data = data.join(credit_card_balance(num_rows),  how='left', on='SK_ID_CURR')
timer("Done with Credit Card balance")

data = postprocess(data)

data = join_features(data, l1_features)
data = join_features(data, neptune_features)
data = join_features(data, mixture_models)
timer("Done with Meta Features")

train = data[data['TARGET'].notnull()]
test = data[data['TARGET'].isnull()]

target = train.TARGET
train_id = train[["SK_ID_CURR"]]
test_id = test[["SK_ID_CURR"]]
test_id_rank = test[["SK_ID_CURR"]]

train = train.drop(['TARGET','SK_ID_CURR','index'], axis=1)
test = test.drop(['TARGET','SK_ID_CURR','index'], axis=1)
# Out:
# Init..  : 5.42397379875 seconds
# Train samples: 307511, test samples: 48744
# Done with Application Train and Test : 17.7580339909 seconds
# Done with Bureau and Bureau Balance : 41.0392742157 seconds
# Done with Previous Applications : 34.5574519634 seconds
# Done with POS Cash : 23.4558558464 seconds
# Done with Installment Payments : 66.7657830715 seconds
# Done with Credit Card balance : 27.0700159073 seconds
# Done with Meta Features : 57.8450059891 seconds

# %% [markdown]
# # Defining Model

# %%
import xgboost as xgb
def model_tree(x_train, x_test, y_train, y_test, test, meta_train, meta_test,train_index, test_index,fold_id):
    
    dtrain = xgb.DMatrix(x_train.values,label=y_train.values)
    dval = xgb.DMatrix(x_test.values, label=y_test.values)
    params = {
        "objective": "binary:logistic",
        "booster":"gbtree",
        "eval_metric" :"auc",
        "nthread":8,
        "eta":0.05,
        "max_depth":6,
        "min_child_weight":30,
        "gamma":0,
        "subsample": 0.85,
        "colsample_bytree": 0.7,
        "colsample_bylevel": 0.632,
        "alpha": 0,
        "lambda" : 0,
        "seed":1343,
        "tree_method":"gpu_exact",
        "gpu_id":1,
    }
    evallist  = [(dtrain,'train'),(dval,'eval')]
    model = xgb.train(params, dtrain, 5000,evals=evallist, early_stopping_rounds=20, verbose_eval=1)

    meta_train[test_index] = model.predict(dval, ntree_limit=model.best_ntree_limit)
    meta_test.append(model.predict(xgb.DMatrix(test.values), ntree_limit=model.best_ntree_limit))
        
    global fold_roc
    fold_roc.append(roc_auc_score(y_test, meta_train[test_index]))

# %% [markdown]
# # Training Classifier

# %%
meta_train = np.zeros(train.shape[0])
meta_test = []
feature_importance = pd.DataFrame(columns = ["feature","split","gain"])
fold_roc = []

kf = StratifiedKFold(n_splits= 10, shuffle=True, random_state=12323)
for fold_id, (train_index, test_index) in enumerate(kf.split(train, target)):
    x_train, x_test = train.iloc[train_index], train.iloc[test_index]
    y_train, y_test = target[train_index], target[test_index]

    model_tree(x_train, x_test, y_train, y_test, test, meta_train, meta_test,train_index, test_index,fold_id)

test_id["TARGET"] = np.array(meta_test).T.mean(axis=1)
test_id_rank["TARGET"] = pd.DataFrame(np.array(meta_test).T).rank(pct = True).mean(axis=1)
train_id["TARGET"] = meta_train

print "Overall ROC: {},  Mean ROC: {}, STD AUC: {}".format(roc_auc_score(target, meta_train), np.mean(fold_roc), np.std(fold_roc))
# Out:
# [0]	train-auc:0.799938	eval-auc:0.794194
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.802287	eval-auc:0.795115
# [2]	train-auc:0.802852	eval-auc:0.795078
# [3]	train-auc:0.803745	eval-auc:0.795673
# [4]	train-auc:0.804235	eval-auc:0.795979
# [5]	train-auc:0.804505	eval-auc:0.796135
# [6]	train-auc:0.804909	eval-auc:0.796328
# [7]	train-auc:0.805151	eval-auc:0.796214
# [8]	train-auc:0.805272	eval-auc:0.79604
# [9]	train-auc:0.805401	eval-auc:0.795997
# [10]	train-auc:0.805544	eval-auc:0.796004
# [11]	train-auc:0.805595	eval-auc:0.796019
# [12]	train-auc:0.805676	eval-auc:0.796018
# [13]	train-auc:0.805747	eval-auc:0.796085
# [14]	train-auc:0.805817	eval-auc:0.796036
# [15]	train-auc:0.805924	eval-auc:0.796093
# [16]	train-auc:0.806114	eval-auc:0.796097
# [17]	train-auc:0.80626	eval-auc:0.796125
# [18]	train-auc:0.806466	eval-auc:0.796125
# [19]	train-auc:0.806694	eval-auc:0.796114
# [20]	train-auc:0.806851	eval-auc:0.796141
# [21]	train-auc:0.807189	eval-auc:0.796189
# [22]	train-auc:0.807448	eval-auc:0.796225
# [23]	train-auc:0.80762	eval-auc:0.796291
# [24]	train-auc:0.807761	eval-auc:0.796296
# [25]	train-auc:0.807892	eval-auc:0.796334
# [26]	train-auc:0.807999	eval-auc:0.796319
# [27]	train-auc:0.80811	eval-auc:0.796242
# [28]	train-auc:0.808231	eval-auc:0.796244
# [29]	train-auc:0.808449	eval-auc:0.796273
# [30]	train-auc:0.808628	eval-auc:0.796323
# [31]	train-auc:0.808758	eval-auc:0.796341
# [32]	train-auc:0.808885	eval-auc:0.796399
# [33]	train-auc:0.809004	eval-auc:0.796396
# [34]	train-auc:0.809216	eval-auc:0.796358
# [35]	train-auc:0.80937	eval-auc:0.79637
# [36]	train-auc:0.80957	eval-auc:0.796342
# [37]	train-auc:0.809723	eval-auc:0.796326
# [38]	train-auc:0.809889	eval-auc:0.79647
# [39]	train-auc:0.810043	eval-auc:0.796493
# [40]	train-auc:0.810178	eval-auc:0.796496
# [41]	train-auc:0.810302	eval-auc:0.79646
# [42]	train-auc:0.810472	eval-auc:0.796528
# [43]	train-auc:0.810641	eval-auc:0.796565
# [44]	train-auc:0.810782	eval-auc:0.796504
# [45]	train-auc:0.810938	eval-auc:0.79648
# [46]	train-auc:0.811214	eval-auc:0.796495
# [47]	train-auc:0.811424	eval-auc:0.796431
# [48]	train-auc:0.811612	eval-auc:0.796528
# [49]	train-auc:0.811793	eval-auc:0.796628
# [50]	train-auc:0.812025	eval-auc:0.796647
# [51]	train-auc:0.812204	eval-auc:0.79663
# [52]	train-auc:0.812366	eval-auc:0.796672
# [53]	train-auc:0.812501	eval-auc:0.796688
# [54]	train-auc:0.812623	eval-auc:0.796772
# [55]	train-auc:0.812807	eval-auc:0.796803
# [56]	train-auc:0.812936	eval-auc:0.796861
# [57]	train-auc:0.813124	eval-auc:0.796854
# [58]	train-auc:0.813252	eval-auc:0.796864
# [59]	train-auc:0.813431	eval-auc:0.796888
# [60]	train-auc:0.8136	eval-auc:0.796945
# [61]	train-auc:0.813753	eval-auc:0.796934
# [62]	train-auc:0.813918	eval-auc:0.796896
# [63]	train-auc:0.814036	eval-auc:0.796945
# [64]	train-auc:0.814282	eval-auc:0.796986
# [65]	train-auc:0.814475	eval-auc:0.797018
# [66]	train-auc:0.81466	eval-auc:0.797096
# [67]	train-auc:0.814891	eval-auc:0.797193
# [68]	train-auc:0.815085	eval-auc:0.797132
# [69]	train-auc:0.815292	eval-auc:0.797206
# [70]	train-auc:0.815444	eval-auc:0.797289
# [71]	train-auc:0.815632	eval-auc:0.797258
# [72]	train-auc:0.815829	eval-auc:0.797221
# [73]	train-auc:0.816023	eval-auc:0.797198
# [74]	train-auc:0.816197	eval-auc:0.797207
# [75]	train-auc:0.816421	eval-auc:0.797252
# [76]	train-auc:0.816622	eval-auc:0.797328
# [77]	train-auc:0.816818	eval-auc:0.797378
# [78]	train-auc:0.817019	eval-auc:0.797407
# [79]	train-auc:0.817234	eval-auc:0.797413
# [80]	train-auc:0.817409	eval-auc:0.797409
# [81]	train-auc:0.817681	eval-auc:0.797493
# [82]	train-auc:0.81789	eval-auc:0.797572
# [83]	train-auc:0.818104	eval-auc:0.797569
# [84]	train-auc:0.818226	eval-auc:0.797652
# [85]	train-auc:0.818394	eval-auc:0.797675
# [86]	train-auc:0.818638	eval-auc:0.797658
# [87]	train-auc:0.818841	eval-auc:0.797606
# [88]	train-auc:0.819019	eval-auc:0.79763
# [89]	train-auc:0.819205	eval-auc:0.797667
# [90]	train-auc:0.819393	eval-auc:0.797702
# [91]	train-auc:0.819552	eval-auc:0.797718
# [92]	train-auc:0.819694	eval-auc:0.797768
# [93]	train-auc:0.819898	eval-auc:0.797779
# [94]	train-auc:0.820118	eval-auc:0.797758
# [95]	train-auc:0.820384	eval-auc:0.797814
# [96]	train-auc:0.820579	eval-auc:0.797836
# [97]	train-auc:0.820761	eval-auc:0.797838
# [98]	train-auc:0.820931	eval-auc:0.797894
# [99]	train-auc:0.82105	eval-auc:0.797901
# [100]	train-auc:0.82117	eval-auc:0.797884
# [101]	train-auc:0.821335	eval-auc:0.797865
# [102]	train-auc:0.821596	eval-auc:0.797993
# [103]	train-auc:0.821763	eval-auc:0.797998
# [104]	train-auc:0.821939	eval-auc:0.798005
# [105]	train-auc:0.822075	eval-auc:0.798002
# [106]	train-auc:0.822164	eval-auc:0.798001
# [107]	train-auc:0.822286	eval-auc:0.798013
# [108]	train-auc:0.822486	eval-auc:0.798004
# [109]	train-auc:0.822624	eval-auc:0.797997
# [110]	train-auc:0.822804	eval-auc:0.797927
# [111]	train-auc:0.823056	eval-auc:0.79797
# [112]	train-auc:0.823254	eval-auc:0.798004
# [113]	train-auc:0.823358	eval-auc:0.798007
# [114]	train-auc:0.823553	eval-auc:0.797999
# [115]	train-auc:0.823643	eval-auc:0.797934
# [116]	train-auc:0.823775	eval-auc:0.797932
# [117]	train-auc:0.823912	eval-auc:0.797992
# [118]	train-auc:0.824031	eval-auc:0.797987
# [119]	train-auc:0.824179	eval-auc:0.797967
# [120]	train-auc:0.82437	eval-auc:0.797938
# [121]	train-auc:0.824582	eval-auc:0.797928
# [122]	train-auc:0.824732	eval-auc:0.797955
# [123]	train-auc:0.824848	eval-auc:0.797965
# [124]	train-auc:0.824892	eval-auc:0.797925
# [125]	train-auc:0.825068	eval-auc:0.797917
# [126]	train-auc:0.825102	eval-auc:0.797909
# [127]	train-auc:0.825214	eval-auc:0.797898
# Stopping. Best iteration:
# [107]	train-auc:0.822286	eval-auc:0.798013
#
# [0]	train-auc:0.800757	eval-auc:0.788953
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.801451	eval-auc:0.789687
# [2]	train-auc:0.802236	eval-auc:0.790331
# [3]	train-auc:0.802725	eval-auc:0.790887
# [4]	train-auc:0.803421	eval-auc:0.791767
# [5]	train-auc:0.804099	eval-auc:0.79244
# [6]	train-auc:0.80462	eval-auc:0.79239
# [7]	train-auc:0.805036	eval-auc:0.792608
# [8]	train-auc:0.805321	eval-auc:0.79295
# [9]	train-auc:0.805623	eval-auc:0.793093
# [10]	train-auc:0.805659	eval-auc:0.793114
# [11]	train-auc:0.805797	eval-auc:0.793298
# [12]	train-auc:0.805953	eval-auc:0.793419
# [13]	train-auc:0.806232	eval-auc:0.793407
# [14]	train-auc:0.806521	eval-auc:0.793469
# [15]	train-auc:0.806649	eval-auc:0.793449
# [16]	train-auc:0.806797	eval-auc:0.793459
# [17]	train-auc:0.806973	eval-auc:0.79343
# [18]	train-auc:0.807139	eval-auc:0.793446
# [19]	train-auc:0.807284	eval-auc:0.79345
# [20]	train-auc:0.807448	eval-auc:0.793596
# [21]	train-auc:0.807566	eval-auc:0.793648
# [22]	train-auc:0.807805	eval-auc:0.79368
# [23]	train-auc:0.807972	eval-auc:0.793682
# [24]	train-auc:0.808194	eval-auc:0.793683
# [25]	train-auc:0.808378	eval-auc:0.793805
# [26]	train-auc:0.808519	eval-auc:0.793861
# [27]	train-auc:0.808649	eval-auc:0.793876
# [28]	train-auc:0.808821	eval-auc:0.793854
# [29]	train-auc:0.808985	eval-auc:0.793778
# [30]	train-auc:0.809118	eval-auc:0.793736
# [31]	train-auc:0.809257	eval-auc:0.793674
# [32]	train-auc:0.809415	eval-auc:0.793662
# [33]	train-auc:0.809586	eval-auc:0.793746
# [34]	train-auc:0.809732	eval-auc:0.793731
# [35]	train-auc:0.80987	eval-auc:0.79372
# [36]	train-auc:0.810032	eval-auc:0.793761
# [37]	train-auc:0.810178	eval-auc:0.793855
# [38]	train-auc:0.810341	eval-auc:0.793923
# [39]	train-auc:0.810545	eval-auc:0.793911
# [40]	train-auc:0.810752	eval-auc:0.793888
# [41]	train-auc:0.810863	eval-auc:0.793815
# [42]	train-auc:0.810973	eval-auc:0.79377
# [43]	train-auc:0.811167	eval-auc:0.793822
# [44]	train-auc:0.811352	eval-auc:0.793733
# [45]	train-auc:0.81156	eval-auc:0.793706
# [46]	train-auc:0.811732	eval-auc:0.793734
# [47]	train-auc:0.811898	eval-auc:0.793792
# [48]	train-auc:0.812068	eval-auc:0.793769
# [49]	train-auc:0.812239	eval-auc:0.793738
# [50]	train-auc:0.812406	eval-auc:0.79383
# [51]	train-auc:0.812575	eval-auc:0.793927
# [52]	train-auc:0.812727	eval-auc:0.794027
# [53]	train-auc:0.812866	eval-auc:0.793977
# [54]	train-auc:0.813044	eval-auc:0.794086
# [55]	train-auc:0.813291	eval-auc:0.794163
# [56]	train-auc:0.813478	eval-auc:0.794188
# [57]	train-auc:0.813688	eval-auc:0.794129
# [58]	train-auc:0.813918	eval-auc:0.794312
# [59]	train-auc:0.814085	eval-auc:0.794326
# [60]	train-auc:0.814281	eval-auc:0.794432
# [61]	train-auc:0.814494	eval-auc:0.794592
# [62]	train-auc:0.814732	eval-auc:0.79465
# [63]	train-auc:0.814938	eval-auc:0.794644
# [64]	train-auc:0.815148	eval-auc:0.794643
# [65]	train-auc:0.815282	eval-auc:0.794571
# [66]	train-auc:0.815529	eval-auc:0.794607
# [67]	train-auc:0.815678	eval-auc:0.79457
# [68]	train-auc:0.815828	eval-auc:0.79457
# [69]	train-auc:0.816039	eval-auc:0.794554
# [70]	train-auc:0.816186	eval-auc:0.794582
# [71]	train-auc:0.816438	eval-auc:0.794645
# [72]	train-auc:0.816628	eval-auc:0.794636
# [73]	train-auc:0.816768	eval-auc:0.794647
# [74]	train-auc:0.81697	eval-auc:0.794683
# [75]	train-auc:0.817159	eval-auc:0.794767
# [76]	train-auc:0.817308	eval-auc:0.794814
# [77]	train-auc:0.817525	eval-auc:0.794798
# [78]	train-auc:0.817646	eval-auc:0.794872
# [79]	train-auc:0.817894	eval-auc:0.794861
# [80]	train-auc:0.818133	eval-auc:0.794847
# [81]	train-auc:0.818309	eval-auc:0.794793
# [82]	train-auc:0.818458	eval-auc:0.794836
# [83]	train-auc:0.81868	eval-auc:0.794898
# [84]	train-auc:0.81881	eval-auc:0.794904
# [85]	train-auc:0.819031	eval-auc:0.794962
# [86]	train-auc:0.819242	eval-auc:0.794954
# [87]	train-auc:0.819329	eval-auc:0.794974
# [88]	train-auc:0.819488	eval-auc:0.795001
# [89]	train-auc:0.81973	eval-auc:0.79499
# [90]	train-auc:0.819941	eval-auc:0.794996
# [91]	train-auc:0.820097	eval-auc:0.794943
# [92]	train-auc:0.820323	eval-auc:0.795033
# [93]	train-auc:0.820546	eval-auc:0.795068
# [94]	train-auc:0.820718	eval-auc:0.795046
# [95]	train-auc:0.820874	eval-auc:0.795139
# [96]	train-auc:0.821164	eval-auc:0.795129
# [97]	train-auc:0.821382	eval-auc:0.795123
# [98]	train-auc:0.821517	eval-auc:0.795104
# [99]	train-auc:0.821658	eval-auc:0.795121
# [100]	train-auc:0.821819	eval-auc:0.795175
# [101]	train-auc:0.821883	eval-auc:0.795168
# [102]	train-auc:0.822042	eval-auc:0.79513
# [103]	train-auc:0.822235	eval-auc:0.795114
# [104]	train-auc:0.822302	eval-auc:0.795112
# [105]	train-auc:0.822398	eval-auc:0.795135
# [106]	train-auc:0.822547	eval-auc:0.795117
# [107]	train-auc:0.822759	eval-auc:0.795089
# [108]	train-auc:0.822865	eval-auc:0.795084
# [109]	train-auc:0.823007	eval-auc:0.79508
# [110]	train-auc:0.823138	eval-auc:0.795089
# [111]	train-auc:0.823195	eval-auc:0.795074
# [112]	train-auc:0.823441	eval-auc:0.795075
# [113]	train-auc:0.823588	eval-auc:0.795057
# [114]	train-auc:0.823789	eval-auc:0.795099
# [115]	train-auc:0.823965	eval-auc:0.795122
# [116]	train-auc:0.82409	eval-auc:0.795099
# [117]	train-auc:0.82426	eval-auc:0.795129
# [118]	train-auc:0.824414	eval-auc:0.795149
# [119]	train-auc:0.824613	eval-auc:0.795185
# [120]	train-auc:0.824731	eval-auc:0.795218
# [121]	train-auc:0.824782	eval-auc:0.795256
# [122]	train-auc:0.82495	eval-auc:0.795242
# [123]	train-auc:0.825163	eval-auc:0.795297
# [124]	train-auc:0.825335	eval-auc:0.795271
# [125]	train-auc:0.825491	eval-auc:0.795237
# [126]	train-auc:0.825528	eval-auc:0.79522
# [127]	train-auc:0.825678	eval-auc:0.795197
# [128]	train-auc:0.825849	eval-auc:0.795208
# [129]	train-auc:0.825972	eval-auc:0.795174
# [130]	train-auc:0.826066	eval-auc:0.795179
# [131]	train-auc:0.82629	eval-auc:0.795247
# [132]	train-auc:0.826474	eval-auc:0.7953
# [133]	train-auc:0.826552	eval-auc:0.795267
# [134]	train-auc:0.826788	eval-auc:0.795355
# [135]	train-auc:0.826921	eval-auc:0.795332
# [136]	train-auc:0.827115	eval-auc:0.795281
# [137]	train-auc:0.8272	eval-auc:0.79526
# [138]	train-auc:0.827264	eval-auc:0.795255
# [139]	train-auc:0.82746	eval-auc:0.795194
# [140]	train-auc:0.827686	eval-auc:0.795224
# [141]	train-auc:0.827897	eval-auc:0.795264
# [142]	train-auc:0.828055	eval-auc:0.79524
# [143]	train-auc:0.828084	eval-auc:0.795222
# [144]	train-auc:0.828184	eval-auc:0.795218
# [145]	train-auc:0.828271	eval-auc:0.795192
# [146]	train-auc:0.828335	eval-auc:0.795184
# [147]	train-auc:0.828489	eval-auc:0.79518
# [148]	train-auc:0.828694	eval-auc:0.795165
# [149]	train-auc:0.82883	eval-auc:0.795177
# [150]	train-auc:0.828867	eval-auc:0.795166
# [151]	train-auc:0.828903	eval-auc:0.795166
# [152]	train-auc:0.828988	eval-auc:0.7952
# [153]	train-auc:0.828995	eval-auc:0.795198
# [154]	train-auc:0.82905	eval-auc:0.7952
# Stopping. Best iteration:
# [134]	train-auc:0.826788	eval-auc:0.795355
#
# [0]	train-auc:0.799232	eval-auc:0.800372
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.800477	eval-auc:0.801327
# [2]	train-auc:0.801422	eval-auc:0.801815
# [3]	train-auc:0.801827	eval-auc:0.802023
# [4]	train-auc:0.802457	eval-auc:0.802501
# [5]	train-auc:0.802873	eval-auc:0.802848
# [6]	train-auc:0.80337	eval-auc:0.803349
# [7]	train-auc:0.803615	eval-auc:0.803574
# [8]	train-auc:0.803784	eval-auc:0.803741
# [9]	train-auc:0.80391	eval-auc:0.803761
# [10]	train-auc:0.803983	eval-auc:0.803883
# [11]	train-auc:0.804274	eval-auc:0.804116
# [12]	train-auc:0.80441	eval-auc:0.804138
# [13]	train-auc:0.804608	eval-auc:0.804198
# [14]	train-auc:0.80467	eval-auc:0.804178
# [15]	train-auc:0.80483	eval-auc:0.804226
# [16]	train-auc:0.805021	eval-auc:0.80429
# [17]	train-auc:0.805213	eval-auc:0.804218
# [18]	train-auc:0.805418	eval-auc:0.804156
# [19]	train-auc:0.805511	eval-auc:0.804064
# [20]	train-auc:0.805704	eval-auc:0.804104
# [21]	train-auc:0.805912	eval-auc:0.804105
# [22]	train-auc:0.806055	eval-auc:0.804108
# [23]	train-auc:0.806298	eval-auc:0.804175
# [24]	train-auc:0.806441	eval-auc:0.804226
# [25]	train-auc:0.806673	eval-auc:0.804254
# [26]	train-auc:0.80689	eval-auc:0.804315
# [27]	train-auc:0.807058	eval-auc:0.8044
# [28]	train-auc:0.807305	eval-auc:0.804452
# [29]	train-auc:0.807426	eval-auc:0.804527
# [30]	train-auc:0.807637	eval-auc:0.804501
# [31]	train-auc:0.807813	eval-auc:0.804531
# [32]	train-auc:0.808004	eval-auc:0.80451
# [33]	train-auc:0.808145	eval-auc:0.80445
# [34]	train-auc:0.808305	eval-auc:0.804421
# [35]	train-auc:0.808417	eval-auc:0.804455
# [36]	train-auc:0.808533	eval-auc:0.804351
# [37]	train-auc:0.808643	eval-auc:0.804266
# [38]	train-auc:0.80875	eval-auc:0.80417
# [39]	train-auc:0.808928	eval-auc:0.804128
# [40]	train-auc:0.809095	eval-auc:0.804205
# [41]	train-auc:0.809283	eval-auc:0.804235
# [42]	train-auc:0.809407	eval-auc:0.804237
# [43]	train-auc:0.809575	eval-auc:0.804321
# [44]	train-auc:0.809758	eval-auc:0.804374
# [45]	train-auc:0.80996	eval-auc:0.804429
# [46]	train-auc:0.810135	eval-auc:0.804594
# [47]	train-auc:0.81028	eval-auc:0.804637
# [48]	train-auc:0.810445	eval-auc:0.804685
# [49]	train-auc:0.810614	eval-auc:0.804615
# [50]	train-auc:0.810844	eval-auc:0.804639
# [51]	train-auc:0.811016	eval-auc:0.804698
# [52]	train-auc:0.811175	eval-auc:0.804764
# [53]	train-auc:0.811351	eval-auc:0.804827
# [54]	train-auc:0.811567	eval-auc:0.804893
# [55]	train-auc:0.811702	eval-auc:0.804868
# [56]	train-auc:0.811919	eval-auc:0.804925
# [57]	train-auc:0.812104	eval-auc:0.804929
# [58]	train-auc:0.812261	eval-auc:0.804932
# [59]	train-auc:0.812532	eval-auc:0.804949
# [60]	train-auc:0.81275	eval-auc:0.804975
# [61]	train-auc:0.812942	eval-auc:0.805078
# [62]	train-auc:0.813135	eval-auc:0.805172
# [63]	train-auc:0.813336	eval-auc:0.805156
# [64]	train-auc:0.813538	eval-auc:0.805157
# [65]	train-auc:0.813757	eval-auc:0.805098
# [66]	train-auc:0.813951	eval-auc:0.805123
# [67]	train-auc:0.814102	eval-auc:0.805183
# [68]	train-auc:0.814325	eval-auc:0.805223
# [69]	train-auc:0.814492	eval-auc:0.805183
# [70]	train-auc:0.814731	eval-auc:0.805202
# [71]	train-auc:0.814988	eval-auc:0.805297
# [72]	train-auc:0.815141	eval-auc:0.805306
# [73]	train-auc:0.815288	eval-auc:0.80523
# [74]	train-auc:0.815504	eval-auc:0.805229
# [75]	train-auc:0.815716	eval-auc:0.805267
# [76]	train-auc:0.815908	eval-auc:0.805322
# [77]	train-auc:0.816098	eval-auc:0.805326
# [78]	train-auc:0.816242	eval-auc:0.80534
# [79]	train-auc:0.816415	eval-auc:0.805278
# [80]	train-auc:0.816564	eval-auc:0.805269
# [81]	train-auc:0.816862	eval-auc:0.805264
# [82]	train-auc:0.817072	eval-auc:0.805261
# [83]	train-auc:0.81727	eval-auc:0.805348
# [84]	train-auc:0.8174	eval-auc:0.805391
# [85]	train-auc:0.817636	eval-auc:0.805424
# [86]	train-auc:0.817773	eval-auc:0.805459
# [87]	train-auc:0.817942	eval-auc:0.805488
# [88]	train-auc:0.818181	eval-auc:0.805394
# [89]	train-auc:0.818329	eval-auc:0.805424
# [90]	train-auc:0.818538	eval-auc:0.805524
# [91]	train-auc:0.818739	eval-auc:0.805515
# [92]	train-auc:0.818917	eval-auc:0.80553
# [93]	train-auc:0.81909	eval-auc:0.805599
# [94]	train-auc:0.819236	eval-auc:0.805546
# [95]	train-auc:0.819453	eval-auc:0.805556
# [96]	train-auc:0.819664	eval-auc:0.805545
# [97]	train-auc:0.819756	eval-auc:0.80557
# [98]	train-auc:0.819896	eval-auc:0.805543
# [99]	train-auc:0.820153	eval-auc:0.805542
# [100]	train-auc:0.820359	eval-auc:0.805575
# [101]	train-auc:0.820546	eval-auc:0.805595
# [102]	train-auc:0.820716	eval-auc:0.805594
# [103]	train-auc:0.820851	eval-auc:0.805644
# [104]	train-auc:0.821079	eval-auc:0.805602
# [105]	train-auc:0.821225	eval-auc:0.805622
# [106]	train-auc:0.821437	eval-auc:0.805617
# [107]	train-auc:0.821641	eval-auc:0.805629
# [108]	train-auc:0.821723	eval-auc:0.805649
# [109]	train-auc:0.821901	eval-auc:0.805621
# [110]	train-auc:0.822131	eval-auc:0.805532
# [111]	train-auc:0.822399	eval-auc:0.80552
# [112]	train-auc:0.822529	eval-auc:0.805483
# [113]	train-auc:0.822682	eval-auc:0.805469
# [114]	train-auc:0.822852	eval-auc:0.805452
# [115]	train-auc:0.823069	eval-auc:0.805485
# [116]	train-auc:0.823316	eval-auc:0.805489
# [117]	train-auc:0.823523	eval-auc:0.805486
# [118]	train-auc:0.823692	eval-auc:0.805449
# [119]	train-auc:0.8238	eval-auc:0.805505
# [120]	train-auc:0.823891	eval-auc:0.805489
# [121]	train-auc:0.824071	eval-auc:0.805478
# [122]	train-auc:0.824229	eval-auc:0.805412
# [123]	train-auc:0.824295	eval-auc:0.805405
# [124]	train-auc:0.824469	eval-auc:0.80542
# [125]	train-auc:0.824543	eval-auc:0.805415
# [126]	train-auc:0.824648	eval-auc:0.8054
# [127]	train-auc:0.82471	eval-auc:0.805394
# [128]	train-auc:0.824944	eval-auc:0.805452
# Stopping. Best iteration:
# [108]	train-auc:0.821723	eval-auc:0.805649
#
# [0]	train-auc:0.800659	eval-auc:0.790333
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.801758	eval-auc:0.791272
# [2]	train-auc:0.802719	eval-auc:0.792021
# [3]	train-auc:0.803732	eval-auc:0.792586
# [4]	train-auc:0.804186	eval-auc:0.792409
# [5]	train-auc:0.804361	eval-auc:0.792327
# [6]	train-auc:0.804619	eval-auc:0.792425
# [7]	train-auc:0.80499	eval-auc:0.792659
# [8]	train-auc:0.805103	eval-auc:0.792666
# [9]	train-auc:0.805234	eval-auc:0.792825
# [10]	train-auc:0.805446	eval-auc:0.792885
# [11]	train-auc:0.805781	eval-auc:0.793002
# [12]	train-auc:0.80592	eval-auc:0.793086
# [13]	train-auc:0.806091	eval-auc:0.793042
# [14]	train-auc:0.806251	eval-auc:0.792939
# [15]	train-auc:0.806563	eval-auc:0.793153
# [16]	train-auc:0.806772	eval-auc:0.793133
# [17]	train-auc:0.806896	eval-auc:0.793131
# [18]	train-auc:0.807104	eval-auc:0.793253
# [19]	train-auc:0.807248	eval-auc:0.793323
# [20]	train-auc:0.807392	eval-auc:0.793381
# [21]	train-auc:0.807518	eval-auc:0.79356
# [22]	train-auc:0.807696	eval-auc:0.793485
# [23]	train-auc:0.807898	eval-auc:0.793406
# [24]	train-auc:0.808027	eval-auc:0.793412
# [25]	train-auc:0.808236	eval-auc:0.793395
# [26]	train-auc:0.808432	eval-auc:0.793298
# [27]	train-auc:0.808569	eval-auc:0.793298
# [28]	train-auc:0.808719	eval-auc:0.793364
# [29]	train-auc:0.808897	eval-auc:0.793346
# [30]	train-auc:0.809036	eval-auc:0.793356
# [31]	train-auc:0.809246	eval-auc:0.793392
# [32]	train-auc:0.809387	eval-auc:0.79342
# [33]	train-auc:0.809565	eval-auc:0.793556
# [34]	train-auc:0.809698	eval-auc:0.793563
# [35]	train-auc:0.809812	eval-auc:0.793534
# [36]	train-auc:0.809922	eval-auc:0.79351
# [37]	train-auc:0.810121	eval-auc:0.79356
# [38]	train-auc:0.810229	eval-auc:0.793622
# [39]	train-auc:0.810391	eval-auc:0.793569
# [40]	train-auc:0.810584	eval-auc:0.793608
# [41]	train-auc:0.810753	eval-auc:0.793584
# [42]	train-auc:0.810948	eval-auc:0.793551
# [43]	train-auc:0.811149	eval-auc:0.79351
# [44]	train-auc:0.811311	eval-auc:0.793447
# [45]	train-auc:0.811474	eval-auc:0.793389
# [46]	train-auc:0.81171	eval-auc:0.793389
# [47]	train-auc:0.81185	eval-auc:0.793318
# [48]	train-auc:0.812022	eval-auc:0.793365
# [49]	train-auc:0.81218	eval-auc:0.793274
# [50]	train-auc:0.812326	eval-auc:0.793237
# [51]	train-auc:0.812489	eval-auc:0.793196
# [52]	train-auc:0.812618	eval-auc:0.793175
# [53]	train-auc:0.812774	eval-auc:0.793091
# [54]	train-auc:0.812913	eval-auc:0.793091
# [55]	train-auc:0.813103	eval-auc:0.793108
# [56]	train-auc:0.813274	eval-auc:0.793073
# [57]	train-auc:0.813535	eval-auc:0.793119
# [58]	train-auc:0.813677	eval-auc:0.79324
# Stopping. Best iteration:
# [38]	train-auc:0.810229	eval-auc:0.793622
#
# [0]	train-auc:0.799522	eval-auc:0.802482
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.801185	eval-auc:0.803219
# [2]	train-auc:0.80151	eval-auc:0.803705
# [3]	train-auc:0.802145	eval-auc:0.803587
# [4]	train-auc:0.803049	eval-auc:0.804151
# [5]	train-auc:0.803164	eval-auc:0.804007
# [6]	train-auc:0.80362	eval-auc:0.804239
# [7]	train-auc:0.804066	eval-auc:0.804452
# [8]	train-auc:0.804242	eval-auc:0.804608
# [9]	train-auc:0.804362	eval-auc:0.804659
# [10]	train-auc:0.804436	eval-auc:0.804653
# [11]	train-auc:0.804671	eval-auc:0.804615
# [12]	train-auc:0.804759	eval-auc:0.804591
# [13]	train-auc:0.80501	eval-auc:0.804756
# [14]	train-auc:0.805163	eval-auc:0.804932
# [15]	train-auc:0.805305	eval-auc:0.804866
# [16]	train-auc:0.80552	eval-auc:0.804791
# [17]	train-auc:0.805634	eval-auc:0.804848
# [18]	train-auc:0.805861	eval-auc:0.804945
# [19]	train-auc:0.806094	eval-auc:0.804961
# [20]	train-auc:0.806273	eval-auc:0.805037
# [21]	train-auc:0.806475	eval-auc:0.805189
# [22]	train-auc:0.806715	eval-auc:0.805282
# [23]	train-auc:0.806927	eval-auc:0.805339
# [24]	train-auc:0.807102	eval-auc:0.805351
# [25]	train-auc:0.807306	eval-auc:0.80543
# [26]	train-auc:0.807396	eval-auc:0.805464
# [27]	train-auc:0.807491	eval-auc:0.805516
# [28]	train-auc:0.807594	eval-auc:0.805531
# [29]	train-auc:0.807774	eval-auc:0.805588
# [30]	train-auc:0.807902	eval-auc:0.805581
# [31]	train-auc:0.808053	eval-auc:0.805576
# [32]	train-auc:0.808195	eval-auc:0.805602
# [33]	train-auc:0.808429	eval-auc:0.805602
# [34]	train-auc:0.808646	eval-auc:0.805702
# [35]	train-auc:0.808782	eval-auc:0.805734
# [36]	train-auc:0.808914	eval-auc:0.805771
# [37]	train-auc:0.809074	eval-auc:0.805717
# [38]	train-auc:0.809234	eval-auc:0.80581
# [39]	train-auc:0.809375	eval-auc:0.805829
# [40]	train-auc:0.809517	eval-auc:0.805757
# [41]	train-auc:0.809652	eval-auc:0.805702
# [42]	train-auc:0.809805	eval-auc:0.805693
# [43]	train-auc:0.809963	eval-auc:0.805753
# [44]	train-auc:0.810122	eval-auc:0.805827
# [45]	train-auc:0.810229	eval-auc:0.805897
# [46]	train-auc:0.810379	eval-auc:0.805928
# [47]	train-auc:0.810567	eval-auc:0.805953
# [48]	train-auc:0.810705	eval-auc:0.806031
# [49]	train-auc:0.81085	eval-auc:0.806088
# [50]	train-auc:0.81106	eval-auc:0.806056
# [51]	train-auc:0.81122	eval-auc:0.806019
# [52]	train-auc:0.811391	eval-auc:0.806153
# [53]	train-auc:0.811555	eval-auc:0.806122
# [54]	train-auc:0.811744	eval-auc:0.806128
# [55]	train-auc:0.811885	eval-auc:0.806171
# [56]	train-auc:0.812061	eval-auc:0.806091
# [57]	train-auc:0.812291	eval-auc:0.806068
# [58]	train-auc:0.812435	eval-auc:0.806077
# [59]	train-auc:0.812655	eval-auc:0.806173
# [60]	train-auc:0.812835	eval-auc:0.806224
# [61]	train-auc:0.813044	eval-auc:0.806222
# [62]	train-auc:0.813242	eval-auc:0.80624
# [63]	train-auc:0.81347	eval-auc:0.806131
# [64]	train-auc:0.813655	eval-auc:0.806208
# [65]	train-auc:0.813882	eval-auc:0.806276
# [66]	train-auc:0.814067	eval-auc:0.806331
# [67]	train-auc:0.814218	eval-auc:0.806313
# [68]	train-auc:0.814389	eval-auc:0.806371
# [69]	train-auc:0.814624	eval-auc:0.806394
# [70]	train-auc:0.814787	eval-auc:0.806397
# [71]	train-auc:0.81506	eval-auc:0.806401
# [72]	train-auc:0.815159	eval-auc:0.806407
# [73]	train-auc:0.815354	eval-auc:0.806444
# [74]	train-auc:0.815562	eval-auc:0.806482
# [75]	train-auc:0.815744	eval-auc:0.806487
# [76]	train-auc:0.815958	eval-auc:0.806516
# [77]	train-auc:0.816159	eval-auc:0.806581
# [78]	train-auc:0.816363	eval-auc:0.806591
# [79]	train-auc:0.816481	eval-auc:0.806576
# [80]	train-auc:0.816727	eval-auc:0.80673
# [81]	train-auc:0.817007	eval-auc:0.806672
# [82]	train-auc:0.817219	eval-auc:0.806627
# [83]	train-auc:0.817444	eval-auc:0.806687
# [84]	train-auc:0.81767	eval-auc:0.80669
# [85]	train-auc:0.817854	eval-auc:0.806699
# [86]	train-auc:0.817998	eval-auc:0.806643
# [87]	train-auc:0.81826	eval-auc:0.806665
# [88]	train-auc:0.818495	eval-auc:0.806638
# [89]	train-auc:0.81868	eval-auc:0.806602
# [90]	train-auc:0.818885	eval-auc:0.806699
# [91]	train-auc:0.819137	eval-auc:0.80668
# [92]	train-auc:0.81934	eval-auc:0.806642
# [93]	train-auc:0.819576	eval-auc:0.806654
# [94]	train-auc:0.819792	eval-auc:0.806656
# [95]	train-auc:0.819972	eval-auc:0.806701
# [96]	train-auc:0.820187	eval-auc:0.806688
# [97]	train-auc:0.820452	eval-auc:0.806732
# [98]	train-auc:0.820658	eval-auc:0.8067
# [99]	train-auc:0.820875	eval-auc:0.806768
# [100]	train-auc:0.821078	eval-auc:0.806748
# [101]	train-auc:0.821285	eval-auc:0.806687
# [102]	train-auc:0.82146	eval-auc:0.806646
# [103]	train-auc:0.821677	eval-auc:0.806679
# [104]	train-auc:0.821868	eval-auc:0.806674
# [105]	train-auc:0.822072	eval-auc:0.806737
# [106]	train-auc:0.822201	eval-auc:0.806747
# [107]	train-auc:0.822344	eval-auc:0.806725
# [108]	train-auc:0.822478	eval-auc:0.806759
# [109]	train-auc:0.822583	eval-auc:0.806735
# [110]	train-auc:0.82277	eval-auc:0.806743
# [111]	train-auc:0.822851	eval-auc:0.806749
# [112]	train-auc:0.822991	eval-auc:0.806779
# [113]	train-auc:0.823159	eval-auc:0.806765
# [114]	train-auc:0.823307	eval-auc:0.8067
# [115]	train-auc:0.823432	eval-auc:0.806713
# [116]	train-auc:0.823601	eval-auc:0.806707
# [117]	train-auc:0.823772	eval-auc:0.806717
# [118]	train-auc:0.823937	eval-auc:0.806728
# [119]	train-auc:0.824097	eval-auc:0.806735
# [120]	train-auc:0.824266	eval-auc:0.806744
# [121]	train-auc:0.824439	eval-auc:0.806707
# [122]	train-auc:0.82463	eval-auc:0.806715
# [123]	train-auc:0.824758	eval-auc:0.806739
# [124]	train-auc:0.824924	eval-auc:0.806769
# [125]	train-auc:0.825017	eval-auc:0.806743
# [126]	train-auc:0.82519	eval-auc:0.806704
# [127]	train-auc:0.825405	eval-auc:0.806662
# [128]	train-auc:0.825546	eval-auc:0.806677
# [129]	train-auc:0.825599	eval-auc:0.806674
# [130]	train-auc:0.825664	eval-auc:0.806661
# [131]	train-auc:0.825712	eval-auc:0.806665
# [132]	train-auc:0.82588	eval-auc:0.80665
# Stopping. Best iteration:
# [112]	train-auc:0.822991	eval-auc:0.806779
#
# [0]	train-auc:0.799605	eval-auc:0.791493
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.800882	eval-auc:0.792407
# [2]	train-auc:0.802114	eval-auc:0.792929
# [3]	train-auc:0.803176	eval-auc:0.79427
# [4]	train-auc:0.803619	eval-auc:0.794363
# [5]	train-auc:0.804358	eval-auc:0.794696
# [6]	train-auc:0.804625	eval-auc:0.794789
# [7]	train-auc:0.804733	eval-auc:0.794957
# [8]	train-auc:0.805113	eval-auc:0.795118
# [9]	train-auc:0.805283	eval-auc:0.795286
# [10]	train-auc:0.8055	eval-auc:0.795386
# [11]	train-auc:0.805541	eval-auc:0.795297
# [12]	train-auc:0.805665	eval-auc:0.795493
# [13]	train-auc:0.805855	eval-auc:0.795598
# [14]	train-auc:0.806026	eval-auc:0.795653
# [15]	train-auc:0.806265	eval-auc:0.795718
# [16]	train-auc:0.806427	eval-auc:0.795631
# [17]	train-auc:0.806555	eval-auc:0.795675
# [18]	train-auc:0.806655	eval-auc:0.795741
# [19]	train-auc:0.806784	eval-auc:0.795787
# [20]	train-auc:0.8069	eval-auc:0.795795
# [21]	train-auc:0.807046	eval-auc:0.795729
# [22]	train-auc:0.807154	eval-auc:0.795679
# [23]	train-auc:0.807393	eval-auc:0.795813
# [24]	train-auc:0.807562	eval-auc:0.795793
# [25]	train-auc:0.8078	eval-auc:0.795816
# [26]	train-auc:0.807982	eval-auc:0.795872
# [27]	train-auc:0.808141	eval-auc:0.79584
# [28]	train-auc:0.808268	eval-auc:0.795888
# [29]	train-auc:0.808477	eval-auc:0.795867
# [30]	train-auc:0.808647	eval-auc:0.795843
# [31]	train-auc:0.808787	eval-auc:0.795824
# [32]	train-auc:0.808953	eval-auc:0.79579
# [33]	train-auc:0.809076	eval-auc:0.795696
# [34]	train-auc:0.809238	eval-auc:0.79578
# [35]	train-auc:0.809402	eval-auc:0.795813
# [36]	train-auc:0.80959	eval-auc:0.795739
# [37]	train-auc:0.809724	eval-auc:0.795723
# [38]	train-auc:0.809893	eval-auc:0.795741
# [39]	train-auc:0.810048	eval-auc:0.79576
# [40]	train-auc:0.810182	eval-auc:0.79574
# [41]	train-auc:0.810318	eval-auc:0.79567
# [42]	train-auc:0.810426	eval-auc:0.795682
# [43]	train-auc:0.810708	eval-auc:0.795747
# [44]	train-auc:0.810911	eval-auc:0.79572
# [45]	train-auc:0.811035	eval-auc:0.795723
# [46]	train-auc:0.811207	eval-auc:0.795725
# [47]	train-auc:0.811361	eval-auc:0.79571
# [48]	train-auc:0.81151	eval-auc:0.795723
# Stopping. Best iteration:
# [28]	train-auc:0.808268	eval-auc:0.795888
#
# [0]	train-auc:0.799264	eval-auc:0.799829
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.801364	eval-auc:0.800789
# [2]	train-auc:0.801698	eval-auc:0.800654
# [3]	train-auc:0.802337	eval-auc:0.800932
# [4]	train-auc:0.802608	eval-auc:0.801107
# [5]	train-auc:0.803313	eval-auc:0.801337
# [6]	train-auc:0.803679	eval-auc:0.801549
# [7]	train-auc:0.803921	eval-auc:0.801782
# [8]	train-auc:0.804155	eval-auc:0.801623
# [9]	train-auc:0.804367	eval-auc:0.801629
# [10]	train-auc:0.804438	eval-auc:0.801563
# [11]	train-auc:0.804498	eval-auc:0.801578
# [12]	train-auc:0.804693	eval-auc:0.80174
# [13]	train-auc:0.804822	eval-auc:0.801771
# [14]	train-auc:0.804917	eval-auc:0.801807
# [15]	train-auc:0.805033	eval-auc:0.801819
# [16]	train-auc:0.805343	eval-auc:0.80195
# [17]	train-auc:0.805493	eval-auc:0.801973
# [18]	train-auc:0.805588	eval-auc:0.802016
# [19]	train-auc:0.805818	eval-auc:0.802024
# [20]	train-auc:0.806058	eval-auc:0.802203
# [21]	train-auc:0.806217	eval-auc:0.802092
# [22]	train-auc:0.80645	eval-auc:0.802164
# [23]	train-auc:0.80666	eval-auc:0.802321
# [24]	train-auc:0.806811	eval-auc:0.802415
# [25]	train-auc:0.806957	eval-auc:0.802449
# [26]	train-auc:0.807082	eval-auc:0.802431
# [27]	train-auc:0.807248	eval-auc:0.80239
# [28]	train-auc:0.807384	eval-auc:0.802404
# [29]	train-auc:0.807525	eval-auc:0.802391
# [30]	train-auc:0.807658	eval-auc:0.802322
# [31]	train-auc:0.807817	eval-auc:0.802333
# [32]	train-auc:0.807992	eval-auc:0.802408
# [33]	train-auc:0.80814	eval-auc:0.802384
# [34]	train-auc:0.80826	eval-auc:0.802462
# [35]	train-auc:0.808481	eval-auc:0.802474
# [36]	train-auc:0.808616	eval-auc:0.802491
# [37]	train-auc:0.808761	eval-auc:0.802564
# [38]	train-auc:0.808913	eval-auc:0.802571
# [39]	train-auc:0.809042	eval-auc:0.802551
# [40]	train-auc:0.809199	eval-auc:0.802557
# [41]	train-auc:0.809362	eval-auc:0.802537
# [42]	train-auc:0.809513	eval-auc:0.802374
# [43]	train-auc:0.809684	eval-auc:0.802416
# [44]	train-auc:0.809822	eval-auc:0.802507
# [45]	train-auc:0.810086	eval-auc:0.802555
# [46]	train-auc:0.810274	eval-auc:0.802584
# [47]	train-auc:0.810508	eval-auc:0.802642
# [48]	train-auc:0.810656	eval-auc:0.802667
# [49]	train-auc:0.810782	eval-auc:0.802769
# [50]	train-auc:0.810923	eval-auc:0.802852
# [51]	train-auc:0.81106	eval-auc:0.802893
# [52]	train-auc:0.81124	eval-auc:0.802939
# [53]	train-auc:0.811498	eval-auc:0.802979
# [54]	train-auc:0.811706	eval-auc:0.803052
# [55]	train-auc:0.811883	eval-auc:0.803056
# [56]	train-auc:0.812044	eval-auc:0.803006
# [57]	train-auc:0.812234	eval-auc:0.803172
# [58]	train-auc:0.812399	eval-auc:0.803192
# [59]	train-auc:0.81262	eval-auc:0.803186
# [60]	train-auc:0.812871	eval-auc:0.803194
# [61]	train-auc:0.813068	eval-auc:0.803226
# [62]	train-auc:0.81331	eval-auc:0.803274
# [63]	train-auc:0.813505	eval-auc:0.803259
# [64]	train-auc:0.813698	eval-auc:0.803328
# [65]	train-auc:0.813898	eval-auc:0.803383
# [66]	train-auc:0.814068	eval-auc:0.803416
# [67]	train-auc:0.81425	eval-auc:0.803399
# [68]	train-auc:0.81447	eval-auc:0.803318
# [69]	train-auc:0.814648	eval-auc:0.803261
# [70]	train-auc:0.81484	eval-auc:0.803282
# [71]	train-auc:0.814961	eval-auc:0.803285
# [72]	train-auc:0.815129	eval-auc:0.80326
# [73]	train-auc:0.81531	eval-auc:0.803324
# [74]	train-auc:0.815514	eval-auc:0.80332
# [75]	train-auc:0.815651	eval-auc:0.803283
# [76]	train-auc:0.815863	eval-auc:0.803351
# [77]	train-auc:0.816138	eval-auc:0.80344
# [78]	train-auc:0.816249	eval-auc:0.803479
# [79]	train-auc:0.816509	eval-auc:0.803479
# [80]	train-auc:0.816679	eval-auc:0.803471
# [81]	train-auc:0.816909	eval-auc:0.803509
# [82]	train-auc:0.817082	eval-auc:0.80345
# [83]	train-auc:0.81729	eval-auc:0.803471
# [84]	train-auc:0.817542	eval-auc:0.803479
# [85]	train-auc:0.817766	eval-auc:0.8035
# [86]	train-auc:0.817933	eval-auc:0.803499
# [87]	train-auc:0.818147	eval-auc:0.803583
# [88]	train-auc:0.818356	eval-auc:0.803558
# [89]	train-auc:0.818631	eval-auc:0.803547
# [90]	train-auc:0.818805	eval-auc:0.803568
# [91]	train-auc:0.819036	eval-auc:0.803548
# [92]	train-auc:0.819171	eval-auc:0.803562
# [93]	train-auc:0.819333	eval-auc:0.80356
# [94]	train-auc:0.819584	eval-auc:0.80351
# [95]	train-auc:0.819702	eval-auc:0.80351
# [96]	train-auc:0.819935	eval-auc:0.803403
# [97]	train-auc:0.820178	eval-auc:0.803359
# [98]	train-auc:0.82036	eval-auc:0.803296
# [99]	train-auc:0.82057	eval-auc:0.803292
# [100]	train-auc:0.820802	eval-auc:0.803259
# [101]	train-auc:0.821033	eval-auc:0.803234
# [102]	train-auc:0.821268	eval-auc:0.80326
# [103]	train-auc:0.821408	eval-auc:0.803189
# [104]	train-auc:0.82158	eval-auc:0.803179
# [105]	train-auc:0.821706	eval-auc:0.803177
# [106]	train-auc:0.821871	eval-auc:0.803217
# [107]	train-auc:0.822067	eval-auc:0.8032
# Stopping. Best iteration:
# [87]	train-auc:0.818147	eval-auc:0.803583
#
# [0]	train-auc:0.799344	eval-auc:0.796287
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.801495	eval-auc:0.798101
# [2]	train-auc:0.802086	eval-auc:0.798786
# [3]	train-auc:0.80292	eval-auc:0.799217
# [4]	train-auc:0.803478	eval-auc:0.7996
# [5]	train-auc:0.803824	eval-auc:0.799921
# [6]	train-auc:0.804206	eval-auc:0.800141
# [7]	train-auc:0.804305	eval-auc:0.800236
# [8]	train-auc:0.804542	eval-auc:0.800378
# [9]	train-auc:0.804678	eval-auc:0.800315
# [10]	train-auc:0.80487	eval-auc:0.800253
# [11]	train-auc:0.804939	eval-auc:0.800318
# [12]	train-auc:0.805196	eval-auc:0.800306
# [13]	train-auc:0.805455	eval-auc:0.800332
# [14]	train-auc:0.805645	eval-auc:0.800392
# [15]	train-auc:0.805824	eval-auc:0.800365
# [16]	train-auc:0.806018	eval-auc:0.800311
# [17]	train-auc:0.806186	eval-auc:0.80021
# [18]	train-auc:0.806285	eval-auc:0.800192
# [19]	train-auc:0.806453	eval-auc:0.800248
# [20]	train-auc:0.806694	eval-auc:0.800298
# [21]	train-auc:0.806943	eval-auc:0.800363
# [22]	train-auc:0.807175	eval-auc:0.800375
# [23]	train-auc:0.807385	eval-auc:0.800355
# [24]	train-auc:0.807542	eval-auc:0.800377
# [25]	train-auc:0.807685	eval-auc:0.800331
# [26]	train-auc:0.807893	eval-auc:0.80028
# [27]	train-auc:0.808107	eval-auc:0.800219
# [28]	train-auc:0.808302	eval-auc:0.800172
# [29]	train-auc:0.808469	eval-auc:0.800133
# [30]	train-auc:0.808642	eval-auc:0.800155
# [31]	train-auc:0.808838	eval-auc:0.80013
# [32]	train-auc:0.808964	eval-auc:0.800095
# [33]	train-auc:0.809088	eval-auc:0.800211
# [34]	train-auc:0.809234	eval-auc:0.800294
# Stopping. Best iteration:
# [14]	train-auc:0.805645	eval-auc:0.800392
#
# [0]	train-auc:0.799564	eval-auc:0.794396
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.800792	eval-auc:0.79526
# [2]	train-auc:0.802503	eval-auc:0.796606
# [3]	train-auc:0.802954	eval-auc:0.796863
# [4]	train-auc:0.803451	eval-auc:0.797218
# [5]	train-auc:0.803707	eval-auc:0.797129
# [6]	train-auc:0.804185	eval-auc:0.797185
# [7]	train-auc:0.804538	eval-auc:0.797218
# [8]	train-auc:0.804791	eval-auc:0.797131
# [9]	train-auc:0.80505	eval-auc:0.79709
# [10]	train-auc:0.805129	eval-auc:0.797179
# [11]	train-auc:0.805268	eval-auc:0.797004
# [12]	train-auc:0.805402	eval-auc:0.797013
# [13]	train-auc:0.805684	eval-auc:0.797339
# [14]	train-auc:0.805928	eval-auc:0.797589
# [15]	train-auc:0.806145	eval-auc:0.797723
# [16]	train-auc:0.806251	eval-auc:0.797702
# [17]	train-auc:0.806388	eval-auc:0.797711
# [18]	train-auc:0.806625	eval-auc:0.797694
# [19]	train-auc:0.806787	eval-auc:0.79776
# [20]	train-auc:0.806888	eval-auc:0.797696
# [21]	train-auc:0.807087	eval-auc:0.797725
# [22]	train-auc:0.807185	eval-auc:0.797689
# [23]	train-auc:0.807453	eval-auc:0.798012
# [24]	train-auc:0.80763	eval-auc:0.798204
# [25]	train-auc:0.807846	eval-auc:0.798322
# [26]	train-auc:0.807997	eval-auc:0.798513
# [27]	train-auc:0.808151	eval-auc:0.798593
# [28]	train-auc:0.808251	eval-auc:0.798621
# [29]	train-auc:0.808418	eval-auc:0.798616
# [30]	train-auc:0.808626	eval-auc:0.798589
# [31]	train-auc:0.808727	eval-auc:0.798616
# [32]	train-auc:0.808867	eval-auc:0.798523
# [33]	train-auc:0.808989	eval-auc:0.798577
# [34]	train-auc:0.809116	eval-auc:0.798559
# [35]	train-auc:0.809226	eval-auc:0.798628
# [36]	train-auc:0.809342	eval-auc:0.798632
# [37]	train-auc:0.809547	eval-auc:0.798794
# [38]	train-auc:0.809652	eval-auc:0.798757
# [39]	train-auc:0.80987	eval-auc:0.798752
# [40]	train-auc:0.810001	eval-auc:0.798841
# [41]	train-auc:0.810146	eval-auc:0.798923
# [42]	train-auc:0.810329	eval-auc:0.798961
# [43]	train-auc:0.810473	eval-auc:0.79898
# [44]	train-auc:0.810636	eval-auc:0.798999
# [45]	train-auc:0.810749	eval-auc:0.799059
# [46]	train-auc:0.810992	eval-auc:0.799018
# [47]	train-auc:0.811199	eval-auc:0.799068
# [48]	train-auc:0.811352	eval-auc:0.799024
# [49]	train-auc:0.81156	eval-auc:0.798999
# [50]	train-auc:0.811775	eval-auc:0.798999
# [51]	train-auc:0.811994	eval-auc:0.79902
# [52]	train-auc:0.812163	eval-auc:0.798998
# [53]	train-auc:0.812301	eval-auc:0.799024
# [54]	train-auc:0.812489	eval-auc:0.799062
# [55]	train-auc:0.812646	eval-auc:0.798985
# [56]	train-auc:0.812834	eval-auc:0.799048
# [57]	train-auc:0.813082	eval-auc:0.799143
# [58]	train-auc:0.813291	eval-auc:0.799155
# [59]	train-auc:0.813472	eval-auc:0.799265
# [60]	train-auc:0.813641	eval-auc:0.799319
# [61]	train-auc:0.813793	eval-auc:0.799397
# [62]	train-auc:0.814007	eval-auc:0.7994
# [63]	train-auc:0.814235	eval-auc:0.799376
# [64]	train-auc:0.814426	eval-auc:0.799403
# [65]	train-auc:0.814623	eval-auc:0.799346
# [66]	train-auc:0.814784	eval-auc:0.799347
# [67]	train-auc:0.81498	eval-auc:0.799286
# [68]	train-auc:0.815172	eval-auc:0.79937
# [69]	train-auc:0.815414	eval-auc:0.799425
# [70]	train-auc:0.815558	eval-auc:0.799486
# [71]	train-auc:0.815807	eval-auc:0.799517
# [72]	train-auc:0.816058	eval-auc:0.799579
# [73]	train-auc:0.816282	eval-auc:0.799624
# [74]	train-auc:0.816504	eval-auc:0.799611
# [75]	train-auc:0.816766	eval-auc:0.799615
# [76]	train-auc:0.816859	eval-auc:0.799698
# [77]	train-auc:0.817107	eval-auc:0.799693
# [78]	train-auc:0.817335	eval-auc:0.799695
# [79]	train-auc:0.817498	eval-auc:0.799709
# [80]	train-auc:0.817676	eval-auc:0.799689
# [81]	train-auc:0.817812	eval-auc:0.799744
# [82]	train-auc:0.818036	eval-auc:0.799794
# [83]	train-auc:0.818221	eval-auc:0.79979
# [84]	train-auc:0.81844	eval-auc:0.799793
# [85]	train-auc:0.81857	eval-auc:0.799799
# [86]	train-auc:0.81877	eval-auc:0.799813
# [87]	train-auc:0.819004	eval-auc:0.799869
# [88]	train-auc:0.819227	eval-auc:0.799789
# [89]	train-auc:0.819397	eval-auc:0.799916
# [90]	train-auc:0.819561	eval-auc:0.7999
# [91]	train-auc:0.81969	eval-auc:0.79981
# [92]	train-auc:0.819891	eval-auc:0.799829
# [93]	train-auc:0.820156	eval-auc:0.799858
# [94]	train-auc:0.820392	eval-auc:0.799933
# [95]	train-auc:0.820612	eval-auc:0.800001
# [96]	train-auc:0.820791	eval-auc:0.799973
# [97]	train-auc:0.820954	eval-auc:0.799958
# [98]	train-auc:0.821218	eval-auc:0.800028
# [99]	train-auc:0.821409	eval-auc:0.800023
# [100]	train-auc:0.821494	eval-auc:0.800017
# [101]	train-auc:0.821701	eval-auc:0.800031
# [102]	train-auc:0.8219	eval-auc:0.800026
# [103]	train-auc:0.822106	eval-auc:0.800002
# [104]	train-auc:0.822339	eval-auc:0.800023
# [105]	train-auc:0.822454	eval-auc:0.800025
# [106]	train-auc:0.822636	eval-auc:0.799976
# [107]	train-auc:0.822819	eval-auc:0.799946
# [108]	train-auc:0.822963	eval-auc:0.799962
# [109]	train-auc:0.823189	eval-auc:0.799916
# [110]	train-auc:0.823304	eval-auc:0.799876
# [111]	train-auc:0.823447	eval-auc:0.799887
# [112]	train-auc:0.82372	eval-auc:0.799845
# [113]	train-auc:0.823859	eval-auc:0.799841
# [114]	train-auc:0.824024	eval-auc:0.799855
# [115]	train-auc:0.824137	eval-auc:0.799858
# [116]	train-auc:0.824328	eval-auc:0.799813
# [117]	train-auc:0.824402	eval-auc:0.799837
# [118]	train-auc:0.824682	eval-auc:0.799738
# [119]	train-auc:0.824946	eval-auc:0.799707
# [120]	train-auc:0.825197	eval-auc:0.799736
# [121]	train-auc:0.825391	eval-auc:0.799681
# Stopping. Best iteration:
# [101]	train-auc:0.821701	eval-auc:0.800031
#
# [0]	train-auc:0.799753	eval-auc:0.795239
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.800976	eval-auc:0.795553
# [2]	train-auc:0.80241	eval-auc:0.79697
# [3]	train-auc:0.803389	eval-auc:0.797629
# [4]	train-auc:0.803937	eval-auc:0.797805
# [5]	train-auc:0.804291	eval-auc:0.798084
# [6]	train-auc:0.80445	eval-auc:0.797932
# [7]	train-auc:0.804644	eval-auc:0.797751
# [8]	train-auc:0.804833	eval-auc:0.798003
# [9]	train-auc:0.804844	eval-auc:0.797969
# [10]	train-auc:0.805036	eval-auc:0.797912
# [11]	train-auc:0.80534	eval-auc:0.797991
# [12]	train-auc:0.805514	eval-auc:0.798021
# [13]	train-auc:0.805772	eval-auc:0.79799
# [14]	train-auc:0.805904	eval-auc:0.798025
# [15]	train-auc:0.80606	eval-auc:0.79806
# [16]	train-auc:0.806279	eval-auc:0.798101
# [17]	train-auc:0.806457	eval-auc:0.79802
# [18]	train-auc:0.806603	eval-auc:0.797902
# [19]	train-auc:0.806727	eval-auc:0.798001
# [20]	train-auc:0.806834	eval-auc:0.797948
# [21]	train-auc:0.80709	eval-auc:0.79801
# [22]	train-auc:0.807314	eval-auc:0.797946
# [23]	train-auc:0.807488	eval-auc:0.797884
# [24]	train-auc:0.807637	eval-auc:0.797952
# [25]	train-auc:0.807782	eval-auc:0.79794
# [26]	train-auc:0.807904	eval-auc:0.798048
# [27]	train-auc:0.808092	eval-auc:0.798094
# [28]	train-auc:0.808253	eval-auc:0.798026
# [29]	train-auc:0.808464	eval-auc:0.798132
# [30]	train-auc:0.80864	eval-auc:0.798186
# [31]	train-auc:0.808828	eval-auc:0.79825
# [32]	train-auc:0.808975	eval-auc:0.798386
# [33]	train-auc:0.809115	eval-auc:0.798326
# [34]	train-auc:0.809262	eval-auc:0.798311
# [35]	train-auc:0.809424	eval-auc:0.798339
# [36]	train-auc:0.809587	eval-auc:0.798333
# [37]	train-auc:0.809742	eval-auc:0.798446
# [38]	train-auc:0.809896	eval-auc:0.798425
# [39]	train-auc:0.81007	eval-auc:0.798479
# [40]	train-auc:0.810259	eval-auc:0.798574
# [41]	train-auc:0.810396	eval-auc:0.79862
# [42]	train-auc:0.81057	eval-auc:0.79869
# [43]	train-auc:0.81079	eval-auc:0.798699
# [44]	train-auc:0.810952	eval-auc:0.798705
# [45]	train-auc:0.811153	eval-auc:0.798827
# [46]	train-auc:0.81137	eval-auc:0.798876
# [47]	train-auc:0.811567	eval-auc:0.798938
# [48]	train-auc:0.811807	eval-auc:0.799025
# [49]	train-auc:0.811955	eval-auc:0.79905
# [50]	train-auc:0.812106	eval-auc:0.798999
# [51]	train-auc:0.812298	eval-auc:0.798997
# [52]	train-auc:0.812483	eval-auc:0.798898
# [53]	train-auc:0.812653	eval-auc:0.798913
# [54]	train-auc:0.812774	eval-auc:0.798854
# [55]	train-auc:0.812921	eval-auc:0.798942
# [56]	train-auc:0.813126	eval-auc:0.798988
# [57]	train-auc:0.813279	eval-auc:0.798957
# [58]	train-auc:0.813496	eval-auc:0.799082
# [59]	train-auc:0.813646	eval-auc:0.799051
# [60]	train-auc:0.813822	eval-auc:0.799065
# [61]	train-auc:0.813999	eval-auc:0.799086
# [62]	train-auc:0.814218	eval-auc:0.799188
# [63]	train-auc:0.814427	eval-auc:0.799317
# [64]	train-auc:0.814536	eval-auc:0.799313
# [65]	train-auc:0.814734	eval-auc:0.799288
# [66]	train-auc:0.814897	eval-auc:0.799372
# [67]	train-auc:0.815084	eval-auc:0.79939
# [68]	train-auc:0.815279	eval-auc:0.799367
# [69]	train-auc:0.815514	eval-auc:0.799371
# [70]	train-auc:0.815759	eval-auc:0.799462
# [71]	train-auc:0.815918	eval-auc:0.799481
# [72]	train-auc:0.816059	eval-auc:0.799554
# [73]	train-auc:0.81628	eval-auc:0.799636
# [74]	train-auc:0.816477	eval-auc:0.799578
# [75]	train-auc:0.816683	eval-auc:0.799579
# [76]	train-auc:0.816823	eval-auc:0.799664
# [77]	train-auc:0.81699	eval-auc:0.799771
# [78]	train-auc:0.817212	eval-auc:0.799739
# [79]	train-auc:0.817329	eval-auc:0.799753
# [80]	train-auc:0.817573	eval-auc:0.799792
# [81]	train-auc:0.817752	eval-auc:0.799768
# [82]	train-auc:0.817885	eval-auc:0.799802
# [83]	train-auc:0.818083	eval-auc:0.799822
# [84]	train-auc:0.818304	eval-auc:0.799881
# [85]	train-auc:0.818427	eval-auc:0.799918
# [86]	train-auc:0.818609	eval-auc:0.79996
# [87]	train-auc:0.818795	eval-auc:0.799949
# [88]	train-auc:0.819084	eval-auc:0.799968
# [89]	train-auc:0.819284	eval-auc:0.799934
# [90]	train-auc:0.819455	eval-auc:0.799936
# [91]	train-auc:0.819672	eval-auc:0.800014
# [92]	train-auc:0.819829	eval-auc:0.800052
# [93]	train-auc:0.819981	eval-auc:0.800095
# [94]	train-auc:0.820184	eval-auc:0.800056
# [95]	train-auc:0.820382	eval-auc:0.800146
# [96]	train-auc:0.820561	eval-auc:0.800144
# [97]	train-auc:0.82077	eval-auc:0.800176
# [98]	train-auc:0.821046	eval-auc:0.800208
# [99]	train-auc:0.821253	eval-auc:0.800212
# [100]	train-auc:0.821432	eval-auc:0.80019
# [101]	train-auc:0.82169	eval-auc:0.800228
# [102]	train-auc:0.821922	eval-auc:0.800226
# [103]	train-auc:0.822085	eval-auc:0.800215
# [104]	train-auc:0.822262	eval-auc:0.800225
# [105]	train-auc:0.822451	eval-auc:0.800266
# [106]	train-auc:0.822646	eval-auc:0.800246
# [107]	train-auc:0.822769	eval-auc:0.800222
# [108]	train-auc:0.822909	eval-auc:0.80023
# [109]	train-auc:0.823195	eval-auc:0.800126
# [110]	train-auc:0.823307	eval-auc:0.800136
# [111]	train-auc:0.823534	eval-auc:0.80018
# [112]	train-auc:0.823695	eval-auc:0.800197
# [113]	train-auc:0.823828	eval-auc:0.800142
# [114]	train-auc:0.823964	eval-auc:0.800172
# [115]	train-auc:0.824159	eval-auc:0.800128
# [116]	train-auc:0.824336	eval-auc:0.80011
# [117]	train-auc:0.824471	eval-auc:0.800106
# [118]	train-auc:0.824672	eval-auc:0.800138
# [119]	train-auc:0.82483	eval-auc:0.800177
# [120]	train-auc:0.824946	eval-auc:0.800224
# [121]	train-auc:0.82511	eval-auc:0.800231
# [122]	train-auc:0.825357	eval-auc:0.800214
# [123]	train-auc:0.825537	eval-auc:0.800218
# [124]	train-auc:0.825732	eval-auc:0.800339
# [125]	train-auc:0.825971	eval-auc:0.800351
# [126]	train-auc:0.826055	eval-auc:0.800327
# [127]	train-auc:0.826154	eval-auc:0.800364
# [128]	train-auc:0.826275	eval-auc:0.800339
# [129]	train-auc:0.826332	eval-auc:0.800357
# [130]	train-auc:0.82639	eval-auc:0.800357
# [131]	train-auc:0.826597	eval-auc:0.800333
# [132]	train-auc:0.826867	eval-auc:0.800357
# [133]	train-auc:0.826957	eval-auc:0.800354
# [134]	train-auc:0.827206	eval-auc:0.800363
# [135]	train-auc:0.827338	eval-auc:0.800342
# [136]	train-auc:0.827458	eval-auc:0.800332
# [137]	train-auc:0.827498	eval-auc:0.800334
# [138]	train-auc:0.827697	eval-auc:0.800296
# [139]	train-auc:0.827757	eval-auc:0.800294
# [140]	train-auc:0.827811	eval-auc:0.800284
# [141]	train-auc:0.827916	eval-auc:0.80028
# [142]	train-auc:0.828106	eval-auc:0.800289
# [143]	train-auc:0.828279	eval-auc:0.800271
# [144]	train-auc:0.828348	eval-auc:0.800286
# [145]	train-auc:0.828413	eval-auc:0.800275
# [146]	train-auc:0.828524	eval-auc:0.800283
# [147]	train-auc:0.828583	eval-auc:0.800266
# Stopping. Best iteration:
# [127]	train-auc:0.826154	eval-auc:0.800364
#
# Overall ROC: 0.750634799616,  Mean ROC: 0.799967679609, STD AUC: 0.00417264270037

# %%
train_id.to_csv("csv/{}_train.csv".format(model_name), index=False)
test_id.to_csv("csv/{}_test.csv".format(model_name), index=False)
test_id_rank.to_csv("csv/{}_rank_test.csv".format(model_name), index=False)

# %%
fold_roc
# Out:
# [0.7968592955141408,
#  0.8046223321379965,
#  0.799132238460245,
#  0.8053018912644471,
#  0.7948497568950683,
#  0.7907930092277814,
#  0.8056664771411471,
#  0.7949826339854964,
#  0.7977866562555906,
#  0.7988201266751856]
