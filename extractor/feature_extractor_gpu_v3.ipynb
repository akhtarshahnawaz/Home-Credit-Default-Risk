# %%
version = "3"

# %%
import numpy as np
import pandas as pd
import gc
from time import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import LabelEncoder,OneHotEncoder, Normalizer
# %matplotlib inline

# %%
timesheet = [time()]
def timer(statement):
    global timesheet
    timesheet.append(time())
    print statement+" :", (timesheet[-1]-timesheet[-2]),"seconds"

# %% [markdown]
# # Feature Generators

# %%
from numba import njit, prange,jit
@jit(nopython=True, parallel=True)
def get_regression_coefficient(ys, xs, counts):
    output = np.zeros(counts.shape[0]-1)
    for i in prange(counts.shape[0]-1):
        x = xs[counts[i] : counts[i+1]]
        y = ys[counts[i] : counts[i+1]]

        output[i] = np.nan
        length = y.shape[0]
        sx = np.sum(x)
        denominator = ((length*np.dot(x, x)) - (sx*sx))
        
        if length >0 and denominator != 0:
            numerator = ((length*np.dot(x, y)) - (sx*np.sum(y)))
            output[i] = numerator/denominator
    return output

# %%
def get_trend_values(data):
        y = data.apply(lambda x: x.dropna().values)
        trends = pd.Series(index =  y.index)
        
        counts = np.insert(y.apply(lambda x: x.shape[0]).values, 0, 0)
        x = np.concatenate(np.array([np.arange(c) for c in counts])).ravel().astype(np.float64)
        y = np.concatenate(y.values).ravel().astype(np.float64)
        counts = np.cumsum(counts)
        
        trends.iloc[:] = get_regression_coefficient(y, x, counts)
        return trends

# %%
def generate_features(prefix, dataGroups, num_lags, colname, get_trend = False, get_kurtosis = True, to_calculate = ["sum", "count","nunique","mean","median","max","min","std","skew"]):
    global output
    if len(to_calculate)> 0 :
        print "Getting Aggregates for column: {}, {}".format(colname, num_lags)
        aggregates = dataGroups[colname].agg(to_calculate)
        aggregates.columns = ["{}_{}_{}_{}".format(prefix,colname, c, num_lags) for c in aggregates.columns]
        output = output.merge(aggregates, how = "left", left_on = "SK_ID_CURR", right_index=True)
        timer("Done Aggregating Column {}".format(colname))
    if get_kurtosis:
        print "Getting Kurtosis for Column: {}, {}".format(colname, num_lags)
        output["{}_{}_kurtosis_{}".format(prefix,colname,num_lags)] = output["SK_ID_CURR"].map(dataGroups[colname].apply(lambda x: x.kurt()))
        timer("Done Getting Kurtosis for Column {}".format(colname))

    if get_trend:
        print "Getting Trend for column: {}, {}".format(colname, num_lags)
        output["{}_{}_trend_{}".format(prefix, colname, num_lags)] = output["SK_ID_CURR"].map(get_trend_values(dataGroups[colname]))
        timer("Done Getting Trend for Column {}".format(colname))

# %% [markdown]
# # Feature Preprocessors

# %%
def one_hot_encoder(data, nan_as_category = True):
    categorical_columns = [col for col in data.columns if data[col].dtype == 'object']
    data = pd.get_dummies(data, columns= categorical_columns, dummy_na= nan_as_category)
    return data

def normalize_features(data, not_to_normalize):
    columns_to_normalize = data.columns.drop(not_to_normalize)
    data = data.replace([np.inf, -np.inf], np.nan)
    print data.shape, "Before dropping Na's"
    data = data.dropna(axis=1, how = "all")
    print data.shape, "After dropping Na's"
    for col in data.columns.drop(not_to_normalize):
        data[col] = data[col].fillna(data[col].mean()).fillna(0)
        data[col]= Normalizer().fit_transform(data[col].values.reshape(-1,1))
    return data

# %% [markdown]
# # Get Installment Features

# %%
def GetInstallmentFeatures(installment_path = "../data/installments_payments.csv"):
    installments = pd.read_csv(installment_path).sort_values(by=["SK_ID_CURR","DAYS_INSTALMENT"]).reset_index(drop = True)
    
    
    # Some Preprocessing
    installments['installment_paid_late_in_days'] = installments['DAYS_ENTRY_PAYMENT'] - installments['DAYS_INSTALMENT']
    installments['installment_paid_over_amount'] = installments['AMT_PAYMENT'] - installments['AMT_INSTALMENT']
    installments['installment_paid_over_amount_ratio'] = installments['AMT_PAYMENT'] / (1+installments['AMT_INSTALMENT'])


    # All Aggregate Features
    groups = installments.groupby("SK_ID_CURR")
    
    installments["installment_paid_late_in_days_diff"] = groups["installment_paid_late_in_days"].diff()
    installments["installment_paid_over_amount_diff"] = groups["installment_paid_over_amount"].diff()
    installments["installment_paid_over_amount_ratio_diff"] = groups["installment_paid_over_amount_ratio"].diff()
    installments["NUM_INSTALMENT_VERSION_diff"] = groups["NUM_INSTALMENT_VERSION"].diff()
    
    installments["installment_paid_late_in_days_diff_diff"] = groups["installment_paid_late_in_days_diff"].diff()
    installments["installment_paid_over_amount_diff_diff"] = groups["installment_paid_over_amount_diff"].diff()
    installments["installment_paid_over_amount_ratio_diff_diff"] = groups["installment_paid_over_amount_ratio_diff"].diff()
    installments["NUM_INSTALMENT_VERSION_diff_diff"] = groups["NUM_INSTALMENT_VERSION_diff"].diff()
    installments["DAYS_INSTALMENT_diff_diff"] = groups["DAYS_INSTALMENT"].diff().diff()

    
    installments["installment_paid_late_in_days_rolling6"] = groups["installment_paid_late_in_days"].apply(lambda x: x.rolling(6).mean())
    installments["installment_paid_over_amount_rolling6"] = groups["installment_paid_over_amount"].apply(lambda x: x.rolling(6).mean())
    installments["installment_paid_over_amount_ratio_rolling6"] = groups["installment_paid_over_amount_ratio"].apply(lambda x: x.rolling(6).mean())
    installments["NUM_INSTALMENT_VERSION_rolling6"] = groups["NUM_INSTALMENT_VERSION"].apply(lambda x: x.rolling(6).mean())
    installments["DAYS_INSTALMENT_rolling6"] = groups["DAYS_INSTALMENT"].apply(lambda x: x.rolling(6).mean())
    
    installments["installment_paid_late_in_days_rolling12"] = groups["installment_paid_late_in_days"].apply(lambda x: x.rolling(12).mean())
    installments["installment_paid_over_amount_rolling12"] = groups["installment_paid_over_amount"].apply(lambda x: x.rolling(12).mean())
    installments["installment_paid_over_amount_ratio_rolling12"] = groups["installment_paid_over_amount_ratio"].apply(lambda x: x.rolling(12).mean())
    installments["NUM_INSTALMENT_VERSION_rolling12"] = groups["NUM_INSTALMENT_VERSION"].apply(lambda x: x.rolling(12).mean())
    installments["DAYS_INSTALMENT_rolling12"] = groups["DAYS_INSTALMENT"].apply(lambda x: x.rolling(12).mean())
    
    # For Lagged Items
    for lags in [12, 60, 90]:
        groups = installments.groupby("SK_ID_CURR").tail(lags).reset_index(drop=True).groupby("SK_ID_CURR")

        generate_features("installment",groups, lags, "installment_paid_late_in_days_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_ratio_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "NUM_INSTALMENT_VERSION_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_late_in_days_diff_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_diff_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_ratio_diff_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "NUM_INSTALMENT_VERSION_diff_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "DAYS_INSTALMENT_diff_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_late_in_days_rolling6", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_rolling6", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_ratio_rolling6", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "NUM_INSTALMENT_VERSION_rolling6", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "DAYS_INSTALMENT_rolling6", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_late_in_days_rolling12", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_rolling12", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_ratio_rolling12", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "NUM_INSTALMENT_VERSION_rolling12", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "DAYS_INSTALMENT_rolling12", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/installments_payments.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
GetInstallmentFeatures(installment_path = "../data/installments_payments.csv")


# Saving Data
if get_unnormalized:
    output.to_csv("csv/installment_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/installment_features_normalized_V{}.csv".format(version), index=False)

# %% [markdown]
# # Get POS Cash Features

# %%
def GetPOSFeatures(pos_cash_path = "../data/POS_CASH_balance.csv"):
    pos_cash = pd.read_csv(pos_cash_path).sort_values(by=["SK_ID_CURR","SK_ID_PREV","MONTHS_BALANCE"]).reset_index(drop = True)
    
    # All Aggregate Features
    groups = pos_cash.groupby("SK_ID_CURR")
    
    pos_cash["SK_DPD_diff"] = groups["SK_DPD"].diff()
    pos_cash["SK_DPD_DEF_diff"] = groups["SK_DPD_DEF"].diff()
    
    pos_cash["SK_DPD_diff_diff"] = groups["SK_DPD_diff"].diff()
    pos_cash["SK_DPD_DEF_diff_diff"] = groups["SK_DPD_DEF_diff"].diff()
    pos_cash["CNT_INSTALMENT_diff_diff"] = groups["CNT_INSTALMENT"].diff().diff()
    pos_cash["CNT_INSTALMENT_FUTURE_diff_diff"] = groups["CNT_INSTALMENT_FUTURE"].diff().diff()

    pos_cash["SK_DPD_rolling6"] = groups["SK_DPD"].apply(lambda x: x.rolling(6).mean())
    pos_cash["SK_DPD_DEF_rolling6"] = groups["SK_DPD_DEF"].apply(lambda x: x.rolling(6).mean())
    pos_cash["CNT_INSTALMENT_rolling6"] = groups["CNT_INSTALMENT"].apply(lambda x: x.rolling(6).mean())
    pos_cash["CNT_INSTALMENT_FUTURE_rolling6"] = groups["CNT_INSTALMENT_FUTURE"].apply(lambda x: x.rolling(6).mean())


    pos_cash["SK_DPD_rolling12"] = groups["SK_DPD"].apply(lambda x: x.rolling(12).mean())
    pos_cash["SK_DPD_DEF_rolling12"] = groups["SK_DPD_DEF"].apply(lambda x: x.rolling(12).mean())
    pos_cash["CNT_INSTALMENT_rolling12"] = groups["CNT_INSTALMENT"].apply(lambda x: x.rolling(12).mean())
    pos_cash["CNT_INSTALMENT_FUTURE_rolling12"] = groups["CNT_INSTALMENT_FUTURE"].apply(lambda x: x.rolling(12).mean())


    #For Lagged Items
    for lags in [6, 12]:
        groups = pos_cash.groupby("SK_ID_CURR").tail(lags).reset_index(drop=True).groupby("SK_ID_CURR")

        generate_features("pos_cash",groups, lags, "SK_DPD_diff", get_trend = True, get_kurtosis = True, to_calculate =  ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "SK_DPD_DEF_diff", get_trend = True, get_kurtosis = True, to_calculate =  ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "SK_DPD_diff_diff", get_trend = True, get_kurtosis = True, to_calculate =  ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "SK_DPD_DEF_diff_diff", get_trend = True, get_kurtosis = True, to_calculate =  ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_diff_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_FUTURE_diff_diff", get_trend = True, get_kurtosis = True, to_calculate =  ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "SK_DPD_rolling6", get_trend = True, get_kurtosis = True, to_calculate =  ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "SK_DPD_DEF_rolling6", get_trend = True, get_kurtosis = True, to_calculate =  ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_rolling6", get_trend = True, get_kurtosis = True, to_calculate =  ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_FUTURE_rolling6", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "SK_DPD_rolling12", get_trend = True, get_kurtosis = True, to_calculate =  ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "SK_DPD_DEF_rolling12", get_trend = True, get_kurtosis = True, to_calculate =  ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_rolling12", get_trend = True, get_kurtosis = True, to_calculate =  ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_FUTURE_rolling12", get_trend = True, get_kurtosis = True, to_calculate =  ["sum","mean","median","max","min","std","skew"])

        del groups
        gc.collect()

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/POS_CASH_balance.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
GetPOSFeatures(pos_cash_path = "../data/POS_CASH_balance.csv")

# Saving Data
if get_unnormalized:
    output.to_csv("csv/pos_cash_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/pos_cash_features_normalized_V{}.csv".format(version), index=False)
# Out:
# Getting Aggregates for column: SK_DPD_diff, 6
# Done Aggregating Column SK_DPD_diff : 1828.79173899 seconds
# Getting Kurtosis for Column: SK_DPD_diff, 6
# Done Getting Kurtosis for Column SK_DPD_diff : 74.5211980343 seconds
# Getting Trend for column: SK_DPD_diff, 6
# Done Getting Trend for Column SK_DPD_diff : 101.981404066 seconds
# Getting Aggregates for column: SK_DPD_DEF_diff, 6
# Done Aggregating Column SK_DPD_DEF_diff : 74.5928058624 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_diff, 6
# Done Getting Kurtosis for Column SK_DPD_DEF_diff : 74.2076630592 seconds
# Getting Trend for column: SK_DPD_DEF_diff, 6
# Done Getting Trend for Column SK_DPD_DEF_diff : 101.479686975 seconds
# Getting Aggregates for column: SK_DPD_diff_diff, 6
# Done Aggregating Column SK_DPD_diff_diff : 74.2912449837 seconds
# Getting Kurtosis for Column: SK_DPD_diff_diff, 6
# Done Getting Kurtosis for Column SK_DPD_diff_diff : 74.5988090038 seconds
# Getting Trend for column: SK_DPD_diff_diff, 6
# Done Getting Trend for Column SK_DPD_diff_diff : 101.746910095 seconds
# Getting Aggregates for column: SK_DPD_DEF_diff_diff, 6
# Done Aggregating Column SK_DPD_DEF_diff_diff : 72.6771090031 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_diff_diff, 6
# Done Getting Kurtosis for Column SK_DPD_DEF_diff_diff : 72.7955379486 seconds
# Getting Trend for column: SK_DPD_DEF_diff_diff, 6
# Done Getting Trend for Column SK_DPD_DEF_diff_diff : 99.278386116 seconds
# Getting Aggregates for column: CNT_INSTALMENT_diff_diff, 6
# Done Aggregating Column CNT_INSTALMENT_diff_diff : 76.9974458218 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_diff_diff, 6
# Done Getting Kurtosis for Column CNT_INSTALMENT_diff_diff : 75.6290471554 seconds
# Getting Trend for column: CNT_INSTALMENT_diff_diff, 6
# Done Getting Trend for Column CNT_INSTALMENT_diff_diff : 100.877393961 seconds
# Getting Aggregates for column: CNT_INSTALMENT_FUTURE_diff_diff, 6
# Done Aggregating Column CNT_INSTALMENT_FUTURE_diff_diff : 73.0463109016 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_FUTURE_diff_diff, 6
# Done Getting Kurtosis for Column CNT_INSTALMENT_FUTURE_diff_diff : 75.5173470974 seconds
# Getting Trend for column: CNT_INSTALMENT_FUTURE_diff_diff, 6
# Done Getting Trend for Column CNT_INSTALMENT_FUTURE_diff_diff : 101.562497854 seconds
# Getting Aggregates for column: SK_DPD_rolling6, 6
# Done Aggregating Column SK_DPD_rolling6 : 73.1100080013 seconds
# Getting Kurtosis for Column: SK_DPD_rolling6, 6
# Done Getting Kurtosis for Column SK_DPD_rolling6 : 72.7473890781 seconds
# Getting Trend for column: SK_DPD_rolling6, 6
# Done Getting Trend for Column SK_DPD_rolling6 : 105.941893101 seconds
# Getting Aggregates for column: SK_DPD_DEF_rolling6, 6
# Done Aggregating Column SK_DPD_DEF_rolling6 : 74.8208618164 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_rolling6, 6
# Done Getting Kurtosis for Column SK_DPD_DEF_rolling6 : 74.0432431698 seconds
# Getting Trend for column: SK_DPD_DEF_rolling6, 6
# Done Getting Trend for Column SK_DPD_DEF_rolling6 : 108.819069862 seconds
# Getting Aggregates for column: CNT_INSTALMENT_rolling6, 6
# Done Aggregating Column CNT_INSTALMENT_rolling6 : 74.9777541161 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_rolling6, 6
# Done Getting Kurtosis for Column CNT_INSTALMENT_rolling6 : 76.9872689247 seconds
# Getting Trend for column: CNT_INSTALMENT_rolling6, 6
# Done Getting Trend for Column CNT_INSTALMENT_rolling6 : 109.800940037 seconds
# Getting Aggregates for column: CNT_INSTALMENT_FUTURE_rolling6, 6
# Done Aggregating Column CNT_INSTALMENT_FUTURE_rolling6 : 74.3370389938 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_FUTURE_rolling6, 6
# Done Getting Kurtosis for Column CNT_INSTALMENT_FUTURE_rolling6 : 78.6566450596 seconds
# Getting Trend for column: CNT_INSTALMENT_FUTURE_rolling6, 6
# Done Getting Trend for Column CNT_INSTALMENT_FUTURE_rolling6 : 110.214192867 seconds
# Getting Aggregates for column: SK_DPD_rolling12, 6
# Done Aggregating Column SK_DPD_rolling12 : 75.5290951729 seconds
# Getting Kurtosis for Column: SK_DPD_rolling12, 6
# Done Getting Kurtosis for Column SK_DPD_rolling12 : 74.4033370018 seconds
# Getting Trend for column: SK_DPD_rolling12, 6
# Done Getting Trend for Column SK_DPD_rolling12 : 128.831782818 seconds
# Getting Aggregates for column: SK_DPD_DEF_rolling12, 6
# Done Aggregating Column SK_DPD_DEF_rolling12 : 74.7318780422 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_rolling12, 6
# Done Getting Kurtosis for Column SK_DPD_DEF_rolling12 : 74.2831909657 seconds
# Getting Trend for column: SK_DPD_DEF_rolling12, 6
# Done Getting Trend for Column SK_DPD_DEF_rolling12 : 127.430325031 seconds
# Getting Aggregates for column: CNT_INSTALMENT_rolling12, 6
# Done Aggregating Column CNT_INSTALMENT_rolling12 : 74.5777759552 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_rolling12, 6
# Done Getting Kurtosis for Column CNT_INSTALMENT_rolling12 : 76.83821702 seconds
# Getting Trend for column: CNT_INSTALMENT_rolling12, 6
# Done Getting Trend for Column CNT_INSTALMENT_rolling12 : 128.739972115 seconds
# Getting Aggregates for column: CNT_INSTALMENT_FUTURE_rolling12, 6
# Done Aggregating Column CNT_INSTALMENT_FUTURE_rolling12 : 75.3248479366 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_FUTURE_rolling12, 6
# Done Getting Kurtosis for Column CNT_INSTALMENT_FUTURE_rolling12 : 77.6980090141 seconds
# Getting Trend for column: CNT_INSTALMENT_FUTURE_rolling12, 6
# Done Getting Trend for Column CNT_INSTALMENT_FUTURE_rolling12 : 129.121131897 seconds
# Getting Aggregates for column: SK_DPD_diff, 12
# Done Aggregating Column SK_DPD_diff : 78.4565770626 seconds
# Getting Kurtosis for Column: SK_DPD_diff, 12
# Done Getting Kurtosis for Column SK_DPD_diff : 74.3324761391 seconds
# Getting Trend for column: SK_DPD_diff, 12
# Done Getting Trend for Column SK_DPD_diff : 106.026697874 seconds
# Getting Aggregates for column: SK_DPD_DEF_diff, 12
# Done Aggregating Column SK_DPD_DEF_diff : 74.5540070534 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_diff, 12
# Done Getting Kurtosis for Column SK_DPD_DEF_diff : 73.761357069 seconds
# Getting Trend for column: SK_DPD_DEF_diff, 12
# Done Getting Trend for Column SK_DPD_DEF_diff : 103.311298847 seconds
# Getting Aggregates for column: SK_DPD_diff_diff, 12
# Done Aggregating Column SK_DPD_diff_diff : 73.3435490131 seconds
# Getting Kurtosis for Column: SK_DPD_diff_diff, 12
# Done Getting Kurtosis for Column SK_DPD_diff_diff : 73.311617136 seconds
# Getting Trend for column: SK_DPD_diff_diff, 12
# Done Getting Trend for Column SK_DPD_diff_diff : 105.297044039 seconds
# Getting Aggregates for column: SK_DPD_DEF_diff_diff, 12
# Done Aggregating Column SK_DPD_DEF_diff_diff : 74.133936882 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_diff_diff, 12
# Done Getting Kurtosis for Column SK_DPD_DEF_diff_diff : 72.9011969566 seconds
# Getting Trend for column: SK_DPD_DEF_diff_diff, 12
# Done Getting Trend for Column SK_DPD_DEF_diff_diff : 104.800421 seconds
# Getting Aggregates for column: CNT_INSTALMENT_diff_diff, 12
# Done Aggregating Column CNT_INSTALMENT_diff_diff : 73.8009409904 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_diff_diff, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_diff_diff : 75.8524770737 seconds
# Getting Trend for column: CNT_INSTALMENT_diff_diff, 12
# Done Getting Trend for Column CNT_INSTALMENT_diff_diff : 104.622277975 seconds
# Getting Aggregates for column: CNT_INSTALMENT_FUTURE_diff_diff, 12
# Done Aggregating Column CNT_INSTALMENT_FUTURE_diff_diff : 74.6620960236 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_FUTURE_diff_diff, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_FUTURE_diff_diff : 77.7413830757 seconds
# Getting Trend for column: CNT_INSTALMENT_FUTURE_diff_diff, 12
# Done Getting Trend for Column CNT_INSTALMENT_FUTURE_diff_diff : 106.728788853 seconds
# Getting Aggregates for column: SK_DPD_rolling6, 12
# Done Aggregating Column SK_DPD_rolling6 : 75.4670031071 seconds
# Getting Kurtosis for Column: SK_DPD_rolling6, 12
# Done Getting Kurtosis for Column SK_DPD_rolling6 : 74.488519907 seconds
# Getting Trend for column: SK_DPD_rolling6, 12
# Done Getting Trend for Column SK_DPD_rolling6 : 119.830400944 seconds
# Getting Aggregates for column: SK_DPD_DEF_rolling6, 12
# Done Aggregating Column SK_DPD_DEF_rolling6 : 75.4288270473 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_rolling6, 12
# Done Getting Kurtosis for Column SK_DPD_DEF_rolling6 : 74.7521190643 seconds
# Getting Trend for column: SK_DPD_DEF_rolling6, 12
# Done Getting Trend for Column SK_DPD_DEF_rolling6 : 117.866225958 seconds
# Getting Aggregates for column: CNT_INSTALMENT_rolling6, 12
# Done Aggregating Column CNT_INSTALMENT_rolling6 : 74.8060290813 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_rolling6, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_rolling6 : 77.163779974 seconds
# Getting Trend for column: CNT_INSTALMENT_rolling6, 12
# Done Getting Trend for Column CNT_INSTALMENT_rolling6 : 119.07503891 seconds
# Getting Aggregates for column: CNT_INSTALMENT_FUTURE_rolling6, 12
# Done Aggregating Column CNT_INSTALMENT_FUTURE_rolling6 : 74.6169810295 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_FUTURE_rolling6, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_FUTURE_rolling6 : 78.7400350571 seconds
# Getting Trend for column: CNT_INSTALMENT_FUTURE_rolling6, 12
# Done Getting Trend for Column CNT_INSTALMENT_FUTURE_rolling6 : 124.195725918 seconds
# Getting Aggregates for column: SK_DPD_rolling12, 12
# Done Aggregating Column SK_DPD_rolling12 : 75.4502849579 seconds
# Getting Kurtosis for Column: SK_DPD_rolling12, 12
# Done Getting Kurtosis for Column SK_DPD_rolling12 : 74.6539001465 seconds
# Getting Trend for column: SK_DPD_rolling12, 12
# Done Getting Trend for Column SK_DPD_rolling12 : 154.288009882 seconds
# Getting Aggregates for column: SK_DPD_DEF_rolling12, 12
# Done Aggregating Column SK_DPD_DEF_rolling12 : 74.9737730026 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_rolling12, 12
# Done Getting Kurtosis for Column SK_DPD_DEF_rolling12 : 73.8246531487 seconds
# Getting Trend for column: SK_DPD_DEF_rolling12, 12
# Done Getting Trend for Column SK_DPD_DEF_rolling12 : 154.724988937 seconds
# Getting Aggregates for column: CNT_INSTALMENT_rolling12, 12
# Done Aggregating Column CNT_INSTALMENT_rolling12 : 74.4550170898 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_rolling12, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_rolling12 : 77.0626599789 seconds
# Getting Trend for column: CNT_INSTALMENT_rolling12, 12
# Done Getting Trend for Column CNT_INSTALMENT_rolling12 : 138.858752966 seconds
# Getting Aggregates for column: CNT_INSTALMENT_FUTURE_rolling12, 12
# Done Aggregating Column CNT_INSTALMENT_FUTURE_rolling12 : 73.3870308399 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_FUTURE_rolling12, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_FUTURE_rolling12 : 79.6894230843 seconds
# Getting Trend for column: CNT_INSTALMENT_FUTURE_rolling12, 12
# Done Getting Trend for Column CNT_INSTALMENT_FUTURE_rolling12 : 151.304018974 seconds
# (337252, 253) Before dropping Na's
# (337252, 253) After dropping Na's

# %% [markdown]
# # Credit Card Features

# %%
def GetCreditCardFeatures(credit_card_path = "../data/credit_card_balance.csv"):
    credit_card = pd.read_csv(credit_card_path).sort_values(by=["SK_ID_CURR","SK_ID_PREV","MONTHS_BALANCE"]).reset_index(drop = True)
    credit_card = credit_card.fillna(0.0)
    
    
    # Generating Ratio Features
    credit_card['cnt_pos_ratio'] = credit_card['CNT_DRAWINGS_POS_CURRENT']/(credit_card['CNT_DRAWINGS_CURRENT']+1.0)
    credit_card['cnt_atm_ratio'] = credit_card['CNT_DRAWINGS_ATM_CURRENT']/(credit_card['CNT_DRAWINGS_CURRENT']+1.0)
    credit_card['amt_pos_ratio'] = credit_card['AMT_DRAWINGS_POS_CURRENT']/(credit_card['AMT_DRAWINGS_CURRENT']+1.0)
    credit_card['amt_atm_ratio'] = credit_card['AMT_DRAWINGS_ATM_CURRENT']/(credit_card['AMT_DRAWINGS_CURRENT']+1.0)
    credit_card['balance_to_drawing_ratio'] = credit_card['AMT_BALANCE']/(credit_card['AMT_DRAWINGS_CURRENT']+1.0)
    credit_card['balance_to_limit_ratio'] = credit_card['AMT_BALANCE']/(credit_card['AMT_CREDIT_LIMIT_ACTUAL']+1.0)
    credit_card['balance_to_total_payment_ratio'] = credit_card['AMT_BALANCE']/(credit_card['AMT_PAYMENT_TOTAL_CURRENT']+1.0)
    credit_card['balance_to_minimum_installment_ratio'] = credit_card['AMT_BALANCE']/(credit_card['AMT_INST_MIN_REGULARITY']+1.0)
    credit_card['minimum_installment_to_total_payment_ratio'] = credit_card['AMT_INST_MIN_REGULARITY']/(credit_card['AMT_PAYMENT_TOTAL_CURRENT']+1.0)
    credit_card['minimum_installment_to_current_payment_ratio'] = credit_card['AMT_INST_MIN_REGULARITY']/(credit_card['AMT_PAYMENT_CURRENT']+1.0)
    credit_card['current_to_total_payment_ratio'] = credit_card['AMT_PAYMENT_CURRENT']/(credit_card['AMT_PAYMENT_TOTAL_CURRENT']+1.0)
    credit_card['payment_to_receivable_min_ratio'] = credit_card['AMT_INST_MIN_REGULARITY']/(credit_card['AMT_RECEIVABLE_PRINCIPAL']+1.0)
    credit_card['payment_to_receivable_curr_ratio'] = credit_card['AMT_PAYMENT_CURRENT']/(credit_card['AMT_RECIVABLE']+1.0)
    credit_card['payment_to_receivable_total_ratio'] = credit_card['AMT_PAYMENT_TOTAL_CURRENT']/(credit_card['AMT_TOTAL_RECEIVABLE']+1.0)

    all_ratio_features = ["cnt_pos_ratio","cnt_atm_ratio","amt_pos_ratio","amt_atm_ratio","balance_to_drawing_ratio","balance_to_limit_ratio","balance_to_total_payment_ratio","balance_to_minimum_installment_ratio","minimum_installment_to_total_payment_ratio","minimum_installment_to_current_payment_ratio","current_to_total_payment_ratio","payment_to_receivable_min_ratio","payment_to_receivable_curr_ratio","payment_to_receivable_total_ratio"]
    other_features = ["SK_DPD","SK_DPD_DEF","CNT_DRAWINGS_ATM_CURRENT","AMT_DRAWINGS_CURRENT","AMT_TOTAL_RECEIVABLE","AMT_PAYMENT_TOTAL_CURRENT","CNT_INSTALMENT_MATURE_CUM","AMT_BALANCE","AMT_DRAWINGS_ATM_CURRENT","AMT_DRAWINGS_POS_CURRENT","CNT_DRAWINGS_POS_CURRENT","CNT_DRAWINGS_POS_CURRENT","CNT_DRAWINGS_CURRENT"]
    
    # Generating Features that will be used
    groups = credit_card.groupby("SK_ID_CURR")
    
    for col in all_ratio_features+other_features:
        credit_card[col+"_diff"] = groups[col].diff()
        credit_card[col+"_diff_diff"] = groups[col+"_diff"].diff()
        credit_card[col+"_rolling6"] = groups[col].apply(lambda x: x.rolling(6).mean())
        credit_card[col+"_rolling12"] = groups[col].apply(lambda x: x.rolling(12).mean())

    
    using_columns = ["{}_diff".format(c) for c in all_ratio_features+other_features] + ["{}_diff_diff".format(c) for c in all_ratio_features+other_features]+["{}_rolling6".format(c) for c in all_ratio_features+other_features]+["{}_rolling12".format(c) for c in all_ratio_features+other_features]
                
    # Lag Aggregate Features
    for lags in [6, 12]:
        groups = credit_card.groupby("SK_ID_CURR").tail(lags).reset_index(drop=True).groupby("SK_ID_CURR")
        
        for col in using_columns:
            generate_features("credit_card",groups, lags, col, get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
     
        del groups
        gc.collect()

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/credit_card_balance.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
GetCreditCardFeatures(credit_card_path = "../data/credit_card_balance.csv")

# Saving Data
if get_unnormalized:
    output.to_csv("csv/credit_card_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/credit_card_features_normalized_V{}.csv".format(version), index=False)
# Out:
# Getting Aggregates for column: cnt_pos_ratio_diff, 6
# Done Aggregating Column cnt_pos_ratio_diff : 4025.372962 seconds
# Getting Kurtosis for Column: cnt_pos_ratio_diff, 6
# Done Getting Kurtosis for Column cnt_pos_ratio_diff : 23.1981739998 seconds
# Getting Trend for column: cnt_pos_ratio_diff, 6
# Done Getting Trend for Column cnt_pos_ratio_diff : 30.7753500938 seconds
# Getting Aggregates for column: cnt_atm_ratio_diff, 6
# Done Aggregating Column cnt_atm_ratio_diff : 22.8141238689 seconds
# Getting Kurtosis for Column: cnt_atm_ratio_diff, 6
# Done Getting Kurtosis for Column cnt_atm_ratio_diff : 23.4760601521 seconds
# Getting Trend for column: cnt_atm_ratio_diff, 6
# Done Getting Trend for Column cnt_atm_ratio_diff : 30.9736218452 seconds
# Getting Aggregates for column: amt_pos_ratio_diff, 6
# Done Aggregating Column amt_pos_ratio_diff : 23.0098161697 seconds
# Getting Kurtosis for Column: amt_pos_ratio_diff, 6
# Done Getting Kurtosis for Column amt_pos_ratio_diff : 23.4225189686 seconds
# Getting Trend for column: amt_pos_ratio_diff, 6
# Done Getting Trend for Column amt_pos_ratio_diff : 31.0580940247 seconds
# Getting Aggregates for column: amt_atm_ratio_diff, 6
# Done Aggregating Column amt_atm_ratio_diff : 22.7416880131 seconds
# Getting Kurtosis for Column: amt_atm_ratio_diff, 6
# Done Getting Kurtosis for Column amt_atm_ratio_diff : 23.1119828224 seconds
# Getting Trend for column: amt_atm_ratio_diff, 6
# Done Getting Trend for Column amt_atm_ratio_diff : 31.3432371616 seconds
# Getting Aggregates for column: balance_to_drawing_ratio_diff, 6
# Done Aggregating Column balance_to_drawing_ratio_diff : 22.8383090496 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio_diff, 6
# Done Getting Kurtosis for Column balance_to_drawing_ratio_diff : 23.2955777645 seconds
# Getting Trend for column: balance_to_drawing_ratio_diff, 6
# Done Getting Trend for Column balance_to_drawing_ratio_diff : 31.2814280987 seconds
# Getting Aggregates for column: balance_to_limit_ratio_diff, 6
# Done Aggregating Column balance_to_limit_ratio_diff : 23.1218369007 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio_diff, 6
# Done Getting Kurtosis for Column balance_to_limit_ratio_diff : 23.748044014 seconds
# Getting Trend for column: balance_to_limit_ratio_diff, 6
# Done Getting Trend for Column balance_to_limit_ratio_diff : 31.8232731819 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio_diff, 6
# Done Aggregating Column balance_to_total_payment_ratio_diff : 23.0943830013 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio_diff, 6
# Done Getting Kurtosis for Column balance_to_total_payment_ratio_diff : 23.6322498322 seconds
# Getting Trend for column: balance_to_total_payment_ratio_diff, 6
# Done Getting Trend for Column balance_to_total_payment_ratio_diff : 31.4260511398 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio_diff, 6
# Done Aggregating Column balance_to_minimum_installment_ratio_diff : 23.1948330402 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio_diff, 6
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio_diff : 23.4093530178 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio_diff, 6
# Done Getting Trend for Column balance_to_minimum_installment_ratio_diff : 30.9765357971 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio_diff, 6
# Done Aggregating Column minimum_installment_to_total_payment_ratio_diff : 23.2306680679 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio_diff, 6
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio_diff : 23.8421559334 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio_diff, 6
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio_diff : 31.4829452038 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio_diff, 6
# Done Aggregating Column minimum_installment_to_current_payment_ratio_diff : 22.702682972 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio_diff, 6
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio_diff : 23.3768877983 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio_diff, 6
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio_diff : 31.2773890495 seconds
# Getting Aggregates for column: current_to_total_payment_ratio_diff, 6
# Done Aggregating Column current_to_total_payment_ratio_diff : 23.1650249958 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio_diff, 6
# Done Getting Kurtosis for Column current_to_total_payment_ratio_diff : 23.2125489712 seconds
# Getting Trend for column: current_to_total_payment_ratio_diff, 6
# Done Getting Trend for Column current_to_total_payment_ratio_diff : 30.988353014 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio_diff, 6
# Done Aggregating Column payment_to_receivable_min_ratio_diff : 23.3431260586 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio_diff, 6
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio_diff : 23.9361360073 seconds
# Getting Trend for column: payment_to_receivable_min_ratio_diff, 6
# Done Getting Trend for Column payment_to_receivable_min_ratio_diff : 31.3212149143 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio_diff, 6
# Done Aggregating Column payment_to_receivable_curr_ratio_diff : 23.0102210045 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio_diff, 6
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio_diff : 23.8314189911 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio_diff, 6
# Done Getting Trend for Column payment_to_receivable_curr_ratio_diff : 31.1273701191 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio_diff, 6
# Done Aggregating Column payment_to_receivable_total_ratio_diff : 23.0103418827 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio_diff, 6
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio_diff : 23.6410322189 seconds
# Getting Trend for column: payment_to_receivable_total_ratio_diff, 6
# Done Getting Trend for Column payment_to_receivable_total_ratio_diff : 30.6705617905 seconds
# Getting Aggregates for column: SK_DPD_diff, 6
# Done Aggregating Column SK_DPD_diff : 23.9210700989 seconds
# Getting Kurtosis for Column: SK_DPD_diff, 6
# Done Getting Kurtosis for Column SK_DPD_diff : 23.0855770111 seconds
# Getting Trend for column: SK_DPD_diff, 6
# Done Getting Trend for Column SK_DPD_diff : 31.2324450016 seconds
# Getting Aggregates for column: SK_DPD_DEF_diff, 6
# Done Aggregating Column SK_DPD_DEF_diff : 23.9458620548 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_diff, 6
# Done Getting Kurtosis for Column SK_DPD_DEF_diff : 22.4570949078 seconds
# Getting Trend for column: SK_DPD_DEF_diff, 6
# Done Getting Trend for Column SK_DPD_DEF_diff : 30.3155930042 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT_diff, 6
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT_diff : 22.5176839828 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT_diff, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT_diff : 22.6073689461 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT_diff, 6
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT_diff : 30.7560300827 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT_diff, 6
# Done Aggregating Column AMT_DRAWINGS_CURRENT_diff : 22.5131249428 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT_diff, 6
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT_diff : 22.9839789867 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT_diff, 6
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT_diff : 30.178951025 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE_diff, 6
# Done Aggregating Column AMT_TOTAL_RECEIVABLE_diff : 22.7468919754 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE_diff, 6
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE_diff : 22.8770229816 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE_diff, 6
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE_diff : 30.5495250225 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT_diff, 6
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT_diff : 22.7141890526 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT_diff, 6
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT_diff : 23.2596149445 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT_diff, 6
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT_diff : 30.6682829857 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM_diff, 6
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM_diff : 22.9886181355 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM_diff, 6
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM_diff : 22.7338769436 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM_diff, 6
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM_diff : 30.6263930798 seconds
# Getting Aggregates for column: AMT_BALANCE_diff, 6
# Done Aggregating Column AMT_BALANCE_diff : 22.7345058918 seconds
# Getting Kurtosis for Column: AMT_BALANCE_diff, 6
# Done Getting Kurtosis for Column AMT_BALANCE_diff : 22.7972631454 seconds
# Getting Trend for column: AMT_BALANCE_diff, 6
# Done Getting Trend for Column AMT_BALANCE_diff : 30.2484619617 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT_diff, 6
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT_diff : 22.5885329247 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT_diff, 6
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT_diff : 23.0946779251 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT_diff, 6
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT_diff : 30.7859840393 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT_diff, 6
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT_diff : 23.0901341438 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT_diff, 6
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT_diff : 22.7368090153 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT_diff, 6
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT_diff : 29.9733297825 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_diff, 6
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_diff : 23.7727901936 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_diff, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_diff : 24.245018959 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_diff, 6
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_diff : 30.8691048622 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_diff, 6
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_diff : 24.0539090633 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_diff, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_diff : 23.7383749485 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_diff, 6
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_diff : 30.1901271343 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT_diff, 6
# Done Aggregating Column CNT_DRAWINGS_CURRENT_diff : 22.9160950184 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT_diff, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT_diff : 23.653275013 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT_diff, 6
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT_diff : 31.2472479343 seconds
# Getting Aggregates for column: cnt_pos_ratio_diff_diff, 6
# Done Aggregating Column cnt_pos_ratio_diff_diff : 23.4111990929 seconds
# Getting Kurtosis for Column: cnt_pos_ratio_diff_diff, 6
# Done Getting Kurtosis for Column cnt_pos_ratio_diff_diff : 23.2769088745 seconds
# Getting Trend for column: cnt_pos_ratio_diff_diff, 6
# Done Getting Trend for Column cnt_pos_ratio_diff_diff : 31.437912941 seconds
# Getting Aggregates for column: cnt_atm_ratio_diff_diff, 6
# Done Aggregating Column cnt_atm_ratio_diff_diff : 23.4310770035 seconds
# Getting Kurtosis for Column: cnt_atm_ratio_diff_diff, 6
# Done Getting Kurtosis for Column cnt_atm_ratio_diff_diff : 23.5459711552 seconds
# Getting Trend for column: cnt_atm_ratio_diff_diff, 6
# Done Getting Trend for Column cnt_atm_ratio_diff_diff : 31.4968860149 seconds
# Getting Aggregates for column: amt_pos_ratio_diff_diff, 6
# Done Aggregating Column amt_pos_ratio_diff_diff : 23.1530809402 seconds
# Getting Kurtosis for Column: amt_pos_ratio_diff_diff, 6
# Done Getting Kurtosis for Column amt_pos_ratio_diff_diff : 23.3380899429 seconds
# Getting Trend for column: amt_pos_ratio_diff_diff, 6
# Done Getting Trend for Column amt_pos_ratio_diff_diff : 31.3429739475 seconds
# Getting Aggregates for column: amt_atm_ratio_diff_diff, 6
# Done Aggregating Column amt_atm_ratio_diff_diff : 23.2794730663 seconds
# Getting Kurtosis for Column: amt_atm_ratio_diff_diff, 6
# Done Getting Kurtosis for Column amt_atm_ratio_diff_diff : 23.0376210213 seconds
# Getting Trend for column: amt_atm_ratio_diff_diff, 6
# Done Getting Trend for Column amt_atm_ratio_diff_diff : 31.2498919964 seconds
# Getting Aggregates for column: balance_to_drawing_ratio_diff_diff, 6
# Done Aggregating Column balance_to_drawing_ratio_diff_diff : 23.0757460594 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio_diff_diff, 6
# Done Getting Kurtosis for Column balance_to_drawing_ratio_diff_diff : 23.8257029057 seconds
# Getting Trend for column: balance_to_drawing_ratio_diff_diff, 6
# Done Getting Trend for Column balance_to_drawing_ratio_diff_diff : 31.1891410351 seconds
# Getting Aggregates for column: balance_to_limit_ratio_diff_diff, 6
# Done Aggregating Column balance_to_limit_ratio_diff_diff : 23.3598439693 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio_diff_diff, 6
# Done Getting Kurtosis for Column balance_to_limit_ratio_diff_diff : 23.5636761189 seconds
# Getting Trend for column: balance_to_limit_ratio_diff_diff, 6
# Done Getting Trend for Column balance_to_limit_ratio_diff_diff : 31.3567328453 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio_diff_diff, 6
# Done Aggregating Column balance_to_total_payment_ratio_diff_diff : 23.1709640026 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio_diff_diff, 6
# Done Getting Kurtosis for Column balance_to_total_payment_ratio_diff_diff : 23.78769207 seconds
# Getting Trend for column: balance_to_total_payment_ratio_diff_diff, 6
# Done Getting Trend for Column balance_to_total_payment_ratio_diff_diff : 32.6122748852 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio_diff_diff, 6
# Done Aggregating Column balance_to_minimum_installment_ratio_diff_diff : 23.2511591911 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio_diff_diff, 6
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio_diff_diff : 23.5828039646 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio_diff_diff, 6
# Done Getting Trend for Column balance_to_minimum_installment_ratio_diff_diff : 31.2239999771 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio_diff_diff, 6
# Done Aggregating Column minimum_installment_to_total_payment_ratio_diff_diff : 23.2354030609 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio_diff_diff, 6
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio_diff_diff : 23.6321258545 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio_diff_diff, 6
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio_diff_diff : 31.2661211491 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio_diff_diff, 6
# Done Aggregating Column minimum_installment_to_current_payment_ratio_diff_diff : 23.2914869785 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio_diff_diff, 6
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio_diff_diff : 23.7009530067 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio_diff_diff, 6
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio_diff_diff : 31.5069749355 seconds
# Getting Aggregates for column: current_to_total_payment_ratio_diff_diff, 6
# Done Aggregating Column current_to_total_payment_ratio_diff_diff : 23.2733740807 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio_diff_diff, 6
# Done Getting Kurtosis for Column current_to_total_payment_ratio_diff_diff : 23.3833069801 seconds
# Getting Trend for column: current_to_total_payment_ratio_diff_diff, 6
# Done Getting Trend for Column current_to_total_payment_ratio_diff_diff : 31.4475779533 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio_diff_diff, 6
# Done Aggregating Column payment_to_receivable_min_ratio_diff_diff : 23.0856020451 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio_diff_diff, 6
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio_diff_diff : 23.8681018353 seconds
# Getting Trend for column: payment_to_receivable_min_ratio_diff_diff, 6
# Done Getting Trend for Column payment_to_receivable_min_ratio_diff_diff : 31.1894190311 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio_diff_diff, 6
# Done Aggregating Column payment_to_receivable_curr_ratio_diff_diff : 23.2975800037 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio_diff_diff, 6
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio_diff_diff : 23.5727570057 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio_diff_diff, 6
# Done Getting Trend for Column payment_to_receivable_curr_ratio_diff_diff : 31.7726039886 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio_diff_diff, 6
# Done Aggregating Column payment_to_receivable_total_ratio_diff_diff : 23.3932991028 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio_diff_diff, 6
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio_diff_diff : 23.6586790085 seconds
# Getting Trend for column: payment_to_receivable_total_ratio_diff_diff, 6
# Done Getting Trend for Column payment_to_receivable_total_ratio_diff_diff : 31.765034914 seconds
# Getting Aggregates for column: SK_DPD_diff_diff, 6
# Done Aggregating Column SK_DPD_diff_diff : 24.6786329746 seconds
# Getting Kurtosis for Column: SK_DPD_diff_diff, 6
# Done Getting Kurtosis for Column SK_DPD_diff_diff : 23.1452350616 seconds
# Getting Trend for column: SK_DPD_diff_diff, 6
# Done Getting Trend for Column SK_DPD_diff_diff : 31.3801209927 seconds
# Getting Aggregates for column: SK_DPD_DEF_diff_diff, 6
# Done Aggregating Column SK_DPD_DEF_diff_diff : 23.2114219666 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_diff_diff, 6
# Done Getting Kurtosis for Column SK_DPD_DEF_diff_diff : 23.2292969227 seconds
# Getting Trend for column: SK_DPD_DEF_diff_diff, 6
# Done Getting Trend for Column SK_DPD_DEF_diff_diff : 31.216809988 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT_diff_diff, 6
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT_diff_diff : 23.333324194 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT_diff_diff, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT_diff_diff : 23.7577259541 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT_diff_diff, 6
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT_diff_diff : 31.1284358501 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT_diff_diff, 6
# Done Aggregating Column AMT_DRAWINGS_CURRENT_diff_diff : 23.3392970562 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT_diff_diff, 6
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT_diff_diff : 23.4921600819 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT_diff_diff, 6
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT_diff_diff : 31.2986540794 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE_diff_diff, 6
# Done Aggregating Column AMT_TOTAL_RECEIVABLE_diff_diff : 23.0966978073 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE_diff_diff, 6
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE_diff_diff : 23.4560520649 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE_diff_diff, 6
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE_diff_diff : 30.9489920139 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT_diff_diff, 6
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT_diff_diff : 23.2046430111 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT_diff_diff, 6
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT_diff_diff : 23.3921639919 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT_diff_diff, 6
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT_diff_diff : 31.3200809956 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM_diff_diff, 6
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM_diff_diff : 24.2961609364 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM_diff_diff, 6
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM_diff_diff : 23.2368459702 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM_diff_diff, 6
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM_diff_diff : 31.8195810318 seconds
# Getting Aggregates for column: AMT_BALANCE_diff_diff, 6
# Done Aggregating Column AMT_BALANCE_diff_diff : 23.4270989895 seconds
# Getting Kurtosis for Column: AMT_BALANCE_diff_diff, 6
# Done Getting Kurtosis for Column AMT_BALANCE_diff_diff : 23.7477521896 seconds
# Getting Trend for column: AMT_BALANCE_diff_diff, 6
# Done Getting Trend for Column AMT_BALANCE_diff_diff : 31.483673811 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT_diff_diff, 6
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT_diff_diff : 23.2285251617 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT_diff_diff, 6
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT_diff_diff : 23.3041698933 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT_diff_diff, 6
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT_diff_diff : 31.5223610401 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT_diff_diff, 6
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT_diff_diff : 23.466242075 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT_diff_diff, 6
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT_diff_diff : 23.3065598011 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT_diff_diff, 6
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT_diff_diff : 31.137275219 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_diff_diff, 6
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_diff_diff : 23.4425308704 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_diff_diff, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_diff_diff : 23.4992311001 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_diff_diff, 6
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_diff_diff : 31.9542088509 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_diff_diff, 6
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_diff_diff : 23.4730021954 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_diff_diff, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_diff_diff : 23.3494439125 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_diff_diff, 6
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_diff_diff : 31.2205719948 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT_diff_diff, 6
# Done Aggregating Column CNT_DRAWINGS_CURRENT_diff_diff : 23.3823170662 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT_diff_diff, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT_diff_diff : 23.452521801 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT_diff_diff, 6
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT_diff_diff : 31.4770669937 seconds
# Getting Aggregates for column: cnt_pos_ratio_rolling6, 6
# Done Aggregating Column cnt_pos_ratio_rolling6 : 23.5066540241 seconds
# Getting Kurtosis for Column: cnt_pos_ratio_rolling6, 6
# Done Getting Kurtosis for Column cnt_pos_ratio_rolling6 : 23.3234009743 seconds
# Getting Trend for column: cnt_pos_ratio_rolling6, 6
# Done Getting Trend for Column cnt_pos_ratio_rolling6 : 32.1776130199 seconds
# Getting Aggregates for column: cnt_atm_ratio_rolling6, 6
# Done Aggregating Column cnt_atm_ratio_rolling6 : 23.692043066 seconds
# Getting Kurtosis for Column: cnt_atm_ratio_rolling6, 6
# Done Getting Kurtosis for Column cnt_atm_ratio_rolling6 : 23.4224081039 seconds
# Getting Trend for column: cnt_atm_ratio_rolling6, 6
# Done Getting Trend for Column cnt_atm_ratio_rolling6 : 32.1439340115 seconds
# Getting Aggregates for column: amt_pos_ratio_rolling6, 6
# Done Aggregating Column amt_pos_ratio_rolling6 : 23.4448108673 seconds
# Getting Kurtosis for Column: amt_pos_ratio_rolling6, 6
# Done Getting Kurtosis for Column amt_pos_ratio_rolling6 : 23.0632650852 seconds
# Getting Trend for column: amt_pos_ratio_rolling6, 6
# Done Getting Trend for Column amt_pos_ratio_rolling6 : 30.7999999523 seconds
# Getting Aggregates for column: amt_atm_ratio_rolling6, 6
# Done Aggregating Column amt_atm_ratio_rolling6 : 22.9326930046 seconds
# Getting Kurtosis for Column: amt_atm_ratio_rolling6, 6
# Done Getting Kurtosis for Column amt_atm_ratio_rolling6 : 23.0919570923 seconds
# Getting Trend for column: amt_atm_ratio_rolling6, 6
# Done Getting Trend for Column amt_atm_ratio_rolling6 : 31.1421928406 seconds
# Getting Aggregates for column: balance_to_drawing_ratio_rolling6, 6
# Done Aggregating Column balance_to_drawing_ratio_rolling6 : 23.0512201786 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio_rolling6, 6
# Done Getting Kurtosis for Column balance_to_drawing_ratio_rolling6 : 22.8963398933 seconds
# Getting Trend for column: balance_to_drawing_ratio_rolling6, 6
# Done Getting Trend for Column balance_to_drawing_ratio_rolling6 : 30.9614100456 seconds
# Getting Aggregates for column: balance_to_limit_ratio_rolling6, 6
# Done Aggregating Column balance_to_limit_ratio_rolling6 : 23.0251739025 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio_rolling6, 6
# Done Getting Kurtosis for Column balance_to_limit_ratio_rolling6 : 22.9984719753 seconds
# Getting Trend for column: balance_to_limit_ratio_rolling6, 6
# Done Getting Trend for Column balance_to_limit_ratio_rolling6 : 30.9263660908 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio_rolling6, 6
# Done Aggregating Column balance_to_total_payment_ratio_rolling6 : 23.041852951 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio_rolling6, 6
# Done Getting Kurtosis for Column balance_to_total_payment_ratio_rolling6 : 23.4741001129 seconds
# Getting Trend for column: balance_to_total_payment_ratio_rolling6, 6
# Done Getting Trend for Column balance_to_total_payment_ratio_rolling6 : 31.1913428307 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio_rolling6, 6
# Done Aggregating Column balance_to_minimum_installment_ratio_rolling6 : 23.1682059765 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio_rolling6, 6
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio_rolling6 : 23.0331070423 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio_rolling6, 6
# Done Getting Trend for Column balance_to_minimum_installment_ratio_rolling6 : 31.319108963 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio_rolling6, 6
# Done Aggregating Column minimum_installment_to_total_payment_ratio_rolling6 : 23.2052631378 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio_rolling6, 6
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio_rolling6 : 23.3076369762 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio_rolling6, 6
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio_rolling6 : 31.3079090118 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio_rolling6, 6
# Done Aggregating Column minimum_installment_to_current_payment_ratio_rolling6 : 23.368737936 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio_rolling6, 6
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio_rolling6 : 23.2486479282 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio_rolling6, 6
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio_rolling6 : 30.958204031 seconds
# Getting Aggregates for column: current_to_total_payment_ratio_rolling6, 6
# Done Aggregating Column current_to_total_payment_ratio_rolling6 : 22.9344511032 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio_rolling6, 6
# Done Getting Kurtosis for Column current_to_total_payment_ratio_rolling6 : 23.138240099 seconds
# Getting Trend for column: current_to_total_payment_ratio_rolling6, 6
# Done Getting Trend for Column current_to_total_payment_ratio_rolling6 : 31.234279871 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio_rolling6, 6
# Done Aggregating Column payment_to_receivable_min_ratio_rolling6 : 23.2800431252 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio_rolling6, 6
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio_rolling6 : 24.5165669918 seconds
# Getting Trend for column: payment_to_receivable_min_ratio_rolling6, 6
# Done Getting Trend for Column payment_to_receivable_min_ratio_rolling6 : 31.5439069271 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio_rolling6, 6
# Done Aggregating Column payment_to_receivable_curr_ratio_rolling6 : 23.1004090309 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio_rolling6, 6
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio_rolling6 : 23.4421880245 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio_rolling6, 6
# Done Getting Trend for Column payment_to_receivable_curr_ratio_rolling6 : 30.9555008411 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio_rolling6, 6
# Done Aggregating Column payment_to_receivable_total_ratio_rolling6 : 22.905174017 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio_rolling6, 6
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio_rolling6 : 23.9248850346 seconds
# Getting Trend for column: payment_to_receivable_total_ratio_rolling6, 6
# Done Getting Trend for Column payment_to_receivable_total_ratio_rolling6 : 30.6121919155 seconds
# Getting Aggregates for column: SK_DPD_rolling6, 6
# Done Aggregating Column SK_DPD_rolling6 : 23.5413081646 seconds
# Getting Kurtosis for Column: SK_DPD_rolling6, 6
# Done Getting Kurtosis for Column SK_DPD_rolling6 : 22.6792299747 seconds
# Getting Trend for column: SK_DPD_rolling6, 6
# Done Getting Trend for Column SK_DPD_rolling6 : 31.9743368626 seconds
# Getting Aggregates for column: SK_DPD_DEF_rolling6, 6
# Done Aggregating Column SK_DPD_DEF_rolling6 : 23.5817840099 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_rolling6, 6
# Done Getting Kurtosis for Column SK_DPD_DEF_rolling6 : 22.5732161999 seconds
# Getting Trend for column: SK_DPD_DEF_rolling6, 6
# Done Getting Trend for Column SK_DPD_DEF_rolling6 : 31.8585758209 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT_rolling6, 6
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT_rolling6 : 23.4782099724 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT_rolling6, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT_rolling6 : 23.0114731789 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT_rolling6, 6
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT_rolling6 : 32.0157239437 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT_rolling6, 6
# Done Aggregating Column AMT_DRAWINGS_CURRENT_rolling6 : 23.727230072 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT_rolling6, 6
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT_rolling6 : 23.1506409645 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT_rolling6, 6
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT_rolling6 : 32.0173740387 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE_rolling6, 6
# Done Aggregating Column AMT_TOTAL_RECEIVABLE_rolling6 : 23.4320878983 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE_rolling6, 6
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE_rolling6 : 23.2670381069 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE_rolling6, 6
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE_rolling6 : 32.3989739418 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT_rolling6, 6
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT_rolling6 : 23.6067829132 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT_rolling6, 6
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT_rolling6 : 23.2582700253 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT_rolling6, 6
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT_rolling6 : 32.3962330818 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM_rolling6, 6
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM_rolling6 : 23.5043439865 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM_rolling6, 6
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM_rolling6 : 23.4560709 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM_rolling6, 6
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM_rolling6 : 32.2745280266 seconds
# Getting Aggregates for column: AMT_BALANCE_rolling6, 6
# Done Aggregating Column AMT_BALANCE_rolling6 : 23.5225989819 seconds
# Getting Kurtosis for Column: AMT_BALANCE_rolling6, 6
# Done Getting Kurtosis for Column AMT_BALANCE_rolling6 : 23.4139239788 seconds
# Getting Trend for column: AMT_BALANCE_rolling6, 6
# Done Getting Trend for Column AMT_BALANCE_rolling6 : 32.8908791542 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT_rolling6, 6
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT_rolling6 : 23.8889889717 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT_rolling6, 6
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT_rolling6 : 23.3029589653 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT_rolling6, 6
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT_rolling6 : 32.3382780552 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT_rolling6, 6
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT_rolling6 : 23.298842907 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT_rolling6, 6
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT_rolling6 : 23.4165489674 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT_rolling6, 6
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT_rolling6 : 31.8539450169 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_rolling6, 6
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 23.629611969 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_rolling6, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 22.9539339542 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_rolling6, 6
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 31.9697401524 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_rolling6, 6
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 23.7205500603 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_rolling6, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 23.1826839447 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_rolling6, 6
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 31.9109840393 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT_rolling6, 6
# Done Aggregating Column CNT_DRAWINGS_CURRENT_rolling6 : 23.7475419044 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT_rolling6, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT_rolling6 : 23.157818079 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT_rolling6, 6
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT_rolling6 : 32.0761799812 seconds
# Getting Aggregates for column: cnt_pos_ratio_rolling12, 6
# Done Aggregating Column cnt_pos_ratio_rolling12 : 23.8012418747 seconds
# Getting Kurtosis for Column: cnt_pos_ratio_rolling12, 6
# Done Getting Kurtosis for Column cnt_pos_ratio_rolling12 : 23.1328959465 seconds
# Getting Trend for column: cnt_pos_ratio_rolling12, 6
# Done Getting Trend for Column cnt_pos_ratio_rolling12 : 34.5770421028 seconds
# Getting Aggregates for column: cnt_atm_ratio_rolling12, 6
# Done Aggregating Column cnt_atm_ratio_rolling12 : 24.1448969841 seconds
# Getting Kurtosis for Column: cnt_atm_ratio_rolling12, 6
# Done Getting Kurtosis for Column cnt_atm_ratio_rolling12 : 23.20896101 seconds
# Getting Trend for column: cnt_atm_ratio_rolling12, 6
# Done Getting Trend for Column cnt_atm_ratio_rolling12 : 34.1765179634 seconds
# Getting Aggregates for column: amt_pos_ratio_rolling12, 6
# Done Aggregating Column amt_pos_ratio_rolling12 : 23.7844851017 seconds
# Getting Kurtosis for Column: amt_pos_ratio_rolling12, 6
# Done Getting Kurtosis for Column amt_pos_ratio_rolling12 : 22.7718379498 seconds
# Getting Trend for column: amt_pos_ratio_rolling12, 6
# Done Getting Trend for Column amt_pos_ratio_rolling12 : 34.0459780693 seconds
# Getting Aggregates for column: amt_atm_ratio_rolling12, 6
# Done Aggregating Column amt_atm_ratio_rolling12 : 23.8810219765 seconds
# Getting Kurtosis for Column: amt_atm_ratio_rolling12, 6
# Done Getting Kurtosis for Column amt_atm_ratio_rolling12 : 23.0584070683 seconds
# Getting Trend for column: amt_atm_ratio_rolling12, 6
# Done Getting Trend for Column amt_atm_ratio_rolling12 : 34.2884998322 seconds
# Getting Aggregates for column: balance_to_drawing_ratio_rolling12, 6
# Done Aggregating Column balance_to_drawing_ratio_rolling12 : 23.7565829754 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio_rolling12, 6
# Done Getting Kurtosis for Column balance_to_drawing_ratio_rolling12 : 23.3043069839 seconds
# Getting Trend for column: balance_to_drawing_ratio_rolling12, 6
# Done Getting Trend for Column balance_to_drawing_ratio_rolling12 : 34.4092841148 seconds
# Getting Aggregates for column: balance_to_limit_ratio_rolling12, 6
# Done Aggregating Column balance_to_limit_ratio_rolling12 : 23.787842989 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio_rolling12, 6
# Done Getting Kurtosis for Column balance_to_limit_ratio_rolling12 : 23.5488810539 seconds
# Getting Trend for column: balance_to_limit_ratio_rolling12, 6
# Done Getting Trend for Column balance_to_limit_ratio_rolling12 : 34.4203169346 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio_rolling12, 6
# Done Aggregating Column balance_to_total_payment_ratio_rolling12 : 24.3392989635 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio_rolling12, 6
# Done Getting Kurtosis for Column balance_to_total_payment_ratio_rolling12 : 23.0940849781 seconds
# Getting Trend for column: balance_to_total_payment_ratio_rolling12, 6
# Done Getting Trend for Column balance_to_total_payment_ratio_rolling12 : 34.2234680653 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio_rolling12, 6
# Done Aggregating Column balance_to_minimum_installment_ratio_rolling12 : 23.5493500233 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio_rolling12, 6
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio_rolling12 : 23.3705480099 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio_rolling12, 6
# Done Getting Trend for Column balance_to_minimum_installment_ratio_rolling12 : 34.0975990295 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio_rolling12, 6
# Done Aggregating Column minimum_installment_to_total_payment_ratio_rolling12 : 23.7805700302 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio_rolling12, 6
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio_rolling12 : 23.1726329327 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio_rolling12, 6
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio_rolling12 : 34.195043087 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio_rolling12, 6
# Done Aggregating Column minimum_installment_to_current_payment_ratio_rolling12 : 23.7137238979 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio_rolling12, 6
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio_rolling12 : 23.2579638958 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio_rolling12, 6
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio_rolling12 : 33.9366960526 seconds
# Getting Aggregates for column: current_to_total_payment_ratio_rolling12, 6
# Done Aggregating Column current_to_total_payment_ratio_rolling12 : 23.6556911469 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio_rolling12, 6
# Done Getting Kurtosis for Column current_to_total_payment_ratio_rolling12 : 23.2862579823 seconds
# Getting Trend for column: current_to_total_payment_ratio_rolling12, 6
# Done Getting Trend for Column current_to_total_payment_ratio_rolling12 : 34.3081169128 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio_rolling12, 6
# Done Aggregating Column payment_to_receivable_min_ratio_rolling12 : 24.2449738979 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio_rolling12, 6
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio_rolling12 : 23.1749081612 seconds
# Getting Trend for column: payment_to_receivable_min_ratio_rolling12, 6
# Done Getting Trend for Column payment_to_receivable_min_ratio_rolling12 : 34.3585150242 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio_rolling12, 6
# Done Aggregating Column payment_to_receivable_curr_ratio_rolling12 : 23.7921118736 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio_rolling12, 6
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio_rolling12 : 23.2405171394 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio_rolling12, 6
# Done Getting Trend for Column payment_to_receivable_curr_ratio_rolling12 : 34.1825590134 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio_rolling12, 6
# Done Aggregating Column payment_to_receivable_total_ratio_rolling12 : 23.8332228661 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio_rolling12, 6
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio_rolling12 : 23.1805999279 seconds
# Getting Trend for column: payment_to_receivable_total_ratio_rolling12, 6
# Done Getting Trend for Column payment_to_receivable_total_ratio_rolling12 : 34.3614630699 seconds
# Getting Aggregates for column: SK_DPD_rolling12, 6
# Done Aggregating Column SK_DPD_rolling12 : 23.5497090816 seconds
# Getting Kurtosis for Column: SK_DPD_rolling12, 6
# Done Getting Kurtosis for Column SK_DPD_rolling12 : 22.6858119965 seconds
# Getting Trend for column: SK_DPD_rolling12, 6
# Done Getting Trend for Column SK_DPD_rolling12 : 32.3509290218 seconds
# Getting Aggregates for column: SK_DPD_DEF_rolling12, 6
# Done Aggregating Column SK_DPD_DEF_rolling12 : 24.6530969143 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_rolling12, 6
# Done Getting Kurtosis for Column SK_DPD_DEF_rolling12 : 23.9450149536 seconds
# Getting Trend for column: SK_DPD_DEF_rolling12, 6
# Done Getting Trend for Column SK_DPD_DEF_rolling12 : 34.0913259983 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT_rolling12, 6
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT_rolling12 : 25.3737330437 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT_rolling12, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT_rolling12 : 23.5355241299 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT_rolling12, 6
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT_rolling12 : 32.226733923 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT_rolling12, 6
# Done Aggregating Column AMT_DRAWINGS_CURRENT_rolling12 : 23.4520349503 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT_rolling12, 6
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT_rolling12 : 22.7049779892 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT_rolling12, 6
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT_rolling12 : 32.3363320827 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE_rolling12, 6
# Done Aggregating Column AMT_TOTAL_RECEIVABLE_rolling12 : 23.2316100597 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE_rolling12, 6
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE_rolling12 : 23.1207778454 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE_rolling12, 6
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE_rolling12 : 33.617538929 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT_rolling12, 6
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT_rolling12 : 23.5929601192 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT_rolling12, 6
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT_rolling12 : 23.2887289524 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT_rolling12, 6
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT_rolling12 : 33.7380280495 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM_rolling12, 6
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM_rolling12 : 23.6822888851 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM_rolling12, 6
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM_rolling12 : 24.6807460785 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM_rolling12, 6
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM_rolling12 : 33.1947090626 seconds
# Getting Aggregates for column: AMT_BALANCE_rolling12, 6
# Done Aggregating Column AMT_BALANCE_rolling12 : 25.0478260517 seconds
# Getting Kurtosis for Column: AMT_BALANCE_rolling12, 6
# Done Getting Kurtosis for Column AMT_BALANCE_rolling12 : 24.3728318214 seconds
# Getting Trend for column: AMT_BALANCE_rolling12, 6
# Done Getting Trend for Column AMT_BALANCE_rolling12 : 33.3907651901 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT_rolling12, 6
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT_rolling12 : 23.9483938217 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT_rolling12, 6
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT_rolling12 : 22.839564085 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT_rolling12, 6
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT_rolling12 : 32.7069580555 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT_rolling12, 6
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT_rolling12 : 23.5112938881 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT_rolling12, 6
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT_rolling12 : 22.6790890694 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT_rolling12, 6
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT_rolling12 : 32.4217550755 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_rolling12, 6
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 23.4380838871 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_rolling12, 6
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 22.5985739231 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_rolling12, 6
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 32.1443190575 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_rolling12, 6
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 23.867702961 seconds
# ...
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT_rolling6 : 23.1891691685 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT_rolling6, 12
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT_rolling6 : 32.2494499683 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM_rolling6, 12
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM_rolling6 : 25.7552890778 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM_rolling6, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM_rolling6 : 24.504365921 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM_rolling6, 12
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM_rolling6 : 33.3519659042 seconds
# Getting Aggregates for column: AMT_BALANCE_rolling6, 12
# Done Aggregating Column AMT_BALANCE_rolling6 : 25.7396380901 seconds
# Getting Kurtosis for Column: AMT_BALANCE_rolling6, 12
# Done Getting Kurtosis for Column AMT_BALANCE_rolling6 : 24.5962049961 seconds
# Getting Trend for column: AMT_BALANCE_rolling6, 12
# Done Getting Trend for Column AMT_BALANCE_rolling6 : 32.8393819332 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT_rolling6, 12
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT_rolling6 : 24.320235014 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT_rolling6 : 22.8960969448 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT_rolling6, 12
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT_rolling6 : 32.1323881149 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT_rolling6 : 24.429931879 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT_rolling6 : 24.1522321701 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT_rolling6 : 32.9901418686 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 24.4684820175 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 24.3910830021 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 32.9522171021 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 24.5814328194 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 23.0911121368 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 32.3559710979 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT_rolling6, 12
# Done Aggregating Column CNT_DRAWINGS_CURRENT_rolling6 : 24.4606277943 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT_rolling6 : 23.2488920689 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT_rolling6, 12
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT_rolling6 : 32.2864201069 seconds
# Getting Aggregates for column: cnt_pos_ratio_rolling12, 12
# Done Aggregating Column cnt_pos_ratio_rolling12 : 24.5109429359 seconds
# Getting Kurtosis for Column: cnt_pos_ratio_rolling12, 12
# Done Getting Kurtosis for Column cnt_pos_ratio_rolling12 : 22.7598659992 seconds
# Getting Trend for column: cnt_pos_ratio_rolling12, 12
# Done Getting Trend for Column cnt_pos_ratio_rolling12 : 34.2511670589 seconds
# Getting Aggregates for column: cnt_atm_ratio_rolling12, 12
# Done Aggregating Column cnt_atm_ratio_rolling12 : 24.5788199902 seconds
# Getting Kurtosis for Column: cnt_atm_ratio_rolling12, 12
# Done Getting Kurtosis for Column cnt_atm_ratio_rolling12 : 22.6926078796 seconds
# Getting Trend for column: cnt_atm_ratio_rolling12, 12
# Done Getting Trend for Column cnt_atm_ratio_rolling12 : 34.39381814 seconds
# Getting Aggregates for column: amt_pos_ratio_rolling12, 12
# Done Aggregating Column amt_pos_ratio_rolling12 : 24.5740368366 seconds
# Getting Kurtosis for Column: amt_pos_ratio_rolling12, 12
# Done Getting Kurtosis for Column amt_pos_ratio_rolling12 : 23.0116331577 seconds
# Getting Trend for column: amt_pos_ratio_rolling12, 12
# Done Getting Trend for Column amt_pos_ratio_rolling12 : 34.0831329823 seconds
# Getting Aggregates for column: amt_atm_ratio_rolling12, 12
# Done Aggregating Column amt_atm_ratio_rolling12 : 24.4052698612 seconds
# Getting Kurtosis for Column: amt_atm_ratio_rolling12, 12
# Done Getting Kurtosis for Column amt_atm_ratio_rolling12 : 22.6830129623 seconds
# Getting Trend for column: amt_atm_ratio_rolling12, 12
# Done Getting Trend for Column amt_atm_ratio_rolling12 : 34.1039450169 seconds
# Getting Aggregates for column: balance_to_drawing_ratio_rolling12, 12
# Done Aggregating Column balance_to_drawing_ratio_rolling12 : 24.3674709797 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio_rolling12, 12
# Done Getting Kurtosis for Column balance_to_drawing_ratio_rolling12 : 22.7770261765 seconds
# Getting Trend for column: balance_to_drawing_ratio_rolling12, 12
# Done Getting Trend for Column balance_to_drawing_ratio_rolling12 : 34.1400468349 seconds
# Getting Aggregates for column: balance_to_limit_ratio_rolling12, 12
# Done Aggregating Column balance_to_limit_ratio_rolling12 : 24.2733712196 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio_rolling12, 12
# Done Getting Kurtosis for Column balance_to_limit_ratio_rolling12 : 23.1835699081 seconds
# Getting Trend for column: balance_to_limit_ratio_rolling12, 12
# Done Getting Trend for Column balance_to_limit_ratio_rolling12 : 34.2428920269 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio_rolling12, 12
# Done Aggregating Column balance_to_total_payment_ratio_rolling12 : 24.3884398937 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio_rolling12, 12
# Done Getting Kurtosis for Column balance_to_total_payment_ratio_rolling12 : 23.227533102 seconds
# Getting Trend for column: balance_to_total_payment_ratio_rolling12, 12
# Done Getting Trend for Column balance_to_total_payment_ratio_rolling12 : 34.4322879314 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio_rolling12, 12
# Done Aggregating Column balance_to_minimum_installment_ratio_rolling12 : 24.5497441292 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio_rolling12, 12
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio_rolling12 : 22.9729609489 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio_rolling12, 12
# Done Getting Trend for Column balance_to_minimum_installment_ratio_rolling12 : 34.1890158653 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio_rolling12, 12
# Done Aggregating Column minimum_installment_to_total_payment_ratio_rolling12 : 24.5062100887 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio_rolling12, 12
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio_rolling12 : 22.9159500599 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio_rolling12, 12
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio_rolling12 : 34.4703760147 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio_rolling12, 12
# Done Aggregating Column minimum_installment_to_current_payment_ratio_rolling12 : 24.5462079048 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio_rolling12, 12
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio_rolling12 : 22.8240349293 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio_rolling12, 12
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio_rolling12 : 34.1848330498 seconds
# Getting Aggregates for column: current_to_total_payment_ratio_rolling12, 12
# Done Aggregating Column current_to_total_payment_ratio_rolling12 : 24.3414969444 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio_rolling12, 12
# Done Getting Kurtosis for Column current_to_total_payment_ratio_rolling12 : 22.9742460251 seconds
# Getting Trend for column: current_to_total_payment_ratio_rolling12, 12
# Done Getting Trend for Column current_to_total_payment_ratio_rolling12 : 34.1996970177 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio_rolling12, 12
# Done Aggregating Column payment_to_receivable_min_ratio_rolling12 : 24.4457299709 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio_rolling12, 12
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio_rolling12 : 22.8654119968 seconds
# Getting Trend for column: payment_to_receivable_min_ratio_rolling12, 12
# Done Getting Trend for Column payment_to_receivable_min_ratio_rolling12 : 34.2308580875 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio_rolling12, 12
# Done Aggregating Column payment_to_receivable_curr_ratio_rolling12 : 24.4986400604 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio_rolling12, 12
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio_rolling12 : 22.9332590103 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio_rolling12, 12
# Done Getting Trend for Column payment_to_receivable_curr_ratio_rolling12 : 35.0303618908 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio_rolling12, 12
# Done Aggregating Column payment_to_receivable_total_ratio_rolling12 : 24.4589579105 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio_rolling12, 12
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio_rolling12 : 24.1051380634 seconds
# Getting Trend for column: payment_to_receivable_total_ratio_rolling12, 12
# Done Getting Trend for Column payment_to_receivable_total_ratio_rolling12 : 34.1496341228 seconds
# Getting Aggregates for column: SK_DPD_rolling12, 12
# Done Aggregating Column SK_DPD_rolling12 : 24.5646529198 seconds
# Getting Kurtosis for Column: SK_DPD_rolling12, 12
# Done Getting Kurtosis for Column SK_DPD_rolling12 : 25.6582860947 seconds
# Getting Trend for column: SK_DPD_rolling12, 12
# Done Getting Trend for Column SK_DPD_rolling12 : 34.5400168896 seconds
# Getting Aggregates for column: SK_DPD_DEF_rolling12, 12
# Done Aggregating Column SK_DPD_DEF_rolling12 : 24.806344986 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_rolling12, 12
# Done Getting Kurtosis for Column SK_DPD_DEF_rolling12 : 22.5214040279 seconds
# Getting Trend for column: SK_DPD_DEF_rolling12, 12
# Done Getting Trend for Column SK_DPD_DEF_rolling12 : 34.4678499699 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT_rolling12, 12
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT_rolling12 : 24.8315060139 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT_rolling12 : 23.079018116 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT_rolling12, 12
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT_rolling12 : 34.4133548737 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT_rolling12, 12
# Done Aggregating Column AMT_DRAWINGS_CURRENT_rolling12 : 24.6382009983 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT_rolling12 : 23.2477591038 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT_rolling12, 12
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT_rolling12 : 34.3126499653 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE_rolling12, 12
# Done Aggregating Column AMT_TOTAL_RECEIVABLE_rolling12 : 24.6313688755 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE_rolling12, 12
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE_rolling12 : 23.4014530182 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE_rolling12, 12
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE_rolling12 : 34.2329959869 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT_rolling12, 12
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT_rolling12 : 24.5493102074 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT_rolling12 : 23.2836477757 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT_rolling12, 12
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT_rolling12 : 34.364454031 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM_rolling12, 12
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM_rolling12 : 24.6380519867 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM_rolling12, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM_rolling12 : 22.9970049858 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM_rolling12, 12
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM_rolling12 : 34.2368161678 seconds
# Getting Aggregates for column: AMT_BALANCE_rolling12, 12
# Done Aggregating Column AMT_BALANCE_rolling12 : 24.4987900257 seconds
# Getting Kurtosis for Column: AMT_BALANCE_rolling12, 12
# Done Getting Kurtosis for Column AMT_BALANCE_rolling12 : 23.3666369915 seconds
# Getting Trend for column: AMT_BALANCE_rolling12, 12
# Done Getting Trend for Column AMT_BALANCE_rolling12 : 34.5510268211 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT_rolling12, 12
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT_rolling12 : 26.1025462151 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT_rolling12 : 24.5025458336 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT_rolling12, 12
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT_rolling12 : 35.0968289375 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT_rolling12 : 24.8217251301 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT_rolling12 : 24.3175048828 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT_rolling12 : 35.1971781254 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 26.2149779797 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 24.2296938896 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 35.1477119923 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 24.7373092175 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 22.6751248837 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 34.260201931 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT_rolling12, 12
# Done Aggregating Column CNT_DRAWINGS_CURRENT_rolling12 : 24.8536641598 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT_rolling12 : 22.9589128494 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT_rolling12, 12
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT_rolling12 : 34.1733319759 seconds
# (103558, 1929) Before dropping Na's
# (103558, 1929) After dropping Na's

# %% [markdown]
# # Previous Application Features

# %%
def GetPreviousAppFeatures(prev_app_path = "../data/previous_application.csv"):
    prev_apps = pd.read_csv(prev_app_path).sort_values(by=["SK_ID_CURR","DAYS_DECISION"]).reset_index(drop = True)
    
    # Generating Some Features
    prev_apps["proportion_granted"] = prev_apps["AMT_APPLICATION"]/(prev_apps["AMT_CREDIT"]+1.0)

    # All Aggregate Features
    usecols = ["CNT_PAYMENT","DAYS_DECISION","DAYS_FIRST_DRAWING","proportion_granted"]
    groups = prev_apps.groupby("SK_ID_CURR")
    
    for col in usecols:
        prev_apps[col+"_diff"] = groups[col].diff()
        prev_apps[col+"_diff_diff"] = groups[col+"_diff"].diff()
        prev_apps[col+"_rolling6"] = groups[col].apply(lambda x: x.rolling(6).mean())
        prev_apps[col+"_rolling12"] = groups[col].apply(lambda x: x.rolling(12).mean())

    using_columns = ["{}_diff".format(c) for c in usecols] + ["{}_diff_diff".format(c) for c in usecols]+ ["{}_rolling6".format(c) for c in usecols]+["{}_rolling12".format(c) for c in usecols]
              
    # For Lagged Items
    for lags in [12,60,90]:
        groups = prev_apps.groupby("SK_ID_CURR").tail(lags).reset_index(drop=True).groupby("SK_ID_CURR")

        for col in using_columns:
            generate_features("prev_apps",groups, lags, col, get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        
        del groups
        gc.collect()

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/previous_application.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
GetPreviousAppFeatures(prev_app_path = "../data/previous_application.csv")

# Saving Data
if get_unnormalized:
    output.to_csv("csv/previous_application_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/previous_application_features_normalized_V{}.csv".format(version), index=False)
