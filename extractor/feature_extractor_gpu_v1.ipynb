# %%
version = "1"

# %%
import numpy as np
import pandas as pd
import gc
from time import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import LabelEncoder,OneHotEncoder, Normalizer
# %matplotlib inline

# %%
timesheet = [time()]
def timer(statement):
    global timesheet
    timesheet.append(time())
    print statement+" :", (timesheet[-1]-timesheet[-2]),"seconds"

# %% [markdown]
# # Feature Generators

# %%
from numba import njit, prange,jit
@jit(nopython=True, parallel=True)
def get_regression_coefficient(ys, xs, counts):
    output = np.zeros(counts.shape[0]-1)
    for i in prange(counts.shape[0]-1):
        x = xs[counts[i] : counts[i+1]]
        y = ys[counts[i] : counts[i+1]]

        output[i] = np.nan
        length = y.shape[0]
        sx = np.sum(x)
        denominator = ((length*np.dot(x, x)) - (sx*sx))
        
        if length >0 and denominator != 0:
            numerator = ((length*np.dot(x, y)) - (sx*np.sum(y)))
            output[i] = numerator/denominator
    return output

# %%
def get_trend_values(data):
        y = data.apply(lambda x: x.dropna().values)
        trends = pd.Series(index =  y.index)
        
        counts = np.insert(y.apply(lambda x: x.shape[0]).values, 0, 0)
        x = np.concatenate(np.array([np.arange(c) for c in counts])).ravel().astype(np.float64)
        y = np.concatenate(y.values).ravel().astype(np.float64)
        counts = np.cumsum(counts)
        
        trends.iloc[:] = get_regression_coefficient(y, x, counts)
        return trends

# %%
def generate_features(prefix, dataGroups, num_lags, colname, get_trend = False, get_kurtosis = True, to_calculate = ["sum", "count","nunique","mean","median","max","min","std","skew"]):
    global output
    if len(to_calculate)> 0 :
        print "Getting Aggregates for column: {}, {}".format(colname, num_lags)
        aggregates = dataGroups[colname].agg(to_calculate)
        aggregates.columns = ["{}_{}_{}_{}".format(prefix,colname, c, num_lags) for c in aggregates.columns]
        output = output.merge(aggregates, how = "left", left_on = "SK_ID_CURR", right_index=True)
        timer("Done Aggregating Column {}".format(colname))
    if get_kurtosis:
        print "Getting Kurtosis for Column: {}, {}".format(colname, num_lags)
        output["{}_{}_kurtosis_{}".format(prefix,colname,num_lags)] = output["SK_ID_CURR"].map(dataGroups[colname].apply(lambda x: x.kurt()))
        timer("Done Getting Kurtosis for Column {}".format(colname))

    if get_trend:
        print "Getting Trend for column: {}, {}".format(colname, num_lags)
        output["{}_{}_trend_{}".format(prefix, colname, num_lags)] = output["SK_ID_CURR"].map(get_trend_values(dataGroups[colname]))
        timer("Done Getting Trend for Column {}".format(colname))

# %% [markdown]
# # Feature Preprocessors

# %%
def one_hot_encoder(data, nan_as_category = True):
    categorical_columns = [col for col in data.columns if data[col].dtype == 'object']
    data = pd.get_dummies(data, columns= categorical_columns, dummy_na= nan_as_category)
    return data

def normalize_features(data, not_to_normalize):
    columns_to_normalize = data.columns.drop(not_to_normalize)
    data = data.replace([np.inf, -np.inf], np.nan)
    print data.shape, "Before dropping Na's"
    data = data.dropna(axis=1, how = "all")
    print data.shape, "After dropping Na's"
    for col in data.columns.drop(not_to_normalize):
        data[col] = data[col].fillna(data[col].mean()).fillna(0)
        data[col]= Normalizer().fit_transform(data[col].values.reshape(-1,1))
    return data

# %% [markdown]
# # Get Application Features

# %%
def GetApplicationFeatures(get_ohe = False, normalize = False, get_flags = False, train_path = "../data/application_train.csv", test_path = "../data/application_test.csv"):
    # Loading Data
    train = pd.read_csv(train_path)
    test = pd.read_csv(test_path)
    data = pd.concat([train, test], axis=0)
    
    # Cleaning {To be improved later}
    data['CODE_GENDER'].replace('XNA', np.nan, inplace=True)
    data['DAYS_EMPLOYED'].replace(365243, np.nan, inplace=True)
    data['DAYS_LAST_PHONE_CHANGE'].replace(0, np.nan, inplace=True)
    data['NAME_FAMILY_STATUS'].replace('Unknown', np.nan, inplace=True)
    data['ORGANIZATION_TYPE'].replace('XNA', np.nan, inplace=True)
    
    # Feature Engineering on groupby
    inc_by_org = data[['AMT_INCOME_TOTAL', 'ORGANIZATION_TYPE']].groupby('ORGANIZATION_TYPE').median()['AMT_INCOME_TOTAL']
    data['new_inc_by_org'] = data['ORGANIZATION_TYPE'].map(inc_by_org)
    
    # Feature Engineering on Flag Columns
    docs = [c for c in data.columns if 'FLAG_DOC' in c]
    live = [c for c in data.columns if ('FLAG_' in c) & ('FLAG_DOC' not in c) & ('_FLAG_' not in c)]
    data['new_doc_ind_kurt'] = data[docs].kurtosis(axis=1)
    data['new_live_ind_sum'] = data[live].sum(axis=1)
    
    # Feature Engineering on feature interations
    data['annuity_income_percentage'] = data['AMT_ANNUITY'] / data['AMT_INCOME_TOTAL'].astype("float32")
    data['car_to_birth_ratio'] = data['OWN_CAR_AGE'] / data['DAYS_BIRTH'].astype("float32")
    data['car_to_employ_ratio'] = data['OWN_CAR_AGE'] / data['DAYS_EMPLOYED'].astype("float32")
    data['children_ratio'] = data['CNT_CHILDREN'] / data['CNT_FAM_MEMBERS'].astype("float32")
    data['credit_to_annuity_ratio'] = data['AMT_CREDIT'] / data['AMT_ANNUITY'].astype("float32")
    data['credit_to_goods_ratio'] = data['AMT_CREDIT'] / data['AMT_GOODS_PRICE'].astype("float32")
    data['credit_to_income_ratio'] = data['AMT_CREDIT'] / data['AMT_INCOME_TOTAL'].astype("float32")
    data['days_employed_percentage'] = data['DAYS_EMPLOYED'] / data['DAYS_BIRTH'].astype("float32")
    data['income_credit_percentage'] = data['AMT_INCOME_TOTAL'] / data['AMT_CREDIT'].astype("float32")
    data['income_per_child'] = data['AMT_INCOME_TOTAL'] / (1 + data['CNT_CHILDREN']).astype("float32")
    data['income_per_person'] = data['AMT_INCOME_TOTAL'] / data['CNT_FAM_MEMBERS'].astype("float32")
    data['payment_rate'] = data['AMT_ANNUITY'] / data['AMT_CREDIT'].astype("float32")
    data['phone_to_birth_ratio'] = data['DAYS_LAST_PHONE_CHANGE'] / data['DAYS_BIRTH'].astype("float32")
    data['phone_to_employ_ratio'] = data['DAYS_LAST_PHONE_CHANGE'] / data['DAYS_EMPLOYED'].astype("float32")
    data['external_sources_weighted'] = data.EXT_SOURCE_1 * 2 + data.EXT_SOURCE_2 * 3 + data.EXT_SOURCE_3 * 4
    data['external_sources_product'] = data.EXT_SOURCE_1 * data.EXT_SOURCE_2 *  data.EXT_SOURCE_3
    data['cnt_non_child'] = data['CNT_FAM_MEMBERS'] - data['CNT_CHILDREN']
    data['child_to_non_child_ratio'] = data['CNT_CHILDREN'] / data['cnt_non_child'].astype("float32")
    data['income_per_non_child'] = data['AMT_INCOME_TOTAL'] / data['cnt_non_child'].astype("float32")
    data['credit_per_person'] = data['AMT_CREDIT'] / data['CNT_FAM_MEMBERS'].astype("float32")
    data['credit_per_child'] = data['AMT_CREDIT'] / (1 + data['CNT_CHILDREN']).astype("float32")
    data['credit_per_non_child'] = data['AMT_CREDIT'] / data['cnt_non_child'].astype("float32")
    for function_name in ['min', 'max', 'sum', 'mean', 'nanmedian',"std"]:
        data['external_sources_{}'.format(function_name)] = eval('np.{}'.format(function_name))(data[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']], axis=1)

    # Generating Binary Indicator Variables for Certain Columns
    data['short_employment'] = (data['DAYS_EMPLOYED'] < -2000).astype(int)
    data['young_age'] = (data['DAYS_BIRTH'] < -14000).astype(int)

    # Handling Categorical Data
    categorical_columns = [c for c in data.columns if data[c].dtype == "object"]

    for bin_feature in ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY']:
        data[bin_feature], uniques = pd.factorize(data[bin_feature])
        
    if get_ohe:
        data = one_hot_encoder(data, True)
    else:
        for col in categorical_columns:
            data[col] = LabelEncoder().fit_transform(data[col])
    
    # Normalizing Features
    if normalize:
        if get_ohe:
            data = normalize_features(data,["SK_ID_CURR","TARGET"])
        else:
            data = normalize_features(data,["SK_ID_CURR","TARGET"]+categorical_columns)
    
    # Handling Flag Columns {Work some more on it}
    flag_columns = ['FLAG_DOCUMENT_2','FLAG_DOCUMENT_4','FLAG_DOCUMENT_5','FLAG_DOCUMENT_6','FLAG_DOCUMENT_7','FLAG_DOCUMENT_8','FLAG_DOCUMENT_9','FLAG_DOCUMENT_10','FLAG_DOCUMENT_11','FLAG_DOCUMENT_12','FLAG_DOCUMENT_13','FLAG_DOCUMENT_14','FLAG_DOCUMENT_15','FLAG_DOCUMENT_16','FLAG_DOCUMENT_17','FLAG_DOCUMENT_18','FLAG_DOCUMENT_19','FLAG_DOCUMENT_20','FLAG_DOCUMENT_21']

    if get_flags:
        return data
    else:
        return data.drop(flag_columns, axis=1)

# %%
get_normalized = True
get_unnormalized = True

if get_normalized:
    output = GetApplicationFeatures(get_ohe = True, normalize = True, get_flags = False, train_path = "../data/application_train.csv", test_path = "../data/application_test.csv")
    output.to_csv("csv/application_features_normalized_V{}.csv".format(version), index=False)
if get_unnormalized:
    output = GetApplicationFeatures(get_ohe = False, normalize = False, get_flags = False, train_path = "../data/application_train.csv", test_path = "../data/application_test.csv")
    output.to_csv("csv/application_features_V{}.csv".format(version), index=False)
# Out:
# /home/sakhtar0092/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# (356255, 286) Before dropping Na's
# (356255, 286) After dropping Na's

# %% [markdown]
# # Get Installment Features

# %%
def GetInstallmentFeatures(installment_path = "../data/installments_payments.csv"):
    installments = pd.read_csv(installment_path).sort_values(by=["SK_ID_CURR","DAYS_INSTALMENT"]).reset_index(drop = True)
    
    # Generating Some Features
    installments['installment_paid_late_in_days'] = installments['DAYS_ENTRY_PAYMENT'] - installments['DAYS_INSTALMENT']
    installments['installment_paid_late'] = (installments['installment_paid_late_in_days'] > 0).astype(int)

    installments['installment_paid_over_amount'] = installments['AMT_PAYMENT'] - installments['AMT_INSTALMENT']
    installments['installment_paid_over_amount_ratio'] = installments['AMT_PAYMENT'] / (1+installments['AMT_INSTALMENT'])
    installments['installment_paid_over'] = (installments['installment_paid_over_amount'] > 0).astype(int)

    installments["amt_instalment_pct_change"] = installments.groupby("SK_ID_CURR")["AMT_INSTALMENT"].pct_change().replace([np.inf, -np.inf], np.nan)
    installments["days_instalment_diff"] = installments.groupby("SK_ID_CURR")["DAYS_INSTALMENT"].diff()
    
    # All Aggregate Features
    groups = installments.groupby("SK_ID_CURR")
    
    generate_features("installment",groups, "all", "SK_ID_PREV", get_trend = False, get_kurtosis = False, to_calculate = ["count","nunique"])
    generate_features("installment",groups, "all", "DAYS_INSTALMENT", get_trend = False, get_kurtosis = False, to_calculate = ["min","max","mean"])
    generate_features("installment",groups, "all", "installment_paid_late_in_days", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("installment",groups, "all", "installment_paid_over_amount", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("installment",groups, "all", "installment_paid_over_amount_ratio", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("installment",groups, "all", "NUM_INSTALMENT_VERSION", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("installment",groups, "all", "amt_instalment_pct_change", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("installment",groups, "all", "days_instalment_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("installment",groups, "all", "installment_paid_late", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("installment",groups, "all", "installment_paid_over", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])

    # For Lagged Items
    for lags in [2, 3, 6, 12, 18, 36, 48, 60, 72]:
        groups = installments.groupby("SK_ID_CURR").tail(lags).reset_index(drop=True).groupby("SK_ID_CURR")

        generate_features("installment",groups, lags, "installment_paid_late_in_days", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_ratio", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "NUM_INSTALMENT_VERSION", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "amt_instalment_pct_change", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "days_instalment_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_late", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
        generate_features("installment",groups, lags, "installment_paid_over", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
        del groups
        gc.collect()

    # For Last Item of Each Previous ID
    groups = installments.groupby("SK_ID_CURR").nth(-1).reset_index().groupby("SK_ID_CURR")
    
    generate_features("installment",groups, "last", "installment_paid_late_in_days", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("installment",groups, "last", "installment_paid_over_amount", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("installment",groups, "last", "installment_paid_over_amount_ratio", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("installment",groups, "last", "NUM_INSTALMENT_VERSION", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("installment",groups, "last", "amt_instalment_pct_change", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("installment",groups, "last", "installment_paid_late", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("installment",groups, "last", "installment_paid_over", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    del groups
    gc.collect()

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/installments_payments.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
GetInstallmentFeatures(installment_path = "../data/installments_payments.csv")

# Some Additional Features
output["installment_IDprevUNIQUE_to_IDprevALL_ratio"] = output["installment_SK_ID_PREV_nunique_all"]/output["installment_SK_ID_PREV_count_all"].astype("float32")

# Saving Data
if get_unnormalized:
    output.to_csv("csv/installment_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/installment_features_normalized_V{}.csv".format(version), index=False)

# %% [markdown]
# # Get POS Cash Features

# %%
def GetPOSFeatures(pos_cash_path = "../data/POS_CASH_balance.csv"):
    pos_cash = pd.read_csv(pos_cash_path).sort_values(by=["SK_ID_CURR","SK_ID_PREV","MONTHS_BALANCE"]).reset_index(drop = True)
    
    # Generating Some Features
    pos_cash['pos_cash_paid_late'] = (pos_cash['SK_DPD'] > 0).astype(int)
    pos_cash['pos_cash_paid_late_with_tolerance'] = (pos_cash['SK_DPD_DEF'] > 0).astype(int)
    pos_cash['contract_is_active'] = (pos_cash['NAME_CONTRACT_STATUS'] == "Active").astype(int)
    pos_cash['contract_is_completed'] = (pos_cash['NAME_CONTRACT_STATUS'] == "Completed").astype(int)
    pos_cash['contract_is_signed'] = (pos_cash['NAME_CONTRACT_STATUS'] == "Signed").astype(int)
    pos_cash["cnt_installment_diff_by_IDprev"] = pos_cash.groupby("SK_ID_PREV")["CNT_INSTALMENT"].diff()
    pos_cash["cnt_installment_future_diff_by_IDprev"] = pos_cash.groupby("SK_ID_PREV")["CNT_INSTALMENT_FUTURE"].diff()

    # All Aggregate Features
    groups = pos_cash.groupby("SK_ID_CURR")
    
    generate_features("pos_cash",groups, "all", "SK_ID_PREV", get_trend = False, get_kurtosis = False, to_calculate = ["count","nunique"])
    generate_features("pos_cash",groups, "all", "MONTHS_BALANCE", get_trend = False, get_kurtosis = False, to_calculate = ["min","max","mean"])
    generate_features("pos_cash",groups, "all", "SK_DPD", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("pos_cash",groups, "all", "SK_DPD_DEF", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("pos_cash",groups, "all", "CNT_INSTALMENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("pos_cash",groups, "all", "CNT_INSTALMENT_FUTURE", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("pos_cash",groups, "all", "cnt_installment_diff_by_IDprev", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("pos_cash",groups, "all", "cnt_installment_future_diff_by_IDprev", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("pos_cash",groups, "all", "pos_cash_paid_late", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("pos_cash",groups, "all", "pos_cash_paid_late_with_tolerance", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("pos_cash",groups, "all", "contract_is_active", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("pos_cash",groups, "all", "contract_is_completed", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("pos_cash",groups, "all", "contract_is_signed", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    
    #For Lagged Items
    for lags in [2, 3, 6, 12, 18, 36, 48, 60, 72]:
        groups = pos_cash.groupby("SK_ID_CURR").tail(lags).reset_index(drop=True).groupby("SK_ID_CURR")

        generate_features("pos_cash",groups, lags, "SK_DPD", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "SK_DPD_DEF", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_FUTURE", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "cnt_installment_diff_by_IDprev", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "cnt_installment_future_diff_by_IDprev", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("pos_cash",groups, lags, "pos_cash_paid_late", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
        generate_features("pos_cash",groups, lags, "pos_cash_paid_late_with_tolerance", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
        generate_features("pos_cash",groups, lags, "contract_is_active", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
        generate_features("pos_cash",groups, lags, "contract_is_completed", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
        generate_features("pos_cash",groups, lags, "contract_is_signed", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    
        del groups
        gc.collect()
    
    # For Last Item of Each Previous ID
    groups = pos_cash.groupby("SK_ID_CURR").nth(-1).reset_index().groupby("SK_ID_CURR")
    
    generate_features("pos_cash",groups, "last", "SK_DPD", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("pos_cash",groups, "last", "SK_DPD_DEF", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("pos_cash",groups, "last", "CNT_INSTALMENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("pos_cash",groups, "last", "CNT_INSTALMENT_FUTURE", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("pos_cash",groups, "last", "cnt_installment_diff_by_IDprev", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("pos_cash",groups, "last", "cnt_installment_future_diff_by_IDprev", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("pos_cash",groups, "last", "pos_cash_paid_late", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("pos_cash",groups, "last", "pos_cash_paid_late_with_tolerance", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("pos_cash",groups, "last", "contract_is_active", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("pos_cash",groups, "last", "contract_is_completed", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("pos_cash",groups, "last", "contract_is_signed", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    del groups
    gc.collect()

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/POS_CASH_balance.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
GetPOSFeatures(pos_cash_path = "../data/POS_CASH_balance.csv")

# Some Additional Features
output["pos_cash_IDprevUNIQUE_to_IDprevALL_ratio"] = output["pos_cash_SK_ID_PREV_nunique_all"]/output["pos_cash_SK_ID_PREV_count_all"].astype("float32")

# Saving Data
if get_unnormalized:
    output.to_csv("csv/pos_cash_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/pos_cash_features_normalized_V{}.csv".format(version), index=False)

# %% [markdown]
# # Credit Card Features

# %%
def GetCreditCardFeatures(credit_card_path = "../data/credit_card_balance.csv"):
    credit_card = pd.read_csv(credit_card_path).sort_values(by=["SK_ID_CURR","SK_ID_PREV","MONTHS_BALANCE"]).reset_index(drop = True)
    credit_card = credit_card.fillna(0.0)
        
    # Generating Some Binary Features 
    credit_card['credit_card_paid_late'] = (credit_card['SK_DPD'] > 0).astype(int)
    credit_card['credit_card_paid_late_with_tolerance'] = (credit_card['SK_DPD_DEF'] > 0).astype(int)
    credit_card['contract_is_active'] = (credit_card['NAME_CONTRACT_STATUS'] == "Active").astype(int)
    credit_card['contract_is_completed'] = (credit_card['NAME_CONTRACT_STATUS'] == "Completed").astype(int)
    credit_card['contract_is_signed'] = (credit_card['NAME_CONTRACT_STATUS'] == "Signed").astype(int)
    
    credit_card['amt_drawings_atm_current_is_zero']=(credit_card['AMT_DRAWINGS_ATM_CURRENT'] == 0).astype(int)
    credit_card['amt_drawings_pos_current_is_zero']=(credit_card['AMT_DRAWINGS_POS_CURRENT'] == 0).astype(int)
    credit_card['amt_drawing_current_is_zero'] = (credit_card['AMT_DRAWINGS_CURRENT'] == 0).astype(int)
    credit_card['cnt_drawings_atm_current_is_zero']=(credit_card['CNT_DRAWINGS_ATM_CURRENT'] == 0).astype(int)
    credit_card['cnt_drawings_pos_current_is_zero']=(credit_card['CNT_DRAWINGS_POS_CURRENT'] == 0).astype(int)
    credit_card['cnt_drawing_current_is_zero'] = (credit_card['CNT_DRAWINGS_CURRENT'] == 0).astype(int)
    credit_card['cnt_installment_mature_cum_is_zero'] = (credit_card['CNT_INSTALMENT_MATURE_CUM'] == 0).astype(int)
    
    all_binary_features = ["credit_card_paid_late","credit_card_paid_late_with_tolerance","contract_is_active","contract_is_completed","contract_is_signed","amt_drawings_atm_current_is_zero","amt_drawings_pos_current_is_zero","amt_drawing_current_is_zero","cnt_drawings_atm_current_is_zero","cnt_drawings_pos_current_is_zero","cnt_drawing_current_is_zero","cnt_installment_mature_cum_is_zero"]
    
    # Generating Ratio Features
    credit_card['cnt_pos_ratio'] = credit_card['CNT_DRAWINGS_POS_CURRENT']/(credit_card['CNT_DRAWINGS_CURRENT']+1.0)
    credit_card['cnt_atm_ratio'] = credit_card['CNT_DRAWINGS_ATM_CURRENT']/(credit_card['CNT_DRAWINGS_CURRENT']+1.0)
    credit_card['amt_pos_ratio'] = credit_card['AMT_DRAWINGS_POS_CURRENT']/(credit_card['AMT_DRAWINGS_CURRENT']+1.0)
    credit_card['amt_atm_ratio'] = credit_card['AMT_DRAWINGS_ATM_CURRENT']/(credit_card['AMT_DRAWINGS_CURRENT']+1.0)
    credit_card['balance_to_drawing_ratio'] = credit_card['AMT_BALANCE']/(credit_card['AMT_DRAWINGS_CURRENT']+1.0)
    
    credit_card['balance_to_limit_ratio'] = credit_card['AMT_BALANCE']/(credit_card['AMT_CREDIT_LIMIT_ACTUAL']+1.0)
    credit_card['balance_to_total_payment_ratio'] = credit_card['AMT_BALANCE']/(credit_card['AMT_PAYMENT_TOTAL_CURRENT']+1.0)
    credit_card['balance_to_minimum_installment_ratio'] = credit_card['AMT_BALANCE']/(credit_card['AMT_INST_MIN_REGULARITY']+1.0)
    credit_card['minimum_installment_to_total_payment_ratio'] = credit_card['AMT_INST_MIN_REGULARITY']/(credit_card['AMT_PAYMENT_TOTAL_CURRENT']+1.0)
    credit_card['minimum_installment_to_current_payment_ratio'] = credit_card['AMT_INST_MIN_REGULARITY']/(credit_card['AMT_PAYMENT_CURRENT']+1.0)
    credit_card['current_to_total_payment_ratio'] = credit_card['AMT_PAYMENT_CURRENT']/(credit_card['AMT_PAYMENT_TOTAL_CURRENT']+1.0)

    credit_card['payment_to_receivable_min_ratio'] = credit_card['AMT_INST_MIN_REGULARITY']/(credit_card['AMT_RECEIVABLE_PRINCIPAL']+1.0)
    credit_card['payment_to_receivable_curr_ratio'] = credit_card['AMT_PAYMENT_CURRENT']/(credit_card['AMT_RECIVABLE']+1.0)
    credit_card['payment_to_receivable_total_ratio'] = credit_card['AMT_PAYMENT_TOTAL_CURRENT']/(credit_card['AMT_TOTAL_RECEIVABLE']+1.0)

    all_ratio_features = ["cnt_pos_ratio","cnt_atm_ratio","amt_pos_ratio","amt_atm_ratio","balance_to_drawing_ratio","balance_to_limit_ratio","balance_to_total_payment_ratio","balance_to_minimum_installment_ratio","minimum_installment_to_total_payment_ratio","minimum_installment_to_current_payment_ratio","current_to_total_payment_ratio","payment_to_receivable_min_ratio","payment_to_receivable_curr_ratio","payment_to_receivable_total_ratio"]
    
    # All Aggregate Features
    groups = credit_card.groupby("SK_ID_CURR")
    
    generate_features("credit_card",groups, "all", "SK_ID_PREV", get_trend = False, get_kurtosis = False, to_calculate = ["count","nunique"])
    generate_features("credit_card",groups, "all", "MONTHS_BALANCE", get_trend = False, get_kurtosis = False, to_calculate = ["min","max","mean"])
    generate_features("credit_card",groups, "all", "SK_DPD", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("credit_card",groups, "all", "SK_DPD_DEF", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("credit_card",groups, "all", "CNT_DRAWINGS_ATM_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("credit_card",groups, "all", "CNT_DRAWINGS_POS_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("credit_card",groups, "all", "CNT_DRAWINGS_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("credit_card",groups, "all", "AMT_DRAWINGS_ATM_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("credit_card",groups, "all", "AMT_DRAWINGS_POS_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("credit_card",groups, "all", "AMT_DRAWINGS_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("credit_card",groups, "all", "CNT_INSTALMENT_MATURE_CUM", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("credit_card",groups, "all", "AMT_BALANCE", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("credit_card",groups, "all", "AMT_PAYMENT_TOTAL_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("credit_card",groups, "all", "AMT_TOTAL_RECEIVABLE", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    
    for col in all_ratio_features:
        generate_features("credit_card",groups, "all", col, get_trend = True, get_kurtosis = True, to_calculate = ["mean","max","min","std","skew"])

    for col in all_binary_features:
        generate_features("credit_card",groups, "all", col, get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])

    # Lag Aggregate Features
    for lags in [3,12, 24, 36]:
        groups = credit_card.groupby("SK_ID_CURR").tail(lags).reset_index(drop=True).groupby("SK_ID_CURR")

        generate_features("credit_card",groups, lags, "SK_DPD", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("credit_card",groups, lags, "SK_DPD_DEF", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("credit_card",groups, lags, "CNT_DRAWINGS_ATM_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("credit_card",groups, lags, "CNT_DRAWINGS_POS_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("credit_card",groups, lags, "CNT_DRAWINGS_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("credit_card",groups, lags, "AMT_DRAWINGS_ATM_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("credit_card",groups, lags, "AMT_DRAWINGS_POS_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("credit_card",groups, lags, "AMT_DRAWINGS_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("credit_card",groups, lags, "CNT_INSTALMENT_MATURE_CUM", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("credit_card",groups, lags, "AMT_BALANCE", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("credit_card",groups, lags, "AMT_PAYMENT_TOTAL_CURRENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("credit_card",groups, lags, "AMT_TOTAL_RECEIVABLE", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])

        for col in all_ratio_features:
            generate_features("credit_card",groups, lags, col, get_trend = True, get_kurtosis = True, to_calculate = ["mean","max","min","std","skew"])

        for col in all_binary_features:
            generate_features("credit_card",groups, lags, col, get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])

        del groups
        gc.collect()

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/credit_card_balance.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
GetCreditCardFeatures(credit_card_path = "../data/credit_card_balance.csv")

# Some Additional Features
output["credit_card_IDprevUNIQUE_to_IDprevALL_ratio"] = output["credit_card_SK_ID_PREV_nunique_all"]/output["credit_card_SK_ID_PREV_count_all"].astype("float32")

# Saving Data
if get_unnormalized:
    output.to_csv("csv/credit_card_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/credit_card_features_normalized_V{}.csv".format(version), index=False)
# Out:
# Getting Aggregates for column: SK_ID_PREV, all
# Done Aggregating Column SK_ID_PREV : 47.2692780495 seconds
# Getting Aggregates for column: MONTHS_BALANCE, all
# Done Aggregating Column MONTHS_BALANCE : 0.128298044205 seconds
# Getting Aggregates for column: SK_DPD, all
# Done Aggregating Column SK_DPD : 23.212305069 seconds
# Getting Kurtosis for Column: SK_DPD, all
# Done Getting Kurtosis for Column SK_DPD : 23.4406239986 seconds
# Getting Trend for column: SK_DPD, all
# Done Getting Trend for Column SK_DPD : 13.463714838 seconds
# Getting Aggregates for column: SK_DPD_DEF, all
# Done Aggregating Column SK_DPD_DEF : 23.3180379868 seconds
# Getting Kurtosis for Column: SK_DPD_DEF, all
# Done Getting Kurtosis for Column SK_DPD_DEF : 23.3007340431 seconds
# Getting Trend for column: SK_DPD_DEF, all
# Done Getting Trend for Column SK_DPD_DEF : 11.7778670788 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT, all
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT : 22.2285349369 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT, all
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT : 22.8490760326 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT, all
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT : 38.4690189362 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT, all
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT : 23.7828571796 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT, all
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT : 22.4465868473 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT, all
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT : 38.4658100605 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT, all
# Done Aggregating Column CNT_DRAWINGS_CURRENT : 23.2615699768 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT, all
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT : 24.0577530861 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT, all
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT : 11.8777108192 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT, all
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT : 22.5655782223 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT, all
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT : 23.0268409252 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT, all
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT : 38.5502519608 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT, all
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT : 22.4326760769 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT, all
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT : 23.3568019867 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT, all
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT : 38.4098918438 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT, all
# Done Aggregating Column AMT_DRAWINGS_CURRENT : 22.1240670681 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT, all
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT : 22.9606800079 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT, all
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT : 38.5557971001 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM, all
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM : 22.3404760361 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM, all
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM : 22.8806779385 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM, all
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM : 38.5662589073 seconds
# Getting Aggregates for column: AMT_BALANCE, all
# Done Aggregating Column AMT_BALANCE : 22.3893270493 seconds
# Getting Kurtosis for Column: AMT_BALANCE, all
# Done Getting Kurtosis for Column AMT_BALANCE : 22.9447700977 seconds
# Getting Trend for column: AMT_BALANCE, all
# Done Getting Trend for Column AMT_BALANCE : 38.3112969398 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT, all
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT : 22.4790718555 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT, all
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT : 22.9561080933 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT, all
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT : 38.1585218906 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE, all
# Done Aggregating Column AMT_TOTAL_RECEIVABLE : 22.1884350777 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE, all
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE : 22.9121029377 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE, all
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE : 37.6508030891 seconds
# Getting Aggregates for column: cnt_pos_ratio, all
# Done Aggregating Column cnt_pos_ratio : 21.6563899517 seconds
# Getting Kurtosis for Column: cnt_pos_ratio, all
# Done Getting Kurtosis for Column cnt_pos_ratio : 22.0583059788 seconds
# Getting Trend for column: cnt_pos_ratio, all
# Done Getting Trend for Column cnt_pos_ratio : 37.6959400177 seconds
# Getting Aggregates for column: cnt_atm_ratio, all
# Done Aggregating Column cnt_atm_ratio : 21.1870820522 seconds
# Getting Kurtosis for Column: cnt_atm_ratio, all
# Done Getting Kurtosis for Column cnt_atm_ratio : 21.447478056 seconds
# Getting Trend for column: cnt_atm_ratio, all
# Done Getting Trend for Column cnt_atm_ratio : 37.7113280296 seconds
# Getting Aggregates for column: amt_pos_ratio, all
# Done Aggregating Column amt_pos_ratio : 20.9229478836 seconds
# Getting Kurtosis for Column: amt_pos_ratio, all
# Done Getting Kurtosis for Column amt_pos_ratio : 21.1452350616 seconds
# Getting Trend for column: amt_pos_ratio, all
# Done Getting Trend for Column amt_pos_ratio : 37.7392690182 seconds
# Getting Aggregates for column: amt_atm_ratio, all
# Done Aggregating Column amt_atm_ratio : 20.9079859257 seconds
# Getting Kurtosis for Column: amt_atm_ratio, all
# Done Getting Kurtosis for Column amt_atm_ratio : 21.5355601311 seconds
# Getting Trend for column: amt_atm_ratio, all
# Done Getting Trend for Column amt_atm_ratio : 37.8165659904 seconds
# Getting Aggregates for column: balance_to_drawing_ratio, all
# Done Aggregating Column balance_to_drawing_ratio : 21.0729830265 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio, all
# Done Getting Kurtosis for Column balance_to_drawing_ratio : 21.5432808399 seconds
# Getting Trend for column: balance_to_drawing_ratio, all
# Done Getting Trend for Column balance_to_drawing_ratio : 37.9057519436 seconds
# Getting Aggregates for column: balance_to_limit_ratio, all
# Done Aggregating Column balance_to_limit_ratio : 21.3260500431 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio, all
# Done Getting Kurtosis for Column balance_to_limit_ratio : 21.6036109924 seconds
# Getting Trend for column: balance_to_limit_ratio, all
# Done Getting Trend for Column balance_to_limit_ratio : 37.6345851421 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio, all
# Done Aggregating Column balance_to_total_payment_ratio : 21.6948759556 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio, all
# Done Getting Kurtosis for Column balance_to_total_payment_ratio : 21.5193760395 seconds
# Getting Trend for column: balance_to_total_payment_ratio, all
# Done Getting Trend for Column balance_to_total_payment_ratio : 37.7257809639 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio, all
# Done Aggregating Column balance_to_minimum_installment_ratio : 20.8328049183 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio, all
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio : 21.5111949444 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio, all
# Done Getting Trend for Column balance_to_minimum_installment_ratio : 37.5822072029 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio, all
# Done Aggregating Column minimum_installment_to_total_payment_ratio : 20.7102789879 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio, all
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio : 22.8347949982 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio, all
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio : 37.814303875 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio, all
# Done Aggregating Column minimum_installment_to_current_payment_ratio : 20.8752930164 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio, all
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio : 22.7342789173 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio, all
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio : 37.8806400299 seconds
# Getting Aggregates for column: current_to_total_payment_ratio, all
# Done Aggregating Column current_to_total_payment_ratio : 20.9091670513 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio, all
# Done Getting Kurtosis for Column current_to_total_payment_ratio : 21.7698459625 seconds
# Getting Trend for column: current_to_total_payment_ratio, all
# Done Getting Trend for Column current_to_total_payment_ratio : 37.9993519783 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio, all
# Done Aggregating Column payment_to_receivable_min_ratio : 20.8258609772 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio, all
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio : 21.6126670837 seconds
# Getting Trend for column: payment_to_receivable_min_ratio, all
# Done Getting Trend for Column payment_to_receivable_min_ratio : 37.9008560181 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio, all
# Done Aggregating Column payment_to_receivable_curr_ratio : 21.1659069061 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio, all
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio : 22.2215549946 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio, all
# Done Getting Trend for Column payment_to_receivable_curr_ratio : 38.4102921486 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio, all
# Done Aggregating Column payment_to_receivable_total_ratio : 22.1927168369 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio, all
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio : 23.0045301914 seconds
# Getting Trend for column: payment_to_receivable_total_ratio, all
# Done Getting Trend for Column payment_to_receivable_total_ratio : 38.3972480297 seconds
# Getting Aggregates for column: credit_card_paid_late, all
# Done Aggregating Column credit_card_paid_late : 0.278852939606 seconds
# Getting Aggregates for column: credit_card_paid_late_with_tolerance, all
# Done Aggregating Column credit_card_paid_late_with_tolerance : 0.171514034271 seconds
# Getting Aggregates for column: contract_is_active, all
# Done Aggregating Column contract_is_active : 0.170974969864 seconds
# Getting Aggregates for column: contract_is_completed, all
# Done Aggregating Column contract_is_completed : 0.172147035599 seconds
# Getting Aggregates for column: contract_is_signed, all
# Done Aggregating Column contract_is_signed : 0.172110795975 seconds
# Getting Aggregates for column: amt_drawings_atm_current_is_zero, all
# Done Aggregating Column amt_drawings_atm_current_is_zero : 0.173006057739 seconds
# Getting Aggregates for column: amt_drawings_pos_current_is_zero, all
# Done Aggregating Column amt_drawings_pos_current_is_zero : 0.17315196991 seconds
# Getting Aggregates for column: amt_drawing_current_is_zero, all
# Done Aggregating Column amt_drawing_current_is_zero : 0.174216985703 seconds
# Getting Aggregates for column: cnt_drawings_atm_current_is_zero, all
# Done Aggregating Column cnt_drawings_atm_current_is_zero : 0.173639059067 seconds
# Getting Aggregates for column: cnt_drawings_pos_current_is_zero, all
# Done Aggregating Column cnt_drawings_pos_current_is_zero : 0.174602031708 seconds
# Getting Aggregates for column: cnt_drawing_current_is_zero, all
# Done Aggregating Column cnt_drawing_current_is_zero : 0.176204919815 seconds
# Getting Aggregates for column: cnt_installment_mature_cum_is_zero, all
# Done Aggregating Column cnt_installment_mature_cum_is_zero : 0.176175117493 seconds
# Getting Aggregates for column: SK_DPD, 3
# Done Aggregating Column SK_DPD : 23.7795369625 seconds
# Getting Kurtosis for Column: SK_DPD, 3
# Done Getting Kurtosis for Column SK_DPD : 22.7905809879 seconds
# Getting Trend for column: SK_DPD, 3
# Done Getting Trend for Column SK_DPD : 11.4482610226 seconds
# Getting Aggregates for column: SK_DPD_DEF, 3
# Done Aggregating Column SK_DPD_DEF : 23.0181701183 seconds
# Getting Kurtosis for Column: SK_DPD_DEF, 3
# Done Getting Kurtosis for Column SK_DPD_DEF : 22.2451918125 seconds
# Getting Trend for column: SK_DPD_DEF, 3
# Done Getting Trend for Column SK_DPD_DEF : 11.4304730892 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT, 3
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT : 21.8859870434 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT, 3
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT : 22.4176208973 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT, 3
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT : 29.6450490952 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT, 3
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT : 22.0231289864 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT, 3
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT : 21.7688639164 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT, 3
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT : 29.8916900158 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT, 3
# Done Aggregating Column CNT_DRAWINGS_CURRENT : 22.9114091396 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT, 3
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT : 22.3077158928 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT, 3
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT : 11.485558033 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT, 3
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT : 22.7315778732 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT, 3
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT : 21.3449289799 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT, 3
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT : 29.671443224 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT, 3
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT : 22.5261678696 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT, 3
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT : 21.5015079975 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT, 3
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT : 29.810988903 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT, 3
# Done Aggregating Column AMT_DRAWINGS_CURRENT : 22.1873202324 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT, 3
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT : 21.5143508911 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT, 3
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT : 29.7478768826 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM, 3
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM : 21.9098160267 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM, 3
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM : 21.0548670292 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM, 3
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM : 29.7803170681 seconds
# Getting Aggregates for column: AMT_BALANCE, 3
# Done Aggregating Column AMT_BALANCE : 22.2158260345 seconds
# Getting Kurtosis for Column: AMT_BALANCE, 3
# Done Getting Kurtosis for Column AMT_BALANCE : 21.5611228943 seconds
# Getting Trend for column: AMT_BALANCE, 3
# Done Getting Trend for Column AMT_BALANCE : 29.6170060635 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT, 3
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT : 21.990926981 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT, 3
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT : 21.8055999279 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT, 3
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT : 29.7531630993 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE, 3
# Done Aggregating Column AMT_TOTAL_RECEIVABLE : 22.4584109783 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE, 3
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE : 21.3908109665 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE, 3
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE : 29.7329950333 seconds
# Getting Aggregates for column: cnt_pos_ratio, 3
# Done Aggregating Column cnt_pos_ratio : 21.673938036 seconds
# Getting Kurtosis for Column: cnt_pos_ratio, 3
# Done Getting Kurtosis for Column cnt_pos_ratio : 21.3553590775 seconds
# Getting Trend for column: cnt_pos_ratio, 3
# Done Getting Trend for Column cnt_pos_ratio : 29.7894208431 seconds
# Getting Aggregates for column: cnt_atm_ratio, 3
# Done Aggregating Column cnt_atm_ratio : 22.1099960804 seconds
# Getting Kurtosis for Column: cnt_atm_ratio, 3
# Done Getting Kurtosis for Column cnt_atm_ratio : 21.8590579033 seconds
# Getting Trend for column: cnt_atm_ratio, 3
# Done Getting Trend for Column cnt_atm_ratio : 29.7440581322 seconds
# Getting Aggregates for column: amt_pos_ratio, 3
# Done Aggregating Column amt_pos_ratio : 22.2942938805 seconds
# Getting Kurtosis for Column: amt_pos_ratio, 3
# Done Getting Kurtosis for Column amt_pos_ratio : 21.3381080627 seconds
# Getting Trend for column: amt_pos_ratio, 3
# Done Getting Trend for Column amt_pos_ratio : 29.7449030876 seconds
# Getting Aggregates for column: amt_atm_ratio, 3
# Done Aggregating Column amt_atm_ratio : 22.2690780163 seconds
# Getting Kurtosis for Column: amt_atm_ratio, 3
# Done Getting Kurtosis for Column amt_atm_ratio : 21.3093497753 seconds
# Getting Trend for column: amt_atm_ratio, 3
# Done Getting Trend for Column amt_atm_ratio : 29.9445850849 seconds
# Getting Aggregates for column: balance_to_drawing_ratio, 3
# Done Aggregating Column balance_to_drawing_ratio : 22.2253749371 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio, 3
# Done Getting Kurtosis for Column balance_to_drawing_ratio : 21.5395112038 seconds
# Getting Trend for column: balance_to_drawing_ratio, 3
# Done Getting Trend for Column balance_to_drawing_ratio : 29.9593579769 seconds
# Getting Aggregates for column: balance_to_limit_ratio, 3
# Done Aggregating Column balance_to_limit_ratio : 22.0920557976 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio, 3
# Done Getting Kurtosis for Column balance_to_limit_ratio : 21.9144592285 seconds
# Getting Trend for column: balance_to_limit_ratio, 3
# Done Getting Trend for Column balance_to_limit_ratio : 29.6068708897 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio, 3
# Done Aggregating Column balance_to_total_payment_ratio : 22.2512300014 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio, 3
# Done Getting Kurtosis for Column balance_to_total_payment_ratio : 21.8002998829 seconds
# Getting Trend for column: balance_to_total_payment_ratio, 3
# Done Getting Trend for Column balance_to_total_payment_ratio : 29.6626870632 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio, 3
# Done Aggregating Column balance_to_minimum_installment_ratio : 21.2870271206 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio, 3
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio : 20.1353850365 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio, 3
# Done Getting Trend for Column balance_to_minimum_installment_ratio : 29.4404227734 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio, 3
# Done Aggregating Column minimum_installment_to_total_payment_ratio : 22.1296410561 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio, 3
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio : 21.6522459984 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio, 3
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio : 29.7439711094 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio, 3
# Done Aggregating Column minimum_installment_to_current_payment_ratio : 22.5529959202 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio, 3
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio : 21.3691120148 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio, 3
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio : 29.7786710262 seconds
# Getting Aggregates for column: current_to_total_payment_ratio, 3
# Done Aggregating Column current_to_total_payment_ratio : 22.0928499699 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio, 3
# Done Getting Kurtosis for Column current_to_total_payment_ratio : 21.7069399357 seconds
# Getting Trend for column: current_to_total_payment_ratio, 3
# Done Getting Trend for Column current_to_total_payment_ratio : 29.8299160004 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio, 3
# Done Aggregating Column payment_to_receivable_min_ratio : 22.513117075 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio, 3
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio : 21.7014760971 seconds
# Getting Trend for column: payment_to_receivable_min_ratio, 3
# Done Getting Trend for Column payment_to_receivable_min_ratio : 29.7370169163 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio, 3
# Done Aggregating Column payment_to_receivable_curr_ratio : 22.0872950554 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio, 3
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio : 21.4686799049 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio, 3
# Done Getting Trend for Column payment_to_receivable_curr_ratio : 29.7902610302 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio, 3
# Done Aggregating Column payment_to_receivable_total_ratio : 21.9291820526 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio, 3
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio : 21.2784340382 seconds
# Getting Trend for column: payment_to_receivable_total_ratio, 3
# Done Getting Trend for Column payment_to_receivable_total_ratio : 29.6374409199 seconds
# Getting Aggregates for column: credit_card_paid_late, 3
# Done Aggregating Column credit_card_paid_late : 0.411994934082 seconds
# Getting Aggregates for column: credit_card_paid_late_with_tolerance, 3
# Done Aggregating Column credit_card_paid_late_with_tolerance : 0.129968166351 seconds
# Getting Aggregates for column: contract_is_active, 3
# Done Aggregating Column contract_is_active : 0.208454847336 seconds
# Getting Aggregates for column: contract_is_completed, 3
# Done Aggregating Column contract_is_completed : 0.128771066666 seconds
# Getting Aggregates for column: contract_is_signed, 3
# Done Aggregating Column contract_is_signed : 0.209354877472 seconds
# Getting Aggregates for column: amt_drawings_atm_current_is_zero, 3
# Done Aggregating Column amt_drawings_atm_current_is_zero : 0.130263090134 seconds
# Getting Aggregates for column: amt_drawings_pos_current_is_zero, 3
# Done Aggregating Column amt_drawings_pos_current_is_zero : 0.211391925812 seconds
# Getting Aggregates for column: amt_drawing_current_is_zero, 3
# Done Aggregating Column amt_drawing_current_is_zero : 0.130033016205 seconds
# Getting Aggregates for column: cnt_drawings_atm_current_is_zero, 3
# Done Aggregating Column cnt_drawings_atm_current_is_zero : 0.211790084839 seconds
# Getting Aggregates for column: cnt_drawings_pos_current_is_zero, 3
# Done Aggregating Column cnt_drawings_pos_current_is_zero : 0.131784915924 seconds
# Getting Aggregates for column: cnt_drawing_current_is_zero, 3
# Done Aggregating Column cnt_drawing_current_is_zero : 0.212946176529 seconds
# Getting Aggregates for column: cnt_installment_mature_cum_is_zero, 3
# Done Aggregating Column cnt_installment_mature_cum_is_zero : 0.133526802063 seconds
# Getting Aggregates for column: SK_DPD, 12
# Done Aggregating Column SK_DPD : 25.1553881168 seconds
# Getting Kurtosis for Column: SK_DPD, 12
# Done Getting Kurtosis for Column SK_DPD : 24.2694208622 seconds
# Getting Trend for column: SK_DPD, 12
# Done Getting Trend for Column SK_DPD : 11.5818920135 seconds
# Getting Aggregates for column: SK_DPD_DEF, 12
# Done Aggregating Column SK_DPD_DEF : 23.3165822029 seconds
# Getting Kurtosis for Column: SK_DPD_DEF, 12
# Done Getting Kurtosis for Column SK_DPD_DEF : 22.7111258507 seconds
# Getting Trend for column: SK_DPD_DEF, 12
# Done Getting Trend for Column SK_DPD_DEF : 11.5421440601 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT, 12
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT : 22.3504629135 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT : 22.442414999 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT, 12
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT : 31.5066289902 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT : 22.8714301586 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT : 22.0127308369 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT : 31.5944750309 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT, 12
# Done Aggregating Column CNT_DRAWINGS_CURRENT : 23.2569689751 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT : 23.3787810802 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT, 12
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT : 11.5633978844 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT, 12
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT : 22.2943081856 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT : 22.1824748516 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT, 12
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT : 31.6190850735 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT, 12
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT : 22.469192028 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT : 22.7835199833 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT, 12
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT : 31.6381499767 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT, 12
# Done Aggregating Column AMT_DRAWINGS_CURRENT : 22.3916230202 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT : 22.7830040455 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT, 12
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT : 31.8698279858 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM, 12
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM : 21.1140880585 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM : 20.9024238586 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM, 12
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM : 31.0150699615 seconds
# Getting Aggregates for column: AMT_BALANCE, 12
# Done Aggregating Column AMT_BALANCE : 21.5471560955 seconds
# Getting Kurtosis for Column: AMT_BALANCE, 12
# Done Getting Kurtosis for Column AMT_BALANCE : 21.9589788914 seconds
# Getting Trend for column: AMT_BALANCE, 12
# Done Getting Trend for Column AMT_BALANCE : 31.0667760372 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT, 12
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT : 20.7825670242 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT, 12
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT : 20.9525101185 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT, 12
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT : 31.0037169456 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE, 12
# Done Aggregating Column AMT_TOTAL_RECEIVABLE : 21.5462288857 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE, 12
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE : 21.8465781212 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE, 12
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE : 30.9331219196 seconds
# Getting Aggregates for column: cnt_pos_ratio, 12
# Done Aggregating Column cnt_pos_ratio : 21.1996810436 seconds
# Getting Kurtosis for Column: cnt_pos_ratio, 12
# Done Getting Kurtosis for Column cnt_pos_ratio : 20.8084099293 seconds
# Getting Trend for column: cnt_pos_ratio, 12
# Done Getting Trend for Column cnt_pos_ratio : 30.8665311337 seconds
# Getting Aggregates for column: cnt_atm_ratio, 12
# Done Aggregating Column cnt_atm_ratio : 21.1705629826 seconds
# Getting Kurtosis for Column: cnt_atm_ratio, 12
# Done Getting Kurtosis for Column cnt_atm_ratio : 20.9061019421 seconds
# Getting Trend for column: cnt_atm_ratio, 12
# Done Getting Trend for Column cnt_atm_ratio : 30.9489779472 seconds
# Getting Aggregates for column: amt_pos_ratio, 12
# Done Aggregating Column amt_pos_ratio : 20.8092989922 seconds
# Getting Kurtosis for Column: amt_pos_ratio, 12
# Done Getting Kurtosis for Column amt_pos_ratio : 20.666162014 seconds
# Getting Trend for column: amt_pos_ratio, 12
# Done Getting Trend for Column amt_pos_ratio : 30.7763199806 seconds
# Getting Aggregates for column: amt_atm_ratio, 12
# Done Aggregating Column amt_atm_ratio : 21.8963830471 seconds
# Getting Kurtosis for Column: amt_atm_ratio, 12
# Done Getting Kurtosis for Column amt_atm_ratio : 20.6959290504 seconds
# Getting Trend for column: amt_atm_ratio, 12
# Done Getting Trend for Column amt_atm_ratio : 30.8251600266 seconds
# Getting Aggregates for column: balance_to_drawing_ratio, 12
# Done Aggregating Column balance_to_drawing_ratio : 21.1696939468 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio, 12
# Done Getting Kurtosis for Column balance_to_drawing_ratio : 21.9192590714 seconds
# Getting Trend for column: balance_to_drawing_ratio, 12
# Done Getting Trend for Column balance_to_drawing_ratio : 30.9904048443 seconds
# Getting Aggregates for column: balance_to_limit_ratio, 12
# Done Aggregating Column balance_to_limit_ratio : 22.4788811207 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio, 12
# Done Getting Kurtosis for Column balance_to_limit_ratio : 22.4001600742 seconds
# Getting Trend for column: balance_to_limit_ratio, 12
# Done Getting Trend for Column balance_to_limit_ratio : 31.6722648144 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio, 12
# Done Aggregating Column balance_to_total_payment_ratio : 22.5171780586 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio, 12
# Done Getting Kurtosis for Column balance_to_total_payment_ratio : 22.3770189285 seconds
# Getting Trend for column: balance_to_total_payment_ratio, 12
# Done Getting Trend for Column balance_to_total_payment_ratio : 31.4434950352 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio, 12
# Done Aggregating Column balance_to_minimum_installment_ratio : 22.5328321457 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio, 12
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio : 21.0634109974 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio, 12
# Done Getting Trend for Column balance_to_minimum_installment_ratio : 31.0628228188 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio, 12
# Done Aggregating Column minimum_installment_to_total_payment_ratio : 21.2637121677 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio, 12
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio : 20.8384268284 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio, 12
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio : 30.9260752201 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio, 12
# Done Aggregating Column minimum_installment_to_current_payment_ratio : 21.1031839848 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio, 12
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio : 21.9472839832 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio, 12
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio : 31.0111429691 seconds
# Getting Aggregates for column: current_to_total_payment_ratio, 12
# Done Aggregating Column current_to_total_payment_ratio : 21.0915260315 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio, 12
# Done Getting Kurtosis for Column current_to_total_payment_ratio : 21.1046888828 seconds
# Getting Trend for column: current_to_total_payment_ratio, 12
# Done Getting Trend for Column current_to_total_payment_ratio : 31.1077151299 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio, 12
# Done Aggregating Column payment_to_receivable_min_ratio : 21.0766320229 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio, 12
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio : 21.2322177887 seconds
# Getting Trend for column: payment_to_receivable_min_ratio, 12
# Done Getting Trend for Column payment_to_receivable_min_ratio : 31.0624191761 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio, 12
# Done Aggregating Column payment_to_receivable_curr_ratio : 21.2308349609 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio, 12
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio : 21.66502285 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio, 12
# Done Getting Trend for Column payment_to_receivable_curr_ratio : 31.1076040268 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio, 12
# Done Aggregating Column payment_to_receivable_total_ratio : 21.0717661381 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio, 12
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio : 20.8977959156 seconds
# Getting Trend for column: payment_to_receivable_total_ratio, 12
# Done Getting Trend for Column payment_to_receivable_total_ratio : 30.8419239521 seconds
# Getting Aggregates for column: credit_card_paid_late, 12
# Done Aggregating Column credit_card_paid_late : 0.642873048782 seconds
# Getting Aggregates for column: credit_card_paid_late_with_tolerance, 12
# Done Aggregating Column credit_card_paid_late_with_tolerance : 0.433959960938 seconds
# Getting Aggregates for column: contract_is_active, 12
# Done Aggregating Column contract_is_active : 0.350703001022 seconds
# Getting Aggregates for column: contract_is_completed, 12
# Done Aggregating Column contract_is_completed : 0.43273806572 seconds
# Getting Aggregates for column: contract_is_signed, 12
# Done Aggregating Column contract_is_signed : 0.353472948074 seconds
# Getting Aggregates for column: amt_drawings_atm_current_is_zero, 12
# Done Aggregating Column amt_drawings_atm_current_is_zero : 0.43456697464 seconds
# Getting Aggregates for column: amt_drawings_pos_current_is_zero, 12
# Done Aggregating Column amt_drawings_pos_current_is_zero : 0.354281187057 seconds
# Getting Aggregates for column: amt_drawing_current_is_zero, 12
# Done Aggregating Column amt_drawing_current_is_zero : 0.435883998871 seconds
# Getting Aggregates for column: cnt_drawings_atm_current_is_zero, 12
# Done Aggregating Column cnt_drawings_atm_current_is_zero : 0.355161905289 seconds
# Getting Aggregates for column: cnt_drawings_pos_current_is_zero, 12
# Done Aggregating Column cnt_drawings_pos_current_is_zero : 0.436703920364 seconds
# Getting Aggregates for column: cnt_drawing_current_is_zero, 12
# Done Aggregating Column cnt_drawing_current_is_zero : 0.356986999512 seconds
# Getting Aggregates for column: cnt_installment_mature_cum_is_zero, 12
# Done Aggregating Column cnt_installment_mature_cum_is_zero : 0.43795800209 seconds
# Getting Aggregates for column: SK_DPD, 24
# Done Aggregating Column SK_DPD : 24.095687151 seconds
# Getting Kurtosis for Column: SK_DPD, 24
# Done Getting Kurtosis for Column SK_DPD : 23.08056283 seconds
# Getting Trend for column: SK_DPD, 24
# Done Getting Trend for Column SK_DPD : 11.4936599731 seconds
# Getting Aggregates for column: SK_DPD_DEF, 24
# Done Aggregating Column SK_DPD_DEF : 24.9395689964 seconds
# Getting Kurtosis for Column: SK_DPD_DEF, 24
# Done Getting Kurtosis for Column SK_DPD_DEF : 22.5214822292 seconds
# Getting Trend for column: SK_DPD_DEF, 24
# Done Getting Trend for Column SK_DPD_DEF : 11.5159518719 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT, 24
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT : 21.1871650219 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT, 24
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT : 22.1566650867 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT, 24
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT : 32.6636638641 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT, 24
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT : 21.3296461105 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT, 24
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT : 22.0376980305 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT, 24
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT : 32.7130119801 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT, 24
# Done Aggregating Column CNT_DRAWINGS_CURRENT : 22.1696128845 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT, 24
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT : 23.289675951 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT, 24
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT : 11.5423731804 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT, 24
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT : 21.288684845 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT, 24
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT : 22.125647068 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT, 24
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT : 32.7683179379 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT, 24
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT : 21.4327750206 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT, 24
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT : 22.0649430752 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT, 24
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT : 32.7389159203 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT, 24
# Done Aggregating Column AMT_DRAWINGS_CURRENT : 21.9014849663 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT, 24
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT : 22.5060441494 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT, 24
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT : 32.7618858814 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM, 24
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM : 21.8581140041 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM, 24
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM : 24.035022974 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM, 24
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM : 33.5968279839 seconds
# Getting Aggregates for column: AMT_BALANCE, 24
# Done Aggregating Column AMT_BALANCE : 23.0584230423 seconds
# Getting Kurtosis for Column: AMT_BALANCE, 24
# Done Getting Kurtosis for Column AMT_BALANCE : 23.8567380905 seconds
# Getting Trend for column: AMT_BALANCE, 24
# Done Getting Trend for Column AMT_BALANCE : 33.5658738613 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT, 24
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT : 22.7789239883 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT, 24
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT : 23.960198164 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT, 24
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT : 33.5218608379 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE, 24
# Done Aggregating Column AMT_TOTAL_RECEIVABLE : 22.7219831944 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE, 24
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE : 23.7294659615 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE, 24
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE : 33.31082201 seconds
# Getting Aggregates for column: cnt_pos_ratio, 24
# Done Aggregating Column cnt_pos_ratio : 22.6580369473 seconds
# Getting Kurtosis for Column: cnt_pos_ratio, 24
# Done Getting Kurtosis for Column cnt_pos_ratio : 23.5171580315 seconds
# Getting Trend for column: cnt_pos_ratio, 24
# Done Getting Trend for Column cnt_pos_ratio : 33.2989599705 seconds
# Getting Aggregates for column: cnt_atm_ratio, 24
# Done Aggregating Column cnt_atm_ratio : 22.8720700741 seconds
# Getting Kurtosis for Column: cnt_atm_ratio, 24
# Done Getting Kurtosis for Column cnt_atm_ratio : 23.5695269108 seconds
# Getting Trend for column: cnt_atm_ratio, 24
# Done Getting Trend for Column cnt_atm_ratio : 33.4825999737 seconds
# Getting Aggregates for column: amt_pos_ratio, 24
# Done Aggregating Column amt_pos_ratio : 22.8986001015 seconds
# Getting Kurtosis for Column: amt_pos_ratio, 24
# Done Getting Kurtosis for Column amt_pos_ratio : 23.5935008526 seconds
# Getting Trend for column: amt_pos_ratio, 24
# Done Getting Trend for Column amt_pos_ratio : 33.381029129 seconds
# Getting Aggregates for column: amt_atm_ratio, 24
# Done Aggregating Column amt_atm_ratio : 22.6876058578 seconds
# Getting Kurtosis for Column: amt_atm_ratio, 24
# Done Getting Kurtosis for Column amt_atm_ratio : 23.8351089954 seconds
# Getting Trend for column: amt_atm_ratio, 24
# Done Getting Trend for Column amt_atm_ratio : 33.3959391117 seconds
# Getting Aggregates for column: balance_to_drawing_ratio, 24
# Done Aggregating Column balance_to_drawing_ratio : 21.3761298656 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio, 24
# Done Getting Kurtosis for Column balance_to_drawing_ratio : 22.4787380695 seconds
# Getting Trend for column: balance_to_drawing_ratio, 24
# Done Getting Trend for Column balance_to_drawing_ratio : 32.8440980911 seconds
# Getting Aggregates for column: balance_to_limit_ratio, 24
# Done Aggregating Column balance_to_limit_ratio : 22.5924248695 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio, 24
# Done Getting Kurtosis for Column balance_to_limit_ratio : 22.5751690865 seconds
# Getting Trend for column: balance_to_limit_ratio, 24
# Done Getting Trend for Column balance_to_limit_ratio : 32.9278759956 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio, 24
# Done Aggregating Column balance_to_total_payment_ratio : 21.4784200191 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio, 24
# Done Getting Kurtosis for Column balance_to_total_payment_ratio : 22.652766943 seconds
# Getting Trend for column: balance_to_total_payment_ratio, 24
# Done Getting Trend for Column balance_to_total_payment_ratio : 32.9545969963 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio, 24
# Done Aggregating Column balance_to_minimum_installment_ratio : 21.4442000389 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio, 24
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio : 22.412391901 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio, 24
# Done Getting Trend for Column balance_to_minimum_installment_ratio : 32.7044460773 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio, 24
# Done Aggregating Column minimum_installment_to_total_payment_ratio : 21.3796839714 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio, 24
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio : 22.4904060364 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio, 24
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio : 32.804060936 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio, 24
# Done Aggregating Column minimum_installment_to_current_payment_ratio : 21.4642000198 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio, 24
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio : 22.4928250313 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio, 24
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio : 33.0335450172 seconds
# Getting Aggregates for column: current_to_total_payment_ratio, 24
# Done Aggregating Column current_to_total_payment_ratio : 21.5588150024 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio, 24
# Done Getting Kurtosis for Column current_to_total_payment_ratio : 22.6976969242 seconds
# Getting Trend for column: current_to_total_payment_ratio, 24
# Done Getting Trend for Column current_to_total_payment_ratio : 32.8186321259 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio, 24
# Done Aggregating Column payment_to_receivable_min_ratio : 21.9419739246 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio, 24
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio : 22.7208271027 seconds
# Getting Trend for column: payment_to_receivable_min_ratio, 24
# Done Getting Trend for Column payment_to_receivable_min_ratio : 32.8151419163 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio, 24
# Done Aggregating Column payment_to_receivable_curr_ratio : 21.5354089737 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio, 24
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio : 22.7164590359 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio, 24
# Done Getting Trend for Column payment_to_receivable_curr_ratio : 32.9095709324 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio, 24
# Done Aggregating Column payment_to_receivable_total_ratio : 21.4294390678 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio, 24
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio : 22.5498468876 seconds
# Getting Trend for column: payment_to_receivable_total_ratio, 24
# Done Getting Trend for Column payment_to_receivable_total_ratio : 32.7760510445 seconds
# Getting Aggregates for column: credit_card_paid_late, 24
# Done Aggregating Column credit_card_paid_late : 0.990288972855 seconds
# Getting Aggregates for column: credit_card_paid_late_with_tolerance, 24
# Done Aggregating Column credit_card_paid_late_with_tolerance : 0.658879995346 seconds
# Getting Aggregates for column: contract_is_active, 24
# Done Aggregating Column contract_is_active : 0.514297008514 seconds
# Getting Aggregates for column: contract_is_completed, 24
# Done Aggregating Column contract_is_completed : 0.59161901474 seconds
# Getting Aggregates for column: contract_is_signed, 24
# Done Aggregating Column contract_is_signed : 0.515001058578 seconds
# Getting Aggregates for column: amt_drawings_atm_current_is_zero, 24
# Done Aggregating Column amt_drawings_atm_current_is_zero : 0.595673084259 seconds
# Getting Aggregates for column: amt_drawings_pos_current_is_zero, 24
# Done Aggregating Column amt_drawings_pos_current_is_zero : 0.514924049377 seconds
# Getting Aggregates for column: amt_drawing_current_is_zero, 24
# Done Aggregating Column amt_drawing_current_is_zero : 0.595052957535 seconds
# Getting Aggregates for column: cnt_drawings_atm_current_is_zero, 24
# Done Aggregating Column cnt_drawings_atm_current_is_zero : 0.559100866318 seconds
# Getting Aggregates for column: cnt_drawings_pos_current_is_zero, 24
# Done Aggregating Column cnt_drawings_pos_current_is_zero : 0.596284151077 seconds
# Getting Aggregates for column: cnt_drawing_current_is_zero, 24
# Done Aggregating Column cnt_drawing_current_is_zero : 0.517879962921 seconds
# Getting Aggregates for column: cnt_installment_mature_cum_is_zero, 24
# Done Aggregating Column cnt_installment_mature_cum_is_zero : 0.595746994019 seconds
# Getting Aggregates for column: SK_DPD, 36
# Done Aggregating Column SK_DPD : 25.8745820522 seconds
# Getting Kurtosis for Column: SK_DPD, 36
# Done Getting Kurtosis for Column SK_DPD : 22.8116509914 seconds
# Getting Trend for column: SK_DPD, 36
# Done Getting Trend for Column SK_DPD : 11.5580530167 seconds
# Getting Aggregates for column: SK_DPD_DEF, 36
# Done Aggregating Column SK_DPD_DEF : 22.4353859425 seconds
# Getting Kurtosis for Column: SK_DPD_DEF, 36
# Done Getting Kurtosis for Column SK_DPD_DEF : 22.6430380344 seconds
# Getting Trend for column: SK_DPD_DEF, 36
# Done Getting Trend for Column SK_DPD_DEF : 11.5505628586 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT, 36
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT : 21.7200291157 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT, 36
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT : 23.3753130436 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT, 36
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT : 34.1707489491 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT, 36
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT : 22.2263300419 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT, 36
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT : 22.410602808 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT, 36
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT : 33.8311491013 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT, 36
# Done Aggregating Column CNT_DRAWINGS_CURRENT : 23.2120769024 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT, 36
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT : 23.5919032097 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT, 36
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT : 11.5267498493 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT, 36
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT : 21.5764689445 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT, 36
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT : 22.7096121311 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT, 36
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT : 33.9799859524 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT, 36
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT : 21.7461140156 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT, 36
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT : 22.3303370476 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT, 36
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT : 34.6041009426 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT, 36
# Done Aggregating Column AMT_DRAWINGS_CURRENT : 23.0756859779 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT, 36
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT : 24.1057729721 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT, 36
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT : 33.9920120239 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM, 36
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM : 22.6533210278 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM, 36
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM : 22.9712998867 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM, 36
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM : 34.1117730141 seconds
# Getting Aggregates for column: AMT_BALANCE, 36
# Done Aggregating Column AMT_BALANCE : 21.9004311562 seconds
# Getting Kurtosis for Column: AMT_BALANCE, 36
# Done Getting Kurtosis for Column AMT_BALANCE : 22.832474947 seconds
# Getting Trend for column: AMT_BALANCE, 36
# Done Getting Trend for Column AMT_BALANCE : 33.9403939247 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT, 36
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT : 21.8016061783 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT, 36
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT : 23.1715948582 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT, 36
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT : 34.0180461407 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE, 36
# Done Aggregating Column AMT_TOTAL_RECEIVABLE : 22.2555558681 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE, 36
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE : 22.9433801174 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE, 36
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE : 34.1496119499 seconds
# Getting Aggregates for column: cnt_pos_ratio, 36
# Done Aggregating Column cnt_pos_ratio : 23.1604268551 seconds
# Getting Kurtosis for Column: cnt_pos_ratio, 36
# Done Getting Kurtosis for Column cnt_pos_ratio : 24.911123991 seconds
# Getting Trend for column: cnt_pos_ratio, 36
# Done Getting Trend for Column cnt_pos_ratio : 34.5942850113 seconds
# Getting Aggregates for column: cnt_atm_ratio, 36
# Done Aggregating Column cnt_atm_ratio : 23.1445610523 seconds
# Getting Kurtosis for Column: cnt_atm_ratio, 36
# Done Getting Kurtosis for Column cnt_atm_ratio : 24.1622350216 seconds
# Getting Trend for column: cnt_atm_ratio, 36
# Done Getting Trend for Column cnt_atm_ratio : 34.6312129498 seconds
# Getting Aggregates for column: amt_pos_ratio, 36
# Done Aggregating Column amt_pos_ratio : 23.1973500252 seconds
# Getting Kurtosis for Column: amt_pos_ratio, 36
# Done Getting Kurtosis for Column amt_pos_ratio : 23.9744231701 seconds
# Getting Trend for column: amt_pos_ratio, 36
# Done Getting Trend for Column amt_pos_ratio : 34.7685358524 seconds
# Getting Aggregates for column: amt_atm_ratio, 36
# Done Aggregating Column amt_atm_ratio : 23.3614900112 seconds
# Getting Kurtosis for Column: amt_atm_ratio, 36
# Done Getting Kurtosis for Column amt_atm_ratio : 24.5787260532 seconds
# Getting Trend for column: amt_atm_ratio, 36
# Done Getting Trend for Column amt_atm_ratio : 34.8920099735 seconds
# Getting Aggregates for column: balance_to_drawing_ratio, 36
# Done Aggregating Column balance_to_drawing_ratio : 23.1226279736 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio, 36
# Done Getting Kurtosis for Column balance_to_drawing_ratio : 24.3961191177 seconds
# Getting Trend for column: balance_to_drawing_ratio, 36
# Done Getting Trend for Column balance_to_drawing_ratio : 34.6913878918 seconds
# Getting Aggregates for column: balance_to_limit_ratio, 36
# Done Aggregating Column balance_to_limit_ratio : 23.0489590168 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio, 36
# Done Getting Kurtosis for Column balance_to_limit_ratio : 24.3946359158 seconds
# Getting Trend for column: balance_to_limit_ratio, 36
# Done Getting Trend for Column balance_to_limit_ratio : 34.6687300205 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio, 36
# Done Aggregating Column balance_to_total_payment_ratio : 24.4232809544 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio, 36
# Done Getting Kurtosis for Column balance_to_total_payment_ratio : 24.275231123 seconds
# Getting Trend for column: balance_to_total_payment_ratio, 36
# Done Getting Trend for Column balance_to_total_payment_ratio : 34.4378430843 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio, 36
# Done Aggregating Column balance_to_minimum_installment_ratio : 23.0672018528 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio, 36
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio : 24.3425719738 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio, 36
# Done Getting Trend for Column balance_to_minimum_installment_ratio : 34.5497391224 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio, 36
# Done Aggregating Column minimum_installment_to_total_payment_ratio : 23.2073998451 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio, 36
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio : 24.5654811859 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio, 36
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio : 34.5160009861 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio, 36
# Done Aggregating Column minimum_installment_to_current_payment_ratio : 23.1908109188 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio, 36
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio : 24.4351909161 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio, 36
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio : 34.78810215 seconds
# Getting Aggregates for column: current_to_total_payment_ratio, 36
# Done Aggregating Column current_to_total_payment_ratio : 23.1544890404 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio, 36
# Done Getting Kurtosis for Column current_to_total_payment_ratio : 23.663902998 seconds
# Getting Trend for column: current_to_total_payment_ratio, 36
# Done Getting Trend for Column current_to_total_payment_ratio : 34.0009858608 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio, 36
# Done Aggregating Column payment_to_receivable_min_ratio : 22.0197210312 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio, 36
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio : 23.1004629135 seconds
# Getting Trend for column: payment_to_receivable_min_ratio, 36
# Done Getting Trend for Column payment_to_receivable_min_ratio : 34.1405351162 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio, 36
# Done Aggregating Column payment_to_receivable_curr_ratio : 21.9562959671 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio, 36
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio : 23.1720309258 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio, 36
# Done Getting Trend for Column payment_to_receivable_curr_ratio : 34.1297249794 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio, 36
# Done Aggregating Column payment_to_receivable_total_ratio : 21.9118990898 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio, 36
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio : 23.313601017 seconds
# Getting Trend for column: payment_to_receivable_total_ratio, 36
# Done Getting Trend for Column payment_to_receivable_total_ratio : 33.9873139858 seconds
# Getting Aggregates for column: credit_card_paid_late, 36
# Done Aggregating Column credit_card_paid_late : 1.33388710022 seconds
# Getting Aggregates for column: credit_card_paid_late_with_tolerance, 36
# Done Aggregating Column credit_card_paid_late_with_tolerance : 0.835826873779 seconds
# Getting Aggregates for column: contract_is_active, 36
# Done Aggregating Column contract_is_active : 0.65530705452 seconds
# Getting Aggregates for column: contract_is_completed, 36
# Done Aggregating Column contract_is_completed : 0.722369909286 seconds
# Getting Aggregates for column: contract_is_signed, 36
# Done Aggregating Column contract_is_signed : 0.650586128235 seconds
# Getting Aggregates for column: amt_drawings_atm_current_is_zero, 36
# Done Aggregating Column amt_drawings_atm_current_is_zero : 0.634564876556 seconds
# Getting Aggregates for column: amt_drawings_pos_current_is_zero, 36
# Done Aggregating Column amt_drawings_pos_current_is_zero : 0.64734005928 seconds
# Getting Aggregates for column: amt_drawing_current_is_zero, 36
# Done Aggregating Column amt_drawing_current_is_zero : 0.566852092743 seconds
# Getting Aggregates for column: cnt_drawings_atm_current_is_zero, 36
# Done Aggregating Column cnt_drawings_atm_current_is_zero : 0.67746591568 seconds
# Getting Aggregates for column: cnt_drawings_pos_current_is_zero, 36
# Done Aggregating Column cnt_drawings_pos_current_is_zero : 0.563956022263 seconds
# Getting Aggregates for column: cnt_drawing_current_is_zero, 36
# Done Aggregating Column cnt_drawing_current_is_zero : 0.646322011948 seconds
# Getting Aggregates for column: cnt_installment_mature_cum_is_zero, 36
# Done Aggregating Column cnt_installment_mature_cum_is_zero : 0.573488950729 seconds
# (103558, 1157) Before dropping Na's
# (103558, 1131) After dropping Na's

# %% [markdown]
# # Bureau Features

# %%
def GetBandBBFeatures(bureau_path = "../data/bureau.csv",bureau_balance_path = "../data/bureau_balance.csv"):
    bureau = pd.read_csv(bureau_path).sort_values(by =["SK_ID_CURR","DAYS_CREDIT"]).reset_index(drop = True)
    bureau_balance = pd.read_csv(bureau_balance_path)

    # Get Bureau Balance Aggregations
    bureau_balance = one_hot_encoder(bureau_balance, nan_as_category = True)

    months_balance_aggregation = bureau_balance.groupby("SK_ID_BUREAU").agg({"MONTHS_BALANCE": ["min","max","mean"]})
    months_balance_aggregation.columns = ["bb_MONTHS_BALANCE_min", "bb_MONTHS_BALANCE_max", "bb_MONTHS_BALANCE_mean"]
    bb_cols = months_balance_aggregation.columns.values.tolist()
    
    status_aggregation = bureau_balance.groupby("SK_ID_BUREAU")[bureau_balance.columns.drop(["SK_ID_BUREAU","MONTHS_BALANCE"])].mean()
    status_aggregation.columns = ["bb_{}_mean".format(c) for c in status_aggregation.columns]
    bb_cols += status_aggregation.columns.values.tolist()
    
    bureau_balance = status_aggregation.merge(months_balance_aggregation, how = "left", left_index=True, right_index = True)
    bureau = bureau.merge(bureau_balance, how = "left", left_on = "SK_ID_BUREAU", right_index = True)

    del months_balance_aggregation, status_aggregation, bureau_balance
    gc.collect()

    # Aggregating Data Part 1
    bureau_groupby = bureau.groupby("SK_ID_CURR")
    aggregates_df = pd.DataFrame()
    aggregates_df["total_counts"] = bureau_groupby["CREDIT_ACTIVE"].count()
    aggregates_df["unique_credit_active_counts"] = bureau_groupby["CREDIT_ACTIVE"].nunique()
    aggregates_df["currency_unique_counts"] = bureau_groupby["CREDIT_CURRENCY"].nunique()
    aggregates_df["credit_type_unique_counts"] = bureau_groupby["CREDIT_TYPE"].nunique()
    aggregates_df["min_days_credit"] = bureau_groupby["DAYS_CREDIT"].min()
    aggregates_df["loan_type_diversification"] = aggregates_df["credit_type_unique_counts"]/aggregates_df["total_counts"].astype("float32")
    aggregates_df["currency_type_diversification"] = aggregates_df["currency_unique_counts"]/aggregates_df["total_counts"].astype("float32")
    aggregates_df["active_type_diversification"] = aggregates_df["unique_credit_active_counts"]/aggregates_df["total_counts"].astype("float32")

    # Handling Categoricals
    bureau.loc[~bureau.CREDIT_TYPE.isin(["Consumer credit", "Credit card", "Car loan", "Mortgage","Microloan"]), "CREDIT_TYPE"] = "Other"
    bureau.loc[~bureau.CREDIT_ACTIVE.isin(["Closed","Active","Sold"]), "CREDIT_ACTIVE"] = "Other"
    bureau["CREDIT_CURRENCY"] = (bureau["CREDIT_CURRENCY"] == "currency 1").astype(int)

    # Generating Integer Columns
    bureau["credit_is_active"] = (bureau["CREDIT_ACTIVE"] == "Active").astype(int)
    bureau["credit_is_closed"] = (bureau["CREDIT_ACTIVE"] == "Closed").astype(int)
    bureau["credit_is_sold"] = (bureau["CREDIT_ACTIVE"] == "Sold").astype(int)
    bureau["credit_is_other"] = (bureau["CREDIT_ACTIVE"] == "Other").astype(int)
    bureau["credit_type_is_consumer_credit"] = (bureau["CREDIT_TYPE"] == "Consumer credit").astype(int)
    bureau["credit_type_is_credit_card"] = (bureau["CREDIT_TYPE"] == "Credit card").astype(int)
    bureau["credit_type_is_car_loan"] = (bureau["CREDIT_TYPE"] == "Car loan").astype(int)
    bureau["credit_type_is_mortgage"] = (bureau["CREDIT_TYPE"] == "Mortgage").astype(int)
    bureau["credit_type_is_microloan"] = (bureau["CREDIT_TYPE"] == "Microloan").astype(int)
    bureau["credit_type_is_other"] = (bureau["CREDIT_TYPE"] == "Other").astype(int)

    bureau.drop(["CREDIT_TYPE", "CREDIT_ACTIVE"], axis=1, inplace = True)
    int_columns = ["credit_is_active", "credit_is_closed","credit_is_sold","credit_is_other","credit_type_is_consumer_credit","credit_type_is_credit_card","credit_type_is_car_loan","credit_type_is_mortgage","credit_type_is_microloan","credit_type_is_other"]
    
    # Aggregating Data Part 2
    bureau_groupby = bureau.groupby("SK_ID_CURR")
    
    aggregates_df_mean = bureau_groupby[int_columns].mean()
    aggregates_df_mean.columns = ["ratio_{}".format(c) for c in aggregates_df_mean.columns]
    aggregates_df = aggregates_df.merge(aggregates_df_mean, how = "left", left_index=True, right_index=True)
    
    aggregates_df_sum = bureau_groupby[int_columns].sum()
    aggregates_df_sum.columns = ["sum_{}".format(c) for c in aggregates_df_sum.columns]
    aggregates_df = aggregates_df.merge(aggregates_df_sum, how = "left", left_index=True, right_index=True)
    del aggregates_df_mean, aggregates_df_sum
    gc.collect()
    
    
    # Ratio Features
    
    bureau["debt_ratio"] = bureau["AMT_CREDIT_SUM_DEBT"]/(1.0+bureau["AMT_CREDIT_SUM"])
    bureau["limit_ratio"] = bureau["AMT_CREDIT_SUM_LIMIT"]/(1.0+bureau["AMT_CREDIT_SUM"])
    bureau["overdue_ratio"] = bureau["AMT_CREDIT_SUM_OVERDUE"]/(1.0+bureau["AMT_CREDIT_SUM"])
    bureau["annuity_ratio"] = bureau["AMT_ANNUITY"]/(1.0+bureau["AMT_CREDIT_SUM"])
    
    # Get Feature Aggregates
    min_max_mean_sum_std = ["CREDIT_DAY_OVERDUE", "DAYS_CREDIT_ENDDATE","DAYS_ENDDATE_FACT","AMT_CREDIT_MAX_OVERDUE","DAYS_CREDIT_UPDATE","AMT_ANNUITY", "CNT_CREDIT_PROLONG"]
    complete_set = ["DAYS_CREDIT","AMT_CREDIT_SUM","AMT_CREDIT_MAX_OVERDUE"]
    
    bureau_groupby = bureau.groupby("SK_ID_CURR")
    
    for col in min_max_mean_sum_std+bb_cols:
        generate_features("bureau",bureau_groupby, "all", col, get_trend = True, get_kurtosis = False, to_calculate = ["sum","mean","max","min","std"])

    for col in complete_set:
        generate_features("bureau",bureau_groupby, "all", col, get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])

    # Get Lag Aggregates
    for lags in [5, 15, 30]:
        bureau_groupby = bureau.groupby("SK_ID_CURR").tail(lags).groupby("SK_ID_CURR")
    
        for col in complete_set:
            generate_features("bureau",bureau_groupby, lags, col, get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])

    return aggregates_df

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/bureau.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
aggregates_df = GetBandBBFeatures(bureau_path = "../data/bureau.csv",bureau_balance_path = "../data/bureau_balance.csv")
output = output.merge(aggregates_df, how = "left", left_on = "SK_ID_CURR", right_index=True)

# Saving Data
if get_unnormalized:
    output.to_csv("csv/bureau_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/bureau_features_normalized_V{}.csv".format(version), index=False)
# Out:
# Getting Aggregates for column: CREDIT_DAY_OVERDUE, all
# Done Aggregating Column CREDIT_DAY_OVERDUE : 13542.5096231 seconds
# Getting Trend for column: CREDIT_DAY_OVERDUE, all
# Done Getting Trend for Column CREDIT_DAY_OVERDUE : 34.5797820091 seconds
# Getting Aggregates for column: DAYS_CREDIT_ENDDATE, all
# Done Aggregating Column DAYS_CREDIT_ENDDATE : 0.226007938385 seconds
# Getting Trend for column: DAYS_CREDIT_ENDDATE, all
# Done Getting Trend for Column DAYS_CREDIT_ENDDATE : 90.110200882 seconds
# Getting Aggregates for column: DAYS_ENDDATE_FACT, all
# Done Aggregating Column DAYS_ENDDATE_FACT : 0.27272105217 seconds
# Getting Trend for column: DAYS_ENDDATE_FACT, all
# Done Getting Trend for Column DAYS_ENDDATE_FACT : 96.9400629997 seconds
# Getting Aggregates for column: AMT_CREDIT_MAX_OVERDUE, all
# Done Aggregating Column AMT_CREDIT_MAX_OVERDUE : 0.265498161316 seconds
# Getting Trend for column: AMT_CREDIT_MAX_OVERDUE, all
# Done Getting Trend for Column AMT_CREDIT_MAX_OVERDUE : 99.0662169456 seconds
# Getting Aggregates for column: DAYS_CREDIT_UPDATE, all
# Done Aggregating Column DAYS_CREDIT_UPDATE : 0.290050029755 seconds
# Getting Trend for column: DAYS_CREDIT_UPDATE, all
# Done Getting Trend for Column DAYS_CREDIT_UPDATE : 35.11043787 seconds
# Getting Aggregates for column: AMT_ANNUITY, all
# Done Aggregating Column AMT_ANNUITY : 0.261130094528 seconds
# Getting Trend for column: AMT_ANNUITY, all
# Done Getting Trend for Column AMT_ANNUITY : 102.19469595 seconds
# Getting Aggregates for column: CNT_CREDIT_PROLONG, all
# Done Aggregating Column CNT_CREDIT_PROLONG : 0.313935995102 seconds
# Getting Trend for column: CNT_CREDIT_PROLONG, all
# Done Getting Trend for Column CNT_CREDIT_PROLONG : 34.2121081352 seconds
# Getting Aggregates for column: bb_MONTHS_BALANCE_min, all
# Done Aggregating Column bb_MONTHS_BALANCE_min : 0.256204843521 seconds
# Getting Trend for column: bb_MONTHS_BALANCE_min, all
# Done Getting Trend for Column bb_MONTHS_BALANCE_min : 106.011131048 seconds
# Getting Aggregates for column: bb_MONTHS_BALANCE_max, all
# Done Aggregating Column bb_MONTHS_BALANCE_max : 0.307944059372 seconds
# Getting Trend for column: bb_MONTHS_BALANCE_max, all
# Done Getting Trend for Column bb_MONTHS_BALANCE_max : 105.802600861 seconds
# Getting Aggregates for column: bb_MONTHS_BALANCE_mean, all
# Done Aggregating Column bb_MONTHS_BALANCE_mean : 0.328914165497 seconds
# Getting Trend for column: bb_MONTHS_BALANCE_mean, all
# Done Getting Trend for Column bb_MONTHS_BALANCE_mean : 107.337222815 seconds
# Getting Aggregates for column: bb_STATUS_0_mean, all
# Done Aggregating Column bb_STATUS_0_mean : 0.334810972214 seconds
# Getting Trend for column: bb_STATUS_0_mean, all
# Done Getting Trend for Column bb_STATUS_0_mean : 105.91456008 seconds
# Getting Aggregates for column: bb_STATUS_1_mean, all
# Done Aggregating Column bb_STATUS_1_mean : 0.353002071381 seconds
# Getting Trend for column: bb_STATUS_1_mean, all
# Done Getting Trend for Column bb_STATUS_1_mean : 105.313845873 seconds
# Getting Aggregates for column: bb_STATUS_2_mean, all
# Done Aggregating Column bb_STATUS_2_mean : 0.360396146774 seconds
# Getting Trend for column: bb_STATUS_2_mean, all
# Done Getting Trend for Column bb_STATUS_2_mean : 107.759202003 seconds
# Getting Aggregates for column: bb_STATUS_3_mean, all
# Done Aggregating Column bb_STATUS_3_mean : 0.364202022552 seconds
# Getting Trend for column: bb_STATUS_3_mean, all
# Done Getting Trend for Column bb_STATUS_3_mean : 105.828275919 seconds
# Getting Aggregates for column: bb_STATUS_4_mean, all
# Done Aggregating Column bb_STATUS_4_mean : 0.397078990936 seconds
# Getting Trend for column: bb_STATUS_4_mean, all
# Done Getting Trend for Column bb_STATUS_4_mean : 107.435027122 seconds
# Getting Aggregates for column: bb_STATUS_5_mean, all
# Done Aggregating Column bb_STATUS_5_mean : 0.394325971603 seconds
# Getting Trend for column: bb_STATUS_5_mean, all
# Done Getting Trend for Column bb_STATUS_5_mean : 106.084653854 seconds
# Getting Aggregates for column: bb_STATUS_C_mean, all
# Done Aggregating Column bb_STATUS_C_mean : 0.418292999268 seconds
# Getting Trend for column: bb_STATUS_C_mean, all
# Done Getting Trend for Column bb_STATUS_C_mean : 105.700662136 seconds
# Getting Aggregates for column: bb_STATUS_X_mean, all
# Done Aggregating Column bb_STATUS_X_mean : 0.417459011078 seconds
# Getting Trend for column: bb_STATUS_X_mean, all
# Done Getting Trend for Column bb_STATUS_X_mean : 107.039588928 seconds
# Getting Aggregates for column: bb_STATUS_nan_mean, all
# Done Aggregating Column bb_STATUS_nan_mean : 0.436424016953 seconds
# Getting Trend for column: bb_STATUS_nan_mean, all
# Done Getting Trend for Column bb_STATUS_nan_mean : 105.867480993 seconds
# Getting Aggregates for column: DAYS_CREDIT, all
# Done Aggregating Column DAYS_CREDIT : 62.9465050697 seconds
# Getting Kurtosis for Column: DAYS_CREDIT, all
# Done Getting Kurtosis for Column DAYS_CREDIT : 65.5987010002 seconds
# Getting Trend for column: DAYS_CREDIT, all
# Done Getting Trend for Column DAYS_CREDIT : 34.105052948 seconds
# Getting Aggregates for column: AMT_CREDIT_SUM, all
# Done Aggregating Column AMT_CREDIT_SUM : 60.8438270092 seconds
# Getting Kurtosis for Column: AMT_CREDIT_SUM, all
# Done Getting Kurtosis for Column AMT_CREDIT_SUM : 62.8416678905 seconds
# Getting Trend for column: AMT_CREDIT_SUM, all
# Done Getting Trend for Column AMT_CREDIT_SUM : 88.7061140537 seconds
# Getting Aggregates for column: AMT_CREDIT_MAX_OVERDUE, all
# Done Aggregating Column AMT_CREDIT_MAX_OVERDUE : 63.3586649895 seconds
# Getting Kurtosis for Column: AMT_CREDIT_MAX_OVERDUE, all
# Done Getting Kurtosis for Column AMT_CREDIT_MAX_OVERDUE : 64.1851820946 seconds
# Getting Trend for column: AMT_CREDIT_MAX_OVERDUE, all
# Done Getting Trend for Column AMT_CREDIT_MAX_OVERDUE : 97.7911279202 seconds
# Getting Aggregates for column: DAYS_CREDIT, 5
# Done Aggregating Column DAYS_CREDIT : 67.7514650822 seconds
# Getting Kurtosis for Column: DAYS_CREDIT, 5
# Done Getting Kurtosis for Column DAYS_CREDIT : 69.9880309105 seconds
# Getting Trend for column: DAYS_CREDIT, 5
# Done Getting Trend for Column DAYS_CREDIT : 34.2856040001 seconds
# Getting Aggregates for column: AMT_CREDIT_SUM, 5
# Done Aggregating Column AMT_CREDIT_SUM : 64.4557440281 seconds
# Getting Kurtosis for Column: AMT_CREDIT_SUM, 5
# Done Getting Kurtosis for Column AMT_CREDIT_SUM : 66.8792409897 seconds
# Getting Trend for column: AMT_CREDIT_SUM, 5
# Done Getting Trend for Column AMT_CREDIT_SUM : 89.3465330601 seconds
# Getting Aggregates for column: AMT_CREDIT_MAX_OVERDUE, 5
# Done Aggregating Column AMT_CREDIT_MAX_OVERDUE : 65.7447018623 seconds
# Getting Kurtosis for Column: AMT_CREDIT_MAX_OVERDUE, 5
# Done Getting Kurtosis for Column AMT_CREDIT_MAX_OVERDUE : 63.7498810291 seconds
# Getting Trend for column: AMT_CREDIT_MAX_OVERDUE, 5
# Done Getting Trend for Column AMT_CREDIT_MAX_OVERDUE : 94.6950321198 seconds
# Getting Aggregates for column: DAYS_CREDIT, 15
# Done Aggregating Column DAYS_CREDIT : 68.6627149582 seconds
# Getting Kurtosis for Column: DAYS_CREDIT, 15
# Done Getting Kurtosis for Column DAYS_CREDIT : 69.9586389065 seconds
# Getting Trend for column: DAYS_CREDIT, 15
# Done Getting Trend for Column DAYS_CREDIT : 34.4645180702 seconds
# Getting Aggregates for column: AMT_CREDIT_SUM, 15
# Done Aggregating Column AMT_CREDIT_SUM : 64.7297148705 seconds
# Getting Kurtosis for Column: AMT_CREDIT_SUM, 15
# Done Getting Kurtosis for Column AMT_CREDIT_SUM : 66.8179171085 seconds
# Getting Trend for column: AMT_CREDIT_SUM, 15
# Done Getting Trend for Column AMT_CREDIT_SUM : 90.2770450115 seconds
# Getting Aggregates for column: AMT_CREDIT_MAX_OVERDUE, 15
# Done Aggregating Column AMT_CREDIT_MAX_OVERDUE : 65.2495470047 seconds
# Getting Kurtosis for Column: AMT_CREDIT_MAX_OVERDUE, 15
# Done Getting Kurtosis for Column AMT_CREDIT_MAX_OVERDUE : 61.7702860832 seconds
# Getting Trend for column: AMT_CREDIT_MAX_OVERDUE, 15
# Done Getting Trend for Column AMT_CREDIT_MAX_OVERDUE : 96.0049729347 seconds
# Getting Aggregates for column: DAYS_CREDIT, 30
# Done Aggregating Column DAYS_CREDIT : 64.6404070854 seconds
# Getting Kurtosis for Column: DAYS_CREDIT, 30
# Done Getting Kurtosis for Column DAYS_CREDIT : 65.8055520058 seconds
# Getting Trend for column: DAYS_CREDIT, 30
# Done Getting Trend for Column DAYS_CREDIT : 34.1796619892 seconds
# Getting Aggregates for column: AMT_CREDIT_SUM, 30
# Done Aggregating Column AMT_CREDIT_SUM : 61.2942039967 seconds
# Getting Kurtosis for Column: AMT_CREDIT_SUM, 30
# Done Getting Kurtosis for Column AMT_CREDIT_SUM : 63.3231608868 seconds
# Getting Trend for column: AMT_CREDIT_SUM, 30
# Done Getting Trend for Column AMT_CREDIT_SUM : 88.7438800335 seconds
# Getting Aggregates for column: AMT_CREDIT_MAX_OVERDUE, 30
# Done Aggregating Column AMT_CREDIT_MAX_OVERDUE : 62.1565458775 seconds
# Getting Kurtosis for Column: AMT_CREDIT_MAX_OVERDUE, 30
# Done Getting Kurtosis for Column AMT_CREDIT_MAX_OVERDUE : 60.3803892136 seconds
# Getting Trend for column: AMT_CREDIT_MAX_OVERDUE, 30
# Done Getting Trend for Column AMT_CREDIT_MAX_OVERDUE : 96.4527668953 seconds
# (305811, 250) Before dropping Na's
# (305811, 250) After dropping Na's

# %% [markdown]
# # Previous Application Features

# %%
def GetPreviousAppFeatures(prev_app_path = "../data/previous_application.csv"):
    prev_apps = pd.read_csv(prev_app_path).sort_values(by=["SK_ID_CURR","DAYS_DECISION"]).reset_index(drop = True)
    global output
    
    # Generating Some Features
    prev_apps['previous_application_was_approved'] = (prev_apps['NAME_CONTRACT_STATUS'] == 'Approved').astype('int') 
    prev_apps['previous_application_was_refused'] = (prev_apps['NAME_CONTRACT_STATUS'] == 'Refused').astype('int') 
    prev_apps['prev_applications_was_revolving_loan'] = (prev_apps['NAME_CONTRACT_TYPE'] == 'Revolving loans').astype('int') 
    prev_apps['prev_applications_was_priviledged'] = (prev_apps['RATE_INTEREST_PRIVILEGED'] == np.nan).astype('int')
    prev_apps['prev_applications_was_primary'] = (prev_apps['RATE_INTEREST_PRIMARY'] == np.nan).astype('int')
    prev_apps['FLAG_LAST_APPL_PER_CONTRACT'] = prev_apps.FLAG_LAST_APPL_PER_CONTRACT.factorize()[0]
    prev_apps["proportion_granted"] = prev_apps["AMT_APPLICATION"]/(prev_apps["AMT_CREDIT"]+1.0)

    # All Aggregate Features
    groups = prev_apps.groupby("SK_ID_CURR")
    
    generate_features("previous_apps",groups, "all", "SK_ID_PREV", get_trend = False, get_kurtosis = False, to_calculate = ["count","nunique"])
    generate_features("previous_apps",groups, "all", "DAYS_DECISION", get_trend = False, get_kurtosis = False, to_calculate = ["min","max","mean"])
    generate_features("previous_apps",groups, "all", "CNT_PAYMENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("previous_apps",groups, "all", "DAYS_DECISION", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("previous_apps",groups, "all", "DAYS_FIRST_DRAWING", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("previous_apps",groups, "all", "proportion_granted", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
    generate_features("previous_apps",groups, "all", "previous_application_was_approved", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("previous_apps",groups, "all", "previous_application_was_refused", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("previous_apps",groups, "all", "prev_applications_was_revolving_loan", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("previous_apps",groups, "all", "prev_applications_was_priviledged", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("previous_apps",groups, "all", "prev_applications_was_primary", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
    generate_features("previous_apps",groups, "all", "FLAG_LAST_APPL_PER_CONTRACT", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])

    # For Lagged Items
    for lags in [3, 6, 12, 18, 36, 72]:
        groups = prev_apps.groupby("SK_ID_CURR").tail(lags).reset_index(drop=True).groupby("SK_ID_CURR")

        generate_features("previous_apps",groups, lags, "CNT_PAYMENT", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("previous_apps",groups, lags, "proportion_granted", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("previous_apps",groups, lags, "DAYS_DECISION", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("previous_apps",groups, lags, "DAYS_FIRST_DRAWING", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("previous_apps",groups, lags, "previous_application_was_approved", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
        generate_features("previous_apps",groups, lags, "previous_application_was_refused", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
        generate_features("previous_apps",groups, lags, "prev_applications_was_revolving_loan", get_trend = False, get_kurtosis = False, to_calculate = ["sum","mean"])
        del groups
        gc.collect()
    
    # For Get Last Item
    output["previous_apps_last_previous_application_was_approved"] = output["SK_ID_CURR"].map(prev_apps.groupby("SK_ID_CURR")["previous_application_was_approved"].last())
    output["previous_apps_last_previous_application_was_refused"] = output["SK_ID_CURR"].map(prev_apps.groupby("SK_ID_CURR")["previous_application_was_refused"].last())
    output["previous_apps_last_prev_applications_was_revolving_loan"] = output["SK_ID_CURR"].map(prev_apps.groupby("SK_ID_CURR")["prev_applications_was_revolving_loan"].last())
    output["previous_apps_last_FLAG_LAST_APPL_PER_CONTRACT"] = output["SK_ID_CURR"].map(prev_apps.groupby("SK_ID_CURR")["FLAG_LAST_APPL_PER_CONTRACT"].last())
    output["previous_apps_last_HOUR_APPR_PROCESS_START"] = output["SK_ID_CURR"].map(prev_apps.groupby("SK_ID_CURR")["HOUR_APPR_PROCESS_START"].last())
    output["previous_apps_last_RATE_INTEREST_PRIVILEGED"] = output["SK_ID_CURR"].map(prev_apps.groupby("SK_ID_CURR")["RATE_INTEREST_PRIVILEGED"].last())
    output["previous_apps_last_RATE_INTEREST_PRIMARY"] = output["SK_ID_CURR"].map(prev_apps.groupby("SK_ID_CURR")["RATE_INTEREST_PRIMARY"].last())
    output["previous_apps_last_DAYS_FIRST_DUE"] = output["SK_ID_CURR"].map(prev_apps.groupby("SK_ID_CURR")["DAYS_FIRST_DUE"].last())
    output["previous_apps_last_DAYS_TERMINATION"] = output["SK_ID_CURR"].map(prev_apps.groupby("SK_ID_CURR")["DAYS_TERMINATION"].last())
    
    
    # All Categoricals
    cats = [c for c in prev_apps.columns if prev_apps[c].dtype == "object"]
    ohe_prev_cols = one_hot_encoder(prev_apps[cats+["SK_ID_CURR"]])
    
    ohe_prev_cols_mean = ohe_prev_cols.groupby("SK_ID_CURR")[ohe_prev_cols.columns.drop(["SK_ID_CURR"])].mean()
    ohe_prev_cols_sum = ohe_prev_cols.groupby("SK_ID_CURR")[ohe_prev_cols.columns.drop(["SK_ID_CURR"])].sum()
    ohe_prev_cols_last = ohe_prev_cols.groupby("SK_ID_CURR")[ohe_prev_cols.columns.drop(["SK_ID_CURR"])].last()
    
    ohe_prev_cols_mean.columns = ["previous_apps_ohe_"+c+"_mean" for c in ohe_prev_cols_mean.columns]
    ohe_prev_cols_sum.columns = ["previous_apps_ohe_"+c+"_sum" for c in ohe_prev_cols_sum.columns]
    ohe_prev_cols_last.columns = ["previous_apps_ohe_"+c+"_last" for c in ohe_prev_cols_last.columns]
    
    output = output.merge(ohe_prev_cols_mean, how = "left", left_on = "SK_ID_CURR", right_index=True)
    output = output.merge(ohe_prev_cols_sum, how = "left", left_on = "SK_ID_CURR", right_index=True)
    output = output.merge(ohe_prev_cols_last, how = "left", left_on = "SK_ID_CURR", right_index=True)

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/previous_application.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
GetPreviousAppFeatures(prev_app_path = "../data/previous_application.csv")

# Saving Data
if get_unnormalized:
    output.to_csv("csv/previous_application_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/previous_application_features_normalized_V{}.csv".format(version), index=False)
# Out:
# Getting Aggregates for column: SK_ID_PREV, all
# Done Aggregating Column SK_ID_PREV : 31266.647419 seconds
# Getting Aggregates for column: DAYS_DECISION, all
# Done Aggregating Column DAYS_DECISION : 0.161512851715 seconds
# Getting Aggregates for column: CNT_PAYMENT, all
# Done Aggregating Column CNT_PAYMENT : 71.4247591496 seconds
# Getting Kurtosis for Column: CNT_PAYMENT, all
# Done Getting Kurtosis for Column CNT_PAYMENT : 73.0183959007 seconds
# Getting Trend for column: CNT_PAYMENT, all
# Done Getting Trend for Column CNT_PAYMENT : 99.8868370056 seconds
# Getting Aggregates for column: DAYS_DECISION, all
# Done Aggregating Column DAYS_DECISION : 69.8875699043 seconds
# Getting Kurtosis for Column: DAYS_DECISION, all
# Done Getting Kurtosis for Column DAYS_DECISION : 72.7901251316 seconds
# Getting Trend for column: DAYS_DECISION, all
# Done Getting Trend for Column DAYS_DECISION : 37.6155669689 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING, all
# Done Aggregating Column DAYS_FIRST_DRAWING : 67.5285480022 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING, all
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING : 66.9532060623 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING, all
# Done Getting Trend for Column DAYS_FIRST_DRAWING : 98.2454299927 seconds
# Getting Aggregates for column: proportion_granted, all
# Done Aggregating Column proportion_granted : 71.6130669117 seconds
# Getting Kurtosis for Column: proportion_granted, all
# Done Getting Kurtosis for Column proportion_granted : 73.9931321144 seconds
# Getting Trend for column: proportion_granted, all
# Done Getting Trend for Column proportion_granted : 100.442603827 seconds
# Getting Aggregates for column: previous_application_was_approved, all
# Done Aggregating Column previous_application_was_approved : 0.245094060898 seconds
# Getting Aggregates for column: previous_application_was_refused, all
# Done Aggregating Column previous_application_was_refused : 0.198498010635 seconds
# Getting Aggregates for column: prev_applications_was_revolving_loan, all
# Done Aggregating Column prev_applications_was_revolving_loan : 0.175641059875 seconds
# Getting Aggregates for column: prev_applications_was_priviledged, all
# Done Aggregating Column prev_applications_was_priviledged : 0.166188001633 seconds
# Getting Aggregates for column: prev_applications_was_primary, all
# Done Aggregating Column prev_applications_was_primary : 0.173660993576 seconds
# Getting Aggregates for column: FLAG_LAST_APPL_PER_CONTRACT, all
# Done Aggregating Column FLAG_LAST_APPL_PER_CONTRACT : 0.177495002747 seconds
# Getting Aggregates for column: CNT_PAYMENT, 3
# Done Aggregating Column CNT_PAYMENT : 68.4405369759 seconds
# Getting Kurtosis for Column: CNT_PAYMENT, 3
# Done Getting Kurtosis for Column CNT_PAYMENT : 66.1331620216 seconds
# Getting Trend for column: CNT_PAYMENT, 3
# Done Getting Trend for Column CNT_PAYMENT : 96.6022660732 seconds
# Getting Aggregates for column: proportion_granted, 3
# Done Aggregating Column proportion_granted : 67.0992629528 seconds
# Getting Kurtosis for Column: proportion_granted, 3
# Done Getting Kurtosis for Column proportion_granted : 65.9313900471 seconds
# Getting Trend for column: proportion_granted, 3
# Done Getting Trend for Column proportion_granted : 95.610768795 seconds
# Getting Aggregates for column: DAYS_DECISION, 3
# Done Aggregating Column DAYS_DECISION : 69.8678810596 seconds
# Getting Kurtosis for Column: DAYS_DECISION, 3
# Done Getting Kurtosis for Column DAYS_DECISION : 68.2623929977 seconds
# Getting Trend for column: DAYS_DECISION, 3
# Done Getting Trend for Column DAYS_DECISION : 37.6360161304 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING, 3
# Done Aggregating Column DAYS_FIRST_DRAWING : 67.5013639927 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING, 3
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING : 65.3923950195 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING, 3
# Done Getting Trend for Column DAYS_FIRST_DRAWING : 98.5650219917 seconds
# Getting Aggregates for column: previous_application_was_approved, 3
# Done Aggregating Column previous_application_was_approved : 0.348050832748 seconds
# Getting Aggregates for column: previous_application_was_refused, 3
# Done Aggregating Column previous_application_was_refused : 0.184196949005 seconds
# Getting Aggregates for column: prev_applications_was_revolving_loan, 3
# Done Aggregating Column prev_applications_was_revolving_loan : 0.189018011093 seconds
# Getting Aggregates for column: CNT_PAYMENT, 6
# Done Aggregating Column CNT_PAYMENT : 74.1834070683 seconds
# Getting Kurtosis for Column: CNT_PAYMENT, 6
# Done Getting Kurtosis for Column CNT_PAYMENT : 72.4833030701 seconds
# Getting Trend for column: CNT_PAYMENT, 6
# Done Getting Trend for Column CNT_PAYMENT : 98.3040709496 seconds
# Getting Aggregates for column: proportion_granted, 6
# Done Aggregating Column proportion_granted : 71.731539011 seconds
# Getting Kurtosis for Column: proportion_granted, 6
# Done Getting Kurtosis for Column proportion_granted : 73.3651359081 seconds
# Getting Trend for column: proportion_granted, 6
# Done Getting Trend for Column proportion_granted : 98.8529360294 seconds
# Getting Aggregates for column: DAYS_DECISION, 6
# Done Aggregating Column DAYS_DECISION : 70.0630741119 seconds
# Getting Kurtosis for Column: DAYS_DECISION, 6
# Done Getting Kurtosis for Column DAYS_DECISION : 72.4229829311 seconds
# Getting Trend for column: DAYS_DECISION, 6
# Done Getting Trend for Column DAYS_DECISION : 37.6892290115 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING, 6
# Done Aggregating Column DAYS_FIRST_DRAWING : 68.2560369968 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING, 6
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING : 66.4151871204 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING, 6
# Done Getting Trend for Column DAYS_FIRST_DRAWING : 98.4833807945 seconds
# Getting Aggregates for column: previous_application_was_approved, 6
# Done Aggregating Column previous_application_was_approved : 0.474515199661 seconds
# Getting Aggregates for column: previous_application_was_refused, 6
# Done Aggregating Column previous_application_was_refused : 0.257678985596 seconds
# Getting Aggregates for column: prev_applications_was_revolving_loan, 6
# Done Aggregating Column prev_applications_was_revolving_loan : 0.222682952881 seconds
# Getting Aggregates for column: CNT_PAYMENT, 12
# Done Aggregating Column CNT_PAYMENT : 69.0345239639 seconds
# Getting Kurtosis for Column: CNT_PAYMENT, 12
# Done Getting Kurtosis for Column CNT_PAYMENT : 68.5625898838 seconds
# Getting Trend for column: CNT_PAYMENT, 12
# Done Getting Trend for Column CNT_PAYMENT : 97.3864982128 seconds
# Getting Aggregates for column: proportion_granted, 12
# Done Aggregating Column proportion_granted : 67.6532869339 seconds
# Getting Kurtosis for Column: proportion_granted, 12
# Done Getting Kurtosis for Column proportion_granted : 69.7837629318 seconds
# Getting Trend for column: proportion_granted, 12
# Done Getting Trend for Column proportion_granted : 97.7894430161 seconds
# Getting Aggregates for column: DAYS_DECISION, 12
# Done Aggregating Column DAYS_DECISION : 71.3302190304 seconds
# Getting Kurtosis for Column: DAYS_DECISION, 12
# Done Getting Kurtosis for Column DAYS_DECISION : 72.7299950123 seconds
# Getting Trend for column: DAYS_DECISION, 12
# Done Getting Trend for Column DAYS_DECISION : 37.8345110416 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING, 12
# Done Aggregating Column DAYS_FIRST_DRAWING : 68.1934659481 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING, 12
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING : 67.0407059193 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING, 12
# Done Getting Trend for Column DAYS_FIRST_DRAWING : 98.4763071537 seconds
# Getting Aggregates for column: previous_application_was_approved, 12
# Done Aggregating Column previous_application_was_approved : 0.58625292778 seconds
# Getting Aggregates for column: previous_application_was_refused, 12
# Done Aggregating Column previous_application_was_refused : 0.287247896194 seconds
# Getting Aggregates for column: prev_applications_was_revolving_loan, 12
# Done Aggregating Column prev_applications_was_revolving_loan : 0.254547119141 seconds
# Getting Aggregates for column: CNT_PAYMENT, 18
# Done Aggregating Column CNT_PAYMENT : 69.9600548744 seconds
# Getting Kurtosis for Column: CNT_PAYMENT, 18
# Done Getting Kurtosis for Column CNT_PAYMENT : 68.2730340958 seconds
# Getting Trend for column: CNT_PAYMENT, 18
# Done Getting Trend for Column CNT_PAYMENT : 97.9404070377 seconds
# Getting Aggregates for column: proportion_granted, 18
# Done Aggregating Column proportion_granted : 67.3992629051 seconds
# Getting Kurtosis for Column: proportion_granted, 18
# Done Getting Kurtosis for Column proportion_granted : 68.7250840664 seconds
# Getting Trend for column: proportion_granted, 18
# Done Getting Trend for Column proportion_granted : 97.3037559986 seconds
# Getting Aggregates for column: DAYS_DECISION, 18
# Done Aggregating Column DAYS_DECISION : 70.7937030792 seconds
# Getting Kurtosis for Column: DAYS_DECISION, 18
# Done Getting Kurtosis for Column DAYS_DECISION : 73.6049189568 seconds
# Getting Trend for column: DAYS_DECISION, 18
# Done Getting Trend for Column DAYS_DECISION : 37.6990950108 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING, 18
# Done Aggregating Column DAYS_FIRST_DRAWING : 68.2255358696 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING, 18
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING : 66.6562800407 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING, 18
# Done Getting Trend for Column DAYS_FIRST_DRAWING : 98.0005149841 seconds
# Getting Aggregates for column: previous_application_was_approved, 18
# Done Aggregating Column previous_application_was_approved : 0.797168016434 seconds
# Getting Aggregates for column: previous_application_was_refused, 18
# Done Aggregating Column previous_application_was_refused : 0.290881156921 seconds
# Getting Aggregates for column: prev_applications_was_revolving_loan, 18
# Done Aggregating Column prev_applications_was_revolving_loan : 0.48717880249 seconds
# Getting Aggregates for column: CNT_PAYMENT, 36
# Done Aggregating Column CNT_PAYMENT : 72.3311200142 seconds
# Getting Kurtosis for Column: CNT_PAYMENT, 36
# Done Getting Kurtosis for Column CNT_PAYMENT : 68.7294080257 seconds
# Getting Trend for column: CNT_PAYMENT, 36
# Done Getting Trend for Column CNT_PAYMENT : 97.3669390678 seconds
# Getting Aggregates for column: proportion_granted, 36
# Done Aggregating Column proportion_granted : 67.8230130672 seconds
# Getting Kurtosis for Column: proportion_granted, 36
# Done Getting Kurtosis for Column proportion_granted : 69.5841829777 seconds
# Getting Trend for column: proportion_granted, 36
# Done Getting Trend for Column proportion_granted : 97.4949259758 seconds
# Getting Aggregates for column: DAYS_DECISION, 36
# Done Aggregating Column DAYS_DECISION : 70.0197298527 seconds
# Getting Kurtosis for Column: DAYS_DECISION, 36
# Done Getting Kurtosis for Column DAYS_DECISION : 72.3844430447 seconds
# Getting Trend for column: DAYS_DECISION, 36
# Done Getting Trend for Column DAYS_DECISION : 37.562059164 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING, 36
# Done Aggregating Column DAYS_FIRST_DRAWING : 67.8382740021 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING, 36
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING : 66.9356548786 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING, 36
# Done Getting Trend for Column DAYS_FIRST_DRAWING : 97.791187048 seconds
# Getting Aggregates for column: previous_application_was_approved, 36
# Done Aggregating Column previous_application_was_approved : 0.775456905365 seconds
# Getting Aggregates for column: previous_application_was_refused, 36
# Done Aggregating Column previous_application_was_refused : 0.419422149658 seconds
# Getting Aggregates for column: prev_applications_was_revolving_loan, 36
# Done Aggregating Column prev_applications_was_revolving_loan : 0.298672914505 seconds
# Getting Aggregates for column: CNT_PAYMENT, 72
# Done Aggregating Column CNT_PAYMENT : 70.124532938 seconds
# Getting Kurtosis for Column: CNT_PAYMENT, 72
# Done Getting Kurtosis for Column CNT_PAYMENT : 68.4052560329 seconds
# Getting Trend for column: CNT_PAYMENT, 72
# Done Getting Trend for Column CNT_PAYMENT : 97.5680749416 seconds
# Getting Aggregates for column: proportion_granted, 72
# Done Aggregating Column proportion_granted : 67.7096230984 seconds
# Getting Kurtosis for Column: proportion_granted, 72
# Done Getting Kurtosis for Column proportion_granted : 69.5247030258 seconds
# Getting Trend for column: proportion_granted, 72
# Done Getting Trend for Column proportion_granted : 97.3251919746 seconds
# Getting Aggregates for column: DAYS_DECISION, 72
# Done Aggregating Column DAYS_DECISION : 71.1389970779 seconds
# Getting Kurtosis for Column: DAYS_DECISION, 72
# Done Getting Kurtosis for Column DAYS_DECISION : 73.5331718922 seconds
# Getting Trend for column: DAYS_DECISION, 72
# Done Getting Trend for Column DAYS_DECISION : 37.8813080788 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING, 72
# Done Aggregating Column DAYS_FIRST_DRAWING : 68.6708669662 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING, 72
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING : 67.4432148933 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING, 72
# Done Getting Trend for Column DAYS_FIRST_DRAWING : 98.1850869656 seconds
# Getting Aggregates for column: previous_application_was_approved, 72
# Done Aggregating Column previous_application_was_approved : 0.858080148697 seconds
# Getting Aggregates for column: previous_application_was_refused, 72
# Done Aggregating Column previous_application_was_refused : 0.320597887039 seconds
# Getting Aggregates for column: prev_applications_was_revolving_loan, 72
# Done Aggregating Column prev_applications_was_revolving_loan : 0.318989038467 seconds
# (338857, 783) Before dropping Na's
# (338857, 779) After dropping Na's
