# %%
version = "3"

# %%
import numpy as np
import pandas as pd
import gc
from time import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import LabelEncoder,OneHotEncoder, Normalizer
# %matplotlib inline

# %%
timesheet = [time()]
def timer(statement):
    global timesheet
    timesheet.append(time())
    print statement+" :", (timesheet[-1]-timesheet[-2]),"seconds"

# %% [markdown]
# # Feature Generators

# %%
from numba import njit, prange,jit
@jit(nopython=True, parallel=True)
def get_regression_coefficient(ys, xs, counts):
    output = np.zeros(counts.shape[0]-1)
    for i in prange(counts.shape[0]-1):
        x = xs[counts[i] : counts[i+1]]
        y = ys[counts[i] : counts[i+1]]

        output[i] = np.nan
        length = y.shape[0]
        sx = np.sum(x)
        denominator = ((length*np.dot(x, x)) - (sx*sx))
        
        if length >0 and denominator != 0:
            numerator = ((length*np.dot(x, y)) - (sx*np.sum(y)))
            output[i] = numerator/denominator
    return output

# %%
def get_trend_values(data):
        y = data.apply(lambda x: x.dropna().values)
        trends = pd.Series(index =  y.index)
        
        counts = np.insert(y.apply(lambda x: x.shape[0]).values, 0, 0)
        x = np.concatenate(np.array([np.arange(c) for c in counts])).ravel().astype(np.float64)
        y = np.concatenate(y.values).ravel().astype(np.float64)
        counts = np.cumsum(counts)
        
        trends.iloc[:] = get_regression_coefficient(y, x, counts)
        return trends

# %%
def generate_features(prefix, dataGroups, num_lags, colname, get_trend = False, get_kurtosis = True, to_calculate = ["sum", "count","nunique","mean","median","max","min","std","skew"]):
    global output
    if len(to_calculate)> 0 :
        print "Getting Aggregates for column: {}, {}".format(colname, num_lags)
        aggregates = dataGroups[colname].agg(to_calculate)
        aggregates.columns = ["{}_{}_{}_{}".format(prefix,colname, c, num_lags) for c in aggregates.columns]
        output = output.merge(aggregates, how = "left", left_on = "SK_ID_CURR", right_index=True)
        timer("Done Aggregating Column {}".format(colname))
    if get_kurtosis:
        print "Getting Kurtosis for Column: {}, {}".format(colname, num_lags)
        output["{}_{}_kurtosis_{}".format(prefix,colname,num_lags)] = output["SK_ID_CURR"].map(dataGroups[colname].apply(lambda x: x.kurt()))
        timer("Done Getting Kurtosis for Column {}".format(colname))

    if get_trend:
        print "Getting Trend for column: {}, {}".format(colname, num_lags)
        output["{}_{}_trend_{}".format(prefix, colname, num_lags)] = output["SK_ID_CURR"].map(get_trend_values(dataGroups[colname]))
        timer("Done Getting Trend for Column {}".format(colname))

# %% [markdown]
# # Feature Preprocessors

# %%
def one_hot_encoder(data, nan_as_category = True):
    categorical_columns = [col for col in data.columns if data[col].dtype == 'object']
    data = pd.get_dummies(data, columns= categorical_columns, dummy_na= nan_as_category)
    return data

def normalize_features(data, not_to_normalize):
    columns_to_normalize = data.columns.drop(not_to_normalize)
    data = data.replace([np.inf, -np.inf], np.nan)
    print data.shape, "Before dropping Na's"
    data = data.dropna(axis=1, how = "all")
    print data.shape, "After dropping Na's"
    for col in data.columns.drop(not_to_normalize):
        data[col] = data[col].fillna(data[col].mean()).fillna(0)
        data[col]= Normalizer().fit_transform(data[col].values.reshape(-1,1))
    return data

# %% [markdown]
# # Get Installment Features

# %%
def GetInstallmentFeatures(installment_path = "../data/installments_payments.csv"):
    installments = pd.read_csv(installment_path).sort_values(by=["SK_ID_CURR","DAYS_INSTALMENT"]).reset_index(drop = True)
    
    
    # Some Preprocessing
    installments['installment_paid_late_in_days'] = installments['DAYS_ENTRY_PAYMENT'] - installments['DAYS_INSTALMENT']
    installments['installment_paid_over_amount'] = installments['AMT_PAYMENT'] - installments['AMT_INSTALMENT']
    installments['installment_paid_over_amount_ratio'] = installments['AMT_PAYMENT'] / (1+installments['AMT_INSTALMENT'])


    # All Aggregate Features
    groups = installments.groupby("SK_ID_CURR")
    
    installments["installment_paid_late_in_days_diff"] = groups["installment_paid_late_in_days"].diff()
    installments["installment_paid_over_amount_diff"] = groups["installment_paid_over_amount"].diff()
    installments["installment_paid_over_amount_ratio_diff"] = groups["installment_paid_over_amount_ratio"].diff()
    installments["NUM_INSTALMENT_VERSION_diff"] = groups["NUM_INSTALMENT_VERSION"].diff()
    
    installments["installment_paid_late_in_days_diff_diff"] = groups["installment_paid_late_in_days_diff"].diff()
    installments["installment_paid_over_amount_diff_diff"] = groups["installment_paid_over_amount_diff"].diff()
    installments["installment_paid_over_amount_ratio_diff_diff"] = groups["installment_paid_over_amount_ratio_diff"].diff()
    installments["NUM_INSTALMENT_VERSION_diff_diff"] = groups["NUM_INSTALMENT_VERSION_diff"].diff()
    installments["DAYS_INSTALMENT_diff_diff"] = groups["DAYS_INSTALMENT"].diff().diff()

    
    installments["installment_paid_late_in_days_rolling6"] = groups["installment_paid_late_in_days"].apply(lambda x: x.rolling(6).mean())
    installments["installment_paid_over_amount_rolling6"] = groups["installment_paid_over_amount"].apply(lambda x: x.rolling(6).mean())
    installments["installment_paid_over_amount_ratio_rolling6"] = groups["installment_paid_over_amount_ratio"].apply(lambda x: x.rolling(6).mean())
    installments["NUM_INSTALMENT_VERSION_rolling6"] = groups["NUM_INSTALMENT_VERSION"].apply(lambda x: x.rolling(6).mean())
    installments["DAYS_INSTALMENT_rolling6"] = groups["DAYS_INSTALMENT"].apply(lambda x: x.rolling(6).mean())
    
    installments["installment_paid_late_in_days_rolling12"] = groups["installment_paid_late_in_days"].apply(lambda x: x.rolling(12).mean())
    installments["installment_paid_over_amount_rolling12"] = groups["installment_paid_over_amount"].apply(lambda x: x.rolling(12).mean())
    installments["installment_paid_over_amount_ratio_rolling12"] = groups["installment_paid_over_amount_ratio"].apply(lambda x: x.rolling(12).mean())
    installments["NUM_INSTALMENT_VERSION_rolling12"] = groups["NUM_INSTALMENT_VERSION"].apply(lambda x: x.rolling(12).mean())
    installments["DAYS_INSTALMENT_rolling12"] = groups["DAYS_INSTALMENT"].apply(lambda x: x.rolling(12).mean())
    
    # For Lagged Items
    for lags in [12, 60, 90]:
        groups = installments.groupby("SK_ID_CURR").tail(lags).reset_index(drop=True).groupby("SK_ID_CURR")

        generate_features("installment",groups, lags, "installment_paid_late_in_days_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_ratio_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "NUM_INSTALMENT_VERSION_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_late_in_days_diff_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_diff_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_ratio_diff_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "NUM_INSTALMENT_VERSION_diff_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "DAYS_INSTALMENT_diff_diff", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_late_in_days_rolling6", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_rolling6", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_ratio_rolling6", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "NUM_INSTALMENT_VERSION_rolling6", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "DAYS_INSTALMENT_rolling6", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_late_in_days_rolling12", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_rolling12", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "installment_paid_over_amount_ratio_rolling12", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "NUM_INSTALMENT_VERSION_rolling12", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        generate_features("installment",groups, lags, "DAYS_INSTALMENT_rolling12", get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/installments_payments.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
GetInstallmentFeatures(installment_path = "../data/installments_payments.csv")


# Saving Data
if get_unnormalized:
    output.to_csv("csv/installment_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/installment_features_normalized_V{}.csv".format(version), index=False)

# %% [markdown]
# # Get POS Cash Features

# %%
def GetPOSFeatures(pos_cash_path = "../data/POS_CASH_balance.csv"):
    pos_cash = pd.read_csv(pos_cash_path).sort_values(by=["SK_ID_CURR","SK_ID_PREV","MONTHS_BALANCE"]).reset_index(drop = True)
    
    # All Aggregate Features
    groups = pos_cash.groupby("SK_ID_CURR")
    
    pos_cash["SK_DPD_diff"] = groups["SK_DPD"].diff()
    pos_cash["SK_DPD_DEF_diff"] = groups["SK_DPD_DEF"].diff()
    
    pos_cash["SK_DPD_diff_diff"] = groups["SK_DPD_diff"].diff()
    pos_cash["SK_DPD_DEF_diff_diff"] = groups["SK_DPD_DEF_diff"].diff()
    pos_cash["CNT_INSTALMENT_diff_diff"] = groups["CNT_INSTALMENT"].diff().diff()
    pos_cash["CNT_INSTALMENT_FUTURE_diff_diff"] = groups["CNT_INSTALMENT_FUTURE"].diff().diff()

    pos_cash["SK_DPD_rolling6"] = groups["SK_DPD"].apply(lambda x: x.rolling(6).mean())
    pos_cash["SK_DPD_DEF_rolling6"] = groups["SK_DPD_DEF"].apply(lambda x: x.rolling(6).mean())
    pos_cash["CNT_INSTALMENT_rolling6"] = groups["CNT_INSTALMENT"].apply(lambda x: x.rolling(6).mean())
    pos_cash["CNT_INSTALMENT_FUTURE_rolling6"] = groups["CNT_INSTALMENT_FUTURE"].apply(lambda x: x.rolling(6).mean())


    pos_cash["SK_DPD_rolling12"] = groups["SK_DPD"].apply(lambda x: x.rolling(12).mean())
    pos_cash["SK_DPD_DEF_rolling12"] = groups["SK_DPD_DEF"].apply(lambda x: x.rolling(12).mean())
    pos_cash["CNT_INSTALMENT_rolling12"] = groups["CNT_INSTALMENT"].apply(lambda x: x.rolling(12).mean())
    pos_cash["CNT_INSTALMENT_FUTURE_rolling12"] = groups["CNT_INSTALMENT_FUTURE"].apply(lambda x: x.rolling(12).mean())


    #For Lagged Items
    for lags in [12, 60, 90]:
        groups = pos_cash.groupby("SK_ID_CURR").tail(lags).reset_index(drop=True).groupby("SK_ID_CURR")

        generate_features("pos_cash",groups, lags, "SK_DPD_diff", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "SK_DPD_DEF_diff", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "SK_DPD_diff_diff", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "SK_DPD_DEF_diff_diff", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_diff_diff", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_FUTURE_diff_diff", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "SK_DPD_rolling6", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "SK_DPD_DEF_rolling6", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_rolling6", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_FUTURE_rolling6", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "SK_DPD_rolling12", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "SK_DPD_DEF_rolling12", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_rolling12", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])
        generate_features("pos_cash",groups, lags, "CNT_INSTALMENT_FUTURE_rolling12", get_trend = True, get_kurtosis = False, to_calculate = ["mean"])

        del groups
        gc.collect()

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/POS_CASH_balance.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
GetPOSFeatures(pos_cash_path = "../data/POS_CASH_balance.csv")

# Saving Data
if get_unnormalized:
    output.to_csv("csv/pos_cash_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/pos_cash_features_normalized_V{}.csv".format(version), index=False)

# %% [markdown]
# # Credit Card Features

# %%
def GetCreditCardFeatures(credit_card_path = "../data/credit_card_balance.csv"):
    credit_card = pd.read_csv(credit_card_path).sort_values(by=["SK_ID_CURR","SK_ID_PREV","MONTHS_BALANCE"]).reset_index(drop = True)
    credit_card = credit_card.fillna(0.0)
    
    
    # Generating Ratio Features
    credit_card['cnt_pos_ratio'] = credit_card['CNT_DRAWINGS_POS_CURRENT']/(credit_card['CNT_DRAWINGS_CURRENT']+1.0)
    credit_card['cnt_atm_ratio'] = credit_card['CNT_DRAWINGS_ATM_CURRENT']/(credit_card['CNT_DRAWINGS_CURRENT']+1.0)
    credit_card['amt_pos_ratio'] = credit_card['AMT_DRAWINGS_POS_CURRENT']/(credit_card['AMT_DRAWINGS_CURRENT']+1.0)
    credit_card['amt_atm_ratio'] = credit_card['AMT_DRAWINGS_ATM_CURRENT']/(credit_card['AMT_DRAWINGS_CURRENT']+1.0)
    credit_card['balance_to_drawing_ratio'] = credit_card['AMT_BALANCE']/(credit_card['AMT_DRAWINGS_CURRENT']+1.0)
    credit_card['balance_to_limit_ratio'] = credit_card['AMT_BALANCE']/(credit_card['AMT_CREDIT_LIMIT_ACTUAL']+1.0)
    credit_card['balance_to_total_payment_ratio'] = credit_card['AMT_BALANCE']/(credit_card['AMT_PAYMENT_TOTAL_CURRENT']+1.0)
    credit_card['balance_to_minimum_installment_ratio'] = credit_card['AMT_BALANCE']/(credit_card['AMT_INST_MIN_REGULARITY']+1.0)
    credit_card['minimum_installment_to_total_payment_ratio'] = credit_card['AMT_INST_MIN_REGULARITY']/(credit_card['AMT_PAYMENT_TOTAL_CURRENT']+1.0)
    credit_card['minimum_installment_to_current_payment_ratio'] = credit_card['AMT_INST_MIN_REGULARITY']/(credit_card['AMT_PAYMENT_CURRENT']+1.0)
    credit_card['current_to_total_payment_ratio'] = credit_card['AMT_PAYMENT_CURRENT']/(credit_card['AMT_PAYMENT_TOTAL_CURRENT']+1.0)
    credit_card['payment_to_receivable_min_ratio'] = credit_card['AMT_INST_MIN_REGULARITY']/(credit_card['AMT_RECEIVABLE_PRINCIPAL']+1.0)
    credit_card['payment_to_receivable_curr_ratio'] = credit_card['AMT_PAYMENT_CURRENT']/(credit_card['AMT_RECIVABLE']+1.0)
    credit_card['payment_to_receivable_total_ratio'] = credit_card['AMT_PAYMENT_TOTAL_CURRENT']/(credit_card['AMT_TOTAL_RECEIVABLE']+1.0)

    all_ratio_features = ["cnt_pos_ratio","cnt_atm_ratio","amt_pos_ratio","amt_atm_ratio","balance_to_drawing_ratio","balance_to_limit_ratio","balance_to_total_payment_ratio","balance_to_minimum_installment_ratio","minimum_installment_to_total_payment_ratio","minimum_installment_to_current_payment_ratio","current_to_total_payment_ratio","payment_to_receivable_min_ratio","payment_to_receivable_curr_ratio","payment_to_receivable_total_ratio"]
    other_features = ["SK_DPD","SK_DPD_DEF","CNT_DRAWINGS_ATM_CURRENT","AMT_DRAWINGS_CURRENT","AMT_TOTAL_RECEIVABLE","AMT_PAYMENT_TOTAL_CURRENT","CNT_INSTALMENT_MATURE_CUM","AMT_BALANCE","AMT_DRAWINGS_ATM_CURRENT","AMT_DRAWINGS_POS_CURRENT","CNT_DRAWINGS_POS_CURRENT","CNT_DRAWINGS_POS_CURRENT","CNT_DRAWINGS_CURRENT"]
    
    # Generating Features that will be used
    groups = credit_card.groupby("SK_ID_CURR")
    
    for col in all_ratio_features+other_features:
        credit_card[col+"_diff"] = groups[col].diff()
        credit_card[col+"_diff_diff"] = groups[col+"_diff"].diff()
        credit_card[col+"_rolling6"] = groups[col].apply(lambda x: x.rolling(6).mean())
        credit_card[col+"_rolling12"] = groups[col].apply(lambda x: x.rolling(12).mean())

    
    using_columns = ["{}_diff".format(c) for c in all_ratio_features+other_features] + ["{}_diff_diff".format(c) for c in all_ratio_features+other_features]+["{}_rolling6".format(c) for c in all_ratio_features+other_features]+["{}_rolling12".format(c) for c in all_ratio_features+other_features]
                
    # Lag Aggregate Features
    for lags in [12, 60, 90]:
        groups = credit_card.groupby("SK_ID_CURR").tail(lags).reset_index(drop=True).groupby("SK_ID_CURR")
        
        for col in using_columns:
            generate_features("credit_card",groups, lags, col, get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
     
        del groups
        gc.collect()

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/credit_card_balance.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
GetCreditCardFeatures(credit_card_path = "../data/credit_card_balance.csv")

# Saving Data
if get_unnormalized:
    output.to_csv("csv/credit_card_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/credit_card_features_normalized_V{}.csv".format(version), index=False)
# Out:
# Getting Aggregates for column: cnt_pos_ratio_diff, 12
# Done Aggregating Column cnt_pos_ratio_diff : 4392.95369411 seconds
# Getting Kurtosis for Column: cnt_pos_ratio_diff, 12
# Done Getting Kurtosis for Column cnt_pos_ratio_diff : 23.5431339741 seconds
# Getting Trend for column: cnt_pos_ratio_diff, 12
# Done Getting Trend for Column cnt_pos_ratio_diff : 34.1200768948 seconds
# Getting Aggregates for column: cnt_atm_ratio_diff, 12
# Done Aggregating Column cnt_atm_ratio_diff : 21.2460391521 seconds
# Getting Kurtosis for Column: cnt_atm_ratio_diff, 12
# Done Getting Kurtosis for Column cnt_atm_ratio_diff : 21.4885969162 seconds
# Getting Trend for column: cnt_atm_ratio_diff, 12
# Done Getting Trend for Column cnt_atm_ratio_diff : 31.8908340931 seconds
# Getting Aggregates for column: amt_pos_ratio_diff, 12
# Done Aggregating Column amt_pos_ratio_diff : 21.2941358089 seconds
# Getting Kurtosis for Column: amt_pos_ratio_diff, 12
# Done Getting Kurtosis for Column amt_pos_ratio_diff : 21.3631651402 seconds
# Getting Trend for column: amt_pos_ratio_diff, 12
# Done Getting Trend for Column amt_pos_ratio_diff : 32.1677880287 seconds
# Getting Aggregates for column: amt_atm_ratio_diff, 12
# Done Aggregating Column amt_atm_ratio_diff : 21.1845679283 seconds
# Getting Kurtosis for Column: amt_atm_ratio_diff, 12
# Done Getting Kurtosis for Column amt_atm_ratio_diff : 21.4955630302 seconds
# Getting Trend for column: amt_atm_ratio_diff, 12
# Done Getting Trend for Column amt_atm_ratio_diff : 31.8380038738 seconds
# Getting Aggregates for column: balance_to_drawing_ratio_diff, 12
# Done Aggregating Column balance_to_drawing_ratio_diff : 22.8172261715 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio_diff, 12
# Done Getting Kurtosis for Column balance_to_drawing_ratio_diff : 22.9749689102 seconds
# Getting Trend for column: balance_to_drawing_ratio_diff, 12
# Done Getting Trend for Column balance_to_drawing_ratio_diff : 32.800645113 seconds
# Getting Aggregates for column: balance_to_limit_ratio_diff, 12
# Done Aggregating Column balance_to_limit_ratio_diff : 22.6257488728 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio_diff, 12
# Done Getting Kurtosis for Column balance_to_limit_ratio_diff : 23.0901200771 seconds
# Getting Trend for column: balance_to_limit_ratio_diff, 12
# Done Getting Trend for Column balance_to_limit_ratio_diff : 32.7743499279 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio_diff, 12
# Done Aggregating Column balance_to_total_payment_ratio_diff : 22.5904979706 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio_diff, 12
# Done Getting Kurtosis for Column balance_to_total_payment_ratio_diff : 23.1996209621 seconds
# Getting Trend for column: balance_to_total_payment_ratio_diff, 12
# Done Getting Trend for Column balance_to_total_payment_ratio_diff : 32.7545681 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio_diff, 12
# Done Aggregating Column balance_to_minimum_installment_ratio_diff : 21.0222029686 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio_diff, 12
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio_diff : 21.7329361439 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio_diff, 12
# Done Getting Trend for Column balance_to_minimum_installment_ratio_diff : 32.1299250126 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio_diff, 12
# Done Aggregating Column minimum_installment_to_total_payment_ratio_diff : 22.6910729408 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio_diff, 12
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio_diff : 22.9252829552 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio_diff, 12
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio_diff : 32.9299180508 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio_diff, 12
# Done Aggregating Column minimum_installment_to_current_payment_ratio_diff : 21.7793519497 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio_diff, 12
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio_diff : 21.4379630089 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio_diff, 12
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio_diff : 32.0464138985 seconds
# Getting Aggregates for column: current_to_total_payment_ratio_diff, 12
# Done Aggregating Column current_to_total_payment_ratio_diff : 21.2570240498 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio_diff, 12
# Done Getting Kurtosis for Column current_to_total_payment_ratio_diff : 21.9912629128 seconds
# Getting Trend for column: current_to_total_payment_ratio_diff, 12
# Done Getting Trend for Column current_to_total_payment_ratio_diff : 32.0955941677 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio_diff, 12
# Done Aggregating Column payment_to_receivable_min_ratio_diff : 21.4986569881 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio_diff, 12
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio_diff : 21.9616818428 seconds
# Getting Trend for column: payment_to_receivable_min_ratio_diff, 12
# Done Getting Trend for Column payment_to_receivable_min_ratio_diff : 32.1065440178 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio_diff, 12
# Done Aggregating Column payment_to_receivable_curr_ratio_diff : 21.5528481007 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio_diff, 12
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio_diff : 21.8831510544 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio_diff, 12
# Done Getting Trend for Column payment_to_receivable_curr_ratio_diff : 32.0459070206 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio_diff, 12
# Done Aggregating Column payment_to_receivable_total_ratio_diff : 21.1443169117 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio_diff, 12
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio_diff : 21.7044119835 seconds
# Getting Trend for column: payment_to_receivable_total_ratio_diff, 12
# Done Getting Trend for Column payment_to_receivable_total_ratio_diff : 32.0299141407 seconds
# Getting Aggregates for column: SK_DPD_diff, 12
# Done Aggregating Column SK_DPD_diff : 21.2996518612 seconds
# Getting Kurtosis for Column: SK_DPD_diff, 12
# Done Getting Kurtosis for Column SK_DPD_diff : 20.7112119198 seconds
# Getting Trend for column: SK_DPD_diff, 12
# Done Getting Trend for Column SK_DPD_diff : 32.0669901371 seconds
# Getting Aggregates for column: SK_DPD_DEF_diff, 12
# Done Aggregating Column SK_DPD_DEF_diff : 22.9217669964 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_diff, 12
# Done Getting Kurtosis for Column SK_DPD_DEF_diff : 21.0879740715 seconds
# Getting Trend for column: SK_DPD_DEF_diff, 12
# Done Getting Trend for Column SK_DPD_DEF_diff : 32.2796859741 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT_diff, 12
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT_diff : 21.5231440067 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT_diff, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT_diff : 21.5721819401 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT_diff, 12
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT_diff : 31.8380069733 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT_diff, 12
# Done Aggregating Column AMT_DRAWINGS_CURRENT_diff : 21.8174419403 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT_diff, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT_diff : 21.7135841846 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT_diff, 12
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT_diff : 31.9556758404 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE_diff, 12
# Done Aggregating Column AMT_TOTAL_RECEIVABLE_diff : 21.1528811455 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE_diff, 12
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE_diff : 21.8499979973 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE_diff, 12
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE_diff : 32.0915048122 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT_diff, 12
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT_diff : 21.7857041359 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT_diff, 12
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT_diff : 22.1426830292 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT_diff, 12
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT_diff : 32.0943818092 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM_diff, 12
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM_diff : 21.3691060543 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM_diff, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM_diff : 21.295320034 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM_diff, 12
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM_diff : 32.1712770462 seconds
# Getting Aggregates for column: AMT_BALANCE_diff, 12
# Done Aggregating Column AMT_BALANCE_diff : 21.4055960178 seconds
# Getting Kurtosis for Column: AMT_BALANCE_diff, 12
# Done Getting Kurtosis for Column AMT_BALANCE_diff : 21.7597968578 seconds
# Getting Trend for column: AMT_BALANCE_diff, 12
# Done Getting Trend for Column AMT_BALANCE_diff : 32.2482261658 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT_diff, 12
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT_diff : 21.9882688522 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT_diff, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT_diff : 21.9617190361 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT_diff, 12
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT_diff : 32.037717104 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT_diff, 12
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT_diff : 21.5363130569 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT_diff, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT_diff : 21.2705698013 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT_diff, 12
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT_diff : 32.1303911209 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_diff, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_diff : 21.4521999359 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_diff, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_diff : 21.4356191158 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_diff, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_diff : 32.0186979771 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_diff, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_diff : 21.6496360302 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_diff, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_diff : 22.0203149319 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_diff, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_diff : 32.0267159939 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT_diff, 12
# Done Aggregating Column CNT_DRAWINGS_CURRENT_diff : 21.6664378643 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT_diff, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT_diff : 22.5138800144 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT_diff, 12
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT_diff : 32.2488410473 seconds
# Getting Aggregates for column: cnt_pos_ratio_diff_diff, 12
# Done Aggregating Column cnt_pos_ratio_diff_diff : 21.339673996 seconds
# Getting Kurtosis for Column: cnt_pos_ratio_diff_diff, 12
# Done Getting Kurtosis for Column cnt_pos_ratio_diff_diff : 21.4792830944 seconds
# Getting Trend for column: cnt_pos_ratio_diff_diff, 12
# Done Getting Trend for Column cnt_pos_ratio_diff_diff : 32.8016219139 seconds
# Getting Aggregates for column: cnt_atm_ratio_diff_diff, 12
# Done Aggregating Column cnt_atm_ratio_diff_diff : 21.4468121529 seconds
# Getting Kurtosis for Column: cnt_atm_ratio_diff_diff, 12
# Done Getting Kurtosis for Column cnt_atm_ratio_diff_diff : 21.840446949 seconds
# Getting Trend for column: cnt_atm_ratio_diff_diff, 12
# Done Getting Trend for Column cnt_atm_ratio_diff_diff : 32.4213180542 seconds
# Getting Aggregates for column: amt_pos_ratio_diff_diff, 12
# Done Aggregating Column amt_pos_ratio_diff_diff : 21.9697899818 seconds
# Getting Kurtosis for Column: amt_pos_ratio_diff_diff, 12
# Done Getting Kurtosis for Column amt_pos_ratio_diff_diff : 21.2996938229 seconds
# Getting Trend for column: amt_pos_ratio_diff_diff, 12
# Done Getting Trend for Column amt_pos_ratio_diff_diff : 32.17663908 seconds
# Getting Aggregates for column: amt_atm_ratio_diff_diff, 12
# Done Aggregating Column amt_atm_ratio_diff_diff : 21.4209740162 seconds
# Getting Kurtosis for Column: amt_atm_ratio_diff_diff, 12
# Done Getting Kurtosis for Column amt_atm_ratio_diff_diff : 21.4350531101 seconds
# Getting Trend for column: amt_atm_ratio_diff_diff, 12
# Done Getting Trend for Column amt_atm_ratio_diff_diff : 32.6145179272 seconds
# Getting Aggregates for column: balance_to_drawing_ratio_diff_diff, 12
# Done Aggregating Column balance_to_drawing_ratio_diff_diff : 21.1903948784 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio_diff_diff, 12
# Done Getting Kurtosis for Column balance_to_drawing_ratio_diff_diff : 21.7281610966 seconds
# Getting Trend for column: balance_to_drawing_ratio_diff_diff, 12
# Done Getting Trend for Column balance_to_drawing_ratio_diff_diff : 32.1016249657 seconds
# Getting Aggregates for column: balance_to_limit_ratio_diff_diff, 12
# Done Aggregating Column balance_to_limit_ratio_diff_diff : 21.9736630917 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio_diff_diff, 12
# Done Getting Kurtosis for Column balance_to_limit_ratio_diff_diff : 21.7263720036 seconds
# Getting Trend for column: balance_to_limit_ratio_diff_diff, 12
# Done Getting Trend for Column balance_to_limit_ratio_diff_diff : 32.1517820358 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio_diff_diff, 12
# Done Aggregating Column balance_to_total_payment_ratio_diff_diff : 22.0411758423 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio_diff_diff, 12
# Done Getting Kurtosis for Column balance_to_total_payment_ratio_diff_diff : 22.0157370567 seconds
# Getting Trend for column: balance_to_total_payment_ratio_diff_diff, 12
# Done Getting Trend for Column balance_to_total_payment_ratio_diff_diff : 32.5868310928 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio_diff_diff, 12
# Done Aggregating Column balance_to_minimum_installment_ratio_diff_diff : 21.1897718906 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio_diff_diff, 12
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio_diff_diff : 21.480494976 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio_diff_diff, 12
# Done Getting Trend for Column balance_to_minimum_installment_ratio_diff_diff : 32.2384181023 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio_diff_diff, 12
# Done Aggregating Column minimum_installment_to_total_payment_ratio_diff_diff : 21.7557799816 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio_diff_diff, 12
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio_diff_diff : 21.8621199131 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio_diff_diff, 12
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio_diff_diff : 32.0457019806 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio_diff_diff, 12
# Done Aggregating Column minimum_installment_to_current_payment_ratio_diff_diff : 21.3867931366 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio_diff_diff, 12
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio_diff_diff : 21.4973819256 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio_diff_diff, 12
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio_diff_diff : 32.3362159729 seconds
# Getting Aggregates for column: current_to_total_payment_ratio_diff_diff, 12
# Done Aggregating Column current_to_total_payment_ratio_diff_diff : 21.5965270996 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio_diff_diff, 12
# Done Getting Kurtosis for Column current_to_total_payment_ratio_diff_diff : 21.7411949635 seconds
# Getting Trend for column: current_to_total_payment_ratio_diff_diff, 12
# Done Getting Trend for Column current_to_total_payment_ratio_diff_diff : 32.1190869808 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio_diff_diff, 12
# Done Aggregating Column payment_to_receivable_min_ratio_diff_diff : 22.0912220478 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio_diff_diff, 12
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio_diff_diff : 21.9716470242 seconds
# Getting Trend for column: payment_to_receivable_min_ratio_diff_diff, 12
# Done Getting Trend for Column payment_to_receivable_min_ratio_diff_diff : 32.4816048145 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio_diff_diff, 12
# Done Aggregating Column payment_to_receivable_curr_ratio_diff_diff : 21.7185549736 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio_diff_diff, 12
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio_diff_diff : 21.9192290306 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio_diff_diff, 12
# Done Getting Trend for Column payment_to_receivable_curr_ratio_diff_diff : 32.0249261856 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio_diff_diff, 12
# Done Aggregating Column payment_to_receivable_total_ratio_diff_diff : 21.6783628464 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio_diff_diff, 12
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio_diff_diff : 22.2537491322 seconds
# Getting Trend for column: payment_to_receivable_total_ratio_diff_diff, 12
# Done Getting Trend for Column payment_to_receivable_total_ratio_diff_diff : 32.1902039051 seconds
# Getting Aggregates for column: SK_DPD_diff_diff, 12
# Done Aggregating Column SK_DPD_diff_diff : 21.6883940697 seconds
# Getting Kurtosis for Column: SK_DPD_diff_diff, 12
# Done Getting Kurtosis for Column SK_DPD_diff_diff : 20.8541738987 seconds
# Getting Trend for column: SK_DPD_diff_diff, 12
# Done Getting Trend for Column SK_DPD_diff_diff : 32.2315199375 seconds
# Getting Aggregates for column: SK_DPD_DEF_diff_diff, 12
# Done Aggregating Column SK_DPD_DEF_diff_diff : 23.0265221596 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_diff_diff, 12
# Done Getting Kurtosis for Column SK_DPD_DEF_diff_diff : 21.2582149506 seconds
# Getting Trend for column: SK_DPD_DEF_diff_diff, 12
# Done Getting Trend for Column SK_DPD_DEF_diff_diff : 32.4125950336 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT_diff_diff, 12
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT_diff_diff : 21.6248118877 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT_diff_diff, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT_diff_diff : 21.8379759789 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT_diff_diff, 12
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT_diff_diff : 32.4693520069 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT_diff_diff, 12
# Done Aggregating Column AMT_DRAWINGS_CURRENT_diff_diff : 22.4037511349 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT_diff_diff, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT_diff_diff : 21.7257449627 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT_diff_diff, 12
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT_diff_diff : 32.205835104 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE_diff_diff, 12
# Done Aggregating Column AMT_TOTAL_RECEIVABLE_diff_diff : 21.6118187904 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE_diff_diff, 12
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE_diff_diff : 21.7687671185 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE_diff_diff, 12
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE_diff_diff : 32.316685915 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT_diff_diff, 12
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT_diff_diff : 21.4252171516 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT_diff_diff, 12
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT_diff_diff : 21.763021946 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT_diff_diff, 12
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT_diff_diff : 32.1077010632 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM_diff_diff, 12
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM_diff_diff : 21.4526867867 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM_diff_diff, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM_diff_diff : 22.0372350216 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM_diff_diff, 12
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM_diff_diff : 32.1669631004 seconds
# Getting Aggregates for column: AMT_BALANCE_diff_diff, 12
# Done Aggregating Column AMT_BALANCE_diff_diff : 21.8744289875 seconds
# Getting Kurtosis for Column: AMT_BALANCE_diff_diff, 12
# Done Getting Kurtosis for Column AMT_BALANCE_diff_diff : 21.8777830601 seconds
# Getting Trend for column: AMT_BALANCE_diff_diff, 12
# Done Getting Trend for Column AMT_BALANCE_diff_diff : 32.0741598606 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT_diff_diff, 12
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT_diff_diff : 21.3815901279 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT_diff_diff, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT_diff_diff : 21.1267118454 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT_diff_diff, 12
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT_diff_diff : 32.2411770821 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT_diff_diff, 12
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT_diff_diff : 22.1103551388 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT_diff_diff, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT_diff_diff : 21.5409069061 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT_diff_diff, 12
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT_diff_diff : 32.112967968 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_diff_diff, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_diff_diff : 22.6433370113 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_diff_diff, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_diff_diff : 21.7553339005 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_diff_diff, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_diff_diff : 32.6278550625 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_diff_diff, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_diff_diff : 21.9197940826 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_diff_diff, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_diff_diff : 22.1586289406 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_diff_diff, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_diff_diff : 32.0702910423 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT_diff_diff, 12
# Done Aggregating Column CNT_DRAWINGS_CURRENT_diff_diff : 21.6891720295 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT_diff_diff, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT_diff_diff : 21.8034188747 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT_diff_diff, 12
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT_diff_diff : 32.4273920059 seconds
# Getting Aggregates for column: cnt_pos_ratio_rolling6, 12
# Done Aggregating Column cnt_pos_ratio_rolling6 : 22.1791110039 seconds
# Getting Kurtosis for Column: cnt_pos_ratio_rolling6, 12
# Done Getting Kurtosis for Column cnt_pos_ratio_rolling6 : 21.405449152 seconds
# Getting Trend for column: cnt_pos_ratio_rolling6, 12
# Done Getting Trend for Column cnt_pos_ratio_rolling6 : 32.7551288605 seconds
# Getting Aggregates for column: cnt_atm_ratio_rolling6, 12
# Done Aggregating Column cnt_atm_ratio_rolling6 : 22.10876894 seconds
# Getting Kurtosis for Column: cnt_atm_ratio_rolling6, 12
# Done Getting Kurtosis for Column cnt_atm_ratio_rolling6 : 21.657102108 seconds
# Getting Trend for column: cnt_atm_ratio_rolling6, 12
# Done Getting Trend for Column cnt_atm_ratio_rolling6 : 32.7342989445 seconds
# Getting Aggregates for column: amt_pos_ratio_rolling6, 12
# Done Aggregating Column amt_pos_ratio_rolling6 : 21.4849331379 seconds
# Getting Kurtosis for Column: amt_pos_ratio_rolling6, 12
# Done Getting Kurtosis for Column amt_pos_ratio_rolling6 : 21.7191100121 seconds
# Getting Trend for column: amt_pos_ratio_rolling6, 12
# Done Getting Trend for Column amt_pos_ratio_rolling6 : 33.2570779324 seconds
# Getting Aggregates for column: amt_atm_ratio_rolling6, 12
# Done Aggregating Column amt_atm_ratio_rolling6 : 21.8747580051 seconds
# Getting Kurtosis for Column: amt_atm_ratio_rolling6, 12
# Done Getting Kurtosis for Column amt_atm_ratio_rolling6 : 21.9349529743 seconds
# Getting Trend for column: amt_atm_ratio_rolling6, 12
# Done Getting Trend for Column amt_atm_ratio_rolling6 : 32.9662749767 seconds
# Getting Aggregates for column: balance_to_drawing_ratio_rolling6, 12
# Done Aggregating Column balance_to_drawing_ratio_rolling6 : 21.9972341061 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio_rolling6, 12
# Done Getting Kurtosis for Column balance_to_drawing_ratio_rolling6 : 21.501322031 seconds
# Getting Trend for column: balance_to_drawing_ratio_rolling6, 12
# Done Getting Trend for Column balance_to_drawing_ratio_rolling6 : 33.1425597668 seconds
# Getting Aggregates for column: balance_to_limit_ratio_rolling6, 12
# Done Aggregating Column balance_to_limit_ratio_rolling6 : 21.656291008 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio_rolling6, 12
# Done Getting Kurtosis for Column balance_to_limit_ratio_rolling6 : 21.990678072 seconds
# Getting Trend for column: balance_to_limit_ratio_rolling6, 12
# Done Getting Trend for Column balance_to_limit_ratio_rolling6 : 33.2679159641 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio_rolling6, 12
# Done Aggregating Column balance_to_total_payment_ratio_rolling6 : 21.9731590748 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio_rolling6, 12
# Done Getting Kurtosis for Column balance_to_total_payment_ratio_rolling6 : 21.6664750576 seconds
# Getting Trend for column: balance_to_total_payment_ratio_rolling6, 12
# Done Getting Trend for Column balance_to_total_payment_ratio_rolling6 : 32.9476399422 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio_rolling6, 12
# Done Aggregating Column balance_to_minimum_installment_ratio_rolling6 : 21.7218859196 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio_rolling6, 12
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio_rolling6 : 21.6298310757 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio_rolling6, 12
# Done Getting Trend for Column balance_to_minimum_installment_ratio_rolling6 : 33.459594965 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio_rolling6, 12
# Done Aggregating Column minimum_installment_to_total_payment_ratio_rolling6 : 21.9794750214 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio_rolling6, 12
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio_rolling6 : 22.3662059307 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio_rolling6, 12
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio_rolling6 : 33.5409350395 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio_rolling6, 12
# Done Aggregating Column minimum_installment_to_current_payment_ratio_rolling6 : 22.1168329716 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio_rolling6, 12
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio_rolling6 : 21.8594601154 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio_rolling6, 12
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio_rolling6 : 33.0093429089 seconds
# Getting Aggregates for column: current_to_total_payment_ratio_rolling6, 12
# Done Aggregating Column current_to_total_payment_ratio_rolling6 : 21.8393599987 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio_rolling6, 12
# Done Getting Kurtosis for Column current_to_total_payment_ratio_rolling6 : 21.5417470932 seconds
# Getting Trend for column: current_to_total_payment_ratio_rolling6, 12
# Done Getting Trend for Column current_to_total_payment_ratio_rolling6 : 33.2004878521 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio_rolling6, 12
# Done Aggregating Column payment_to_receivable_min_ratio_rolling6 : 21.6335630417 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio_rolling6, 12
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio_rolling6 : 21.5793001652 seconds
# Getting Trend for column: payment_to_receivable_min_ratio_rolling6, 12
# Done Getting Trend for Column payment_to_receivable_min_ratio_rolling6 : 33.0445158482 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio_rolling6, 12
# Done Aggregating Column payment_to_receivable_curr_ratio_rolling6 : 22.5152180195 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio_rolling6, 12
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio_rolling6 : 21.7292521 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio_rolling6, 12
# Done Getting Trend for Column payment_to_receivable_curr_ratio_rolling6 : 33.3324899673 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio_rolling6, 12
# Done Aggregating Column payment_to_receivable_total_ratio_rolling6 : 21.9144239426 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio_rolling6, 12
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio_rolling6 : 22.4228620529 seconds
# Getting Trend for column: payment_to_receivable_total_ratio_rolling6, 12
# Done Getting Trend for Column payment_to_receivable_total_ratio_rolling6 : 32.9596960545 seconds
# Getting Aggregates for column: SK_DPD_rolling6, 12
# Done Aggregating Column SK_DPD_rolling6 : 22.1196649075 seconds
# Getting Kurtosis for Column: SK_DPD_rolling6, 12
# Done Getting Kurtosis for Column SK_DPD_rolling6 : 20.8773379326 seconds
# Getting Trend for column: SK_DPD_rolling6, 12
# Done Getting Trend for Column SK_DPD_rolling6 : 33.8534100056 seconds
# Getting Aggregates for column: SK_DPD_DEF_rolling6, 12
# Done Aggregating Column SK_DPD_DEF_rolling6 : 22.2404100895 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_rolling6, 12
# Done Getting Kurtosis for Column SK_DPD_DEF_rolling6 : 21.1122090816 seconds
# Getting Trend for column: SK_DPD_DEF_rolling6, 12
# Done Getting Trend for Column SK_DPD_DEF_rolling6 : 32.7870359421 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT_rolling6, 12
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT_rolling6 : 21.7103860378 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT_rolling6 : 21.7311799526 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT_rolling6, 12
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT_rolling6 : 32.7803878784 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT_rolling6, 12
# Done Aggregating Column AMT_DRAWINGS_CURRENT_rolling6 : 22.3350510597 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT_rolling6 : 21.7278990746 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT_rolling6, 12
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT_rolling6 : 33.3155229092 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE_rolling6, 12
# Done Aggregating Column AMT_TOTAL_RECEIVABLE_rolling6 : 21.7809889317 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE_rolling6, 12
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE_rolling6 : 22.5761330128 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE_rolling6, 12
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE_rolling6 : 33.3900229931 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT_rolling6, 12
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT_rolling6 : 22.119603157 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT_rolling6 : 21.9076399803 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT_rolling6, 12
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT_rolling6 : 33.1109418869 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM_rolling6, 12
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM_rolling6 : 22.1570000648 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM_rolling6, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM_rolling6 : 21.5300281048 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM_rolling6, 12
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM_rolling6 : 32.9339728355 seconds
# Getting Aggregates for column: AMT_BALANCE_rolling6, 12
# Done Aggregating Column AMT_BALANCE_rolling6 : 22.0873060226 seconds
# Getting Kurtosis for Column: AMT_BALANCE_rolling6, 12
# Done Getting Kurtosis for Column AMT_BALANCE_rolling6 : 21.5488591194 seconds
# Getting Trend for column: AMT_BALANCE_rolling6, 12
# Done Getting Trend for Column AMT_BALANCE_rolling6 : 32.945212841 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT_rolling6, 12
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT_rolling6 : 22.5261750221 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT_rolling6 : 22.0173261166 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT_rolling6, 12
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT_rolling6 : 33.2820179462 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT_rolling6 : 22.2595379353 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT_rolling6 : 22.0177900791 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT_rolling6 : 33.2424030304 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 22.1027338505 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 21.6207261086 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 32.7788059711 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 21.9514811039 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 21.5166838169 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_rolling6, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_rolling6 : 33.0513460636 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT_rolling6, 12
# Done Aggregating Column CNT_DRAWINGS_CURRENT_rolling6 : 21.8927409649 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT_rolling6, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT_rolling6 : 21.7398250103 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT_rolling6, 12
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT_rolling6 : 32.9889171124 seconds
# Getting Aggregates for column: cnt_pos_ratio_rolling12, 12
# Done Aggregating Column cnt_pos_ratio_rolling12 : 22.286864996 seconds
# Getting Kurtosis for Column: cnt_pos_ratio_rolling12, 12
# Done Getting Kurtosis for Column cnt_pos_ratio_rolling12 : 21.6100950241 seconds
# Getting Trend for column: cnt_pos_ratio_rolling12, 12
# Done Getting Trend for Column cnt_pos_ratio_rolling12 : 35.9240908623 seconds
# Getting Aggregates for column: cnt_atm_ratio_rolling12, 12
# Done Aggregating Column cnt_atm_ratio_rolling12 : 22.0141589642 seconds
# Getting Kurtosis for Column: cnt_atm_ratio_rolling12, 12
# Done Getting Kurtosis for Column cnt_atm_ratio_rolling12 : 21.7351250648 seconds
# Getting Trend for column: cnt_atm_ratio_rolling12, 12
# Done Getting Trend for Column cnt_atm_ratio_rolling12 : 36.1093540192 seconds
# Getting Aggregates for column: amt_pos_ratio_rolling12, 12
# Done Aggregating Column amt_pos_ratio_rolling12 : 22.5362269878 seconds
# Getting Kurtosis for Column: amt_pos_ratio_rolling12, 12
# Done Getting Kurtosis for Column amt_pos_ratio_rolling12 : 21.2616860867 seconds
# Getting Trend for column: amt_pos_ratio_rolling12, 12
# Done Getting Trend for Column amt_pos_ratio_rolling12 : 36.3601880074 seconds
# Getting Aggregates for column: amt_atm_ratio_rolling12, 12
# Done Aggregating Column amt_atm_ratio_rolling12 : 21.9742379189 seconds
# Getting Kurtosis for Column: amt_atm_ratio_rolling12, 12
# Done Getting Kurtosis for Column amt_atm_ratio_rolling12 : 21.2526140213 seconds
# Getting Trend for column: amt_atm_ratio_rolling12, 12
# Done Getting Trend for Column amt_atm_ratio_rolling12 : 36.2897028923 seconds
# Getting Aggregates for column: balance_to_drawing_ratio_rolling12, 12
# Done Aggregating Column balance_to_drawing_ratio_rolling12 : 22.114700079 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio_rolling12, 12
# Done Getting Kurtosis for Column balance_to_drawing_ratio_rolling12 : 21.8656771183 seconds
# Getting Trend for column: balance_to_drawing_ratio_rolling12, 12
# Done Getting Trend for Column balance_to_drawing_ratio_rolling12 : 35.246325016 seconds
# Getting Aggregates for column: balance_to_limit_ratio_rolling12, 12
# Done Aggregating Column balance_to_limit_ratio_rolling12 : 22.64595294 seconds
# Getting Kurtosis for Column: balance_to_limit_ratio_rolling12, 12
# Done Getting Kurtosis for Column balance_to_limit_ratio_rolling12 : 21.5128839016 seconds
# Getting Trend for column: balance_to_limit_ratio_rolling12, 12
# Done Getting Trend for Column balance_to_limit_ratio_rolling12 : 35.8333079815 seconds
# Getting Aggregates for column: balance_to_total_payment_ratio_rolling12, 12
# Done Aggregating Column balance_to_total_payment_ratio_rolling12 : 23.111274004 seconds
# Getting Kurtosis for Column: balance_to_total_payment_ratio_rolling12, 12
# Done Getting Kurtosis for Column balance_to_total_payment_ratio_rolling12 : 21.5580961704 seconds
# Getting Trend for column: balance_to_total_payment_ratio_rolling12, 12
# Done Getting Trend for Column balance_to_total_payment_ratio_rolling12 : 35.9233047962 seconds
# Getting Aggregates for column: balance_to_minimum_installment_ratio_rolling12, 12
# Done Aggregating Column balance_to_minimum_installment_ratio_rolling12 : 22.2698330879 seconds
# Getting Kurtosis for Column: balance_to_minimum_installment_ratio_rolling12, 12
# Done Getting Kurtosis for Column balance_to_minimum_installment_ratio_rolling12 : 21.6749820709 seconds
# Getting Trend for column: balance_to_minimum_installment_ratio_rolling12, 12
# Done Getting Trend for Column balance_to_minimum_installment_ratio_rolling12 : 36.1653158665 seconds
# Getting Aggregates for column: minimum_installment_to_total_payment_ratio_rolling12, 12
# Done Aggregating Column minimum_installment_to_total_payment_ratio_rolling12 : 22.4246211052 seconds
# Getting Kurtosis for Column: minimum_installment_to_total_payment_ratio_rolling12, 12
# Done Getting Kurtosis for Column minimum_installment_to_total_payment_ratio_rolling12 : 21.5544109344 seconds
# Getting Trend for column: minimum_installment_to_total_payment_ratio_rolling12, 12
# Done Getting Trend for Column minimum_installment_to_total_payment_ratio_rolling12 : 36.0109889507 seconds
# Getting Aggregates for column: minimum_installment_to_current_payment_ratio_rolling12, 12
# Done Aggregating Column minimum_installment_to_current_payment_ratio_rolling12 : 22.1312410831 seconds
# Getting Kurtosis for Column: minimum_installment_to_current_payment_ratio_rolling12, 12
# Done Getting Kurtosis for Column minimum_installment_to_current_payment_ratio_rolling12 : 21.7051429749 seconds
# Getting Trend for column: minimum_installment_to_current_payment_ratio_rolling12, 12
# Done Getting Trend for Column minimum_installment_to_current_payment_ratio_rolling12 : 36.7348399162 seconds
# Getting Aggregates for column: current_to_total_payment_ratio_rolling12, 12
# Done Aggregating Column current_to_total_payment_ratio_rolling12 : 22.1196391582 seconds
# Getting Kurtosis for Column: current_to_total_payment_ratio_rolling12, 12
# Done Getting Kurtosis for Column current_to_total_payment_ratio_rolling12 : 21.5007648468 seconds
# Getting Trend for column: current_to_total_payment_ratio_rolling12, 12
# Done Getting Trend for Column current_to_total_payment_ratio_rolling12 : 35.8025450706 seconds
# Getting Aggregates for column: payment_to_receivable_min_ratio_rolling12, 12
# Done Aggregating Column payment_to_receivable_min_ratio_rolling12 : 22.2835140228 seconds
# Getting Kurtosis for Column: payment_to_receivable_min_ratio_rolling12, 12
# Done Getting Kurtosis for Column payment_to_receivable_min_ratio_rolling12 : 21.311177969 seconds
# Getting Trend for column: payment_to_receivable_min_ratio_rolling12, 12
# Done Getting Trend for Column payment_to_receivable_min_ratio_rolling12 : 36.1311850548 seconds
# Getting Aggregates for column: payment_to_receivable_curr_ratio_rolling12, 12
# Done Aggregating Column payment_to_receivable_curr_ratio_rolling12 : 22.2839999199 seconds
# Getting Kurtosis for Column: payment_to_receivable_curr_ratio_rolling12, 12
# Done Getting Kurtosis for Column payment_to_receivable_curr_ratio_rolling12 : 21.7908010483 seconds
# Getting Trend for column: payment_to_receivable_curr_ratio_rolling12, 12
# Done Getting Trend for Column payment_to_receivable_curr_ratio_rolling12 : 36.2715599537 seconds
# Getting Aggregates for column: payment_to_receivable_total_ratio_rolling12, 12
# Done Aggregating Column payment_to_receivable_total_ratio_rolling12 : 21.8773531914 seconds
# Getting Kurtosis for Column: payment_to_receivable_total_ratio_rolling12, 12
# Done Getting Kurtosis for Column payment_to_receivable_total_ratio_rolling12 : 21.3362829685 seconds
# Getting Trend for column: payment_to_receivable_total_ratio_rolling12, 12
# Done Getting Trend for Column payment_to_receivable_total_ratio_rolling12 : 35.9050958157 seconds
# Getting Aggregates for column: SK_DPD_rolling12, 12
# Done Aggregating Column SK_DPD_rolling12 : 22.1720352173 seconds
# Getting Kurtosis for Column: SK_DPD_rolling12, 12
# Done Getting Kurtosis for Column SK_DPD_rolling12 : 21.267239809 seconds
# Getting Trend for column: SK_DPD_rolling12, 12
# Done Getting Trend for Column SK_DPD_rolling12 : 35.8285040855 seconds
# Getting Aggregates for column: SK_DPD_DEF_rolling12, 12
# Done Aggregating Column SK_DPD_DEF_rolling12 : 22.1138279438 seconds
# Getting Kurtosis for Column: SK_DPD_DEF_rolling12, 12
# Done Getting Kurtosis for Column SK_DPD_DEF_rolling12 : 21.1105461121 seconds
# Getting Trend for column: SK_DPD_DEF_rolling12, 12
# Done Getting Trend for Column SK_DPD_DEF_rolling12 : 36.1160709858 seconds
# Getting Aggregates for column: CNT_DRAWINGS_ATM_CURRENT_rolling12, 12
# Done Aggregating Column CNT_DRAWINGS_ATM_CURRENT_rolling12 : 23.0267548561 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_ATM_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_ATM_CURRENT_rolling12 : 21.2426660061 seconds
# Getting Trend for column: CNT_DRAWINGS_ATM_CURRENT_rolling12, 12
# Done Getting Trend for Column CNT_DRAWINGS_ATM_CURRENT_rolling12 : 35.9693410397 seconds
# Getting Aggregates for column: AMT_DRAWINGS_CURRENT_rolling12, 12
# Done Aggregating Column AMT_DRAWINGS_CURRENT_rolling12 : 22.0958409309 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_CURRENT_rolling12 : 21.8137161732 seconds
# Getting Trend for column: AMT_DRAWINGS_CURRENT_rolling12, 12
# Done Getting Trend for Column AMT_DRAWINGS_CURRENT_rolling12 : 36.308795929 seconds
# Getting Aggregates for column: AMT_TOTAL_RECEIVABLE_rolling12, 12
# Done Aggregating Column AMT_TOTAL_RECEIVABLE_rolling12 : 22.0750861168 seconds
# Getting Kurtosis for Column: AMT_TOTAL_RECEIVABLE_rolling12, 12
# Done Getting Kurtosis for Column AMT_TOTAL_RECEIVABLE_rolling12 : 21.7822709084 seconds
# Getting Trend for column: AMT_TOTAL_RECEIVABLE_rolling12, 12
# Done Getting Trend for Column AMT_TOTAL_RECEIVABLE_rolling12 : 36.1995120049 seconds
# Getting Aggregates for column: AMT_PAYMENT_TOTAL_CURRENT_rolling12, 12
# Done Aggregating Column AMT_PAYMENT_TOTAL_CURRENT_rolling12 : 22.1293919086 seconds
# Getting Kurtosis for Column: AMT_PAYMENT_TOTAL_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column AMT_PAYMENT_TOTAL_CURRENT_rolling12 : 21.5653049946 seconds
# Getting Trend for column: AMT_PAYMENT_TOTAL_CURRENT_rolling12, 12
# Done Getting Trend for Column AMT_PAYMENT_TOTAL_CURRENT_rolling12 : 35.5890581608 seconds
# Getting Aggregates for column: CNT_INSTALMENT_MATURE_CUM_rolling12, 12
# Done Aggregating Column CNT_INSTALMENT_MATURE_CUM_rolling12 : 21.9843609333 seconds
# Getting Kurtosis for Column: CNT_INSTALMENT_MATURE_CUM_rolling12, 12
# Done Getting Kurtosis for Column CNT_INSTALMENT_MATURE_CUM_rolling12 : 23.0127589703 seconds
# Getting Trend for column: CNT_INSTALMENT_MATURE_CUM_rolling12, 12
# Done Getting Trend for Column CNT_INSTALMENT_MATURE_CUM_rolling12 : 35.6402719021 seconds
# Getting Aggregates for column: AMT_BALANCE_rolling12, 12
# Done Aggregating Column AMT_BALANCE_rolling12 : 22.4938690662 seconds
# Getting Kurtosis for Column: AMT_BALANCE_rolling12, 12
# Done Getting Kurtosis for Column AMT_BALANCE_rolling12 : 21.5685889721 seconds
# Getting Trend for column: AMT_BALANCE_rolling12, 12
# Done Getting Trend for Column AMT_BALANCE_rolling12 : 35.3437130451 seconds
# Getting Aggregates for column: AMT_DRAWINGS_ATM_CURRENT_rolling12, 12
# Done Aggregating Column AMT_DRAWINGS_ATM_CURRENT_rolling12 : 22.327534914 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_ATM_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_ATM_CURRENT_rolling12 : 21.1878800392 seconds
# Getting Trend for column: AMT_DRAWINGS_ATM_CURRENT_rolling12, 12
# Done Getting Trend for Column AMT_DRAWINGS_ATM_CURRENT_rolling12 : 35.7504081726 seconds
# Getting Aggregates for column: AMT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Aggregating Column AMT_DRAWINGS_POS_CURRENT_rolling12 : 22.2670447826 seconds
# Getting Kurtosis for Column: AMT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column AMT_DRAWINGS_POS_CURRENT_rolling12 : 21.2632410526 seconds
# Getting Trend for column: AMT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Getting Trend for Column AMT_DRAWINGS_POS_CURRENT_rolling12 : 36.1392719746 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 22.4107701778 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 21.2380638123 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 36.4728021622 seconds
# Getting Aggregates for column: CNT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Aggregating Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 22.3112499714 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 22.0693640709 seconds
# Getting Trend for column: CNT_DRAWINGS_POS_CURRENT_rolling12, 12
# Done Getting Trend for Column CNT_DRAWINGS_POS_CURRENT_rolling12 : 35.9680869579 seconds
# Getting Aggregates for column: CNT_DRAWINGS_CURRENT_rolling12, 12
# Done Aggregating Column CNT_DRAWINGS_CURRENT_rolling12 : 22.6213729382 seconds
# Getting Kurtosis for Column: CNT_DRAWINGS_CURRENT_rolling12, 12
# Done Getting Kurtosis for Column CNT_DRAWINGS_CURRENT_rolling12 : 21.6918900013 seconds
# Getting Trend for column: CNT_DRAWINGS_CURRENT_rolling12, 12
# Done Getting Trend for Column CNT_DRAWINGS_CURRENT_rolling12 : 35.4992909431 seconds
# Getting Aggregates for column: cnt_pos_ratio_diff, 60
# Done Aggregating Column cnt_pos_ratio_diff : 30.6571819782 seconds
# Getting Kurtosis for Column: cnt_pos_ratio_diff, 60
# Done Getting Kurtosis for Column cnt_pos_ratio_diff : 21.8954210281 seconds
# Getting Trend for column: cnt_pos_ratio_diff, 60
# Done Getting Trend for Column cnt_pos_ratio_diff : 37.6531860828 seconds
# Getting Aggregates for column: cnt_atm_ratio_diff, 60
# Done Aggregating Column cnt_atm_ratio_diff : 22.8563170433 seconds
# Getting Kurtosis for Column: cnt_atm_ratio_diff, 60
# Done Getting Kurtosis for Column cnt_atm_ratio_diff : 22.4441549778 seconds
# Getting Trend for column: cnt_atm_ratio_diff, 60
# Done Getting Trend for Column cnt_atm_ratio_diff : 37.2126488686 seconds
# Getting Aggregates for column: amt_pos_ratio_diff, 60
# Done Aggregating Column amt_pos_ratio_diff : 22.4407980442 seconds
# Getting Kurtosis for Column: amt_pos_ratio_diff, 60
# Done Getting Kurtosis for Column amt_pos_ratio_diff : 21.9561400414 seconds
# Getting Trend for column: amt_pos_ratio_diff, 60
# Done Getting Trend for Column amt_pos_ratio_diff : 37.4150130749 seconds
# Getting Aggregates for column: amt_atm_ratio_diff, 60
# Done Aggregating Column amt_atm_ratio_diff : 22.5374917984 seconds
# Getting Kurtosis for Column: amt_atm_ratio_diff, 60
# Done Getting Kurtosis for Column amt_atm_ratio_diff : 22.1051671505 seconds
# Getting Trend for column: amt_atm_ratio_diff, 60
# Done Getting Trend for Column amt_atm_ratio_diff : 37.5080308914 seconds
# Getting Aggregates for column: balance_to_drawing_ratio_diff, 60
# Done Aggregating Column balance_to_drawing_ratio_diff : 22.3212721348 seconds
# Getting Kurtosis for Column: balance_to_drawing_ratio_diff, 60
# Done Getting Kurtosis for Column balance_to_drawing_ratio_diff : 22.2588758469 seconds
# Getting Trend for column: balance_to_drawing_ratio_diff, 60

# %% [markdown]
# # Previous Application Features

# %%
def GetPreviousAppFeatures(prev_app_path = "../data/previous_application.csv"):
    prev_apps = pd.read_csv(prev_app_path).sort_values(by=["SK_ID_CURR","DAYS_DECISION"]).reset_index(drop = True)
    
    # Generating Some Features
    prev_apps["proportion_granted"] = prev_apps["AMT_APPLICATION"]/(prev_apps["AMT_CREDIT"]+1.0)

    # All Aggregate Features
    usecols = ["CNT_PAYMENT","DAYS_DECISION","DAYS_FIRST_DRAWING","proportion_granted"]
    groups = prev_apps.groupby("SK_ID_CURR")
    
    for col in usecols:
        prev_apps[col+"_diff"] = groups[col].diff()
        prev_apps[col+"_diff_diff"] = groups[col+"_diff"].diff()
        prev_apps[col+"_rolling6"] = groups[col].apply(lambda x: x.rolling(6).mean())
        prev_apps[col+"_rolling12"] = groups[col].apply(lambda x: x.rolling(12).mean())

    using_columns = ["{}_diff".format(c) for c in usecols] + ["{}_diff_diff".format(c) for c in usecols]+ ["{}_rolling6".format(c) for c in usecols]+["{}_rolling12".format(c) for c in usecols]
              
    # For Lagged Items
    for lags in [12,60,90]:
        groups = prev_apps.groupby("SK_ID_CURR").tail(lags).reset_index(drop=True).groupby("SK_ID_CURR")

        for col in using_columns:
            generate_features("prev_apps",groups, lags, col, get_trend = True, get_kurtosis = True, to_calculate = ["sum","mean","median","max","min","std","skew"])
        
        del groups
        gc.collect()

# %%
get_normalized = True
get_unnormalized = True

# Calling Generator
output = pd.read_csv("../data/previous_application.csv", usecols = ["SK_ID_CURR"]).drop_duplicates().reset_index(drop=True)
GetPreviousAppFeatures(prev_app_path = "../data/previous_application.csv")

# Saving Data
if get_unnormalized:
    output.to_csv("csv/previous_application_features_V{}.csv".format(version), index=False)
if get_normalized:
    normalize_features(output, ["SK_ID_CURR"]).to_csv("csv/previous_application_features_normalized_V{}.csv".format(version), index=False)
# Out:
# Getting Aggregates for column: CNT_PAYMENT_diff, 12
# Done Aggregating Column CNT_PAYMENT_diff : 1891.09295511 seconds
# Getting Kurtosis for Column: CNT_PAYMENT_diff, 12
# Done Getting Kurtosis for Column CNT_PAYMENT_diff : 75.003333807 seconds
# Getting Trend for column: CNT_PAYMENT_diff, 12
# Done Getting Trend for Column CNT_PAYMENT_diff : 110.784151077 seconds
# Getting Aggregates for column: DAYS_DECISION_diff, 12
# Done Aggregating Column DAYS_DECISION_diff : 74.680095911 seconds
# Getting Kurtosis for Column: DAYS_DECISION_diff, 12
# Done Getting Kurtosis for Column DAYS_DECISION_diff : 76.1747350693 seconds
# Getting Trend for column: DAYS_DECISION_diff, 12
# Done Getting Trend for Column DAYS_DECISION_diff : 111.713050127 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING_diff, 12
# Done Aggregating Column DAYS_FIRST_DRAWING_diff : 74.1199069023 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING_diff, 12
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING_diff : 73.0808529854 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING_diff, 12
# Done Getting Trend for Column DAYS_FIRST_DRAWING_diff : 109.761106968 seconds
# Getting Aggregates for column: proportion_granted_diff, 12
# Done Aggregating Column proportion_granted_diff : 74.4337360859 seconds
# Getting Kurtosis for Column: proportion_granted_diff, 12
# Done Getting Kurtosis for Column proportion_granted_diff : 75.8026559353 seconds
# Getting Trend for column: proportion_granted_diff, 12
# Done Getting Trend for Column proportion_granted_diff : 111.828946114 seconds
# Getting Aggregates for column: CNT_PAYMENT_diff_diff, 12
# Done Aggregating Column CNT_PAYMENT_diff_diff : 74.8784019947 seconds
# Getting Kurtosis for Column: CNT_PAYMENT_diff_diff, 12
# Done Getting Kurtosis for Column CNT_PAYMENT_diff_diff : 74.4776499271 seconds
# Getting Trend for column: CNT_PAYMENT_diff_diff, 12
# Done Getting Trend for Column CNT_PAYMENT_diff_diff : 113.371793032 seconds
# Getting Aggregates for column: DAYS_DECISION_diff_diff, 12
# Done Aggregating Column DAYS_DECISION_diff_diff : 74.4088230133 seconds
# Getting Kurtosis for Column: DAYS_DECISION_diff_diff, 12
# Done Getting Kurtosis for Column DAYS_DECISION_diff_diff : 75.659318924 seconds
# Getting Trend for column: DAYS_DECISION_diff_diff, 12
# Done Getting Trend for Column DAYS_DECISION_diff_diff : 117.613522053 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING_diff_diff, 12
# Done Aggregating Column DAYS_FIRST_DRAWING_diff_diff : 75.651031971 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING_diff_diff, 12
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING_diff_diff : 73.4130690098 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING_diff_diff, 12
# Done Getting Trend for Column DAYS_FIRST_DRAWING_diff_diff : 110.11263895 seconds
# Getting Aggregates for column: proportion_granted_diff_diff, 12
# Done Aggregating Column proportion_granted_diff_diff : 74.3776099682 seconds
# Getting Kurtosis for Column: proportion_granted_diff_diff, 12
# Done Getting Kurtosis for Column proportion_granted_diff_diff : 75.1530511379 seconds
# Getting Trend for column: proportion_granted_diff_diff, 12
# Done Getting Trend for Column proportion_granted_diff_diff : 119.182092905 seconds
# Getting Aggregates for column: CNT_PAYMENT_rolling6, 12
# Done Aggregating Column CNT_PAYMENT_rolling6 : 75.6283340454 seconds
# Getting Kurtosis for Column: CNT_PAYMENT_rolling6, 12
# Done Getting Kurtosis for Column CNT_PAYMENT_rolling6 : 73.6008629799 seconds
# Getting Trend for column: CNT_PAYMENT_rolling6, 12
# Done Getting Trend for Column CNT_PAYMENT_rolling6 : 108.669292927 seconds
# Getting Aggregates for column: DAYS_DECISION_rolling6, 12
# Done Aggregating Column DAYS_DECISION_rolling6 : 74.9556040764 seconds
# Getting Kurtosis for Column: DAYS_DECISION_rolling6, 12
# Done Getting Kurtosis for Column DAYS_DECISION_rolling6 : 74.365500927 seconds
# Getting Trend for column: DAYS_DECISION_rolling6, 12
# Done Getting Trend for Column DAYS_DECISION_rolling6 : 116.967236996 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING_rolling6, 12
# Done Aggregating Column DAYS_FIRST_DRAWING_rolling6 : 75.0215950012 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING_rolling6, 12
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING_rolling6 : 72.7590401173 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING_rolling6, 12
# Done Getting Trend for Column DAYS_FIRST_DRAWING_rolling6 : 103.858455896 seconds
# Getting Aggregates for column: proportion_granted_rolling6, 12
# Done Aggregating Column proportion_granted_rolling6 : 74.9915611744 seconds
# Getting Kurtosis for Column: proportion_granted_rolling6, 12
# Done Getting Kurtosis for Column proportion_granted_rolling6 : 74.1469810009 seconds
# Getting Trend for column: proportion_granted_rolling6, 12
# Done Getting Trend for Column proportion_granted_rolling6 : 116.001778841 seconds
# Getting Aggregates for column: CNT_PAYMENT_rolling12, 12
# Done Aggregating Column CNT_PAYMENT_rolling12 : 75.2098701 seconds
# Getting Kurtosis for Column: CNT_PAYMENT_rolling12, 12
# Done Getting Kurtosis for Column CNT_PAYMENT_rolling12 : 73.5474760532 seconds
# Getting Trend for column: CNT_PAYMENT_rolling12, 12
# Done Getting Trend for Column CNT_PAYMENT_rolling12 : 102.675870895 seconds
# Getting Aggregates for column: DAYS_DECISION_rolling12, 12
# Done Aggregating Column DAYS_DECISION_rolling12 : 75.6048469543 seconds
# Getting Kurtosis for Column: DAYS_DECISION_rolling12, 12
# Done Getting Kurtosis for Column DAYS_DECISION_rolling12 : 73.9754991531 seconds
# Getting Trend for column: DAYS_DECISION_rolling12, 12
# Done Getting Trend for Column DAYS_DECISION_rolling12 : 105.775748014 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING_rolling12, 12
# Done Aggregating Column DAYS_FIRST_DRAWING_rolling12 : 74.5662209988 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING_rolling12, 12
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING_rolling12 : 73.0498919487 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING_rolling12, 12
# Done Getting Trend for Column DAYS_FIRST_DRAWING_rolling12 : 102.270375967 seconds
# Getting Aggregates for column: proportion_granted_rolling12, 12
# Done Aggregating Column proportion_granted_rolling12 : 75.1388368607 seconds
# Getting Kurtosis for Column: proportion_granted_rolling12, 12
# Done Getting Kurtosis for Column proportion_granted_rolling12 : 73.3304681778 seconds
# Getting Trend for column: proportion_granted_rolling12, 12
# Done Getting Trend for Column proportion_granted_rolling12 : 105.733790874 seconds
# Getting Aggregates for column: CNT_PAYMENT_diff, 60
# Done Aggregating Column CNT_PAYMENT_diff : 77.4825451374 seconds
# Getting Kurtosis for Column: CNT_PAYMENT_diff, 60
# Done Getting Kurtosis for Column CNT_PAYMENT_diff : 74.652987957 seconds
# Getting Trend for column: CNT_PAYMENT_diff, 60
# Done Getting Trend for Column CNT_PAYMENT_diff : 110.832594872 seconds
# Getting Aggregates for column: DAYS_DECISION_diff, 60
# Done Aggregating Column DAYS_DECISION_diff : 74.4803462029 seconds
# Getting Kurtosis for Column: DAYS_DECISION_diff, 60
# Done Getting Kurtosis for Column DAYS_DECISION_diff : 75.7589139938 seconds
# Getting Trend for column: DAYS_DECISION_diff, 60
# Done Getting Trend for Column DAYS_DECISION_diff : 111.874169827 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING_diff, 60
# Done Aggregating Column DAYS_FIRST_DRAWING_diff : 75.0958349705 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING_diff, 60
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING_diff : 73.2174141407 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING_diff, 60
# Done Getting Trend for Column DAYS_FIRST_DRAWING_diff : 110.292639017 seconds
# Getting Aggregates for column: proportion_granted_diff, 60
# Done Aggregating Column proportion_granted_diff : 74.6214990616 seconds
# Getting Kurtosis for Column: proportion_granted_diff, 60
# Done Getting Kurtosis for Column proportion_granted_diff : 75.8335008621 seconds
# Getting Trend for column: proportion_granted_diff, 60
# Done Getting Trend for Column proportion_granted_diff : 112.522011042 seconds
# Getting Aggregates for column: CNT_PAYMENT_diff_diff, 60
# Done Aggregating Column CNT_PAYMENT_diff_diff : 74.7730638981 seconds
# Getting Kurtosis for Column: CNT_PAYMENT_diff_diff, 60
# Done Getting Kurtosis for Column CNT_PAYMENT_diff_diff : 74.1610350609 seconds
# Getting Trend for column: CNT_PAYMENT_diff_diff, 60
# Done Getting Trend for Column CNT_PAYMENT_diff_diff : 113.828392029 seconds
# Getting Aggregates for column: DAYS_DECISION_diff_diff, 60
# Done Aggregating Column DAYS_DECISION_diff_diff : 74.5335640907 seconds
# Getting Kurtosis for Column: DAYS_DECISION_diff_diff, 60
# Done Getting Kurtosis for Column DAYS_DECISION_diff_diff : 75.6779727936 seconds
# Getting Trend for column: DAYS_DECISION_diff_diff, 60
# Done Getting Trend for Column DAYS_DECISION_diff_diff : 120.603204012 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING_diff_diff, 60
# Done Aggregating Column DAYS_FIRST_DRAWING_diff_diff : 75.0567731857 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING_diff_diff, 60
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING_diff_diff : 73.9011778831 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING_diff_diff, 60
# Done Getting Trend for Column DAYS_FIRST_DRAWING_diff_diff : 109.821489096 seconds
# Getting Aggregates for column: proportion_granted_diff_diff, 60
# Done Aggregating Column proportion_granted_diff_diff : 74.4569289684 seconds
# Getting Kurtosis for Column: proportion_granted_diff_diff, 60
# Done Getting Kurtosis for Column proportion_granted_diff_diff : 75.9924218655 seconds
# Getting Trend for column: proportion_granted_diff_diff, 60
# Done Getting Trend for Column proportion_granted_diff_diff : 117.932690144 seconds
# Getting Aggregates for column: CNT_PAYMENT_rolling6, 60
# Done Aggregating Column CNT_PAYMENT_rolling6 : 75.8837070465 seconds
# Getting Kurtosis for Column: CNT_PAYMENT_rolling6, 60
# Done Getting Kurtosis for Column CNT_PAYMENT_rolling6 : 73.8662879467 seconds
# Getting Trend for column: CNT_PAYMENT_rolling6, 60
# Done Getting Trend for Column CNT_PAYMENT_rolling6 : 108.405678988 seconds
# Getting Aggregates for column: DAYS_DECISION_rolling6, 60
# Done Aggregating Column DAYS_DECISION_rolling6 : 75.2882890701 seconds
# Getting Kurtosis for Column: DAYS_DECISION_rolling6, 60
# Done Getting Kurtosis for Column DAYS_DECISION_rolling6 : 73.8980698586 seconds
# Getting Trend for column: DAYS_DECISION_rolling6, 60
# Done Getting Trend for Column DAYS_DECISION_rolling6 : 118.959361076 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING_rolling6, 60
# Done Aggregating Column DAYS_FIRST_DRAWING_rolling6 : 75.4922399521 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING_rolling6, 60
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING_rolling6 : 73.1654560566 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING_rolling6, 60
# Done Getting Trend for Column DAYS_FIRST_DRAWING_rolling6 : 103.837161064 seconds
# Getting Aggregates for column: proportion_granted_rolling6, 60
# Done Aggregating Column proportion_granted_rolling6 : 75.9691109657 seconds
# Getting Kurtosis for Column: proportion_granted_rolling6, 60
# Done Getting Kurtosis for Column proportion_granted_rolling6 : 74.1593289375 seconds
# Getting Trend for column: proportion_granted_rolling6, 60
# Done Getting Trend for Column proportion_granted_rolling6 : 117.714104891 seconds
# Getting Aggregates for column: CNT_PAYMENT_rolling12, 60
# Done Aggregating Column CNT_PAYMENT_rolling12 : 75.7864611149 seconds
# Getting Kurtosis for Column: CNT_PAYMENT_rolling12, 60
# Done Getting Kurtosis for Column CNT_PAYMENT_rolling12 : 73.4536840916 seconds
# Getting Trend for column: CNT_PAYMENT_rolling12, 60
# Done Getting Trend for Column CNT_PAYMENT_rolling12 : 102.614048958 seconds
# Getting Aggregates for column: DAYS_DECISION_rolling12, 60
# Done Aggregating Column DAYS_DECISION_rolling12 : 76.4197268486 seconds
# Getting Kurtosis for Column: DAYS_DECISION_rolling12, 60
# Done Getting Kurtosis for Column DAYS_DECISION_rolling12 : 73.5799319744 seconds
# Getting Trend for column: DAYS_DECISION_rolling12, 60
# Done Getting Trend for Column DAYS_DECISION_rolling12 : 106.681836128 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING_rolling12, 60
# Done Aggregating Column DAYS_FIRST_DRAWING_rolling12 : 76.1067869663 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING_rolling12, 60
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING_rolling12 : 72.8525431156 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING_rolling12, 60
# Done Getting Trend for Column DAYS_FIRST_DRAWING_rolling12 : 101.859265804 seconds
# Getting Aggregates for column: proportion_granted_rolling12, 60
# Done Aggregating Column proportion_granted_rolling12 : 75.1087510586 seconds
# Getting Kurtosis for Column: proportion_granted_rolling12, 60
# Done Getting Kurtosis for Column proportion_granted_rolling12 : 73.7991039753 seconds
# Getting Trend for column: proportion_granted_rolling12, 60
# Done Getting Trend for Column proportion_granted_rolling12 : 106.956429005 seconds
# Getting Aggregates for column: CNT_PAYMENT_diff, 90
# Done Aggregating Column CNT_PAYMENT_diff : 77.7284669876 seconds
# Getting Kurtosis for Column: CNT_PAYMENT_diff, 90
# Done Getting Kurtosis for Column CNT_PAYMENT_diff : 75.544770956 seconds
# Getting Trend for column: CNT_PAYMENT_diff, 90
# Done Getting Trend for Column CNT_PAYMENT_diff : 110.690876007 seconds
# Getting Aggregates for column: DAYS_DECISION_diff, 90
# Done Aggregating Column DAYS_DECISION_diff : 74.118046999 seconds
# Getting Kurtosis for Column: DAYS_DECISION_diff, 90
# Done Getting Kurtosis for Column DAYS_DECISION_diff : 77.0772042274 seconds
# Getting Trend for column: DAYS_DECISION_diff, 90
# Done Getting Trend for Column DAYS_DECISION_diff : 112.699331999 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING_diff, 90
# Done Aggregating Column DAYS_FIRST_DRAWING_diff : 75.3530387878 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING_diff, 90
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING_diff : 75.8835201263 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING_diff, 90
# Done Getting Trend for Column DAYS_FIRST_DRAWING_diff : 110.181555986 seconds
# Getting Aggregates for column: proportion_granted_diff, 90
# Done Aggregating Column proportion_granted_diff : 74.8781549931 seconds
# Getting Kurtosis for Column: proportion_granted_diff, 90
# Done Getting Kurtosis for Column proportion_granted_diff : 75.7236850262 seconds
# Getting Trend for column: proportion_granted_diff, 90
# Done Getting Trend for Column proportion_granted_diff : 112.081225872 seconds
# Getting Aggregates for column: CNT_PAYMENT_diff_diff, 90
# Done Aggregating Column CNT_PAYMENT_diff_diff : 75.6534240246 seconds
# Getting Kurtosis for Column: CNT_PAYMENT_diff_diff, 90
# Done Getting Kurtosis for Column CNT_PAYMENT_diff_diff : 74.2834291458 seconds
# Getting Trend for column: CNT_PAYMENT_diff_diff, 90
# Done Getting Trend for Column CNT_PAYMENT_diff_diff : 114.385063887 seconds
# Getting Aggregates for column: DAYS_DECISION_diff_diff, 90
# Done Aggregating Column DAYS_DECISION_diff_diff : 75.7083959579 seconds
# Getting Kurtosis for Column: DAYS_DECISION_diff_diff, 90
# Done Getting Kurtosis for Column DAYS_DECISION_diff_diff : 74.9783611298 seconds
# Getting Trend for column: DAYS_DECISION_diff_diff, 90
# Done Getting Trend for Column DAYS_DECISION_diff_diff : 117.091888905 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING_diff_diff, 90
# Done Aggregating Column DAYS_FIRST_DRAWING_diff_diff : 78.3708250523 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING_diff_diff, 90
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING_diff_diff : 73.4401080608 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING_diff_diff, 90
# Done Getting Trend for Column DAYS_FIRST_DRAWING_diff_diff : 111.622120857 seconds
# Getting Aggregates for column: proportion_granted_diff_diff, 90
# Done Aggregating Column proportion_granted_diff_diff : 75.0202791691 seconds
# Getting Kurtosis for Column: proportion_granted_diff_diff, 90
# Done Getting Kurtosis for Column proportion_granted_diff_diff : 75.2397739887 seconds
# Getting Trend for column: proportion_granted_diff_diff, 90
# Done Getting Trend for Column proportion_granted_diff_diff : 118.358452797 seconds
# Getting Aggregates for column: CNT_PAYMENT_rolling6, 90
# Done Aggregating Column CNT_PAYMENT_rolling6 : 75.7991571426 seconds
# Getting Kurtosis for Column: CNT_PAYMENT_rolling6, 90
# Done Getting Kurtosis for Column CNT_PAYMENT_rolling6 : 73.9106600285 seconds
# Getting Trend for column: CNT_PAYMENT_rolling6, 90
# Done Getting Trend for Column CNT_PAYMENT_rolling6 : 108.850867987 seconds
# Getting Aggregates for column: DAYS_DECISION_rolling6, 90
# Done Aggregating Column DAYS_DECISION_rolling6 : 76.199764967 seconds
# Getting Kurtosis for Column: DAYS_DECISION_rolling6, 90
# Done Getting Kurtosis for Column DAYS_DECISION_rolling6 : 74.3538448811 seconds
# Getting Trend for column: DAYS_DECISION_rolling6, 90
# Done Getting Trend for Column DAYS_DECISION_rolling6 : 117.027230024 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING_rolling6, 90
# Done Aggregating Column DAYS_FIRST_DRAWING_rolling6 : 75.9079740047 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING_rolling6, 90
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING_rolling6 : 72.8433921337 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING_rolling6, 90
# Done Getting Trend for Column DAYS_FIRST_DRAWING_rolling6 : 103.309516907 seconds
# Getting Aggregates for column: proportion_granted_rolling6, 90
# Done Aggregating Column proportion_granted_rolling6 : 75.6508469582 seconds
# Getting Kurtosis for Column: proportion_granted_rolling6, 90
# Done Getting Kurtosis for Column proportion_granted_rolling6 : 74.1794471741 seconds
# Getting Trend for column: proportion_granted_rolling6, 90
# Done Getting Trend for Column proportion_granted_rolling6 : 117.65395999 seconds
# Getting Aggregates for column: CNT_PAYMENT_rolling12, 90
# Done Aggregating Column CNT_PAYMENT_rolling12 : 75.7373549938 seconds
# Getting Kurtosis for Column: CNT_PAYMENT_rolling12, 90
# Done Getting Kurtosis for Column CNT_PAYMENT_rolling12 : 73.2553658485 seconds
# Getting Trend for column: CNT_PAYMENT_rolling12, 90
# Done Getting Trend for Column CNT_PAYMENT_rolling12 : 102.400890112 seconds
# Getting Aggregates for column: DAYS_DECISION_rolling12, 90
# Done Aggregating Column DAYS_DECISION_rolling12 : 75.82127285 seconds
# Getting Kurtosis for Column: DAYS_DECISION_rolling12, 90
# Done Getting Kurtosis for Column DAYS_DECISION_rolling12 : 73.2896502018 seconds
# Getting Trend for column: DAYS_DECISION_rolling12, 90
# Done Getting Trend for Column DAYS_DECISION_rolling12 : 107.561909914 seconds
# Getting Aggregates for column: DAYS_FIRST_DRAWING_rolling12, 90
# Done Aggregating Column DAYS_FIRST_DRAWING_rolling12 : 75.1019659042 seconds
# Getting Kurtosis for Column: DAYS_FIRST_DRAWING_rolling12, 90
# Done Getting Kurtosis for Column DAYS_FIRST_DRAWING_rolling12 : 73.0937800407 seconds
# Getting Trend for column: DAYS_FIRST_DRAWING_rolling12, 90
# Done Getting Trend for Column DAYS_FIRST_DRAWING_rolling12 : 101.710140944 seconds
# Getting Aggregates for column: proportion_granted_rolling12, 90
# Done Aggregating Column proportion_granted_rolling12 : 76.1626121998 seconds
# Getting Kurtosis for Column: proportion_granted_rolling12, 90
# Done Getting Kurtosis for Column proportion_granted_rolling12 : 73.2927918434 seconds
# Getting Trend for column: proportion_granted_rolling12, 90
# Done Getting Trend for Column proportion_granted_rolling12 : 106.835044146 seconds
# (338857, 433) Before dropping Na's
# (338857, 433) After dropping Na's
