# %%
model_name = "l1_nn"

# %%
import numpy as np
import pandas as pd
import gc
from time import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
timesheet = [time()]
def timer(statement):
    global timesheet
    timesheet.append(time())
    print statement+" :", (timesheet[-1]-timesheet[-2]),"seconds"

# %%
def load_meta(directory, prefix, modeltype):
    m_tr = pd.read_csv(directory+prefix+"_train.csv")
    m_te = pd.read_csv(directory+prefix+"_test.csv")
    data = pd.concat([m_tr, m_te], axis=0).reset_index(drop=True)
    data.columns = ["{}_{}_{}".format(c, prefix, modeltype) if c!="SK_ID_CURR" else c for c in data.columns]
    return data

def join_features(data, features):
    for item in features:
        data = data.merge(item, how = "left", on = "SK_ID_CURR")
    return data

def postprocess(df):
    cols = [c for c in df.columns if c not in ["SK_ID_CURR","SK_ID_PREV","TARGET"]]
    df = df.replace([np.inf, -np.inf], np.nan)
    df.loc[:, cols] = MinMaxScaler().fit_transform(df.loc[:, cols].fillna(df.loc[:, cols].mean()).clip(-1e11,1e11))
    return df

def processColNames(df):
    df.columns = [c.replace(" ","_") for c in df.columns]
    return df

# %% [markdown]
# ## Loading Features

# %% [markdown]
# Loading All Features File

# %%
applications = processColNames(pd.read_csv("../extractor/csv/application_features_normalized_V1.csv").dropna(axis=1, how="all")).drop(["TARGET"], axis=1)
bureau_balance_bb = processColNames(pd.read_csv("../extractor/csv/bureau_features_normalized_V1.csv").dropna(axis=1, how="all"))
credit_card_balance = processColNames(pd.read_csv("../extractor/csv/credit_card_features_normalized_V1.csv").dropna(axis=1, how="all"))
installment_features = processColNames(pd.read_csv("../extractor/csv/installment_features_normalized_V1.csv").dropna(axis=1, how="all"))
pos_cash_balance = processColNames(pd.read_csv("../extractor/csv/pos_cash_features_normalized_V1.csv").dropna(axis=1, how="all"))
previous_apps = processColNames(pd.read_csv("../extractor/csv/previous_application_features_normalized_V1.csv").dropna(axis=1, how="all"))

base_features = [applications, bureau_balance_bb, credit_card_balance, installment_features, pos_cash_balance,previous_apps ]

# %% [markdown]
# ## Loading Meta Features

# %%
tree_meta_features = [
    load_meta("../base trees/csv/", "application", "trees"),
    load_meta("../base trees/csv/", "bureau_balance_bb", "trees"),
    load_meta("../base trees/csv/", "credit_card_balance", "trees"),
    load_meta("../base trees/csv/", "installment", "trees"),
    load_meta("../base trees/csv/", "pos_cash_balance", "trees"),
    load_meta("../base trees/csv/", "previous_apps", "trees"),
]

lr_meta_features = [
    load_meta("../base lr/csv/", "application", "lr"),
    load_meta("../base lr/csv/", "bureau_balance_bb", "lr"),
    load_meta("../base lr/csv/", "credit_card_balance", "lr"),
    load_meta("../base lr/csv/", "installment", "lr"),
    load_meta("../base lr/csv/", "pos_cash_balance", "lr"),
    load_meta("../base lr/csv/", "previous_apps", "lr"),
]

nb_meta_features = [
    load_meta("../base nb/csv/", "application", "nb"),
    load_meta("../base nb/csv/", "bureau_balance_bb", "nb"),
    load_meta("../base nb/csv/", "credit_card_balance", "nb"),
    load_meta("../base nb/csv/", "installment", "nb"),
    load_meta("../base nb/csv/", "pos_cash_balance", "nb"),
    load_meta("../base nb/csv/", "previous_apps", "nb"),
]

nn_meta_features = [
    load_meta("../base nn/csv/", "application", "nb"),
    load_meta("../base nn/csv/", "bureau_balance_bb", "nb"),
    load_meta("../base nn/csv/", "credit_card_balance", "nb"),
    load_meta("../base nn/csv/", "installment", "nb"),
    load_meta("../base nn/csv/", "pos_cash_balance", "nb"),
    load_meta("../base nn/csv/", "previous_apps", "nb"),
]

# %%
train = pd.read_csv("../data/application_train.csv", usecols = ["SK_ID_CURR","TARGET"])
test = pd.read_csv("../data/application_test.csv", usecols = ["SK_ID_CURR"])

data = pd.concat([train, test], axis=0).reset_index(drop=True)
data = join_features(data, base_features)
data = join_features(data, tree_meta_features)
data = join_features(data, lr_meta_features)
data = join_features(data, nb_meta_features)
data = join_features(data, nn_meta_features)

data = postprocess(data)
train = data.loc[data.TARGET.notnull()].reset_index(drop=True)
test = data.loc[data.TARGET.isnull()].reset_index(drop=True)

train_id = train[["SK_ID_CURR"]]
test_id = test[["SK_ID_CURR"]]
target =train.TARGET

train.drop(["SK_ID_CURR", "TARGET"], axis=1, inplace=True)
test.drop(["SK_ID_CURR","TARGET"], axis=1, inplace = True)

# %% [markdown]
# # Defining Model

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Activation,InputLayer, Dropout, PReLU, BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from keras import metrics
from keras import optimizers
from keras import backend as K

K.tf.set_random_seed(0)
cfg = K.tf.ConfigProto()
cfg.gpu_options.allow_growth = True 
K.set_session(K.tf.Session(config=cfg))
np.random.seed(0)

def model_nn(x_train, x_test, y_train, y_test, test, meta_train, meta_test,train_index, test_index,fold_id):
    model = Sequential()
    model.add(Dense(units = 400 , kernel_initializer = 'normal', input_dim = x_train.shape[1]))
    model.add(PReLU())
    model.add(Dropout(.4))
    model.add(BatchNormalization())
    model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
    model.compile(loss="binary_crossentropy", optimizer="rmsprop")
    
    checkpoint = ModelCheckpoint("weights/{}.hdf5".format(model_name), monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    early_stop = EarlyStopping(monitor='val_loss', patience=5, mode='auto') 

    model.fit(x_train, y_train, epochs=100, batch_size=30000, validation_data =(x_test, y_test), callbacks=[checkpoint, early_stop], class_weight={1:np.mean(y_train), 0: 1-np.mean(y_train)})

    model.load_weights("weights/{}.hdf5".format(model_name))
    meta_train[test_index] = model.predict(x_test).flatten()
    meta_test.append(model.predict(test).flatten())
    print "ROC_AUC_SCORE: {}".format(roc_auc_score(y_test, meta_train[test_index]))

    del model
    gc.collect()
    K.clear_session()
    K.tf.set_random_seed(0)

# %% [markdown]
# # Training Model

# %%
meta_train = np.zeros(train.shape[0])
meta_test = []

kf = StratifiedKFold(n_splits= 10, shuffle=True, random_state=47)
for fold_id, (train_index, test_index) in enumerate(kf.split(train, target)):
    x_train, x_test = train.iloc[train_index].as_matrix(), train.iloc[test_index].as_matrix()
    y_train, y_test = target[train_index], target[test_index]

    model_nn(x_train, x_test, y_train, y_test, test.as_matrix(), meta_train, meta_test,train_index, test_index,fold_id)

test_id["TARGET"] = np.array(meta_test).T.mean(axis=1)
train_id["TARGET"] = meta_train
print "Overall ROC AUC SCORE: ",roc_auc_score(target,meta_train)
# Out:
# Train on 276759 samples, validate on 30752 samples
# Epoch 1/100
# 270000/276759 [============================>.] - ETA: 3s - loss: 0.5885
# Epoch 00001: val_loss improved from inf to 0.64768, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 128s 462us/step - loss: 0.5883 - val_loss: 0.6477
# Epoch 2/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5761
# Epoch 00002: val_loss did not improve
# 276759/276759 [==============================] - 117s 423us/step - loss: 0.5760 - val_loss: 0.6530
# Epoch 3/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5650
# Epoch 00003: val_loss did not improve
# 276759/276759 [==============================] - 114s 411us/step - loss: 0.5649 - val_loss: 0.6555
# Epoch 4/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5515
# Epoch 00004: val_loss improved from 0.64768 to 0.62927, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 115s 416us/step - loss: 0.5513 - val_loss: 0.6293
# Epoch 5/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5363
# Epoch 00005: val_loss improved from 0.62927 to 0.58114, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 111s 401us/step - loss: 0.5361 - val_loss: 0.5811
# Epoch 6/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5192
# Epoch 00006: val_loss did not improve
# 276759/276759 [==============================] - 110s 396us/step - loss: 0.5190 - val_loss: 0.6009
# Epoch 7/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5003
# Epoch 00007: val_loss improved from 0.58114 to 0.57002, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 113s 410us/step - loss: 0.5000 - val_loss: 0.5700
# Epoch 8/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4799
# Epoch 00008: val_loss improved from 0.57002 to 0.56191, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 111s 402us/step - loss: 0.4797 - val_loss: 0.5619
# Epoch 9/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4564
# Epoch 00009: val_loss improved from 0.56191 to 0.52601, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 113s 407us/step - loss: 0.4560 - val_loss: 0.5260
# Epoch 10/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4328
# Epoch 00010: val_loss did not improve
# 276759/276759 [==============================] - 113s 407us/step - loss: 0.4325 - val_loss: 0.5300
# Epoch 11/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4079
# Epoch 00011: val_loss did not improve
# 276759/276759 [==============================] - 112s 406us/step - loss: 0.4077 - val_loss: 0.5320
# Epoch 12/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3817
# Epoch 00012: val_loss improved from 0.52601 to 0.49656, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 114s 412us/step - loss: 0.3814 - val_loss: 0.4966
# Epoch 13/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3562
# Epoch 00013: val_loss improved from 0.49656 to 0.48601, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 109s 396us/step - loss: 0.3559 - val_loss: 0.4860
# Epoch 14/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3306
# Epoch 00014: val_loss improved from 0.48601 to 0.45841, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 101s 365us/step - loss: 0.3304 - val_loss: 0.4584
# Epoch 15/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3056
# Epoch 00015: val_loss improved from 0.45841 to 0.45066, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 91s 328us/step - loss: 0.3053 - val_loss: 0.4507
# Epoch 16/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2815
# Epoch 00016: val_loss improved from 0.45066 to 0.41964, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 99s 357us/step - loss: 0.2813 - val_loss: 0.4196
# Epoch 17/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2580
# Epoch 00017: val_loss improved from 0.41964 to 0.39803, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 113s 409us/step - loss: 0.2578 - val_loss: 0.3980
# Epoch 18/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2380
# Epoch 00018: val_loss improved from 0.39803 to 0.37444, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 109s 393us/step - loss: 0.2376 - val_loss: 0.3744
# Epoch 19/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2159
# Epoch 00019: val_loss improved from 0.37444 to 0.35200, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 109s 393us/step - loss: 0.2158 - val_loss: 0.3520
# Epoch 20/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1968
# Epoch 00020: val_loss improved from 0.35200 to 0.33702, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 114s 411us/step - loss: 0.1968 - val_loss: 0.3370
# Epoch 21/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1807
# Epoch 00021: val_loss improved from 0.33702 to 0.31779, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 111s 401us/step - loss: 0.1804 - val_loss: 0.3178
# Epoch 22/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1613
# Epoch 00022: val_loss improved from 0.31779 to 0.30642, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 90s 325us/step - loss: 0.1611 - val_loss: 0.3064
# Epoch 23/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1472
# Epoch 00023: val_loss improved from 0.30642 to 0.29671, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 121s 437us/step - loss: 0.1470 - val_loss: 0.2967
# Epoch 24/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1317
# Epoch 00024: val_loss improved from 0.29671 to 0.28930, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 111s 403us/step - loss: 0.1316 - val_loss: 0.2893
# Epoch 25/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1194
# Epoch 00025: val_loss improved from 0.28930 to 0.28488, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 119s 429us/step - loss: 0.1195 - val_loss: 0.2849
# Epoch 26/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1089
# Epoch 00026: val_loss improved from 0.28488 to 0.28168, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 112s 405us/step - loss: 0.1088 - val_loss: 0.2817
# Epoch 27/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0974
# Epoch 00027: val_loss improved from 0.28168 to 0.28052, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 111s 400us/step - loss: 0.0973 - val_loss: 0.2805
# Epoch 28/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0883
# Epoch 00028: val_loss did not improve
# 276759/276759 [==============================] - 115s 416us/step - loss: 0.0882 - val_loss: 0.2810
# Epoch 29/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0814
# Epoch 00029: val_loss did not improve
# 276759/276759 [==============================] - 112s 406us/step - loss: 0.0813 - val_loss: 0.2831
# Epoch 30/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0731
# Epoch 00030: val_loss did not improve
# 276759/276759 [==============================] - 114s 411us/step - loss: 0.0731 - val_loss: 0.2857
# Epoch 31/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0679
# Epoch 00031: val_loss did not improve
# 276759/276759 [==============================] - 119s 430us/step - loss: 0.0684 - val_loss: 0.2889
# Epoch 32/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0641
# Epoch 00032: val_loss did not improve
# 276759/276759 [==============================] - 120s 434us/step - loss: 0.0641 - val_loss: 0.2952
# ROC_AUC_SCORE: 0.601293749921
# Train on 276759 samples, validate on 30752 samples
# Epoch 1/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5903
# Epoch 00001: val_loss improved from inf to 0.69704, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 118s 427us/step - loss: 0.5901 - val_loss: 0.6970
# Epoch 2/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5768
# Epoch 00002: val_loss improved from 0.69704 to 0.68651, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 124s 448us/step - loss: 0.5766 - val_loss: 0.6865
# Epoch 3/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5654
# Epoch 00003: val_loss did not improve
# 276759/276759 [==============================] - 119s 430us/step - loss: 0.5651 - val_loss: 0.6871
# Epoch 4/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5518
# Epoch 00004: val_loss improved from 0.68651 to 0.63932, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 121s 437us/step - loss: 0.5516 - val_loss: 0.6393
# Epoch 5/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5364
# Epoch 00005: val_loss improved from 0.63932 to 0.61226, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 123s 445us/step - loss: 0.5362 - val_loss: 0.6123
# Epoch 6/100
# 270000/276759 [============================>.] - ETA: 3s - loss: 0.5195
# Epoch 00006: val_loss improved from 0.61226 to 0.60362, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 128s 461us/step - loss: 0.5192 - val_loss: 0.6036
# Epoch 7/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5009
# Epoch 00007: val_loss improved from 0.60362 to 0.60338, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 100s 363us/step - loss: 0.5007 - val_loss: 0.6034
# Epoch 8/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4809
# Epoch 00008: val_loss did not improve
# 276759/276759 [==============================] - 95s 342us/step - loss: 0.4808 - val_loss: 0.6234
# Epoch 9/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4593
# Epoch 00009: val_loss improved from 0.60338 to 0.54298, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 120s 433us/step - loss: 0.4590 - val_loss: 0.5430
# Epoch 10/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4348
# Epoch 00010: val_loss improved from 0.54298 to 0.53238, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 112s 406us/step - loss: 0.4345 - val_loss: 0.5324
# Epoch 11/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4107
# Epoch 00011: val_loss improved from 0.53238 to 0.52723, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 112s 404us/step - loss: 0.4104 - val_loss: 0.5272
# Epoch 12/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3838
# Epoch 00012: val_loss improved from 0.52723 to 0.52654, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 111s 400us/step - loss: 0.3836 - val_loss: 0.5265
# Epoch 13/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3595
# Epoch 00013: val_loss improved from 0.52654 to 0.48952, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 117s 421us/step - loss: 0.3592 - val_loss: 0.4895
# Epoch 14/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3334
# Epoch 00014: val_loss improved from 0.48952 to 0.46546, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 113s 408us/step - loss: 0.3331 - val_loss: 0.4655
# Epoch 15/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3074
# Epoch 00015: val_loss did not improve
# 276759/276759 [==============================] - 117s 423us/step - loss: 0.3070 - val_loss: 0.4888
# Epoch 16/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2830
# Epoch 00016: val_loss improved from 0.46546 to 0.45782, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 124s 448us/step - loss: 0.2828 - val_loss: 0.4578
# Epoch 17/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2598
# Epoch 00017: val_loss improved from 0.45782 to 0.42258, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 111s 400us/step - loss: 0.2595 - val_loss: 0.4226
# Epoch 18/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2368
# Epoch 00018: val_loss improved from 0.42258 to 0.39340, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 117s 423us/step - loss: 0.2367 - val_loss: 0.3934
# Epoch 19/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2151
# Epoch 00019: val_loss improved from 0.39340 to 0.36520, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 123s 444us/step - loss: 0.2149 - val_loss: 0.3652
# Epoch 20/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1963
# Epoch 00020: val_loss improved from 0.36520 to 0.34139, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 117s 422us/step - loss: 0.1962 - val_loss: 0.3414
# Epoch 21/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1777
# Epoch 00021: val_loss improved from 0.34139 to 0.32517, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 121s 437us/step - loss: 0.1776 - val_loss: 0.3252
# Epoch 22/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1601
# Epoch 00022: val_loss improved from 0.32517 to 0.31046, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 94s 340us/step - loss: 0.1600 - val_loss: 0.3105
# Epoch 23/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1468
# Epoch 00023: val_loss improved from 0.31046 to 0.29924, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 118s 426us/step - loss: 0.1467 - val_loss: 0.2992
# Epoch 24/100
# 270000/276759 [============================>.] - ETA: 3s - loss: 0.1324
# Epoch 00024: val_loss improved from 0.29924 to 0.29144, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 129s 465us/step - loss: 0.1323 - val_loss: 0.2914
# Epoch 25/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1191
# Epoch 00025: val_loss improved from 0.29144 to 0.28596, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 114s 414us/step - loss: 0.1189 - val_loss: 0.2860
# Epoch 26/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1072
# Epoch 00026: val_loss improved from 0.28596 to 0.28236, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 122s 440us/step - loss: 0.1071 - val_loss: 0.2824
# Epoch 27/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0979
# Epoch 00027: val_loss improved from 0.28236 to 0.28059, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 106s 383us/step - loss: 0.0978 - val_loss: 0.2806
# Epoch 28/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0899
# Epoch 00028: val_loss improved from 0.28059 to 0.28057, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 93s 335us/step - loss: 0.0904 - val_loss: 0.2806
# Epoch 29/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0816
# Epoch 00029: val_loss did not improve
# 276759/276759 [==============================] - 101s 364us/step - loss: 0.0816 - val_loss: 0.2819
# Epoch 30/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0736
# Epoch 00030: val_loss did not improve
# 276759/276759 [==============================] - 116s 418us/step - loss: 0.0735 - val_loss: 0.2848
# Epoch 31/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0671
# Epoch 00031: val_loss did not improve
# 276759/276759 [==============================] - 115s 416us/step - loss: 0.0670 - val_loss: 0.2893
# Epoch 32/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0627
# Epoch 00032: val_loss did not improve
# 276759/276759 [==============================] - 117s 422us/step - loss: 0.0626 - val_loss: 0.2949
# Epoch 33/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0592
# Epoch 00033: val_loss did not improve
# 276759/276759 [==============================] - 113s 408us/step - loss: 0.0591 - val_loss: 0.3007
# ROC_AUC_SCORE: 0.574396461576
# Train on 276759 samples, validate on 30752 samples
# Epoch 1/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5880
# Epoch 00001: val_loss improved from inf to 0.68939, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 116s 417us/step - loss: 0.5878 - val_loss: 0.6894
# Epoch 2/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5761
# Epoch 00002: val_loss did not improve
# 276759/276759 [==============================] - 118s 425us/step - loss: 0.5760 - val_loss: 0.7048
# Epoch 3/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5654
# Epoch 00003: val_loss improved from 0.68939 to 0.65332, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 114s 413us/step - loss: 0.5652 - val_loss: 0.6533
# Epoch 4/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5524
# Epoch 00004: val_loss did not improve
# 276759/276759 [==============================] - 115s 414us/step - loss: 0.5521 - val_loss: 0.6629
# Epoch 5/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5369
# Epoch 00005: val_loss improved from 0.65332 to 0.62191, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 116s 418us/step - loss: 0.5367 - val_loss: 0.6219
# Epoch 6/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5201
# Epoch 00006: val_loss improved from 0.62191 to 0.58375, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 116s 418us/step - loss: 0.5198 - val_loss: 0.5837
# Epoch 7/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5014
# Epoch 00007: val_loss improved from 0.58375 to 0.58073, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 116s 418us/step - loss: 0.5012 - val_loss: 0.5807
# Epoch 8/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4812
# Epoch 00008: val_loss improved from 0.58073 to 0.54745, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 116s 419us/step - loss: 0.4809 - val_loss: 0.5475
# Epoch 9/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4601
# Epoch 00009: val_loss improved from 0.54745 to 0.54596, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 106s 385us/step - loss: 0.4598 - val_loss: 0.5460
# Epoch 10/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4358
# Epoch 00010: val_loss improved from 0.54596 to 0.50248, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 103s 372us/step - loss: 0.4355 - val_loss: 0.5025
# Epoch 11/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4105
# Epoch 00011: val_loss improved from 0.50248 to 0.48735, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 115s 415us/step - loss: 0.4104 - val_loss: 0.4873
# Epoch 12/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3853
# Epoch 00012: val_loss improved from 0.48735 to 0.43590, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 116s 419us/step - loss: 0.3850 - val_loss: 0.4359
# Epoch 13/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3601
# Epoch 00013: val_loss improved from 0.43590 to 0.41299, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 113s 410us/step - loss: 0.3597 - val_loss: 0.4130
# Epoch 14/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3331
# Epoch 00014: val_loss improved from 0.41299 to 0.39012, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 119s 431us/step - loss: 0.3328 - val_loss: 0.3901
# Epoch 15/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3075
# Epoch 00015: val_loss improved from 0.39012 to 0.37469, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 115s 414us/step - loss: 0.3077 - val_loss: 0.3747
# Epoch 16/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2846
# Epoch 00016: val_loss improved from 0.37469 to 0.36081, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 118s 425us/step - loss: 0.2842 - val_loss: 0.3608
# Epoch 17/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2619
# Epoch 00017: val_loss improved from 0.36081 to 0.35025, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 109s 393us/step - loss: 0.2617 - val_loss: 0.3502
# Epoch 18/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2406
# Epoch 00018: val_loss improved from 0.35025 to 0.33897, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 112s 405us/step - loss: 0.2403 - val_loss: 0.3390
# Epoch 19/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2168
# Epoch 00019: val_loss improved from 0.33897 to 0.32818, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 94s 339us/step - loss: 0.2165 - val_loss: 0.3282
# Epoch 20/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1978
# Epoch 00020: val_loss improved from 0.32818 to 0.31801, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 91s 328us/step - loss: 0.1976 - val_loss: 0.3180
# Epoch 21/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1793
# Epoch 00021: val_loss improved from 0.31801 to 0.30911, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 112s 406us/step - loss: 0.1790 - val_loss: 0.3091
# Epoch 22/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1626
# Epoch 00022: val_loss improved from 0.30911 to 0.30183, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 110s 398us/step - loss: 0.1625 - val_loss: 0.3018
# Epoch 23/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1499
# Epoch 00023: val_loss improved from 0.30183 to 0.29551, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 109s 395us/step - loss: 0.1497 - val_loss: 0.2955
# Epoch 24/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1335
# Epoch 00024: val_loss improved from 0.29551 to 0.28886, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 107s 385us/step - loss: 0.1333 - val_loss: 0.2889
# Epoch 25/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1209
# Epoch 00025: val_loss improved from 0.28886 to 0.28428, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 112s 404us/step - loss: 0.1209 - val_loss: 0.2843
# Epoch 26/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1090
# Epoch 00026: val_loss improved from 0.28428 to 0.28170, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 120s 434us/step - loss: 0.1089 - val_loss: 0.2817
# Epoch 27/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0998
# Epoch 00027: val_loss improved from 0.28170 to 0.28049, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 108s 392us/step - loss: 0.0997 - val_loss: 0.2805
# Epoch 28/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0910
# Epoch 00028: val_loss did not improve
# 276759/276759 [==============================] - 116s 419us/step - loss: 0.0911 - val_loss: 0.2812
# Epoch 29/100
# 270000/276759 [============================>.] - ETA: 3s - loss: 0.0835
# Epoch 00029: val_loss did not improve
# 276759/276759 [==============================] - 128s 462us/step - loss: 0.0834 - val_loss: 0.2826
# Epoch 30/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0759
# Epoch 00030: val_loss did not improve
# 276759/276759 [==============================] - 112s 405us/step - loss: 0.0758 - val_loss: 0.2860
# Epoch 31/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0688
# Epoch 00031: val_loss did not improve
# 276759/276759 [==============================] - 112s 406us/step - loss: 0.0688 - val_loss: 0.2907
# Epoch 32/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0627
# Epoch 00032: val_loss did not improve
# 276759/276759 [==============================] - 109s 393us/step - loss: 0.0627 - val_loss: 0.2965
# ROC_AUC_SCORE: 0.62643642053
# Train on 276759 samples, validate on 30752 samples
# Epoch 1/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5886
# Epoch 00001: val_loss improved from inf to 0.66838, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 122s 441us/step - loss: 0.5884 - val_loss: 0.6684
# Epoch 2/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5763
# Epoch 00002: val_loss improved from 0.66838 to 0.66097, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 112s 403us/step - loss: 0.5763 - val_loss: 0.6610
# Epoch 3/100
# 270000/276759 [============================>.] - ETA: 3s - loss: 0.5655
# Epoch 00003: val_loss improved from 0.66097 to 0.63227, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 132s 477us/step - loss: 0.5654 - val_loss: 0.6323
# Epoch 4/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5525
# Epoch 00004: val_loss did not improve
# 276759/276759 [==============================] - 108s 390us/step - loss: 0.5523 - val_loss: 0.6436
# Epoch 5/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5375
# Epoch 00005: val_loss did not improve
# 276759/276759 [==============================] - 115s 415us/step - loss: 0.5373 - val_loss: 0.6329
# Epoch 6/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5206
# Epoch 00006: val_loss improved from 0.63227 to 0.61928, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 121s 439us/step - loss: 0.5203 - val_loss: 0.6193
# Epoch 7/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5023
# Epoch 00007: val_loss did not improve
# 276759/276759 [==============================] - 120s 434us/step - loss: 0.5021 - val_loss: 0.6223
# Epoch 8/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4827
# Epoch 00008: val_loss improved from 0.61928 to 0.55075, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 112s 404us/step - loss: 0.4825 - val_loss: 0.5508
# Epoch 9/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4618
# Epoch 00009: val_loss did not improve
# 276759/276759 [==============================] - 114s 412us/step - loss: 0.4616 - val_loss: 0.5556
# Epoch 10/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4398
# Epoch 00010: val_loss improved from 0.55075 to 0.50773, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 119s 431us/step - loss: 0.4396 - val_loss: 0.5077
# Epoch 11/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4158
# Epoch 00011: val_loss improved from 0.50773 to 0.46886, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 117s 424us/step - loss: 0.4156 - val_loss: 0.4689
# Epoch 12/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3913
# Epoch 00012: val_loss improved from 0.46886 to 0.46838, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 114s 410us/step - loss: 0.3908 - val_loss: 0.4684
# Epoch 13/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3646
# Epoch 00013: val_loss improved from 0.46838 to 0.45324, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 112s 403us/step - loss: 0.3642 - val_loss: 0.4532
# Epoch 14/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3391
# Epoch 00014: val_loss improved from 0.45324 to 0.41270, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 119s 429us/step - loss: 0.3386 - val_loss: 0.4127
# Epoch 15/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3104
# Epoch 00015: val_loss improved from 0.41270 to 0.39889, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 113s 409us/step - loss: 0.3103 - val_loss: 0.3989
# Epoch 16/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2872
# Epoch 00016: val_loss improved from 0.39889 to 0.37801, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 104s 374us/step - loss: 0.2868 - val_loss: 0.3780
# Epoch 17/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2616
# Epoch 00017: val_loss improved from 0.37801 to 0.36135, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 96s 346us/step - loss: 0.2614 - val_loss: 0.3613
# Epoch 18/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2400
# Epoch 00018: val_loss improved from 0.36135 to 0.34525, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 100s 363us/step - loss: 0.2397 - val_loss: 0.3453
# Epoch 19/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2187
# Epoch 00019: val_loss improved from 0.34525 to 0.33310, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 106s 385us/step - loss: 0.2185 - val_loss: 0.3331
# Epoch 20/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1998
# Epoch 00020: val_loss improved from 0.33310 to 0.32052, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 115s 415us/step - loss: 0.1996 - val_loss: 0.3205
# Epoch 21/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1806
# Epoch 00021: val_loss improved from 0.32052 to 0.31065, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 107s 386us/step - loss: 0.1806 - val_loss: 0.3106
# Epoch 22/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1653
# Epoch 00022: val_loss improved from 0.31065 to 0.30176, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 117s 423us/step - loss: 0.1650 - val_loss: 0.3018
# Epoch 23/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1486
# Epoch 00023: val_loss improved from 0.30176 to 0.29416, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 116s 420us/step - loss: 0.1483 - val_loss: 0.2942
# Epoch 24/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1351
# Epoch 00024: val_loss improved from 0.29416 to 0.28839, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 106s 384us/step - loss: 0.1350 - val_loss: 0.2884
# Epoch 25/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1218
# Epoch 00025: val_loss improved from 0.28839 to 0.28440, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 120s 432us/step - loss: 0.1217 - val_loss: 0.2844
# Epoch 26/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1097
# Epoch 00026: val_loss improved from 0.28440 to 0.28176, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 113s 409us/step - loss: 0.1096 - val_loss: 0.2818
# Epoch 27/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1009
# Epoch 00027: val_loss improved from 0.28176 to 0.28061, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 110s 398us/step - loss: 0.1008 - val_loss: 0.2806
# Epoch 28/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0902
# Epoch 00028: val_loss did not improve
# 276759/276759 [==============================] - 115s 416us/step - loss: 0.0901 - val_loss: 0.2811
# Epoch 29/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0834
# Epoch 00029: val_loss did not improve
# 276759/276759 [==============================] - 111s 403us/step - loss: 0.0832 - val_loss: 0.2829
# Epoch 30/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0738
# Epoch 00030: val_loss did not improve
# 276759/276759 [==============================] - 111s 399us/step - loss: 0.0738 - val_loss: 0.2864
# Epoch 31/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0684
# Epoch 00031: val_loss did not improve
# 276759/276759 [==============================] - 118s 426us/step - loss: 0.0684 - val_loss: 0.2907
# Epoch 32/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0636
# Epoch 00032: val_loss did not improve
# 276759/276759 [==============================] - 116s 419us/step - loss: 0.0635 - val_loss: 0.2963
# ROC_AUC_SCORE: 0.570511563246
# Train on 276759 samples, validate on 30752 samples
# Epoch 1/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5880
# Epoch 00001: val_loss improved from inf to 0.68365, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 118s 425us/step - loss: 0.5878 - val_loss: 0.6837
# Epoch 2/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5762
# Epoch 00002: val_loss improved from 0.68365 to 0.64989, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 115s 417us/step - loss: 0.5760 - val_loss: 0.6499
# Epoch 3/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5652
# Epoch 00003: val_loss did not improve
# 276759/276759 [==============================] - 113s 407us/step - loss: 0.5650 - val_loss: 0.6823
# Epoch 4/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5519
# Epoch 00004: val_loss improved from 0.64989 to 0.63239, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 116s 419us/step - loss: 0.5518 - val_loss: 0.6324
# Epoch 5/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5370
# Epoch 00005: val_loss improved from 0.63239 to 0.60526, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 112s 405us/step - loss: 0.5368 - val_loss: 0.6053
# Epoch 6/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5204
# Epoch 00006: val_loss improved from 0.60526 to 0.58797, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 118s 425us/step - loss: 0.5202 - val_loss: 0.5880
# Epoch 7/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.5018
# Epoch 00007: val_loss did not improve
# 276759/276759 [==============================] - 113s 407us/step - loss: 0.5015 - val_loss: 0.5889
# Epoch 8/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4821
# Epoch 00008: val_loss improved from 0.58797 to 0.57900, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 118s 427us/step - loss: 0.4819 - val_loss: 0.5790
# Epoch 9/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4606
# Epoch 00009: val_loss improved from 0.57900 to 0.57013, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 116s 420us/step - loss: 0.4603 - val_loss: 0.5701
# Epoch 10/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4381
# Epoch 00010: val_loss improved from 0.57013 to 0.55608, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 110s 398us/step - loss: 0.4378 - val_loss: 0.5561
# Epoch 11/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.4138
# Epoch 00011: val_loss improved from 0.55608 to 0.50551, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 95s 344us/step - loss: 0.4135 - val_loss: 0.5055
# Epoch 12/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3878
# Epoch 00012: val_loss did not improve
# 276759/276759 [==============================] - 94s 339us/step - loss: 0.3874 - val_loss: 0.5134
# Epoch 13/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3611
# Epoch 00013: val_loss improved from 0.50551 to 0.48398, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 118s 426us/step - loss: 0.3609 - val_loss: 0.4840
# Epoch 14/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3344
# Epoch 00014: val_loss improved from 0.48398 to 0.46354, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 115s 416us/step - loss: 0.3342 - val_loss: 0.4635
# Epoch 15/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.3089
# Epoch 00015: val_loss improved from 0.46354 to 0.43959, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 114s 411us/step - loss: 0.3085 - val_loss: 0.4396
# Epoch 16/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2845
# Epoch 00016: val_loss improved from 0.43959 to 0.41185, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 114s 412us/step - loss: 0.2844 - val_loss: 0.4118
# Epoch 17/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2615
# Epoch 00017: val_loss improved from 0.41185 to 0.38805, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 114s 410us/step - loss: 0.2613 - val_loss: 0.3881
# Epoch 18/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2394
# Epoch 00018: val_loss improved from 0.38805 to 0.36712, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 118s 426us/step - loss: 0.2391 - val_loss: 0.3671
# Epoch 19/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.2175
# Epoch 00019: val_loss improved from 0.36712 to 0.34635, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 115s 415us/step - loss: 0.2173 - val_loss: 0.3464
# Epoch 20/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1991
# Epoch 00020: val_loss improved from 0.34635 to 0.33002, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 115s 416us/step - loss: 0.1989 - val_loss: 0.3300
# Epoch 21/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1797
# Epoch 00021: val_loss improved from 0.33002 to 0.31519, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 115s 417us/step - loss: 0.1795 - val_loss: 0.3152
# Epoch 22/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1643
# Epoch 00022: val_loss improved from 0.31519 to 0.30421, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 117s 424us/step - loss: 0.1641 - val_loss: 0.3042
# Epoch 23/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1467
# Epoch 00023: val_loss improved from 0.30421 to 0.29649, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 111s 402us/step - loss: 0.1467 - val_loss: 0.2965
# Epoch 24/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1349
# Epoch 00024: val_loss improved from 0.29649 to 0.28946, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 111s 401us/step - loss: 0.1347 - val_loss: 0.2895
# Epoch 25/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1213
# Epoch 00025: val_loss improved from 0.28946 to 0.28475, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 115s 415us/step - loss: 0.1211 - val_loss: 0.2848
# Epoch 26/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.1105
# Epoch 00026: val_loss improved from 0.28475 to 0.28188, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 115s 416us/step - loss: 0.1103 - val_loss: 0.2819
# Epoch 27/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0985
# Epoch 00027: val_loss improved from 0.28188 to 0.28063, saving model to weights/l1_nn.hdf5
# 276759/276759 [==============================] - 109s 394us/step - loss: 0.0984 - val_loss: 0.2806
# Epoch 28/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0892
# Epoch 00028: val_loss did not improve
# 276759/276759 [==============================] - 116s 418us/step - loss: 0.0891 - val_loss: 0.2809
# Epoch 29/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0827
# Epoch 00029: val_loss did not improve
# 276759/276759 [==============================] - 115s 416us/step - loss: 0.0826 - val_loss: 0.2820
# Epoch 30/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0748
# Epoch 00030: val_loss did not improve
# 276759/276759 [==============================] - 112s 406us/step - loss: 0.0748 - val_loss: 0.2857
# Epoch 31/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0682
# Epoch 00031: val_loss did not improve
# 276759/276759 [==============================] - 116s 419us/step - loss: 0.0682 - val_loss: 0.2903
# Epoch 32/100
# 270000/276759 [============================>.] - ETA: 2s - loss: 0.0634
# Epoch 00032: val_loss did not improve
# 276759/276759 [==============================] - 118s 428us/step - loss: 0.0633 - val_loss: 0.2960
# ROC_AUC_SCORE: 0.590824098617
# Train on 276760 samples, validate on 30751 samples
# Epoch 1/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.5902
# Epoch 00001: val_loss improved from inf to 0.75395, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 111s 399us/step - loss: 0.5900 - val_loss: 0.7540
# Epoch 2/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.5765
# Epoch 00002: val_loss improved from 0.75395 to 0.70338, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 111s 402us/step - loss: 0.5764 - val_loss: 0.7034
# Epoch 3/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.5649
# Epoch 00003: val_loss did not improve
# 276760/276760 [==============================] - 116s 420us/step - loss: 0.5647 - val_loss: 0.7402
# Epoch 4/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.5520
# Epoch 00004: val_loss did not improve
# 276760/276760 [==============================] - 107s 386us/step - loss: 0.5518 - val_loss: 0.7322
# Epoch 5/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.5368
# Epoch 00005: val_loss improved from 0.70338 to 0.66760, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 93s 335us/step - loss: 0.5367 - val_loss: 0.6676
# Epoch 6/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.5194
# Epoch 00006: val_loss improved from 0.66760 to 0.60103, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 107s 387us/step - loss: 0.5192 - val_loss: 0.6010
# Epoch 7/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.5014
# Epoch 00007: val_loss did not improve
# 276760/276760 [==============================] - 105s 379us/step - loss: 0.5012 - val_loss: 0.6118
# Epoch 8/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.4814
# Epoch 00008: val_loss improved from 0.60103 to 0.59753, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 109s 394us/step - loss: 0.4811 - val_loss: 0.5975
# Epoch 9/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.4602
# Epoch 00009: val_loss improved from 0.59753 to 0.58553, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 108s 389us/step - loss: 0.4599 - val_loss: 0.5855
# Epoch 10/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.4362
# Epoch 00010: val_loss improved from 0.58553 to 0.53696, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 105s 379us/step - loss: 0.4358 - val_loss: 0.5370
# Epoch 11/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.4126
# Epoch 00011: val_loss improved from 0.53696 to 0.53570, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 108s 389us/step - loss: 0.4124 - val_loss: 0.5357
# Epoch 12/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.3868
# Epoch 00012: val_loss improved from 0.53570 to 0.50175, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 107s 386us/step - loss: 0.3864 - val_loss: 0.5017
# Epoch 13/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.3613
# Epoch 00013: val_loss improved from 0.50175 to 0.47856, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 102s 369us/step - loss: 0.3610 - val_loss: 0.4786
# Epoch 14/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.3351
# Epoch 00014: val_loss improved from 0.47856 to 0.44032, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 106s 383us/step - loss: 0.3350 - val_loss: 0.4403
# Epoch 15/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.3111
# Epoch 00015: val_loss improved from 0.44032 to 0.41248, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 109s 395us/step - loss: 0.3112 - val_loss: 0.4125
# Epoch 16/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.2873
# Epoch 00016: val_loss improved from 0.41248 to 0.39309, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 101s 364us/step - loss: 0.2870 - val_loss: 0.3931
# Epoch 17/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.2622
# Epoch 00017: val_loss improved from 0.39309 to 0.37213, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 105s 381us/step - loss: 0.2619 - val_loss: 0.3721
# Epoch 18/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.2406
# Epoch 00018: val_loss improved from 0.37213 to 0.34442, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 106s 384us/step - loss: 0.2403 - val_loss: 0.3444
# Epoch 19/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.2174
# Epoch 00019: val_loss improved from 0.34442 to 0.32425, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 99s 357us/step - loss: 0.2173 - val_loss: 0.3243
# Epoch 20/100
# 270000/276760 [============================>.] - ETA: 2s - loss: 0.1993
# Epoch 00020: val_loss improved from 0.32425 to 0.30705, saving model to weights/l1_nn.hdf5
# 276760/276760 [==============================] - 104s 374us/step - loss: 0.1991 - val_loss: 0.3071
# Epoch 21/100
# ...
# Epoch 00007: val_loss improved from 0.62267 to 0.57464, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 112s 403us/step - loss: 0.5024 - val_loss: 0.5746
# Epoch 8/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.4828
# Epoch 00008: val_loss did not improve
# 276761/276761 [==============================] - 106s 381us/step - loss: 0.4826 - val_loss: 0.5976
# Epoch 9/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.4619
# Epoch 00009: val_loss improved from 0.57464 to 0.55588, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 102s 367us/step - loss: 0.4615 - val_loss: 0.5559
# Epoch 10/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.4402
# Epoch 00010: val_loss improved from 0.55588 to 0.51284, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 104s 377us/step - loss: 0.4400 - val_loss: 0.5128
# Epoch 11/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.4161
# Epoch 00011: val_loss did not improve
# 276761/276761 [==============================] - 103s 372us/step - loss: 0.4159 - val_loss: 0.5148
# Epoch 12/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.3896
# Epoch 00012: val_loss improved from 0.51284 to 0.48967, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 107s 385us/step - loss: 0.3893 - val_loss: 0.4897
# Epoch 13/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.3646
# Epoch 00013: val_loss improved from 0.48967 to 0.46842, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 105s 379us/step - loss: 0.3645 - val_loss: 0.4684
# Epoch 14/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.3373
# Epoch 00014: val_loss did not improve
# 276761/276761 [==============================] - 103s 371us/step - loss: 0.3370 - val_loss: 0.4770
# Epoch 15/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.3119
# Epoch 00015: val_loss improved from 0.46842 to 0.44437, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 104s 377us/step - loss: 0.3118 - val_loss: 0.4444
# Epoch 16/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.2879
# Epoch 00016: val_loss improved from 0.44437 to 0.42671, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 108s 388us/step - loss: 0.2877 - val_loss: 0.4267
# Epoch 17/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.2651
# Epoch 00017: val_loss improved from 0.42671 to 0.39353, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 104s 374us/step - loss: 0.2647 - val_loss: 0.3935
# Epoch 18/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.2413
# Epoch 00018: val_loss improved from 0.39353 to 0.36189, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 105s 379us/step - loss: 0.2411 - val_loss: 0.3619
# Epoch 19/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.2219
# Epoch 00019: val_loss improved from 0.36189 to 0.33908, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 107s 385us/step - loss: 0.2216 - val_loss: 0.3391
# Epoch 20/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.2006
# Epoch 00020: val_loss improved from 0.33908 to 0.31576, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 104s 374us/step - loss: 0.2008 - val_loss: 0.3158
# Epoch 21/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1835
# Epoch 00021: val_loss improved from 0.31576 to 0.30910, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 100s 363us/step - loss: 0.1832 - val_loss: 0.3091
# Epoch 22/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1644
# Epoch 00022: val_loss improved from 0.30910 to 0.30320, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 105s 380us/step - loss: 0.1643 - val_loss: 0.3032
# Epoch 23/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1497
# Epoch 00023: val_loss improved from 0.30320 to 0.29142, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 106s 383us/step - loss: 0.1495 - val_loss: 0.2914
# Epoch 24/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1357
# Epoch 00024: val_loss improved from 0.29142 to 0.28583, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 101s 365us/step - loss: 0.1356 - val_loss: 0.2858
# Epoch 25/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1209
# Epoch 00025: val_loss improved from 0.28583 to 0.28217, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 109s 393us/step - loss: 0.1207 - val_loss: 0.2822
# Epoch 26/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1096
# Epoch 00026: val_loss improved from 0.28217 to 0.28184, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 99s 357us/step - loss: 0.1097 - val_loss: 0.2818
# Epoch 27/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1015
# Epoch 00027: val_loss improved from 0.28184 to 0.27996, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 101s 365us/step - loss: 0.1014 - val_loss: 0.2800
# Epoch 28/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.0905
# Epoch 00028: val_loss did not improve
# 276761/276761 [==============================] - 102s 369us/step - loss: 0.0904 - val_loss: 0.2807
# Epoch 29/100
# 270000/276761 [============================>.] - ETA: 1s - loss: 0.0825
# Epoch 00029: val_loss did not improve
# 276761/276761 [==============================] - 80s 288us/step - loss: 0.0833 - val_loss: 0.2820
# Epoch 30/100
# 270000/276761 [============================>.] - ETA: 1s - loss: 0.0753
# Epoch 00030: val_loss did not improve
# 276761/276761 [==============================] - 58s 209us/step - loss: 0.0753 - val_loss: 0.2857
# Epoch 31/100
# 270000/276761 [============================>.] - ETA: 1s - loss: 0.0685
# Epoch 00031: val_loss did not improve
# 276761/276761 [==============================] - 60s 215us/step - loss: 0.0688 - val_loss: 0.2868
# Epoch 32/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.0643
# Epoch 00032: val_loss did not improve
# 276761/276761 [==============================] - 92s 333us/step - loss: 0.0643 - val_loss: 0.2929
# ROC_AUC_SCORE: 0.597116509279
# Train on 276761 samples, validate on 30750 samples
# Epoch 1/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.5877
# Epoch 00001: val_loss improved from inf to 0.70612, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 111s 402us/step - loss: 0.5876 - val_loss: 0.7061
# Epoch 2/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.5761
# Epoch 00002: val_loss improved from 0.70612 to 0.66031, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 106s 384us/step - loss: 0.5760 - val_loss: 0.6603
# Epoch 3/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.5650
# Epoch 00003: val_loss did not improve
# 276761/276761 [==============================] - 104s 375us/step - loss: 0.5648 - val_loss: 0.6656
# Epoch 4/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.5519
# Epoch 00004: val_loss did not improve
# 276761/276761 [==============================] - 107s 388us/step - loss: 0.5518 - val_loss: 0.6761
# Epoch 5/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.5366
# Epoch 00005: val_loss improved from 0.66031 to 0.66016, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 106s 384us/step - loss: 0.5364 - val_loss: 0.6602
# Epoch 6/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.5196
# Epoch 00006: val_loss improved from 0.66016 to 0.62569, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 112s 403us/step - loss: 0.5194 - val_loss: 0.6257
# Epoch 7/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.5012
# Epoch 00007: val_loss did not improve
# 276761/276761 [==============================] - 107s 386us/step - loss: 0.5010 - val_loss: 0.6266
# Epoch 8/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.4805
# Epoch 00008: val_loss improved from 0.62569 to 0.59967, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 109s 393us/step - loss: 0.4802 - val_loss: 0.5997
# Epoch 9/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.4599
# Epoch 00009: val_loss improved from 0.59967 to 0.58196, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 111s 400us/step - loss: 0.4597 - val_loss: 0.5820
# Epoch 10/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.4362
# Epoch 00010: val_loss improved from 0.58196 to 0.56196, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 108s 389us/step - loss: 0.4359 - val_loss: 0.5620
# Epoch 11/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.4115
# Epoch 00011: val_loss improved from 0.56196 to 0.54762, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 106s 384us/step - loss: 0.4112 - val_loss: 0.5476
# Epoch 12/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.3853
# Epoch 00012: val_loss improved from 0.54762 to 0.50870, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 105s 378us/step - loss: 0.3850 - val_loss: 0.5087
# Epoch 13/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.3594
# Epoch 00013: val_loss improved from 0.50870 to 0.49950, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 91s 331us/step - loss: 0.3591 - val_loss: 0.4995
# Epoch 14/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.3342
# Epoch 00014: val_loss improved from 0.49950 to 0.46791, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 115s 416us/step - loss: 0.3340 - val_loss: 0.4679
# Epoch 15/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.3089
# Epoch 00015: val_loss improved from 0.46791 to 0.40784, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 101s 364us/step - loss: 0.3086 - val_loss: 0.4078
# Epoch 16/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.2841
# Epoch 00016: val_loss improved from 0.40784 to 0.38630, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 103s 372us/step - loss: 0.2838 - val_loss: 0.3863
# Epoch 17/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.2613
# Epoch 00017: val_loss improved from 0.38630 to 0.35518, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 112s 404us/step - loss: 0.2610 - val_loss: 0.3552
# Epoch 18/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.2392
# Epoch 00018: val_loss improved from 0.35518 to 0.34263, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 113s 407us/step - loss: 0.2390 - val_loss: 0.3426
# Epoch 19/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.2176
# Epoch 00019: val_loss improved from 0.34263 to 0.32708, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 109s 393us/step - loss: 0.2175 - val_loss: 0.3271
# Epoch 20/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1983
# Epoch 00020: val_loss improved from 0.32708 to 0.31292, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 105s 379us/step - loss: 0.1982 - val_loss: 0.3129
# Epoch 21/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1804
# Epoch 00021: val_loss improved from 0.31292 to 0.30206, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 110s 396us/step - loss: 0.1803 - val_loss: 0.3021
# Epoch 22/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1651
# Epoch 00022: val_loss improved from 0.30206 to 0.29588, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 108s 391us/step - loss: 0.1650 - val_loss: 0.2959
# Epoch 23/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1486
# Epoch 00023: val_loss improved from 0.29588 to 0.29128, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 109s 394us/step - loss: 0.1484 - val_loss: 0.2913
# Epoch 24/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1327
# Epoch 00024: val_loss improved from 0.29128 to 0.28570, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 120s 433us/step - loss: 0.1326 - val_loss: 0.2857
# Epoch 25/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1203
# Epoch 00025: val_loss improved from 0.28570 to 0.28236, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 107s 387us/step - loss: 0.1203 - val_loss: 0.2824
# Epoch 26/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1098
# Epoch 00026: val_loss improved from 0.28236 to 0.28150, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 121s 436us/step - loss: 0.1098 - val_loss: 0.2815
# Epoch 27/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.1000
# Epoch 00027: val_loss improved from 0.28150 to 0.28024, saving model to weights/l1_nn.hdf5
# 276761/276761 [==============================] - 97s 350us/step - loss: 0.0999 - val_loss: 0.2802
# Epoch 28/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.0892
# Epoch 00028: val_loss did not improve
# 276761/276761 [==============================] - 107s 388us/step - loss: 0.0891 - val_loss: 0.2806
# Epoch 29/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.0829
# Epoch 00029: val_loss did not improve
# 276761/276761 [==============================] - 114s 411us/step - loss: 0.0827 - val_loss: 0.2839
# Epoch 30/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.0738
# Epoch 00030: val_loss did not improve
# 276761/276761 [==============================] - 107s 388us/step - loss: 0.0737 - val_loss: 0.2868
# Epoch 31/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.0684
# Epoch 00031: val_loss did not improve
# 276761/276761 [==============================] - 108s 391us/step - loss: 0.0684 - val_loss: 0.2908
# Epoch 32/100
# 270000/276761 [============================>.] - ETA: 2s - loss: 0.0627
# Epoch 00032: val_loss did not improve
# 276761/276761 [==============================] - 110s 396us/step - loss: 0.0633 - val_loss: 0.3395
# ROC_AUC_SCORE: 0.580120813539
# /home/sakhtar0092/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/sakhtar0092/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# Overall ROC AUC SCORE:  0.520250874507322

# %%
train_id.to_csv("csv/{}_train.csv".format(model_name), index=False)
test_id.to_csv("csv/{}_test.csv".format(model_name), index=False)
